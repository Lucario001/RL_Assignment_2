# %% [markdown]
# ### Importing Modules

# %%
import numpy as np
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.distributions import Categorical

from collections import namedtuple, deque
import datetime

import gym
from gym.wrappers.record_video import RecordVideo


import matplotlib.pyplot as plt

# %% [markdown]
# ### Defining the two game environments

# %%
#Defining Environments
#Environment 1

env1 = gym.make("Acrobot-v1")
#env1.seed(0)

env1_state_shape = env1.observation_space.shape[0]
env1_no_of_actions = env1.action_space.n

env1_state = env1.reset(seed = 0)


#Environment 2

env2 = gym.make("CartPole-v1")
#env2.seed(0)

env2_state_shape = env2.observation_space.shape[0]
env2_no_of_actions = env2.action_space.n

env2_state = env2.reset(seed = 0)


# Note For both Environments
# For choosing actions :
# action = env.action_space.sample()

# For step :
# next_state, reward, done, info = env.step(action)
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
SavedAction = namedtuple('SavedAction', ['log_prob', 'value'])
Transitions = namedtuple('Transitions', ['state', 'action', 'reward', 'next_state'])

class Policy(nn.Module):
  def __init__(self, state_size, action_size, seed, fc1_units = 128, fc2_units = 64):
    super(Policy, self).__init__()
    self.seed = torch.manual_seed(seed)
    self.fc1 = nn.Linear(state_size, fc1_units)
    self.fc2 = nn.Linear(fc1_units, fc2_units)
    self.PI = nn.Linear(fc2_units, action_size)
  def forward(self, x):
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    PI = F.softmax(self.PI(x), dim = -1)
    return PI

class Value(nn.Module):
  def __init__(self, state_size, seed, fc1_units = 128, fc2_units = 64):
    super(Value, self).__init__()
    self.fc1 = nn.Linear(state_size, fc1_units)
    self.fc2 = nn.Linear(fc1_units, fc2_units)
    self.V = nn.Linear(fc2_units, 1)
  def forward(self, x):
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    V = self.V(x)
    return V

# %%
class MC_Reinforce:
  def __init__(self, env, parameters, seed, id, Policy = Policy, Value = Value, gamma = 0.99, lr = 5e-4):
    self.env = env
    self.fc1, self.fc2 = parameters
    self.gamma = gamma
    self.lr = lr
    self.seed = seed
    self.id = id                             # id = 1 : Type 1, id = 2 : Type 2
    self.state_size = env.observation_space.shape[0]
    self.action_size = env.action_space.n
    self.Policy = Policy(self.state_size, self.action_size, self.seed, self.fc1, self.fc2)
    self.Value = Value(self.state_size, self.seed, self.fc1, self.fc2)
    self.Policy_optimizer = optim.Adam(self.Policy.parameters(), lr = lr)
    self.Value_optimizer = optim.Adam(self.Value.parameters(), lr = lr)
    self.eps = np.finfo(np.float32).eps.item()

  def select_action(self, state):
    state = torch.from_numpy(state).float()
    pi = self.Policy(state)
    m = Categorical(pi)
    action = m.sample()
    return action

  def train(self, n_episodes = 1000):
    ep_returns = deque()
    scores = deque(maxlen = 100)
    for i in range(1, n_episodes + 1):
      state = self.env.reset()
      ep_reward = 0
      rewards = []
      transitions = []
      while True:
        action = self.select_action(state)
        next_state, reward, done, _ = self.env.step(action.item())
        transitions.append([state, action, reward, next_state])
        rewards.append(reward)
        ep_reward += reward
        if done:
          break
        state = next_state
      policy_losses = []
      value_losses = []
      returns = []
      R = 0
      for r in rewards[::-1]:
        R = r + self.gamma * R
        returns.insert(0, R)
      for j in range(len(transitions)):
        transition = transitions[j]
        return_1 = returns[j]
        state, action, reward, next_state = transition
        state = torch.from_numpy(state).float()
        next_state = torch.from_numpy(next_state).float()
        pi = self.Policy(state)
        m = Categorical(pi)
        if self.id == 1:
          policy_losses.append(- m.log_prob(action) * (return_1))
        else:
          policy_losses.append(- m.log_prob(action) * (return_1 - self.Value(state)))
        value_losses.append(F.mse_loss(reward + self.gamma * self.Value(next_state), self.Value(state)))
      p_loss = torch.stack(policy_losses).sum()
      v_loss = torch.stack(value_losses).sum()
      self.Policy_optimizer.zero_grad()
      p_loss.backward()
      self.Policy_optimizer.step()
      if self.id == 2:
        self.Value_optimizer.zero_grad()
        v_loss.backward()
        self.Value_optimizer.step()
      scores.append(ep_reward)
      R = 0
      for r in rewards:
        R = r + R
      print(f"Episode number {i}, and it's corresponding return is {R}, average rewards : {np.mean(scores)}")
      ep_returns.append(R)
    return list(ep_returns)

# %% [markdown]
# ### Tuning

# %%
def tuning(env = env1):
    upper_limit = 0 if env == env1 else 500
    hyper_parameters = [(128, 64), (64, 32), (32, 16), (16, 8)]
    dictionary = {}
    for par in hyper_parameters:
        tuning_MC = MC_Reinforce(env, par, 0, 1)
        returns = tuning_MC.train(1000)
        regret = [upper_limit - r for r in returns]
        dictionary[par] = np.sum(np.array(regret))
    return dictionary, min(dictionary.keys(), key = lambda x : dictionary[x]) # Returns the dictionary and the pair with minimum regret

# %%
dict_1_1, opt_par_1_1 = tuning()
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode number 1, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 2, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 3, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 4, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 5, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 6, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 7, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 8, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 9, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 10, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 11, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 12, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 13, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 14, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 15, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 16, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 17, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 18, and it's corresponding return is -420.0, average rewards : -495.55555555555554
# Episode number 19, and it's corresponding return is -442.0, average rewards : -492.7368421052632
# Episode number 20, and it's corresponding return is -500.0, average rewards : -493.1
# Episode number 21, and it's corresponding return is -500.0, average rewards : -493.42857142857144
# Episode number 22, and it's corresponding return is -500.0, average rewards : -493.72727272727275
# Episode number 23, and it's corresponding return is -500.0, average rewards : -494.0
# Episode number 24, and it's corresponding return is -500.0, average rewards : -494.25
# Episode number 25, and it's corresponding return is -353.0, average rewards : -488.6
# Episode number 26, and it's corresponding return is -461.0, average rewards : -487.53846153846155
# Episode number 27, and it's corresponding return is -500.0, average rewards : -488.0
# Episode number 28, and it's corresponding return is -500.0, average rewards : -488.42857142857144
# Episode number 29, and it's corresponding return is -500.0, average rewards : -488.82758620689657
# Episode number 30, and it's corresponding return is -332.0, average rewards : -483.6
# Episode number 31, and it's corresponding return is -500.0, average rewards : -484.1290322580645
# Episode number 32, and it's corresponding return is -500.0, average rewards : -484.625
# Episode number 33, and it's corresponding return is -435.0, average rewards : -483.1212121212121
# Episode number 34, and it's corresponding return is -500.0, average rewards : -483.61764705882354
# Episode number 35, and it's corresponding return is -500.0, average rewards : -484.0857142857143
# Episode number 36, and it's corresponding return is -500.0, average rewards : -484.52777777777777
# Episode number 37, and it's corresponding return is -500.0, average rewards : -484.94594594594594
# Episode number 38, and it's corresponding return is -500.0, average rewards : -485.3421052631579
# Episode number 39, and it's corresponding return is -498.0, average rewards : -485.6666666666667
# Episode number 40, and it's corresponding return is -500.0, average rewards : -486.025
# Episode number 41, and it's corresponding return is -500.0, average rewards : -486.3658536585366
# Episode number 42, and it's corresponding return is -500.0, average rewards : -486.6904761904762
# Episode number 43, and it's corresponding return is -500.0, average rewards : -487.0
# Episode number 44, and it's corresponding return is -500.0, average rewards : -487.29545454545456
# Episode number 45, and it's corresponding return is -500.0, average rewards : -487.5777777777778
# Episode number 46, and it's corresponding return is -500.0, average rewards : -487.8478260869565
# Episode number 47, and it's corresponding return is -500.0, average rewards : -488.1063829787234
# Episode number 48, and it's corresponding return is -500.0, average rewards : -488.3541666666667
# Episode number 49, and it's corresponding return is -455.0, average rewards : -487.6734693877551
# Episode number 50, and it's corresponding return is -500.0, average rewards : -487.92
# Episode number 51, and it's corresponding return is -500.0, average rewards : -488.15686274509807
# Episode number 52, and it's corresponding return is -500.0, average rewards : -488.38461538461536
# Episode number 53, and it's corresponding return is -500.0, average rewards : -488.60377358490564
# Episode number 54, and it's corresponding return is -500.0, average rewards : -488.81481481481484
# Episode number 55, and it's corresponding return is -500.0, average rewards : -489.0181818181818
# Episode number 56, and it's corresponding return is -373.0, average rewards : -486.94642857142856
# Episode number 57, and it's corresponding return is -500.0, average rewards : -487.17543859649123
# Episode number 58, and it's corresponding return is -500.0, average rewards : -487.3965517241379
# Episode number 59, and it's corresponding return is -500.0, average rewards : -487.6101694915254
# Episode number 60, and it's corresponding return is -500.0, average rewards : -487.81666666666666
# Episode number 61, and it's corresponding return is -388.0, average rewards : -486.1803278688525
# Episode number 62, and it's corresponding return is -423.0, average rewards : -485.16129032258067
# Episode number 63, and it's corresponding return is -273.0, average rewards : -481.7936507936508
# Episode number 64, and it's corresponding return is -408.0, average rewards : -480.640625
# Episode number 65, and it's corresponding return is -373.0, average rewards : -478.9846153846154
# Episode number 66, and it's corresponding return is -500.0, average rewards : -479.3030303030303
# Episode number 67, and it's corresponding return is -481.0, average rewards : -479.32835820895525
# Episode number 68, and it's corresponding return is -381.0, average rewards : -477.88235294117646
# Episode number 69, and it's corresponding return is -438.0, average rewards : -477.30434782608694
# Episode number 70, and it's corresponding return is -284.0, average rewards : -474.54285714285714
# Episode number 71, and it's corresponding return is -478.0, average rewards : -474.59154929577466
# Episode number 72, and it's corresponding return is -313.0, average rewards : -472.34722222222223
# Episode number 73, and it's corresponding return is -424.0, average rewards : -471.6849315068493
# Episode number 74, and it's corresponding return is -500.0, average rewards : -472.06756756756755
# Episode number 75, and it's corresponding return is -380.0, average rewards : -470.84
# Episode number 76, and it's corresponding return is -500.0, average rewards : -471.2236842105263
# Episode number 77, and it's corresponding return is -341.0, average rewards : -469.53246753246754
# Episode number 78, and it's corresponding return is -333.0, average rewards : -467.78205128205127
# Episode number 79, and it's corresponding return is -500.0, average rewards : -468.1898734177215
# Episode number 80, and it's corresponding return is -323.0, average rewards : -466.375
# Episode number 81, and it's corresponding return is -331.0, average rewards : -464.7037037037037
# Episode number 82, and it's corresponding return is -307.0, average rewards : -462.780487804878
# Episode number 83, and it's corresponding return is -398.0, average rewards : -462.0
# Episode number 84, and it's corresponding return is -500.0, average rewards : -462.45238095238096
# Episode number 85, and it's corresponding return is -331.0, average rewards : -460.90588235294115
# Episode number 86, and it's corresponding return is -260.0, average rewards : -458.56976744186045
# Episode number 87, and it's corresponding return is -500.0, average rewards : -459.04597701149424
# Episode number 88, and it's corresponding return is -381.0, average rewards : -458.15909090909093
# Episode number 89, and it's corresponding return is -500.0, average rewards : -458.6292134831461
# Episode number 90, and it's corresponding return is -320.0, average rewards : -457.0888888888889
# Episode number 91, and it's corresponding return is -385.0, average rewards : -456.2967032967033
# Episode number 92, and it's corresponding return is -371.0, average rewards : -455.3695652173913
# Episode number 93, and it's corresponding return is -500.0, average rewards : -455.8494623655914
# Episode number 94, and it's corresponding return is -467.0, average rewards : -455.968085106383
# Episode number 95, and it's corresponding return is -281.0, average rewards : -454.12631578947367
# Episode number 96, and it's corresponding return is -328.0, average rewards : -452.8125
# Episode number 97, and it's corresponding return is -256.0, average rewards : -450.78350515463916
# Episode number 98, and it's corresponding return is -500.0, average rewards : -451.2857142857143
# Episode number 99, and it's corresponding return is -477.0, average rewards : -451.54545454545456
# Episode number 100, and it's corresponding return is -298.0, average rewards : -450.01
# Episode number 101, and it's corresponding return is -296.0, average rewards : -447.97
# Episode number 102, and it's corresponding return is -500.0, average rewards : -447.97
# Episode number 103, and it's corresponding return is -278.0, average rewards : -445.75
# Episode number 104, and it's corresponding return is -500.0, average rewards : -445.75
# Episode number 105, and it's corresponding return is -500.0, average rewards : -445.75
# Episode number 106, and it's corresponding return is -312.0, average rewards : -443.87
# Episode number 107, and it's corresponding return is -307.0, average rewards : -441.94
# Episode number 108, and it's corresponding return is -476.0, average rewards : -441.7
# Episode number 109, and it's corresponding return is -261.0, average rewards : -439.31
# Episode number 110, and it's corresponding return is -500.0, average rewards : -439.31
# Episode number 111, and it's corresponding return is -242.0, average rewards : -436.73
# Episode number 112, and it's corresponding return is -243.0, average rewards : -434.16
# Episode number 113, and it's corresponding return is -262.0, average rewards : -431.78
# Episode number 114, and it's corresponding return is -500.0, average rewards : -431.78
# Episode number 115, and it's corresponding return is -500.0, average rewards : -431.78
# Episode number 116, and it's corresponding return is -393.0, average rewards : -430.71
# Episode number 117, and it's corresponding return is -215.0, average rewards : -427.86
# Episode number 118, and it's corresponding return is -355.0, average rewards : -427.21
# Episode number 119, and it's corresponding return is -322.0, average rewards : -426.01
# Episode number 120, and it's corresponding return is -256.0, average rewards : -423.57
# Episode number 121, and it's corresponding return is -444.0, average rewards : -423.01
# Episode number 122, and it's corresponding return is -303.0, average rewards : -421.04
# Episode number 123, and it's corresponding return is -358.0, average rewards : -419.62
# Episode number 124, and it's corresponding return is -500.0, average rewards : -419.62
# Episode number 125, and it's corresponding return is -242.0, average rewards : -418.51
# Episode number 126, and it's corresponding return is -500.0, average rewards : -418.9
# Episode number 127, and it's corresponding return is -457.0, average rewards : -418.47
# Episode number 128, and it's corresponding return is -282.0, average rewards : -416.29
# Episode number 129, and it's corresponding return is -500.0, average rewards : -416.29
# Episode number 130, and it's corresponding return is -500.0, average rewards : -417.97
# Episode number 131, and it's corresponding return is -447.0, average rewards : -417.44
# Episode number 132, and it's corresponding return is -449.0, average rewards : -416.93
# Episode number 133, and it's corresponding return is -265.0, average rewards : -415.23
# Episode number 134, and it's corresponding return is -324.0, average rewards : -413.47
# Episode number 135, and it's corresponding return is -342.0, average rewards : -411.89
# Episode number 136, and it's corresponding return is -372.0, average rewards : -410.61
# Episode number 137, and it's corresponding return is -338.0, average rewards : -408.99
# Episode number 138, and it's corresponding return is -287.0, average rewards : -406.86
# Episode number 139, and it's corresponding return is -382.0, average rewards : -405.7
# Episode number 140, and it's corresponding return is -259.0, average rewards : -403.29
# Episode number 141, and it's corresponding return is -193.0, average rewards : -400.22
# Episode number 142, and it's corresponding return is -415.0, average rewards : -399.37
# Episode number 143, and it's corresponding return is -333.0, average rewards : -397.7
# Episode number 144, and it's corresponding return is -325.0, average rewards : -395.95
# Episode number 145, and it's corresponding return is -257.0, average rewards : -393.52
# Episode number 146, and it's corresponding return is -471.0, average rewards : -393.23
# Episode number 147, and it's corresponding return is -273.0, average rewards : -390.96
# Episode number 148, and it's corresponding return is -262.0, average rewards : -388.58
# Episode number 149, and it's corresponding return is -274.0, average rewards : -386.77
# Episode number 150, and it's corresponding return is -451.0, average rewards : -386.28
# Episode number 151, and it's corresponding return is -397.0, average rewards : -385.25
# Episode number 152, and it's corresponding return is -207.0, average rewards : -382.32
# Episode number 153, and it's corresponding return is -285.0, average rewards : -380.17
# Episode number 154, and it's corresponding return is -440.0, average rewards : -379.57
# Episode number 155, and it's corresponding return is -378.0, average rewards : -378.35
# Episode number 156, and it's corresponding return is -483.0, average rewards : -379.45
# Episode number 157, and it's corresponding return is -460.0, average rewards : -379.05
# Episode number 158, and it's corresponding return is -421.0, average rewards : -378.26
# Episode number 159, and it's corresponding return is -494.0, average rewards : -378.2
# Episode number 160, and it's corresponding return is -371.0, average rewards : -376.91
# Episode number 161, and it's corresponding return is -271.0, average rewards : -375.74
# Episode number 162, and it's corresponding return is -451.0, average rewards : -376.02
# Episode number 163, and it's corresponding return is -278.0, average rewards : -376.07
# Episode number 164, and it's corresponding return is -269.0, average rewards : -374.68
# Episode number 165, and it's corresponding return is -196.0, average rewards : -372.91
# Episode number 166, and it's corresponding return is -211.0, average rewards : -370.02
# Episode number 167, and it's corresponding return is -245.0, average rewards : -367.66
# Episode number 168, and it's corresponding return is -271.0, average rewards : -366.56
# Episode number 169, and it's corresponding return is -250.0, average rewards : -364.68
# Episode number 170, and it's corresponding return is -183.0, average rewards : -363.67
# Episode number 171, and it's corresponding return is -399.0, average rewards : -362.88
# Episode number 172, and it's corresponding return is -255.0, average rewards : -362.3
# Episode number 173, and it's corresponding return is -359.0, average rewards : -361.65
# Episode number 174, and it's corresponding return is -262.0, average rewards : -359.27
# Episode number 175, and it's corresponding return is -295.0, average rewards : -358.42
# Episode number 176, and it's corresponding return is -246.0, average rewards : -355.88
# Episode number 177, and it's corresponding return is -194.0, average rewards : -354.41
# Episode number 178, and it's corresponding return is -288.0, average rewards : -353.96
# Episode number 179, and it's corresponding return is -170.0, average rewards : -350.66
# Episode number 180, and it's corresponding return is -172.0, average rewards : -349.15
# Episode number 181, and it's corresponding return is -228.0, average rewards : -348.12
# Episode number 182, and it's corresponding return is -401.0, average rewards : -349.06
# Episode number 183, and it's corresponding return is -224.0, average rewards : -347.32
# Episode number 184, and it's corresponding return is -289.0, average rewards : -345.21
# Episode number 185, and it's corresponding return is -226.0, average rewards : -344.16
# Episode number 186, and it's corresponding return is -220.0, average rewards : -343.76
# Episode number 187, and it's corresponding return is -204.0, average rewards : -340.8
# Episode number 188, and it's corresponding return is -268.0, average rewards : -339.67
# Episode number 189, and it's corresponding return is -147.0, average rewards : -336.14
# Episode number 190, and it's corresponding return is -254.0, average rewards : -335.48
# Episode number 191, and it's corresponding return is -223.0, average rewards : -333.86
# Episode number 192, and it's corresponding return is -245.0, average rewards : -332.6
# Episode number 193, and it's corresponding return is -158.0, average rewards : -329.18
# Episode number 194, and it's corresponding return is -270.0, average rewards : -327.21
# Episode number 195, and it's corresponding return is -186.0, average rewards : -326.26
# Episode number 196, and it's corresponding return is -168.0, average rewards : -324.66
# Episode number 197, and it's corresponding return is -153.0, average rewards : -323.63
# Episode number 198, and it's corresponding return is -205.0, average rewards : -320.68
# Episode number 199, and it's corresponding return is -185.0, average rewards : -317.76
# Episode number 200, and it's corresponding return is -331.0, average rewards : -318.09
# Episode number 201, and it's corresponding return is -206.0, average rewards : -317.19
# Episode number 202, and it's corresponding return is -309.0, average rewards : -315.28
# Episode number 203, and it's corresponding return is -197.0, average rewards : -314.47
# Episode number 204, and it's corresponding return is -396.0, average rewards : -313.43
# Episode number 205, and it's corresponding return is -139.0, average rewards : -309.82
# Episode number 206, and it's corresponding return is -193.0, average rewards : -308.63
# Episode number 207, and it's corresponding return is -146.0, average rewards : -307.02
# Episode number 208, and it's corresponding return is -237.0, average rewards : -304.63
# Episode number 209, and it's corresponding return is -205.0, average rewards : -304.07
# Episode number 210, and it's corresponding return is -209.0, average rewards : -301.16
# Episode number 211, and it's corresponding return is -213.0, average rewards : -300.87
# Episode number 212, and it's corresponding return is -307.0, average rewards : -301.51
# Episode number 213, and it's corresponding return is -256.0, average rewards : -301.45
# Episode number 214, and it's corresponding return is -355.0, average rewards : -300.0
# Episode number 215, and it's corresponding return is -314.0, average rewards : -298.14
# Episode number 216, and it's corresponding return is -327.0, average rewards : -297.48
# Episode number 217, and it's corresponding return is -243.0, average rewards : -297.76
# Episode number 218, and it's corresponding return is -174.0, average rewards : -295.95
# Episode number 219, and it's corresponding return is -222.0, average rewards : -294.95
# Episode number 220, and it's corresponding return is -246.0, average rewards : -294.85
# Episode number 221, and it's corresponding return is -205.0, average rewards : -292.46
# Episode number 222, and it's corresponding return is -249.0, average rewards : -291.92
# Episode number 223, and it's corresponding return is -246.0, average rewards : -290.8
# Episode number 224, and it's corresponding return is -360.0, average rewards : -289.4
# Episode number 225, and it's corresponding return is -189.0, average rewards : -288.87
# Episode number 226, and it's corresponding return is -253.0, average rewards : -286.4
# Episode number 227, and it's corresponding return is -225.0, average rewards : -284.08
# Episode number 228, and it's corresponding return is -237.0, average rewards : -283.63
# Episode number 229, and it's corresponding return is -245.0, average rewards : -281.08
# Episode number 230, and it's corresponding return is -199.0, average rewards : -278.07
# Episode number 231, and it's corresponding return is -286.0, average rewards : -276.46
# Episode number 232, and it's corresponding return is -329.0, average rewards : -275.26
# Episode number 233, and it's corresponding return is -192.0, average rewards : -274.53
# Episode number 234, and it's corresponding return is -364.0, average rewards : -274.93
# Episode number 235, and it's corresponding return is -303.0, average rewards : -274.54
# Episode number 236, and it's corresponding return is -174.0, average rewards : -272.56
# Episode number 237, and it's corresponding return is -232.0, average rewards : -271.5
# Episode number 238, and it's corresponding return is -149.0, average rewards : -270.12
# Episode number 239, and it's corresponding return is -171.0, average rewards : -268.01
# Episode number 240, and it's corresponding return is -100.0, average rewards : -266.42
# Episode number 241, and it's corresponding return is -182.0, average rewards : -266.31
# Episode number 242, and it's corresponding return is -229.0, average rewards : -264.45
# Episode number 243, and it's corresponding return is -194.0, average rewards : -263.06
# Episode number 244, and it's corresponding return is -295.0, average rewards : -262.76
# Episode number 245, and it's corresponding return is -257.0, average rewards : -262.76
# Episode number 246, and it's corresponding return is -145.0, average rewards : -259.5
# Episode number 247, and it's corresponding return is -147.0, average rewards : -258.24
# Episode number 248, and it's corresponding return is -189.0, average rewards : -257.51
# Episode number 249, and it's corresponding return is -147.0, average rewards : -256.24
# Episode number 250, and it's corresponding return is -117.0, average rewards : -252.9
# Episode number 251, and it's corresponding return is -148.0, average rewards : -250.41
# Episode number 252, and it's corresponding return is -190.0, average rewards : -250.24
# Episode number 253, and it's corresponding return is -199.0, average rewards : -249.38
# Episode number 254, and it's corresponding return is -166.0, average rewards : -246.64
# Episode number 255, and it's corresponding return is -243.0, average rewards : -245.29
# Episode number 256, and it's corresponding return is -179.0, average rewards : -242.25
# Episode number 257, and it's corresponding return is -187.0, average rewards : -239.52
# Episode number 258, and it's corresponding return is -166.0, average rewards : -236.97
# Episode number 259, and it's corresponding return is -137.0, average rewards : -233.4
# Episode number 260, and it's corresponding return is -116.0, average rewards : -230.85
# Episode number 261, and it's corresponding return is -135.0, average rewards : -229.49
# Episode number 262, and it's corresponding return is -171.0, average rewards : -226.69
# Episode number 263, and it's corresponding return is -171.0, average rewards : -225.62
# Episode number 264, and it's corresponding return is -226.0, average rewards : -225.19
# Episode number 265, and it's corresponding return is -163.0, average rewards : -224.86
# Episode number 266, and it's corresponding return is -123.0, average rewards : -223.98
# Episode number 267, and it's corresponding return is -156.0, average rewards : -223.09
# Episode number 268, and it's corresponding return is -158.0, average rewards : -221.96
# Episode number 269, and it's corresponding return is -146.0, average rewards : -220.92
# Episode number 270, and it's corresponding return is -220.0, average rewards : -221.29
# Episode number 271, and it's corresponding return is -196.0, average rewards : -219.26
# Episode number 272, and it's corresponding return is -191.0, average rewards : -218.62
# Episode number 273, and it's corresponding return is -190.0, average rewards : -216.93
# Episode number 274, and it's corresponding return is -295.0, average rewards : -217.26
# Episode number 275, and it's corresponding return is -159.0, average rewards : -215.9
# Episode number 276, and it's corresponding return is -212.0, average rewards : -215.56
# Episode number 277, and it's corresponding return is -193.0, average rewards : -215.55
# Episode number 278, and it's corresponding return is -167.0, average rewards : -214.34
# Episode number 279, and it's corresponding return is -205.0, average rewards : -214.69
# Episode number 280, and it's corresponding return is -199.0, average rewards : -214.96
# Episode number 281, and it's corresponding return is -225.0, average rewards : -214.93
# Episode number 282, and it's corresponding return is -171.0, average rewards : -212.63
# Episode number 283, and it's corresponding return is -198.0, average rewards : -212.37
# Episode number 284, and it's corresponding return is -153.0, average rewards : -211.01
# Episode number 285, and it's corresponding return is -164.0, average rewards : -210.39
# Episode number 286, and it's corresponding return is -210.0, average rewards : -210.29
# Episode number 287, and it's corresponding return is -187.0, average rewards : -210.12
# Episode number 288, and it's corresponding return is -174.0, average rewards : -209.18
# Episode number 289, and it's corresponding return is -133.0, average rewards : -209.04
# Episode number 290, and it's corresponding return is -174.0, average rewards : -208.24
# Episode number 291, and it's corresponding return is -162.0, average rewards : -207.63
# Episode number 292, and it's corresponding return is -240.0, average rewards : -207.58
# Episode number 293, and it's corresponding return is -155.0, average rewards : -207.55
# Episode number 294, and it's corresponding return is -204.0, average rewards : -206.89
# Episode number 295, and it's corresponding return is -139.0, average rewards : -206.42
# Episode number 296, and it's corresponding return is -110.0, average rewards : -205.84
# Episode number 297, and it's corresponding return is -155.0, average rewards : -205.86
# Episode number 298, and it's corresponding return is -159.0, average rewards : -205.4
# Episode number 299, and it's corresponding return is -173.0, average rewards : -205.28
# Episode number 300, and it's corresponding return is -156.0, average rewards : -203.53
# Episode number 301, and it's corresponding return is -145.0, average rewards : -202.92
# Episode number 302, and it's corresponding return is -141.0, average rewards : -201.24
# Episode number 303, and it's corresponding return is -192.0, average rewards : -201.19
# Episode number 304, and it's corresponding return is -237.0, average rewards : -199.6
# Episode number 305, and it's corresponding return is -191.0, average rewards : -200.12
# Episode number 306, and it's corresponding return is -129.0, average rewards : -199.48
# Episode number 307, and it's corresponding return is -183.0, average rewards : -199.85
# Episode number 308, and it's corresponding return is -176.0, average rewards : -199.24
# Episode number 309, and it's corresponding return is -156.0, average rewards : -198.75
# Episode number 310, and it's corresponding return is -155.0, average rewards : -198.21
# Episode number 311, and it's corresponding return is -117.0, average rewards : -197.25
# Episode number 312, and it's corresponding return is -141.0, average rewards : -195.59
# Episode number 313, and it's corresponding return is -151.0, average rewards : -194.54
# Episode number 314, and it's corresponding return is -143.0, average rewards : -192.42
# Episode number 315, and it's corresponding return is -140.0, average rewards : -190.68
# Episode number 316, and it's corresponding return is -156.0, average rewards : -188.97
# Episode number 317, and it's corresponding return is -159.0, average rewards : -188.13
# Episode number 318, and it's corresponding return is -170.0, average rewards : -188.09
# Episode number 319, and it's corresponding return is -125.0, average rewards : -187.12
# Episode number 320, and it's corresponding return is -144.0, average rewards : -186.1
# Episode number 321, and it's corresponding return is -168.0, average rewards : -185.73
# Episode number 322, and it's corresponding return is -188.0, average rewards : -185.12
# Episode number 323, and it's corresponding return is -152.0, average rewards : -184.18
# Episode number 324, and it's corresponding return is -176.0, average rewards : -182.34
# Episode number 325, and it's corresponding return is -163.0, average rewards : -182.08
# Episode number 326, and it's corresponding return is -181.0, average rewards : -181.36
# Episode number 327, and it's corresponding return is -152.0, average rewards : -180.63
# Episode number 328, and it's corresponding return is -125.0, average rewards : -179.51
# Episode number 329, and it's corresponding return is -158.0, average rewards : -178.64
# Episode number 330, and it's corresponding return is -158.0, average rewards : -178.23
# Episode number 331, and it's corresponding return is -139.0, average rewards : -176.76
# Episode number 332, and it's corresponding return is -211.0, average rewards : -175.58
# Episode number 333, and it's corresponding return is -235.0, average rewards : -176.01
# Episode number 334, and it's corresponding return is -182.0, average rewards : -174.19
# Episode number 335, and it's corresponding return is -304.0, average rewards : -174.2
# Episode number 336, and it's corresponding return is -169.0, average rewards : -174.15
# Episode number 337, and it's corresponding return is -177.0, average rewards : -173.6
# Episode number 338, and it's corresponding return is -173.0, average rewards : -173.84
# Episode number 339, and it's corresponding return is -254.0, average rewards : -174.67
# Episode number 340, and it's corresponding return is -116.0, average rewards : -174.83
# Episode number 341, and it's corresponding return is -135.0, average rewards : -174.36
# Episode number 342, and it's corresponding return is -165.0, average rewards : -173.72
# Episode number 343, and it's corresponding return is -185.0, average rewards : -173.63
# Episode number 344, and it's corresponding return is -134.0, average rewards : -172.02
# Episode number 345, and it's corresponding return is -171.0, average rewards : -171.16
# Episode number 346, and it's corresponding return is -127.0, average rewards : -170.98
# Episode number 347, and it's corresponding return is -176.0, average rewards : -171.27
# Episode number 348, and it's corresponding return is -150.0, average rewards : -170.88
# Episode number 349, and it's corresponding return is -136.0, average rewards : -170.77
# Episode number 350, and it's corresponding return is -157.0, average rewards : -171.17
# Episode number 351, and it's corresponding return is -168.0, average rewards : -171.37
# Episode number 352, and it's corresponding return is -177.0, average rewards : -171.24
# Episode number 353, and it's corresponding return is -141.0, average rewards : -170.66
# Episode number 354, and it's corresponding return is -201.0, average rewards : -171.01
# Episode number 355, and it's corresponding return is -140.0, average rewards : -169.98
# Episode number 356, and it's corresponding return is -198.0, average rewards : -170.17
# Episode number 357, and it's corresponding return is -142.0, average rewards : -169.72
# Episode number 358, and it's corresponding return is -136.0, average rewards : -169.42
# Episode number 359, and it's corresponding return is -152.0, average rewards : -169.57
# Episode number 360, and it's corresponding return is -159.0, average rewards : -170.0
# Episode number 361, and it's corresponding return is -129.0, average rewards : -169.94
# Episode number 362, and it's corresponding return is -141.0, average rewards : -169.64
# Episode number 363, and it's corresponding return is -143.0, average rewards : -169.36
# Episode number 364, and it's corresponding return is -155.0, average rewards : -168.65
# Episode number 365, and it's corresponding return is -131.0, average rewards : -168.33
# Episode number 366, and it's corresponding return is -149.0, average rewards : -168.59
# Episode number 367, and it's corresponding return is -191.0, average rewards : -168.94
# Episode number 368, and it's corresponding return is -135.0, average rewards : -168.71
# Episode number 369, and it's corresponding return is -110.0, average rewards : -168.35
# Episode number 370, and it's corresponding return is -128.0, average rewards : -167.43
# Episode number 371, and it's corresponding return is -148.0, average rewards : -166.95
# Episode number 372, and it's corresponding return is -157.0, average rewards : -166.61
# Episode number 373, and it's corresponding return is -125.0, average rewards : -165.96
# Episode number 374, and it's corresponding return is -140.0, average rewards : -164.41
# Episode number 375, and it's corresponding return is -157.0, average rewards : -164.39
# Episode number 376, and it's corresponding return is -111.0, average rewards : -163.38
# Episode number 377, and it's corresponding return is -137.0, average rewards : -162.82
# Episode number 378, and it's corresponding return is -141.0, average rewards : -162.56
# Episode number 379, and it's corresponding return is -176.0, average rewards : -162.27
# Episode number 380, and it's corresponding return is -158.0, average rewards : -161.86
# Episode number 381, and it's corresponding return is -199.0, average rewards : -161.6
# Episode number 382, and it's corresponding return is -93.0, average rewards : -160.82
# Episode number 383, and it's corresponding return is -123.0, average rewards : -160.07
# Episode number 384, and it's corresponding return is -334.0, average rewards : -161.88
# Episode number 385, and it's corresponding return is -176.0, average rewards : -162.0
# Episode number 386, and it's corresponding return is -177.0, average rewards : -161.67
# Episode number 387, and it's corresponding return is -91.0, average rewards : -160.71
# Episode number 388, and it's corresponding return is -94.0, average rewards : -159.91
# Episode number 389, and it's corresponding return is -126.0, average rewards : -159.84
# Episode number 390, and it's corresponding return is -102.0, average rewards : -159.12
# Episode number 391, and it's corresponding return is -123.0, average rewards : -158.73
# Episode number 392, and it's corresponding return is -140.0, average rewards : -157.73
# Episode number 393, and it's corresponding return is -117.0, average rewards : -157.35
# Episode number 394, and it's corresponding return is -151.0, average rewards : -156.82
# Episode number 395, and it's corresponding return is -167.0, average rewards : -157.1
# Episode number 396, and it's corresponding return is -123.0, average rewards : -157.23
# Episode number 397, and it's corresponding return is -135.0, average rewards : -157.03
# Episode number 398, and it's corresponding return is -142.0, average rewards : -156.86
# Episode number 399, and it's corresponding return is -123.0, average rewards : -156.36
# Episode number 400, and it's corresponding return is -117.0, average rewards : -155.97
# Episode number 401, and it's corresponding return is -171.0, average rewards : -156.23
# Episode number 402, and it's corresponding return is -114.0, average rewards : -155.96
# Episode number 403, and it's corresponding return is -145.0, average rewards : -155.49
# Episode number 404, and it's corresponding return is -130.0, average rewards : -154.42
# Episode number 405, and it's corresponding return is -117.0, average rewards : -153.68
# Episode number 406, and it's corresponding return is -111.0, average rewards : -153.5
# Episode number 407, and it's corresponding return is -93.0, average rewards : -152.6
# Episode number 408, and it's corresponding return is -143.0, average rewards : -152.27
# Episode number 409, and it's corresponding return is -107.0, average rewards : -151.78
# Episode number 410, and it's corresponding return is -142.0, average rewards : -151.65
# Episode number 411, and it's corresponding return is -128.0, average rewards : -151.76
# Episode number 412, and it's corresponding return is -138.0, average rewards : -151.73
# Episode number 413, and it's corresponding return is -132.0, average rewards : -151.54
# Episode number 414, and it's corresponding return is -161.0, average rewards : -151.72
# Episode number 415, and it's corresponding return is -162.0, average rewards : -151.94
# Episode number 416, and it's corresponding return is -118.0, average rewards : -151.56
# Episode number 417, and it's corresponding return is -145.0, average rewards : -151.42
# Episode number 418, and it's corresponding return is -141.0, average rewards : -151.13
# Episode number 419, and it's corresponding return is -128.0, average rewards : -151.16
# Episode number 420, and it's corresponding return is -154.0, average rewards : -151.26
# Episode number 421, and it's corresponding return is -131.0, average rewards : -150.89
# Episode number 422, and it's corresponding return is -127.0, average rewards : -150.28
# Episode number 423, and it's corresponding return is -110.0, average rewards : -149.86
# Episode number 424, and it's corresponding return is -133.0, average rewards : -149.43
# Episode number 425, and it's corresponding return is -140.0, average rewards : -149.2
# Episode number 426, and it's corresponding return is -94.0, average rewards : -148.33
# Episode number 427, and it's corresponding return is -100.0, average rewards : -147.81
# Episode number 428, and it's corresponding return is -158.0, average rewards : -148.14
# Episode number 429, and it's corresponding return is -137.0, average rewards : -147.93
# Episode number 430, and it's corresponding return is -277.0, average rewards : -149.12
# Episode number 431, and it's corresponding return is -120.0, average rewards : -148.93
# Episode number 432, and it's corresponding return is -145.0, average rewards : -148.27
# Episode number 433, and it's corresponding return is -123.0, average rewards : -147.15
# Episode number 434, and it's corresponding return is -101.0, average rewards : -146.34
# Episode number 435, and it's corresponding return is -185.0, average rewards : -145.15
# Episode number 436, and it's corresponding return is -114.0, average rewards : -144.6
# Episode number 437, and it's corresponding return is -151.0, average rewards : -144.34
# Episode number 438, and it's corresponding return is -152.0, average rewards : -144.13
# Episode number 439, and it's corresponding return is -196.0, average rewards : -143.55
# Episode number 440, and it's corresponding return is -142.0, average rewards : -143.81
# Episode number 441, and it's corresponding return is -120.0, average rewards : -143.66
# Episode number 442, and it's corresponding return is -120.0, average rewards : -143.21
# Episode number 443, and it's corresponding return is -125.0, average rewards : -142.61
# Episode number 444, and it's corresponding return is -164.0, average rewards : -142.91
# Episode number 445, and it's corresponding return is -110.0, average rewards : -142.3
# Episode number 446, and it's corresponding return is -116.0, average rewards : -142.19
# Episode number 447, and it's corresponding return is -142.0, average rewards : -141.85
# Episode number 448, and it's corresponding return is -130.0, average rewards : -141.65
# Episode number 449, and it's corresponding return is -125.0, average rewards : -141.54
# Episode number 450, and it's corresponding return is -110.0, average rewards : -141.07
# Episode number 451, and it's corresponding return is -103.0, average rewards : -140.42
# Episode number 452, and it's corresponding return is -134.0, average rewards : -139.99
# Episode number 453, and it's corresponding return is -135.0, average rewards : -139.93
# Episode number 454, and it's corresponding return is -141.0, average rewards : -139.33
# Episode number 455, and it's corresponding return is -149.0, average rewards : -139.42
# Episode number 456, and it's corresponding return is -177.0, average rewards : -139.21
# Episode number 457, and it's corresponding return is -116.0, average rewards : -138.95
# Episode number 458, and it's corresponding return is -332.0, average rewards : -140.91
# Episode number 459, and it's corresponding return is -109.0, average rewards : -140.48
# Episode number 460, and it's corresponding return is -256.0, average rewards : -141.45
# Episode number 461, and it's corresponding return is -140.0, average rewards : -141.56
# Episode number 462, and it's corresponding return is -104.0, average rewards : -141.19
# Episode number 463, and it's corresponding return is -120.0, average rewards : -140.96
# Episode number 464, and it's corresponding return is -126.0, average rewards : -140.67
# Episode number 465, and it's corresponding return is -151.0, average rewards : -140.87
# Episode number 466, and it's corresponding return is -193.0, average rewards : -141.31
# Episode number 467, and it's corresponding return is -118.0, average rewards : -140.58
# Episode number 468, and it's corresponding return is -174.0, average rewards : -140.97
# Episode number 469, and it's corresponding return is -141.0, average rewards : -141.28
# Episode number 470, and it's corresponding return is -123.0, average rewards : -141.23
# Episode number 471, and it's corresponding return is -150.0, average rewards : -141.25
# Episode number 472, and it's corresponding return is -112.0, average rewards : -140.8
# Episode number 473, and it's corresponding return is -99.0, average rewards : -140.54
# Episode number 474, and it's corresponding return is -113.0, average rewards : -140.27
# Episode number 475, and it's corresponding return is -121.0, average rewards : -139.91
# Episode number 476, and it's corresponding return is -104.0, average rewards : -139.84
# Episode number 477, and it's corresponding return is -84.0, average rewards : -139.31
# Episode number 478, and it's corresponding return is -137.0, average rewards : -139.27
# Episode number 479, and it's corresponding return is -147.0, average rewards : -138.98
# Episode number 480, and it's corresponding return is -99.0, average rewards : -138.39
# Episode number 481, and it's corresponding return is -140.0, average rewards : -137.8
# Episode number 482, and it's corresponding return is -114.0, average rewards : -138.01
# Episode number 483, and it's corresponding return is -101.0, average rewards : -137.79
# Episode number 484, and it's corresponding return is -102.0, average rewards : -135.47
# Episode number 485, and it's corresponding return is -108.0, average rewards : -134.79
# Episode number 486, and it's corresponding return is -115.0, average rewards : -134.17
# Episode number 487, and it's corresponding return is -110.0, average rewards : -134.36
# Episode number 488, and it's corresponding return is -167.0, average rewards : -135.09
# Episode number 489, and it's corresponding return is -129.0, average rewards : -135.12
# Episode number 490, and it's corresponding return is -94.0, average rewards : -135.04
# Episode number 491, and it's corresponding return is -198.0, average rewards : -135.79
# Episode number 492, and it's corresponding return is -130.0, average rewards : -135.69
# Episode number 493, and it's corresponding return is -94.0, average rewards : -135.46
# Episode number 494, and it's corresponding return is -139.0, average rewards : -135.34
# Episode number 495, and it's corresponding return is -118.0, average rewards : -134.85
# Episode number 496, and it's corresponding return is -134.0, average rewards : -134.96
# Episode number 497, and it's corresponding return is -87.0, average rewards : -134.48
# Episode number 498, and it's corresponding return is -99.0, average rewards : -134.05
# Episode number 499, and it's corresponding return is -107.0, average rewards : -133.89
# Episode number 500, and it's corresponding return is -143.0, average rewards : -134.15
# Episode number 501, and it's corresponding return is -110.0, average rewards : -133.54
# Episode number 502, and it's corresponding return is -140.0, average rewards : -133.8
# Episode number 503, and it's corresponding return is -141.0, average rewards : -133.76
# Episode number 504, and it's corresponding return is -136.0, average rewards : -133.82
# Episode number 505, and it's corresponding return is -131.0, average rewards : -133.96
# Episode number 506, and it's corresponding return is -109.0, average rewards : -133.94
# Episode number 507, and it's corresponding return is -113.0, average rewards : -134.14
# Episode number 508, and it's corresponding return is -104.0, average rewards : -133.75
# Episode number 509, and it's corresponding return is -99.0, average rewards : -133.67
# Episode number 510, and it's corresponding return is -103.0, average rewards : -133.28
# Episode number 511, and it's corresponding return is -124.0, average rewards : -133.24
# Episode number 512, and it's corresponding return is -87.0, average rewards : -132.73
# Episode number 513, and it's corresponding return is -113.0, average rewards : -132.54
# Episode number 514, and it's corresponding return is -120.0, average rewards : -132.13
# Episode number 515, and it's corresponding return is -139.0, average rewards : -131.9
# Episode number 516, and it's corresponding return is -101.0, average rewards : -131.73
# Episode number 517, and it's corresponding return is -127.0, average rewards : -131.55
# Episode number 518, and it's corresponding return is -102.0, average rewards : -131.16
# Episode number 519, and it's corresponding return is -102.0, average rewards : -130.9
# Episode number 520, and it's corresponding return is -175.0, average rewards : -131.11
# Episode number 521, and it's corresponding return is -99.0, average rewards : -130.79
# Episode number 522, and it's corresponding return is -100.0, average rewards : -130.52
# Episode number 523, and it's corresponding return is -112.0, average rewards : -130.54
# Episode number 524, and it's corresponding return is -93.0, average rewards : -130.14
# Episode number 525, and it's corresponding return is -94.0, average rewards : -129.68
# Episode number 526, and it's corresponding return is -120.0, average rewards : -129.94
# Episode number 527, and it's corresponding return is -116.0, average rewards : -130.1
# Episode number 528, and it's corresponding return is -89.0, average rewards : -129.41
# Episode number 529, and it's corresponding return is -153.0, average rewards : -129.57
# Episode number 530, and it's corresponding return is -106.0, average rewards : -127.86
# Episode number 531, and it's corresponding return is -102.0, average rewards : -127.68
# Episode number 532, and it's corresponding return is -101.0, average rewards : -127.24
# Episode number 533, and it's corresponding return is -122.0, average rewards : -127.23
# Episode number 534, and it's corresponding return is -116.0, average rewards : -127.38
# Episode number 535, and it's corresponding return is -87.0, average rewards : -126.4
# Episode number 536, and it's corresponding return is -135.0, average rewards : -126.61
# Episode number 537, and it's corresponding return is -106.0, average rewards : -126.16
# Episode number 538, and it's corresponding return is -144.0, average rewards : -126.08
# Episode number 539, and it's corresponding return is -117.0, average rewards : -125.29
# Episode number 540, and it's corresponding return is -101.0, average rewards : -124.88
# Episode number 541, and it's corresponding return is -116.0, average rewards : -124.84
# Episode number 542, and it's corresponding return is -114.0, average rewards : -124.78
# ...
# Episode number 818, and it's corresponding return is -500.0, average rewards : -499.91
# Episode number 819, and it's corresponding return is -500.0, average rewards : -499.91
# Episode number 820, and it's corresponding return is -500.0, average rewards : -499.91
# Episode number 821, and it's corresponding return is -500.0, average rewards : -499.91
# Episode number 822, and it's corresponding return is -500.0, average rewards : -499.91
# Episode number 823, and it's corresponding return is -500.0, average rewards : -499.91
# Episode number 824, and it's corresponding return is -500.0, average rewards : -499.91
# Episode number 825, and it's corresponding return is -500.0, average rewards : -499.91
# Episode number 826, and it's corresponding return is -500.0, average rewards : -499.91
# Episode number 827, and it's corresponding return is -500.0, average rewards : -499.91
# Episode number 828, and it's corresponding return is -500.0, average rewards : -499.91
# Episode number 829, and it's corresponding return is -500.0, average rewards : -499.91
# Episode number 830, and it's corresponding return is -500.0, average rewards : -499.91
# Episode number 831, and it's corresponding return is -500.0, average rewards : -499.91
# Episode number 832, and it's corresponding return is -500.0, average rewards : -499.91
# Episode number 833, and it's corresponding return is -472.0, average rewards : -499.63
# Episode number 834, and it's corresponding return is -500.0, average rewards : -499.63
# Episode number 835, and it's corresponding return is -500.0, average rewards : -499.63
# Episode number 836, and it's corresponding return is -500.0, average rewards : -499.63
# Episode number 837, and it's corresponding return is -500.0, average rewards : -499.63
# Episode number 838, and it's corresponding return is -500.0, average rewards : -499.63
# Episode number 839, and it's corresponding return is -500.0, average rewards : -499.63
# Episode number 840, and it's corresponding return is -500.0, average rewards : -499.63
# Episode number 841, and it's corresponding return is -500.0, average rewards : -499.63
# Episode number 842, and it's corresponding return is -500.0, average rewards : -499.63
# Episode number 843, and it's corresponding return is -500.0, average rewards : -499.63
# Episode number 844, and it's corresponding return is -500.0, average rewards : -499.63
# Episode number 845, and it's corresponding return is -500.0, average rewards : -499.63
# Episode number 846, and it's corresponding return is -500.0, average rewards : -499.63
# Episode number 847, and it's corresponding return is -500.0, average rewards : -499.63
# Episode number 848, and it's corresponding return is -500.0, average rewards : -499.63
# Episode number 849, and it's corresponding return is -500.0, average rewards : -499.63
# Episode number 850, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 851, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 852, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 853, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 854, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 855, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 856, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 857, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 858, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 859, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 860, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 861, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 862, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 863, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 864, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 865, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 866, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 867, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 868, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 869, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 870, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 871, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 872, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 873, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 874, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 875, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 876, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 877, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 878, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 879, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 880, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 881, and it's corresponding return is -500.0, average rewards : -499.71
# Episode number 882, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 883, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 884, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 885, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 886, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 887, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 888, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 889, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 890, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 891, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 892, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 893, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 894, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 895, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 896, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 897, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 898, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 899, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 900, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 901, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 902, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 903, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 904, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 905, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 906, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 907, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 908, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 909, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 910, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 911, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 912, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 913, and it's corresponding return is -500.0, average rewards : -499.72
# Episode number 914, and it's corresponding return is -421.0, average rewards : -498.93
# Episode number 915, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 916, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 917, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 918, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 919, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 920, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 921, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 922, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 923, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 924, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 925, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 926, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 927, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 928, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 929, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 930, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 931, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 932, and it's corresponding return is -500.0, average rewards : -498.93
# Episode number 933, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 934, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 935, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 936, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 937, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 938, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 939, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 940, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 941, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 942, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 943, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 944, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 945, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 946, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 947, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 948, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 949, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 950, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 951, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 952, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 953, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 954, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 955, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 956, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 957, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 958, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 959, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 960, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 961, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 962, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 963, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 964, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 965, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 966, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 967, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 968, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 969, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 970, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 971, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 972, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 973, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 974, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 975, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 976, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 977, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 978, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 979, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 980, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 981, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 982, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 983, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 984, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 985, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 986, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 987, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 988, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 989, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 990, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 991, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 992, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 993, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 994, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 995, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 996, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 997, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 998, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 999, and it's corresponding return is -500.0, average rewards : -499.21
# Episode number 1000, and it's corresponding return is -500.0, average rewards : -499.21

# %%
dict_2_1, opt_par_2_1 = tuning(env = env2)
# Out:
# Episode number 1, and it's corresponding return is 18.0, average rewards : 18.0
# Episode number 2, and it's corresponding return is 23.0, average rewards : 20.5
# Episode number 3, and it's corresponding return is 21.0, average rewards : 20.666666666666668
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Episode number 4, and it's corresponding return is 15.0, average rewards : 19.25
# Episode number 5, and it's corresponding return is 16.0, average rewards : 18.6
# Episode number 6, and it's corresponding return is 15.0, average rewards : 18.0
# Episode number 7, and it's corresponding return is 20.0, average rewards : 18.285714285714285
# Episode number 8, and it's corresponding return is 83.0, average rewards : 26.375
# Episode number 9, and it's corresponding return is 22.0, average rewards : 25.88888888888889
# Episode number 10, and it's corresponding return is 13.0, average rewards : 24.6
# Episode number 11, and it's corresponding return is 18.0, average rewards : 24.0
# Episode number 12, and it's corresponding return is 17.0, average rewards : 23.416666666666668
# Episode number 13, and it's corresponding return is 14.0, average rewards : 22.692307692307693
# Episode number 14, and it's corresponding return is 25.0, average rewards : 22.857142857142858
# Episode number 15, and it's corresponding return is 13.0, average rewards : 22.2
# Episode number 16, and it's corresponding return is 21.0, average rewards : 22.125
# Episode number 17, and it's corresponding return is 13.0, average rewards : 21.58823529411765
# Episode number 18, and it's corresponding return is 11.0, average rewards : 21.0
# Episode number 19, and it's corresponding return is 20.0, average rewards : 20.94736842105263
# Episode number 20, and it's corresponding return is 16.0, average rewards : 20.7
# Episode number 21, and it's corresponding return is 19.0, average rewards : 20.61904761904762
# Episode number 22, and it's corresponding return is 20.0, average rewards : 20.59090909090909
# Episode number 23, and it's corresponding return is 21.0, average rewards : 20.608695652173914
# Episode number 24, and it's corresponding return is 14.0, average rewards : 20.333333333333332
# Episode number 25, and it's corresponding return is 26.0, average rewards : 20.56
# Episode number 26, and it's corresponding return is 16.0, average rewards : 20.384615384615383
# Episode number 27, and it's corresponding return is 27.0, average rewards : 20.62962962962963
# Episode number 28, and it's corresponding return is 22.0, average rewards : 20.678571428571427
# Episode number 29, and it's corresponding return is 15.0, average rewards : 20.482758620689655
# Episode number 30, and it's corresponding return is 31.0, average rewards : 20.833333333333332
# Episode number 31, and it's corresponding return is 57.0, average rewards : 22.0
# Episode number 32, and it's corresponding return is 35.0, average rewards : 22.40625
# Episode number 33, and it's corresponding return is 60.0, average rewards : 23.545454545454547
# Episode number 34, and it's corresponding return is 16.0, average rewards : 23.323529411764707
# Episode number 35, and it's corresponding return is 16.0, average rewards : 23.114285714285714
# Episode number 36, and it's corresponding return is 23.0, average rewards : 23.11111111111111
# Episode number 37, and it's corresponding return is 49.0, average rewards : 23.81081081081081
# Episode number 38, and it's corresponding return is 24.0, average rewards : 23.81578947368421
# Episode number 39, and it's corresponding return is 17.0, average rewards : 23.641025641025642
# Episode number 40, and it's corresponding return is 17.0, average rewards : 23.475
# Episode number 41, and it's corresponding return is 20.0, average rewards : 23.390243902439025
# Episode number 42, and it's corresponding return is 17.0, average rewards : 23.238095238095237
# Episode number 43, and it's corresponding return is 50.0, average rewards : 23.86046511627907
# Episode number 44, and it's corresponding return is 19.0, average rewards : 23.75
# Episode number 45, and it's corresponding return is 21.0, average rewards : 23.68888888888889
# Episode number 46, and it's corresponding return is 93.0, average rewards : 25.195652173913043
# Episode number 47, and it's corresponding return is 27.0, average rewards : 25.23404255319149
# Episode number 48, and it's corresponding return is 18.0, average rewards : 25.083333333333332
# Episode number 49, and it's corresponding return is 24.0, average rewards : 25.06122448979592
# Episode number 50, and it's corresponding return is 35.0, average rewards : 25.26
# Episode number 51, and it's corresponding return is 43.0, average rewards : 25.607843137254903
# Episode number 52, and it's corresponding return is 20.0, average rewards : 25.5
# Episode number 53, and it's corresponding return is 16.0, average rewards : 25.32075471698113
# Episode number 54, and it's corresponding return is 31.0, average rewards : 25.425925925925927
# Episode number 55, and it's corresponding return is 37.0, average rewards : 25.636363636363637
# Episode number 56, and it's corresponding return is 20.0, average rewards : 25.535714285714285
# Episode number 57, and it's corresponding return is 22.0, average rewards : 25.473684210526315
# Episode number 58, and it's corresponding return is 25.0, average rewards : 25.46551724137931
# Episode number 59, and it's corresponding return is 22.0, average rewards : 25.406779661016948
# Episode number 60, and it's corresponding return is 18.0, average rewards : 25.283333333333335
# Episode number 61, and it's corresponding return is 13.0, average rewards : 25.081967213114755
# Episode number 62, and it's corresponding return is 23.0, average rewards : 25.048387096774192
# Episode number 63, and it's corresponding return is 19.0, average rewards : 24.952380952380953
# Episode number 64, and it's corresponding return is 23.0, average rewards : 24.921875
# Episode number 65, and it's corresponding return is 21.0, average rewards : 24.861538461538462
# Episode number 66, and it's corresponding return is 38.0, average rewards : 25.060606060606062
# Episode number 67, and it's corresponding return is 16.0, average rewards : 24.925373134328357
# Episode number 68, and it's corresponding return is 55.0, average rewards : 25.36764705882353
# Episode number 69, and it's corresponding return is 56.0, average rewards : 25.81159420289855
# Episode number 70, and it's corresponding return is 35.0, average rewards : 25.942857142857143
# Episode number 71, and it's corresponding return is 43.0, average rewards : 26.183098591549296
# Episode number 72, and it's corresponding return is 16.0, average rewards : 26.041666666666668
# Episode number 73, and it's corresponding return is 35.0, average rewards : 26.164383561643834
# Episode number 74, and it's corresponding return is 28.0, average rewards : 26.18918918918919
# Episode number 75, and it's corresponding return is 20.0, average rewards : 26.106666666666666
# Episode number 76, and it's corresponding return is 27.0, average rewards : 26.11842105263158
# Episode number 77, and it's corresponding return is 69.0, average rewards : 26.675324675324674
# Episode number 78, and it's corresponding return is 13.0, average rewards : 26.5
# Episode number 79, and it's corresponding return is 17.0, average rewards : 26.379746835443036
# Episode number 80, and it's corresponding return is 16.0, average rewards : 26.25
# Episode number 81, and it's corresponding return is 23.0, average rewards : 26.209876543209877
# Episode number 82, and it's corresponding return is 38.0, average rewards : 26.353658536585368
# Episode number 83, and it's corresponding return is 18.0, average rewards : 26.253012048192772
# Episode number 84, and it's corresponding return is 26.0, average rewards : 26.25
# Episode number 85, and it's corresponding return is 20.0, average rewards : 26.176470588235293
# Episode number 86, and it's corresponding return is 97.0, average rewards : 27.0
# Episode number 87, and it's corresponding return is 29.0, average rewards : 27.022988505747126
# Episode number 88, and it's corresponding return is 40.0, average rewards : 27.170454545454547
# Episode number 89, and it's corresponding return is 27.0, average rewards : 27.168539325842698
# Episode number 90, and it's corresponding return is 48.0, average rewards : 27.4
# Episode number 91, and it's corresponding return is 57.0, average rewards : 27.725274725274726
# Episode number 92, and it's corresponding return is 14.0, average rewards : 27.57608695652174
# Episode number 93, and it's corresponding return is 20.0, average rewards : 27.49462365591398
# Episode number 94, and it's corresponding return is 58.0, average rewards : 27.819148936170212
# Episode number 95, and it's corresponding return is 17.0, average rewards : 27.705263157894738
# Episode number 96, and it's corresponding return is 23.0, average rewards : 27.65625
# Episode number 97, and it's corresponding return is 44.0, average rewards : 27.824742268041238
# Episode number 98, and it's corresponding return is 125.0, average rewards : 28.816326530612244
# Episode number 99, and it's corresponding return is 38.0, average rewards : 28.90909090909091
# Episode number 100, and it's corresponding return is 70.0, average rewards : 29.32
# Episode number 101, and it's corresponding return is 26.0, average rewards : 29.4
# Episode number 102, and it's corresponding return is 119.0, average rewards : 30.36
# Episode number 103, and it's corresponding return is 51.0, average rewards : 30.66
# Episode number 104, and it's corresponding return is 83.0, average rewards : 31.34
# Episode number 105, and it's corresponding return is 43.0, average rewards : 31.61
# Episode number 106, and it's corresponding return is 31.0, average rewards : 31.77
# Episode number 107, and it's corresponding return is 24.0, average rewards : 31.81
# Episode number 108, and it's corresponding return is 40.0, average rewards : 31.38
# Episode number 109, and it's corresponding return is 30.0, average rewards : 31.46
# Episode number 110, and it's corresponding return is 34.0, average rewards : 31.67
# Episode number 111, and it's corresponding return is 51.0, average rewards : 32.0
# Episode number 112, and it's corresponding return is 26.0, average rewards : 32.09
# Episode number 113, and it's corresponding return is 15.0, average rewards : 32.1
# Episode number 114, and it's corresponding return is 31.0, average rewards : 32.16
# Episode number 115, and it's corresponding return is 33.0, average rewards : 32.36
# Episode number 116, and it's corresponding return is 65.0, average rewards : 32.8
# Episode number 117, and it's corresponding return is 169.0, average rewards : 34.36
# Episode number 118, and it's corresponding return is 87.0, average rewards : 35.12
# Episode number 119, and it's corresponding return is 32.0, average rewards : 35.24
# Episode number 120, and it's corresponding return is 21.0, average rewards : 35.29
# Episode number 121, and it's corresponding return is 182.0, average rewards : 36.92
# Episode number 122, and it's corresponding return is 43.0, average rewards : 37.15
# Episode number 123, and it's corresponding return is 33.0, average rewards : 37.27
# Episode number 124, and it's corresponding return is 70.0, average rewards : 37.83
# Episode number 125, and it's corresponding return is 24.0, average rewards : 37.81
# Episode number 126, and it's corresponding return is 42.0, average rewards : 38.07
# Episode number 127, and it's corresponding return is 30.0, average rewards : 38.1
# Episode number 128, and it's corresponding return is 166.0, average rewards : 39.54
# Episode number 129, and it's corresponding return is 43.0, average rewards : 39.82
# Episode number 130, and it's corresponding return is 12.0, average rewards : 39.63
# Episode number 131, and it's corresponding return is 87.0, average rewards : 39.93
# Episode number 132, and it's corresponding return is 68.0, average rewards : 40.26
# Episode number 133, and it's corresponding return is 52.0, average rewards : 40.18
# Episode number 134, and it's corresponding return is 49.0, average rewards : 40.51
# Episode number 135, and it's corresponding return is 99.0, average rewards : 41.34
# Episode number 136, and it's corresponding return is 65.0, average rewards : 41.76
# Episode number 137, and it's corresponding return is 78.0, average rewards : 42.05
# Episode number 138, and it's corresponding return is 105.0, average rewards : 42.86
# Episode number 139, and it's corresponding return is 123.0, average rewards : 43.92
# Episode number 140, and it's corresponding return is 84.0, average rewards : 44.59
# Episode number 141, and it's corresponding return is 137.0, average rewards : 45.76
# Episode number 142, and it's corresponding return is 68.0, average rewards : 46.27
# Episode number 143, and it's corresponding return is 72.0, average rewards : 46.49
# Episode number 144, and it's corresponding return is 30.0, average rewards : 46.6
# Episode number 145, and it's corresponding return is 57.0, average rewards : 46.96
# Episode number 146, and it's corresponding return is 161.0, average rewards : 47.64
# Episode number 147, and it's corresponding return is 119.0, average rewards : 48.56
# Episode number 148, and it's corresponding return is 37.0, average rewards : 48.75
# Episode number 149, and it's corresponding return is 35.0, average rewards : 48.86
# Episode number 150, and it's corresponding return is 119.0, average rewards : 49.7
# Episode number 151, and it's corresponding return is 53.0, average rewards : 49.8
# Episode number 152, and it's corresponding return is 63.0, average rewards : 50.23
# Episode number 153, and it's corresponding return is 140.0, average rewards : 51.47
# Episode number 154, and it's corresponding return is 110.0, average rewards : 52.26
# Episode number 155, and it's corresponding return is 117.0, average rewards : 53.06
# Episode number 156, and it's corresponding return is 74.0, average rewards : 53.6
# Episode number 157, and it's corresponding return is 73.0, average rewards : 54.11
# Episode number 158, and it's corresponding return is 315.0, average rewards : 57.01
# Episode number 159, and it's corresponding return is 120.0, average rewards : 57.99
# Episode number 160, and it's corresponding return is 19.0, average rewards : 58.0
# Episode number 161, and it's corresponding return is 25.0, average rewards : 58.12
# Episode number 162, and it's corresponding return is 159.0, average rewards : 59.48
# Episode number 163, and it's corresponding return is 104.0, average rewards : 60.33
# Episode number 164, and it's corresponding return is 86.0, average rewards : 60.96
# Episode number 165, and it's corresponding return is 103.0, average rewards : 61.78
# Episode number 166, and it's corresponding return is 176.0, average rewards : 63.16
# Episode number 167, and it's corresponding return is 141.0, average rewards : 64.41
# Episode number 168, and it's corresponding return is 69.0, average rewards : 64.55
# Episode number 169, and it's corresponding return is 53.0, average rewards : 64.52
# Episode number 170, and it's corresponding return is 63.0, average rewards : 64.8
# Episode number 171, and it's corresponding return is 126.0, average rewards : 65.63
# Episode number 172, and it's corresponding return is 100.0, average rewards : 66.47
# Episode number 173, and it's corresponding return is 50.0, average rewards : 66.62
# Episode number 174, and it's corresponding return is 121.0, average rewards : 67.55
# Episode number 175, and it's corresponding return is 173.0, average rewards : 69.08
# Episode number 176, and it's corresponding return is 85.0, average rewards : 69.66
# Episode number 177, and it's corresponding return is 56.0, average rewards : 69.53
# Episode number 178, and it's corresponding return is 114.0, average rewards : 70.54
# Episode number 179, and it's corresponding return is 149.0, average rewards : 71.86
# Episode number 180, and it's corresponding return is 39.0, average rewards : 72.09
# Episode number 181, and it's corresponding return is 70.0, average rewards : 72.56
# Episode number 182, and it's corresponding return is 73.0, average rewards : 72.91
# Episode number 183, and it's corresponding return is 112.0, average rewards : 73.85
# Episode number 184, and it's corresponding return is 117.0, average rewards : 74.76
# Episode number 185, and it's corresponding return is 77.0, average rewards : 75.33
# Episode number 186, and it's corresponding return is 93.0, average rewards : 75.29
# Episode number 187, and it's corresponding return is 47.0, average rewards : 75.47
# Episode number 188, and it's corresponding return is 199.0, average rewards : 77.06
# Episode number 189, and it's corresponding return is 45.0, average rewards : 77.24
# Episode number 190, and it's corresponding return is 95.0, average rewards : 77.71
# Episode number 191, and it's corresponding return is 96.0, average rewards : 78.1
# Episode number 192, and it's corresponding return is 57.0, average rewards : 78.53
# Episode number 193, and it's corresponding return is 81.0, average rewards : 79.14
# Episode number 194, and it's corresponding return is 102.0, average rewards : 79.58
# Episode number 195, and it's corresponding return is 83.0, average rewards : 80.24
# Episode number 196, and it's corresponding return is 82.0, average rewards : 80.83
# Episode number 197, and it's corresponding return is 139.0, average rewards : 81.78
# Episode number 198, and it's corresponding return is 165.0, average rewards : 82.18
# Episode number 199, and it's corresponding return is 120.0, average rewards : 83.0
# Episode number 200, and it's corresponding return is 403.0, average rewards : 86.33
# Episode number 201, and it's corresponding return is 201.0, average rewards : 88.08
# Episode number 202, and it's corresponding return is 255.0, average rewards : 89.44
# Episode number 203, and it's corresponding return is 125.0, average rewards : 90.18
# Episode number 204, and it's corresponding return is 169.0, average rewards : 91.04
# Episode number 205, and it's corresponding return is 188.0, average rewards : 92.49
# Episode number 206, and it's corresponding return is 318.0, average rewards : 95.36
# Episode number 207, and it's corresponding return is 109.0, average rewards : 96.21
# Episode number 208, and it's corresponding return is 378.0, average rewards : 99.59
# Episode number 209, and it's corresponding return is 94.0, average rewards : 100.23
# Episode number 210, and it's corresponding return is 138.0, average rewards : 101.27
# Episode number 211, and it's corresponding return is 106.0, average rewards : 101.82
# Episode number 212, and it's corresponding return is 172.0, average rewards : 103.28
# Episode number 213, and it's corresponding return is 44.0, average rewards : 103.57
# Episode number 214, and it's corresponding return is 60.0, average rewards : 103.86
# Episode number 215, and it's corresponding return is 89.0, average rewards : 104.42
# Episode number 216, and it's corresponding return is 22.0, average rewards : 103.99
# Episode number 217, and it's corresponding return is 54.0, average rewards : 102.84
# Episode number 218, and it's corresponding return is 51.0, average rewards : 102.48
# Episode number 219, and it's corresponding return is 71.0, average rewards : 102.87
# Episode number 220, and it's corresponding return is 103.0, average rewards : 103.69
# Episode number 221, and it's corresponding return is 67.0, average rewards : 102.54
# Episode number 222, and it's corresponding return is 121.0, average rewards : 103.32
# Episode number 223, and it's corresponding return is 70.0, average rewards : 103.69
# Episode number 224, and it's corresponding return is 81.0, average rewards : 103.8
# Episode number 225, and it's corresponding return is 52.0, average rewards : 104.08
# Episode number 226, and it's corresponding return is 59.0, average rewards : 104.25
# Episode number 227, and it's corresponding return is 23.0, average rewards : 104.18
# Episode number 228, and it's corresponding return is 78.0, average rewards : 103.3
# Episode number 229, and it's corresponding return is 115.0, average rewards : 104.02
# Episode number 230, and it's corresponding return is 101.0, average rewards : 104.91
# Episode number 231, and it's corresponding return is 81.0, average rewards : 104.85
# Episode number 232, and it's corresponding return is 226.0, average rewards : 106.43
# Episode number 233, and it's corresponding return is 50.0, average rewards : 106.41
# Episode number 234, and it's corresponding return is 127.0, average rewards : 107.19
# Episode number 235, and it's corresponding return is 78.0, average rewards : 106.98
# Episode number 236, and it's corresponding return is 133.0, average rewards : 107.66
# Episode number 237, and it's corresponding return is 113.0, average rewards : 108.01
# Episode number 238, and it's corresponding return is 151.0, average rewards : 108.47
# Episode number 239, and it's corresponding return is 110.0, average rewards : 108.34
# Episode number 240, and it's corresponding return is 86.0, average rewards : 108.36
# Episode number 241, and it's corresponding return is 279.0, average rewards : 109.78
# Episode number 242, and it's corresponding return is 155.0, average rewards : 110.65
# Episode number 243, and it's corresponding return is 125.0, average rewards : 111.18
# Episode number 244, and it's corresponding return is 205.0, average rewards : 112.93
# Episode number 245, and it's corresponding return is 204.0, average rewards : 114.4
# Episode number 246, and it's corresponding return is 225.0, average rewards : 115.04
# Episode number 247, and it's corresponding return is 298.0, average rewards : 116.83
# Episode number 248, and it's corresponding return is 220.0, average rewards : 118.66
# Episode number 249, and it's corresponding return is 159.0, average rewards : 119.9
# Episode number 250, and it's corresponding return is 180.0, average rewards : 120.51
# Episode number 251, and it's corresponding return is 188.0, average rewards : 121.86
# Episode number 252, and it's corresponding return is 133.0, average rewards : 122.56
# Episode number 253, and it's corresponding return is 369.0, average rewards : 124.85
# Episode number 254, and it's corresponding return is 111.0, average rewards : 124.86
# Episode number 255, and it's corresponding return is 50.0, average rewards : 124.19
# Episode number 256, and it's corresponding return is 177.0, average rewards : 125.22
# Episode number 257, and it's corresponding return is 161.0, average rewards : 126.1
# Episode number 258, and it's corresponding return is 151.0, average rewards : 124.46
# Episode number 259, and it's corresponding return is 302.0, average rewards : 126.28
# Episode number 260, and it's corresponding return is 131.0, average rewards : 127.4
# Episode number 261, and it's corresponding return is 256.0, average rewards : 129.71
# Episode number 262, and it's corresponding return is 324.0, average rewards : 131.36
# Episode number 263, and it's corresponding return is 189.0, average rewards : 132.21
# Episode number 264, and it's corresponding return is 102.0, average rewards : 132.37
# Episode number 265, and it's corresponding return is 126.0, average rewards : 132.6
# Episode number 266, and it's corresponding return is 302.0, average rewards : 133.86
# Episode number 267, and it's corresponding return is 145.0, average rewards : 133.9
# Episode number 268, and it's corresponding return is 459.0, average rewards : 137.8
# Episode number 269, and it's corresponding return is 203.0, average rewards : 139.3
# Episode number 270, and it's corresponding return is 259.0, average rewards : 141.26
# Episode number 271, and it's corresponding return is 186.0, average rewards : 141.86
# Episode number 272, and it's corresponding return is 296.0, average rewards : 143.82
# Episode number 273, and it's corresponding return is 109.0, average rewards : 144.41
# Episode number 274, and it's corresponding return is 324.0, average rewards : 146.44
# Episode number 275, and it's corresponding return is 336.0, average rewards : 148.07
# Episode number 276, and it's corresponding return is 355.0, average rewards : 150.77
# Episode number 277, and it's corresponding return is 428.0, average rewards : 154.49
# Episode number 278, and it's corresponding return is 398.0, average rewards : 157.33
# Episode number 279, and it's corresponding return is 242.0, average rewards : 158.26
# Episode number 280, and it's corresponding return is 316.0, average rewards : 161.03
# Episode number 281, and it's corresponding return is 227.0, average rewards : 162.6
# Episode number 282, and it's corresponding return is 145.0, average rewards : 163.32
# Episode number 283, and it's corresponding return is 203.0, average rewards : 164.23
# Episode number 284, and it's corresponding return is 188.0, average rewards : 164.94
# Episode number 285, and it's corresponding return is 177.0, average rewards : 165.94
# Episode number 286, and it's corresponding return is 133.0, average rewards : 166.34
# Episode number 287, and it's corresponding return is 176.0, average rewards : 167.63
# Episode number 288, and it's corresponding return is 135.0, average rewards : 166.99
# Episode number 289, and it's corresponding return is 163.0, average rewards : 168.17
# Episode number 290, and it's corresponding return is 214.0, average rewards : 169.36
# Episode number 291, and it's corresponding return is 150.0, average rewards : 169.9
# Episode number 292, and it's corresponding return is 198.0, average rewards : 171.31
# Episode number 293, and it's corresponding return is 99.0, average rewards : 171.49
# Episode number 294, and it's corresponding return is 154.0, average rewards : 172.01
# Episode number 295, and it's corresponding return is 155.0, average rewards : 172.73
# Episode number 296, and it's corresponding return is 105.0, average rewards : 172.96
# Episode number 297, and it's corresponding return is 227.0, average rewards : 173.84
# Episode number 298, and it's corresponding return is 268.0, average rewards : 174.87
# Episode number 299, and it's corresponding return is 221.0, average rewards : 175.88
# Episode number 300, and it's corresponding return is 242.0, average rewards : 174.27
# Episode number 301, and it's corresponding return is 119.0, average rewards : 173.45
# Episode number 302, and it's corresponding return is 216.0, average rewards : 173.06
# Episode number 303, and it's corresponding return is 300.0, average rewards : 174.81
# Episode number 304, and it's corresponding return is 119.0, average rewards : 174.31
# Episode number 305, and it's corresponding return is 340.0, average rewards : 175.83
# Episode number 306, and it's corresponding return is 190.0, average rewards : 174.55
# Episode number 307, and it's corresponding return is 426.0, average rewards : 177.72
# Episode number 308, and it's corresponding return is 442.0, average rewards : 178.36
# Episode number 309, and it's corresponding return is 500.0, average rewards : 182.42
# Episode number 310, and it's corresponding return is 401.0, average rewards : 185.05
# Episode number 311, and it's corresponding return is 141.0, average rewards : 185.4
# Episode number 312, and it's corresponding return is 280.0, average rewards : 186.48
# Episode number 313, and it's corresponding return is 223.0, average rewards : 188.27
# Episode number 314, and it's corresponding return is 203.0, average rewards : 189.7
# Episode number 315, and it's corresponding return is 147.0, average rewards : 190.28
# Episode number 316, and it's corresponding return is 229.0, average rewards : 192.35
# Episode number 317, and it's corresponding return is 241.0, average rewards : 194.22
# Episode number 318, and it's corresponding return is 307.0, average rewards : 196.78
# Episode number 319, and it's corresponding return is 214.0, average rewards : 198.21
# Episode number 320, and it's corresponding return is 154.0, average rewards : 198.72
# Episode number 321, and it's corresponding return is 127.0, average rewards : 199.32
# Episode number 322, and it's corresponding return is 177.0, average rewards : 199.88
# Episode number 323, and it's corresponding return is 158.0, average rewards : 200.76
# Episode number 324, and it's corresponding return is 149.0, average rewards : 201.44
# Episode number 325, and it's corresponding return is 182.0, average rewards : 202.74
# Episode number 326, and it's corresponding return is 119.0, average rewards : 203.34
# Episode number 327, and it's corresponding return is 137.0, average rewards : 204.48
# Episode number 328, and it's corresponding return is 129.0, average rewards : 204.99
# Episode number 329, and it's corresponding return is 126.0, average rewards : 205.1
# Episode number 330, and it's corresponding return is 150.0, average rewards : 205.59
# Episode number 331, and it's corresponding return is 223.0, average rewards : 207.01
# Episode number 332, and it's corresponding return is 145.0, average rewards : 206.2
# Episode number 333, and it's corresponding return is 204.0, average rewards : 207.74
# Episode number 334, and it's corresponding return is 177.0, average rewards : 208.24
# Episode number 335, and it's corresponding return is 169.0, average rewards : 209.15
# Episode number 336, and it's corresponding return is 168.0, average rewards : 209.5
# Episode number 337, and it's corresponding return is 307.0, average rewards : 211.44
# Episode number 338, and it's corresponding return is 220.0, average rewards : 212.13
# Episode number 339, and it's corresponding return is 172.0, average rewards : 212.75
# Episode number 340, and it's corresponding return is 146.0, average rewards : 213.35
# Episode number 341, and it's corresponding return is 300.0, average rewards : 213.56
# Episode number 342, and it's corresponding return is 260.0, average rewards : 214.61
# Episode number 343, and it's corresponding return is 198.0, average rewards : 215.34
# Episode number 344, and it's corresponding return is 247.0, average rewards : 215.76
# Episode number 345, and it's corresponding return is 394.0, average rewards : 217.66
# Episode number 346, and it's corresponding return is 267.0, average rewards : 218.08
# Episode number 347, and it's corresponding return is 500.0, average rewards : 220.1
# Episode number 348, and it's corresponding return is 340.0, average rewards : 221.3
# Episode number 349, and it's corresponding return is 225.0, average rewards : 221.96
# Episode number 350, and it's corresponding return is 500.0, average rewards : 225.16
# Episode number 351, and it's corresponding return is 208.0, average rewards : 225.36
# Episode number 352, and it's corresponding return is 274.0, average rewards : 226.77
# Episode number 353, and it's corresponding return is 500.0, average rewards : 228.08
# Episode number 354, and it's corresponding return is 130.0, average rewards : 228.27
# Episode number 355, and it's corresponding return is 309.0, average rewards : 230.86
# Episode number 356, and it's corresponding return is 147.0, average rewards : 230.56
# Episode number 357, and it's corresponding return is 500.0, average rewards : 233.95
# Episode number 358, and it's corresponding return is 329.0, average rewards : 235.73
# Episode number 359, and it's corresponding return is 210.0, average rewards : 234.81
# Episode number 360, and it's corresponding return is 342.0, average rewards : 236.92
# Episode number 361, and it's corresponding return is 314.0, average rewards : 237.5
# Episode number 362, and it's corresponding return is 461.0, average rewards : 238.87
# Episode number 363, and it's corresponding return is 231.0, average rewards : 239.29
# Episode number 364, and it's corresponding return is 500.0, average rewards : 243.27
# Episode number 365, and it's corresponding return is 351.0, average rewards : 245.52
# Episode number 366, and it's corresponding return is 187.0, average rewards : 244.37
# Episode number 367, and it's corresponding return is 362.0, average rewards : 246.54
# Episode number 368, and it's corresponding return is 295.0, average rewards : 244.9
# Episode number 369, and it's corresponding return is 357.0, average rewards : 246.44
# Episode number 370, and it's corresponding return is 141.0, average rewards : 245.26
# Episode number 371, and it's corresponding return is 147.0, average rewards : 244.87
# Episode number 372, and it's corresponding return is 281.0, average rewards : 244.72
# Episode number 373, and it's corresponding return is 500.0, average rewards : 248.63
# Episode number 374, and it's corresponding return is 284.0, average rewards : 248.23
# Episode number 375, and it's corresponding return is 256.0, average rewards : 247.43
# Episode number 376, and it's corresponding return is 238.0, average rewards : 246.26
# Episode number 377, and it's corresponding return is 500.0, average rewards : 246.98
# Episode number 378, and it's corresponding return is 253.0, average rewards : 245.53
# Episode number 379, and it's corresponding return is 285.0, average rewards : 245.96
# Episode number 380, and it's corresponding return is 500.0, average rewards : 247.8
# Episode number 381, and it's corresponding return is 257.0, average rewards : 248.1
# Episode number 382, and it's corresponding return is 328.0, average rewards : 249.93
# Episode number 383, and it's corresponding return is 382.0, average rewards : 251.72
# Episode number 384, and it's corresponding return is 500.0, average rewards : 254.84
# Episode number 385, and it's corresponding return is 135.0, average rewards : 254.42
# Episode number 386, and it's corresponding return is 316.0, average rewards : 256.25
# Episode number 387, and it's corresponding return is 459.0, average rewards : 259.08
# Episode number 388, and it's corresponding return is 406.0, average rewards : 261.79
# Episode number 389, and it's corresponding return is 241.0, average rewards : 262.57
# Episode number 390, and it's corresponding return is 243.0, average rewards : 262.86
# Episode number 391, and it's corresponding return is 500.0, average rewards : 266.36
# Episode number 392, and it's corresponding return is 462.0, average rewards : 269.0
# Episode number 393, and it's corresponding return is 500.0, average rewards : 273.01
# Episode number 394, and it's corresponding return is 230.0, average rewards : 273.77
# Episode number 395, and it's corresponding return is 216.0, average rewards : 274.38
# Episode number 396, and it's corresponding return is 500.0, average rewards : 278.33
# Episode number 397, and it's corresponding return is 211.0, average rewards : 278.17
# Episode number 398, and it's corresponding return is 263.0, average rewards : 278.12
# Episode number 399, and it's corresponding return is 200.0, average rewards : 277.91
# Episode number 400, and it's corresponding return is 233.0, average rewards : 277.82
# Episode number 401, and it's corresponding return is 225.0, average rewards : 278.88
# Episode number 402, and it's corresponding return is 243.0, average rewards : 279.15
# Episode number 403, and it's corresponding return is 221.0, average rewards : 278.36
# Episode number 404, and it's corresponding return is 169.0, average rewards : 278.86
# Episode number 405, and it's corresponding return is 175.0, average rewards : 277.21
# Episode number 406, and it's corresponding return is 157.0, average rewards : 276.88
# Episode number 407, and it's corresponding return is 183.0, average rewards : 274.45
# Episode number 408, and it's corresponding return is 144.0, average rewards : 271.47
# Episode number 409, and it's corresponding return is 127.0, average rewards : 267.74
# Episode number 410, and it's corresponding return is 115.0, average rewards : 264.88
# Episode number 411, and it's corresponding return is 243.0, average rewards : 265.9
# Episode number 412, and it's corresponding return is 129.0, average rewards : 264.39
# Episode number 413, and it's corresponding return is 170.0, average rewards : 263.86
# Episode number 414, and it's corresponding return is 249.0, average rewards : 264.32
# Episode number 415, and it's corresponding return is 133.0, average rewards : 264.18
# Episode number 416, and it's corresponding return is 66.0, average rewards : 262.55
# Episode number 417, and it's corresponding return is 219.0, average rewards : 262.33
# Episode number 418, and it's corresponding return is 158.0, average rewards : 260.84
# Episode number 419, and it's corresponding return is 184.0, average rewards : 260.54
# Episode number 420, and it's corresponding return is 144.0, average rewards : 260.44
# Episode number 421, and it's corresponding return is 227.0, average rewards : 261.44
# Episode number 422, and it's corresponding return is 191.0, average rewards : 261.58
# Episode number 423, and it's corresponding return is 114.0, average rewards : 261.14
# Episode number 424, and it's corresponding return is 500.0, average rewards : 264.65
# Episode number 425, and it's corresponding return is 172.0, average rewards : 264.55
# Episode number 426, and it's corresponding return is 211.0, average rewards : 265.47
# Episode number 427, and it's corresponding return is 246.0, average rewards : 266.56
# Episode number 428, and it's corresponding return is 378.0, average rewards : 269.05
# Episode number 429, and it's corresponding return is 179.0, average rewards : 269.58
# Episode number 430, and it's corresponding return is 97.0, average rewards : 269.05
# Episode number 431, and it's corresponding return is 225.0, average rewards : 269.07
# Episode number 432, and it's corresponding return is 192.0, average rewards : 269.54
# Episode number 433, and it's corresponding return is 436.0, average rewards : 271.86
# Episode number 434, and it's corresponding return is 422.0, average rewards : 274.31
# Episode number 435, and it's corresponding return is 500.0, average rewards : 277.62
# Episode number 436, and it's corresponding return is 500.0, average rewards : 280.94
# Episode number 437, and it's corresponding return is 500.0, average rewards : 282.87
# Episode number 438, and it's corresponding return is 460.0, average rewards : 285.27
# Episode number 439, and it's corresponding return is 171.0, average rewards : 285.26
# Episode number 440, and it's corresponding return is 225.0, average rewards : 286.05
# Episode number 441, and it's corresponding return is 350.0, average rewards : 286.55
# Episode number 442, and it's corresponding return is 356.0, average rewards : 287.51
# Episode number 443, and it's corresponding return is 269.0, average rewards : 288.22
# Episode number 444, and it's corresponding return is 311.0, average rewards : 288.86
# Episode number 445, and it's corresponding return is 311.0, average rewards : 288.03
# Episode number 446, and it's corresponding return is 421.0, average rewards : 289.57
# Episode number 447, and it's corresponding return is 273.0, average rewards : 287.3
# Episode number 448, and it's corresponding return is 441.0, average rewards : 288.31
# Episode number 449, and it's corresponding return is 327.0, average rewards : 289.33
# Episode number 450, and it's corresponding return is 110.0, average rewards : 285.43
# Episode number 451, and it's corresponding return is 500.0, average rewards : 288.35
# Episode number 452, and it's corresponding return is 154.0, average rewards : 287.15
# Episode number 453, and it's corresponding return is 183.0, average rewards : 283.98
# Episode number 454, and it's corresponding return is 315.0, average rewards : 285.83
# Episode number 455, and it's corresponding return is 89.0, average rewards : 283.63
# Episode number 456, and it's corresponding return is 164.0, average rewards : 283.8
# Episode number 457, and it's corresponding return is 133.0, average rewards : 280.13
# Episode number 458, and it's corresponding return is 416.0, average rewards : 281.0
# Episode number 459, and it's corresponding return is 177.0, average rewards : 280.67
# Episode number 460, and it's corresponding return is 182.0, average rewards : 279.07
# Episode number 461, and it's corresponding return is 211.0, average rewards : 278.04
# Episode number 462, and it's corresponding return is 395.0, average rewards : 277.38
# Episode number 463, and it's corresponding return is 399.0, average rewards : 279.06
# Episode number 464, and it's corresponding return is 243.0, average rewards : 276.49
# Episode number 465, and it's corresponding return is 407.0, average rewards : 277.05
# Episode number 466, and it's corresponding return is 415.0, average rewards : 279.33
# Episode number 467, and it's corresponding return is 175.0, average rewards : 277.46
# Episode number 468, and it's corresponding return is 273.0, average rewards : 277.24
# Episode number 469, and it's corresponding return is 435.0, average rewards : 278.02
# Episode number 470, and it's corresponding return is 431.0, average rewards : 280.92
# Episode number 471, and it's corresponding return is 298.0, average rewards : 282.43
# Episode number 472, and it's corresponding return is 230.0, average rewards : 281.92
# Episode number 473, and it's corresponding return is 249.0, average rewards : 279.41
# Episode number 474, and it's corresponding return is 321.0, average rewards : 279.78
# Episode number 475, and it's corresponding return is 244.0, average rewards : 279.66
# Episode number 476, and it's corresponding return is 500.0, average rewards : 282.28
# Episode number 477, and it's corresponding return is 500.0, average rewards : 282.28
# Episode number 478, and it's corresponding return is 169.0, average rewards : 281.44
# Episode number 479, and it's corresponding return is 203.0, average rewards : 280.62
# Episode number 480, and it's corresponding return is 126.0, average rewards : 276.88
# Episode number 481, and it's corresponding return is 316.0, average rewards : 277.47
# Episode number 482, and it's corresponding return is 437.0, average rewards : 278.56
# Episode number 483, and it's corresponding return is 185.0, average rewards : 276.59
# Episode number 484, and it's corresponding return is 489.0, average rewards : 276.48
# Episode number 485, and it's corresponding return is 472.0, average rewards : 279.85
# Episode number 486, and it's corresponding return is 500.0, average rewards : 281.69
# Episode number 487, and it's corresponding return is 436.0, average rewards : 281.46
# Episode number 488, and it's corresponding return is 355.0, average rewards : 280.95
# Episode number 489, and it's corresponding return is 332.0, average rewards : 281.86
# Episode number 490, and it's corresponding return is 382.0, average rewards : 283.25
# Episode number 491, and it's corresponding return is 347.0, average rewards : 281.72
# Episode number 492, and it's corresponding return is 328.0, average rewards : 280.38
# Episode number 493, and it's corresponding return is 472.0, average rewards : 280.1
# Episode number 494, and it's corresponding return is 341.0, average rewards : 281.21
# Episode number 495, and it's corresponding return is 411.0, average rewards : 283.16
# Episode number 496, and it's corresponding return is 348.0, average rewards : 281.64
# Episode number 497, and it's corresponding return is 335.0, average rewards : 282.88
# Episode number 498, and it's corresponding return is 374.0, average rewards : 283.99
# Episode number 499, and it's corresponding return is 500.0, average rewards : 286.99
# Episode number 500, and it's corresponding return is 476.0, average rewards : 289.42
# Episode number 501, and it's corresponding return is 364.0, average rewards : 290.81
# Episode number 502, and it's corresponding return is 410.0, average rewards : 292.48
# Episode number 503, and it's corresponding return is 500.0, average rewards : 295.27
# Episode number 504, and it's corresponding return is 195.0, average rewards : 295.53
# Episode number 505, and it's corresponding return is 239.0, average rewards : 296.17
# Episode number 506, and it's corresponding return is 173.0, average rewards : 296.33
# Episode number 507, and it's corresponding return is 113.0, average rewards : 295.63
# Episode number 508, and it's corresponding return is 500.0, average rewards : 299.19
# Episode number 509, and it's corresponding return is 500.0, average rewards : 302.92
# Episode number 510, and it's corresponding return is 500.0, average rewards : 306.77
# Episode number 511, and it's corresponding return is 500.0, average rewards : 309.34
# Episode number 512, and it's corresponding return is 296.0, average rewards : 311.01
# Episode number 513, and it's corresponding return is 306.0, average rewards : 312.37
# Episode number 514, and it's corresponding return is 405.0, average rewards : 313.93
# Episode number 515, and it's corresponding return is 397.0, average rewards : 316.57
# Episode number 516, and it's corresponding return is 295.0, average rewards : 318.86
# Episode number 517, and it's corresponding return is 327.0, average rewards : 319.94
# Episode number 518, and it's corresponding return is 304.0, average rewards : 321.4
# Episode number 519, and it's corresponding return is 339.0, average rewards : 322.95
# Episode number 520, and it's corresponding return is 301.0, average rewards : 324.52
# Episode number 521, and it's corresponding return is 308.0, average rewards : 325.33
# Episode number 522, and it's corresponding return is 374.0, average rewards : 327.16
# Episode number 523, and it's corresponding return is 336.0, average rewards : 329.38
# Episode number 524, and it's corresponding return is 214.0, average rewards : 326.52
# Episode number 525, and it's corresponding return is 254.0, average rewards : 327.34
# Episode number 526, and it's corresponding return is 346.0, average rewards : 328.69
# Episode number 527, and it's corresponding return is 353.0, average rewards : 329.76
# Episode number 528, and it's corresponding return is 339.0, average rewards : 329.37
# Episode number 529, and it's corresponding return is 357.0, average rewards : 331.15
# Episode number 530, and it's corresponding return is 411.0, average rewards : 334.29
# Episode number 531, and it's corresponding return is 128.0, average rewards : 333.32
# Episode number 532, and it's corresponding return is 406.0, average rewards : 335.46
# Episode number 533, and it's corresponding return is 443.0, average rewards : 335.53
# Episode number 534, and it's corresponding return is 251.0, average rewards : 333.82
# Episode number 535, and it's corresponding return is 500.0, average rewards : 333.82
# Episode number 536, and it's corresponding return is 500.0, average rewards : 333.82
# Episode number 537, and it's corresponding return is 384.0, average rewards : 332.66
# Episode number 538, and it's corresponding return is 368.0, average rewards : 331.74
# Episode number 539, and it's corresponding return is 500.0, average rewards : 335.03
# Episode number 540, and it's corresponding return is 500.0, average rewards : 337.78
# Episode number 541, and it's corresponding return is 421.0, average rewards : 338.49
# Episode number 542, and it's corresponding return is 500.0, average rewards : 339.93
# Episode number 543, and it's corresponding return is 500.0, average rewards : 342.24
# Episode number 544, and it's corresponding return is 246.0, average rewards : 341.59
# Episode number 545, and it's corresponding return is 489.0, average rewards : 343.37
# Episode number 546, and it's corresponding return is 257.0, average rewards : 341.73
# Episode number 547, and it's corresponding return is 274.0, average rewards : 341.74
# Episode number 548, and it's corresponding return is 500.0, average rewards : 342.33
# Episode number 549, and it's corresponding return is 354.0, average rewards : 342.6
# Episode number 550, and it's corresponding return is 500.0, average rewards : 346.5
# Episode number 551, and it's corresponding return is 206.0, average rewards : 343.56
# Episode number 552, and it's corresponding return is 413.0, average rewards : 346.15
# Episode number 553, and it's corresponding return is 500.0, average rewards : 349.32
# Episode number 554, and it's corresponding return is 490.0, average rewards : 351.07
# Episode number 555, and it's corresponding return is 467.0, average rewards : 354.85
# Episode number 556, and it's corresponding return is 357.0, average rewards : 356.78
# ...
# Episode number 812, and it's corresponding return is 147.0, average rewards : 75.21
# Episode number 813, and it's corresponding return is 132.0, average rewards : 76.1
# Episode number 814, and it's corresponding return is 61.0, average rewards : 76.26
# Episode number 815, and it's corresponding return is 111.0, average rewards : 76.68
# Episode number 816, and it's corresponding return is 41.0, average rewards : 76.36
# Episode number 817, and it's corresponding return is 66.0, average rewards : 76.58
# Episode number 818, and it's corresponding return is 93.0, average rewards : 77.36
# Episode number 819, and it's corresponding return is 50.0, average rewards : 77.03
# Episode number 820, and it's corresponding return is 105.0, average rewards : 77.7
# Episode number 821, and it's corresponding return is 263.0, average rewards : 79.1
# Episode number 822, and it's corresponding return is 82.0, average rewards : 79.46
# Episode number 823, and it's corresponding return is 93.0, average rewards : 80.04
# Episode number 824, and it's corresponding return is 311.0, average rewards : 82.91
# Episode number 825, and it's corresponding return is 45.0, average rewards : 82.41
# Episode number 826, and it's corresponding return is 79.0, average rewards : 82.85
# Episode number 827, and it's corresponding return is 36.0, average rewards : 83.01
# Episode number 828, and it's corresponding return is 102.0, average rewards : 83.3
# Episode number 829, and it's corresponding return is 82.0, average rewards : 83.53
# Episode number 830, and it's corresponding return is 68.0, average rewards : 83.85
# Episode number 831, and it's corresponding return is 53.0, average rewards : 83.82
# Episode number 832, and it's corresponding return is 40.0, average rewards : 83.47
# Episode number 833, and it's corresponding return is 178.0, average rewards : 84.76
# Episode number 834, and it's corresponding return is 77.0, average rewards : 83.85
# Episode number 835, and it's corresponding return is 42.0, average rewards : 83.8
# Episode number 836, and it's corresponding return is 70.0, average rewards : 84.17
# Episode number 837, and it's corresponding return is 129.0, average rewards : 85.2
# Episode number 838, and it's corresponding return is 146.0, average rewards : 86.42
# Episode number 839, and it's corresponding return is 156.0, average rewards : 87.53
# Episode number 840, and it's corresponding return is 180.0, average rewards : 88.77
# Episode number 841, and it's corresponding return is 104.0, average rewards : 88.9
# Episode number 842, and it's corresponding return is 94.0, average rewards : 89.5
# Episode number 843, and it's corresponding return is 123.0, average rewards : 89.82
# Episode number 844, and it's corresponding return is 93.0, average rewards : 90.3
# Episode number 845, and it's corresponding return is 147.0, average rewards : 90.21
# Episode number 846, and it's corresponding return is 128.0, average rewards : 90.1
# Episode number 847, and it's corresponding return is 182.0, average rewards : 90.89
# Episode number 848, and it's corresponding return is 63.0, average rewards : 90.65
# Episode number 849, and it's corresponding return is 132.0, average rewards : 91.69
# Episode number 850, and it's corresponding return is 88.0, average rewards : 91.62
# Episode number 851, and it's corresponding return is 218.0, average rewards : 92.78
# Episode number 852, and it's corresponding return is 75.0, average rewards : 92.57
# Episode number 853, and it's corresponding return is 82.0, average rewards : 93.15
# Episode number 854, and it's corresponding return is 112.0, average rewards : 93.38
# Episode number 855, and it's corresponding return is 110.0, average rewards : 92.45
# Episode number 856, and it's corresponding return is 181.0, average rewards : 93.25
# Episode number 857, and it's corresponding return is 97.0, average rewards : 93.73
# Episode number 858, and it's corresponding return is 57.0, average rewards : 93.21
# Episode number 859, and it's corresponding return is 158.0, average rewards : 93.89
# Episode number 860, and it's corresponding return is 170.0, average rewards : 94.91
# Episode number 861, and it's corresponding return is 164.0, average rewards : 95.79
# Episode number 862, and it's corresponding return is 46.0, average rewards : 95.54
# Episode number 863, and it's corresponding return is 162.0, average rewards : 96.63
# Episode number 864, and it's corresponding return is 131.0, average rewards : 96.85
# Episode number 865, and it's corresponding return is 217.0, average rewards : 97.7
# Episode number 866, and it's corresponding return is 56.0, average rewards : 97.27
# Episode number 867, and it's corresponding return is 198.0, average rewards : 98.93
# Episode number 868, and it's corresponding return is 32.0, average rewards : 98.68
# Episode number 869, and it's corresponding return is 139.0, average rewards : 99.72
# Episode number 870, and it's corresponding return is 109.0, average rewards : 100.36
# Episode number 871, and it's corresponding return is 94.0, average rewards : 100.46
# Episode number 872, and it's corresponding return is 89.0, average rewards : 100.44
# Episode number 873, and it's corresponding return is 269.0, average rewards : 102.42
# Episode number 874, and it's corresponding return is 105.0, average rewards : 102.56
# Episode number 875, and it's corresponding return is 98.0, average rewards : 102.08
# Episode number 876, and it's corresponding return is 111.0, average rewards : 102.98
# Episode number 877, and it's corresponding return is 78.0, average rewards : 102.99
# Episode number 878, and it's corresponding return is 120.0, average rewards : 103.63
# Episode number 879, and it's corresponding return is 180.0, average rewards : 104.96
# Episode number 880, and it's corresponding return is 175.0, average rewards : 106.29
# Episode number 881, and it's corresponding return is 170.0, average rewards : 107.41
# Episode number 882, and it's corresponding return is 41.0, average rewards : 107.01
# Episode number 883, and it's corresponding return is 110.0, average rewards : 107.3
# Episode number 884, and it's corresponding return is 196.0, average rewards : 108.85
# Episode number 885, and it's corresponding return is 171.0, average rewards : 109.99
# Episode number 886, and it's corresponding return is 413.0, average rewards : 113.46
# Episode number 887, and it's corresponding return is 68.0, average rewards : 113.5
# Episode number 888, and it's corresponding return is 91.0, average rewards : 113.84
# Episode number 889, and it's corresponding return is 173.0, average rewards : 114.48
# Episode number 890, and it's corresponding return is 160.0, average rewards : 115.59
# Episode number 891, and it's corresponding return is 21.0, average rewards : 115.42
# Episode number 892, and it's corresponding return is 98.0, average rewards : 115.79
# Episode number 893, and it's corresponding return is 212.0, average rewards : 117.66
# Episode number 894, and it's corresponding return is 287.0, average rewards : 120.24
# Episode number 895, and it's corresponding return is 67.0, average rewards : 119.85
# Episode number 896, and it's corresponding return is 61.0, average rewards : 119.93
# Episode number 897, and it's corresponding return is 84.0, average rewards : 117.41
# Episode number 898, and it's corresponding return is 91.0, average rewards : 116.68
# Episode number 899, and it's corresponding return is 107.0, average rewards : 116.83
# Episode number 900, and it's corresponding return is 105.0, average rewards : 117.53
# Episode number 901, and it's corresponding return is 305.0, average rewards : 119.86
# Episode number 902, and it's corresponding return is 167.0, average rewards : 120.31
# Episode number 903, and it's corresponding return is 348.0, average rewards : 123.36
# Episode number 904, and it's corresponding return is 199.0, average rewards : 124.65
# Episode number 905, and it's corresponding return is 292.0, average rewards : 127.06
# Episode number 906, and it's corresponding return is 247.0, average rewards : 128.52
# Episode number 907, and it's corresponding return is 274.0, average rewards : 130.21
# Episode number 908, and it's corresponding return is 120.0, average rewards : 131.11
# Episode number 909, and it's corresponding return is 229.0, average rewards : 132.34
# Episode number 910, and it's corresponding return is 293.0, average rewards : 133.45
# Episode number 911, and it's corresponding return is 178.0, average rewards : 134.03
# Episode number 912, and it's corresponding return is 98.0, average rewards : 133.54
# Episode number 913, and it's corresponding return is 157.0, average rewards : 133.79
# Episode number 914, and it's corresponding return is 89.0, average rewards : 134.07
# Episode number 915, and it's corresponding return is 109.0, average rewards : 134.05
# Episode number 916, and it's corresponding return is 323.0, average rewards : 136.87
# Episode number 917, and it's corresponding return is 88.0, average rewards : 137.09
# Episode number 918, and it's corresponding return is 165.0, average rewards : 137.81
# Episode number 919, and it's corresponding return is 256.0, average rewards : 139.87
# Episode number 920, and it's corresponding return is 148.0, average rewards : 140.3
# Episode number 921, and it's corresponding return is 200.0, average rewards : 139.67
# Episode number 922, and it's corresponding return is 138.0, average rewards : 140.23
# Episode number 923, and it's corresponding return is 312.0, average rewards : 142.42
# Episode number 924, and it's corresponding return is 121.0, average rewards : 140.52
# Episode number 925, and it's corresponding return is 150.0, average rewards : 141.57
# Episode number 926, and it's corresponding return is 113.0, average rewards : 141.91
# Episode number 927, and it's corresponding return is 123.0, average rewards : 142.78
# Episode number 928, and it's corresponding return is 246.0, average rewards : 144.22
# Episode number 929, and it's corresponding return is 500.0, average rewards : 148.4
# Episode number 930, and it's corresponding return is 290.0, average rewards : 150.62
# Episode number 931, and it's corresponding return is 337.0, average rewards : 153.46
# Episode number 932, and it's corresponding return is 143.0, average rewards : 154.49
# Episode number 933, and it's corresponding return is 26.0, average rewards : 152.97
# Episode number 934, and it's corresponding return is 326.0, average rewards : 155.46
# Episode number 935, and it's corresponding return is 135.0, average rewards : 156.39
# Episode number 936, and it's corresponding return is 34.0, average rewards : 156.03
# Episode number 937, and it's corresponding return is 64.0, average rewards : 155.38
# Episode number 938, and it's corresponding return is 278.0, average rewards : 156.7
# Episode number 939, and it's corresponding return is 133.0, average rewards : 156.47
# Episode number 940, and it's corresponding return is 78.0, average rewards : 155.45
# Episode number 941, and it's corresponding return is 140.0, average rewards : 155.81
# Episode number 942, and it's corresponding return is 260.0, average rewards : 157.47
# Episode number 943, and it's corresponding return is 124.0, average rewards : 157.48
# Episode number 944, and it's corresponding return is 246.0, average rewards : 159.01
# Episode number 945, and it's corresponding return is 146.0, average rewards : 159.0
# Episode number 946, and it's corresponding return is 250.0, average rewards : 160.22
# Episode number 947, and it's corresponding return is 203.0, average rewards : 160.43
# Episode number 948, and it's corresponding return is 208.0, average rewards : 161.88
# Episode number 949, and it's corresponding return is 114.0, average rewards : 161.7
# Episode number 950, and it's corresponding return is 191.0, average rewards : 162.73
# Episode number 951, and it's corresponding return is 127.0, average rewards : 161.82
# Episode number 952, and it's corresponding return is 116.0, average rewards : 162.23
# Episode number 953, and it's corresponding return is 89.0, average rewards : 162.3
# Episode number 954, and it's corresponding return is 198.0, average rewards : 163.16
# Episode number 955, and it's corresponding return is 111.0, average rewards : 163.17
# Episode number 956, and it's corresponding return is 68.0, average rewards : 162.04
# Episode number 957, and it's corresponding return is 104.0, average rewards : 162.11
# Episode number 958, and it's corresponding return is 68.0, average rewards : 162.22
# Episode number 959, and it's corresponding return is 183.0, average rewards : 162.47
# Episode number 960, and it's corresponding return is 325.0, average rewards : 164.02
# Episode number 961, and it's corresponding return is 156.0, average rewards : 163.94
# Episode number 962, and it's corresponding return is 121.0, average rewards : 164.69
# Episode number 963, and it's corresponding return is 230.0, average rewards : 165.37
# Episode number 964, and it's corresponding return is 183.0, average rewards : 165.89
# Episode number 965, and it's corresponding return is 208.0, average rewards : 165.8
# Episode number 966, and it's corresponding return is 149.0, average rewards : 166.73
# Episode number 967, and it's corresponding return is 71.0, average rewards : 165.46
# Episode number 968, and it's corresponding return is 150.0, average rewards : 166.64
# Episode number 969, and it's corresponding return is 239.0, average rewards : 167.64
# Episode number 970, and it's corresponding return is 190.0, average rewards : 168.45
# Episode number 971, and it's corresponding return is 66.0, average rewards : 168.17
# Episode number 972, and it's corresponding return is 204.0, average rewards : 169.32
# Episode number 973, and it's corresponding return is 326.0, average rewards : 169.89
# Episode number 974, and it's corresponding return is 122.0, average rewards : 170.06
# Episode number 975, and it's corresponding return is 41.0, average rewards : 169.49
# Episode number 976, and it's corresponding return is 500.0, average rewards : 173.38
# Episode number 977, and it's corresponding return is 133.0, average rewards : 173.93
# Episode number 978, and it's corresponding return is 301.0, average rewards : 175.74
# Episode number 979, and it's corresponding return is 253.0, average rewards : 176.47
# Episode number 980, and it's corresponding return is 34.0, average rewards : 175.06
# Episode number 981, and it's corresponding return is 203.0, average rewards : 175.39
# Episode number 982, and it's corresponding return is 172.0, average rewards : 176.7
# Episode number 983, and it's corresponding return is 151.0, average rewards : 177.11
# Episode number 984, and it's corresponding return is 152.0, average rewards : 176.67
# Episode number 985, and it's corresponding return is 148.0, average rewards : 176.44
# Episode number 986, and it's corresponding return is 247.0, average rewards : 174.78
# Episode number 987, and it's corresponding return is 249.0, average rewards : 176.59
# Episode number 988, and it's corresponding return is 52.0, average rewards : 176.2
# Episode number 989, and it's corresponding return is 458.0, average rewards : 179.05
# Episode number 990, and it's corresponding return is 189.0, average rewards : 179.34
# Episode number 991, and it's corresponding return is 42.0, average rewards : 179.55
# Episode number 992, and it's corresponding return is 287.0, average rewards : 181.44
# Episode number 993, and it's corresponding return is 167.0, average rewards : 180.99
# Episode number 994, and it's corresponding return is 85.0, average rewards : 178.97
# Episode number 995, and it's corresponding return is 234.0, average rewards : 180.64
# Episode number 996, and it's corresponding return is 280.0, average rewards : 182.83
# Episode number 997, and it's corresponding return is 100.0, average rewards : 182.99
# Episode number 998, and it's corresponding return is 500.0, average rewards : 187.08
# Episode number 999, and it's corresponding return is 373.0, average rewards : 189.74
# Episode number 1000, and it's corresponding return is 500.0, average rewards : 193.69

# %%
print(dict_1_1)
# Out:
# {(128, 64): 182490.0, (64, 32): 339290.0, (32, 16): 386444.0, (16, 8): 499320.0}

# %%
print(opt_par_1_1)
print(dict_1_1[opt_par_1_1])
# Out:
# (128, 64)
# 182490.0

# %%
print(dict_2_1)
# Out:
# {(128, 64): 236221.0, (64, 32): 249053.0, (32, 16): 335248.0, (16, 8): 440683.0}

# %%
print(opt_par_2_1)
print(dict_2_1[opt_par_2_1])
# Out:
# (128, 64)
# 236221.0

# %%
y = list(dict_1_1.values())
x = [1,2,3,4]
plt.plot(x,y)
plt.title("Parameter's id vs their regret")
plt.xlabel("Parameter's id")
plt.ylabel("Regret")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
y = list(dict_2_1.values())
x = [1,2,3,4]
plt.plot(x,y)
plt.title("Parameter's id vs their regret")
plt.xlabel("Parameter's id")
plt.ylabel("Regret")
plt.show()
