# %% [markdown]
# ### Importing Modules

# %%
import numpy as np
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from collections import namedtuple, deque
import datetime

import gym
from gym.wrappers.record_video import RecordVideo

import glob
import io
import base64

import matplotlib.pyplot as plt

# %% [markdown]
# ### Defining the two game environments

# %%
#Defining Environments

#Environment 1

env1 = gym.make("Acrobot-v1")
env1.seed(0)

env1_state_shape = env1.observation_space.shape[0]
env1_no_of_actions = env1.action_space.n

env1_state = env1.reset()


#Environment 2

env2 = gym.make("CartPole-v1")
env2.seed(0)

env2_state_shape = env2.observation_space.shape[0]
env2_no_of_actions = env2.action_space.n

env2_state = env2.reset()


# Note For both Environments
# For choosing actions :
# action = env.action_space.sample()

# For step :
# next_state, reward, done, info = env.step(action)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(

# %% [markdown]
# ### Defining the two Neural networks required

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

BUFFER_SIZE = int(1e5)
BATCH_SIZE = 64       # Need to be learnt?
GAMMA = 0.99
LR = 5e-4             # Need to be learnt
UPDATE_EVERY = 20

class QNetwork1(nn.Module):
  def __init__(self, state_size, action_size, seed, fc1_units = 128, fc2_units = 64, fc3_units = 32, fc4_units = 16):
    super(QNetwork1, self).__init__()
    self.seed = torch.manual_seed(seed)                                               # Making the initialization of weights the same all the time
    self.fc1 = nn.Linear(state_size, fc1_units)
    self.fc2 = nn.Linear(fc1_units, fc2_units)
    self.V = nn.Linear(fc2_units, 1)
    self.A = nn.Linear(fc2_units, action_size)

  def forward(self, state):
    x = F.relu(self.fc1(state))
    x = F.relu(self.fc2(x))
    V = self.V(x)
    A = self.A(x)
    return V + A - A.mean()

class QNetwork2(nn.Module):
  def __init__(self, state_size, action_size, seed, fc1_units = 128, fc2_units = 64, fc3_units = 32, fc4_units = 16):
    super(QNetwork2, self).__init__()
    self.seed = torch.manual_seed(seed)
    self.fc1 = nn.Linear(state_size, fc1_units)
    self.fc2 = nn.Linear(fc1_units, fc2_units)
    self.V = nn.Linear(fc2_units, 1)
    self.A = nn.Linear(fc2_units, action_size)

  def forward(self, state):
    x = F.relu(self.fc1(state))
    x = F.relu(self.fc2(x))
    V = self.V(x)
    A = self.A(x)
    return V + A - A.max()

# %% [markdown]
# ### Class for Replay buffer

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class ReplayBuffer:
  def __init__(self, action_size, buffer_size, batch_size, seed):
    self.action_size = action_size
    self.memory = deque(maxlen = buffer_size)                                                                       # Memory that stores experiences
    self.batch_size = batch_size                                                                                    # Stores batch size for sampling
    self.experience = namedtuple('Experience', field_names = ["state", "action", "reward", "next_state", "done"])   # Named Tuple that is used to store experience
    self.seed = random.seed(seed)

  def add(self, state, action, reward, next_state, done):                                                         # Function for adding experiences in memory
    e = self.experience(state, action, reward, next_state, done)
    self.memory.append(e)

  def sample(self):                                                                                               # Sampling experiences randomly
    experiences = random.sample(self.memory, k = self.batch_size)

    states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
    actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(device)
    rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
    next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
    dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)

    return (states, actions, rewards, next_states, dones)

  def __len__(self):
    return len(self.memory)

# %% [markdown]
# ### Defining tutorial agent, where it learns and acts according to the policy

# %%
class TutorialAgent():
  def __init__(self, state_size, action_size, seed, fc1_units, fc2_units, tau = 0.1, QNetwork = QNetwork1):
    self.state_size = state_size
    self.action_size = action_size
    self.seed = random.seed(seed)

    self.qnetwork_local = QNetwork(state_size, action_size, seed, fc1_units, fc2_units).to(device)                  # Local network
    self.qnetwork_target = QNetwork(state_size, action_size, seed, fc1_units, fc2_units).to(device)                 # Target network
    self.optimizer = optim.Adam(self.qnetwork_local.parameters(), lr = LR)

    self.memory = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, seed)         # To store experiences and sample

    self.t_step = 0                                                                # For maintaining a count of when to update Target Q network
    self.tau = tau                                                                 # Parameter for updating Target Q network using Polyak updation

  def step(self, state, action, reward, next_state, done):
    self.memory.add(state, action, reward, next_state, done)

    if len(self.memory) >= BATCH_SIZE:
      experiences = self.memory.sample()
      self.learn(experiences)

    self.t_step = (self.t_step + 1) % UPDATE_EVERY
    if self.t_step == 0:
      for (name1, par1), (name2, par2) in zip(self.qnetwork_local.state_dict().items(), self.qnetwork_target.state_dict().items()):
        par2.copy_(self.tau * par1 + (1 - self.tau) * par2)                        # Polyak update

  def act(self, state, eps = 0.0):
    state = torch.from_numpy(state).float().unsqueeze(0).to(device)                           # Conveting the numpy array to a torch tensor

    self.qnetwork_local.eval()                                                     # The model is set to evaluating
    with torch.no_grad():                                                          # Evaluation is done without taking gradients
      action_values = self.qnetwork_local(state)                                   # The Q values are obtained
    self.qnetwork_local.train()                                                    # The model is set to training

    if random.random() > eps:                                                      # Implementing of Epsilon greedy policy
      return np.argmax(action_values.cpu().data.numpy())
    else:
      return random.choice(np.arange(self.action_size))

  def learn(self, experiences):
    states, actions, rewards, next_states, dones = experiences
    Q_targets_next = self.qnetwork_target(next_states).detach().max(1)[0].unsqueeze(1)
    Q_targets = rewards + GAMMA * Q_targets_next * (1 - dones)
    Q_current = self.qnetwork_local(states).gather(1, actions)

    loss = F.mse_loss(Q_current, Q_targets)

    self.optimizer.zero_grad()
    loss.backward()

    for param in self.qnetwork_local.parameters():                                 # Gradient clipping
      param.grad.data.clamp_(-1, 1)                                                # For preventing exploding gradient situation

    self.optimizer.step()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### A class for running Dueling DQN

# %%
class dueling_dqn:
  def __init__(self, fc1_units, fc2_units, env = env1, QNetwork = QNetwork1, tau = 0.1, seed = 0):
    self.env = env
    self.state_shape = env.observation_space.shape[0]
    self.action_space = env.action_space.n
    self.agent = TutorialAgent(self.state_shape, self.action_space, seed, fc1_units, fc2_units, tau = tau, QNetwork = QNetwork)

  def run(self, n_episodes = 1000, max_t = 500, eps_start = 1.0, eps_end = 0.01, eps_decay = 0.995):
    returns = deque()
    scores = deque(maxlen = 100)
    eps = eps_start
    for i in range(1, n_episodes + 1):
      state = self.env.reset()
      ep_reward = 0
      rewards = deque()
      while True:
        action = self.agent.act(state, eps)
        next_state, reward, done, _ = self.env.step(action)
        self.agent.step(state, action, reward, next_state, done)
        state = next_state
        ep_reward += reward
        rewards.append(reward)

        if done:
          break
      eps = max(eps_end, eps_decay * eps)
      scores.append(ep_reward)
      R = 0
      for r in list(rewards):
        R = r + R
      print(f"Episode number {i}, and it's corresponding return is {R}, average rewards : {np.mean(scores)}")
      returns.append(R)
    return list(returns)

# %%
from tqdm import tqdm
def tuning(env = env1, QNetwork = QNetwork1):
    upper_limit = 0
    hyper_parameters = [(128, 64), (64, 32), (32, 16), (16, 8)]
    dictionary = {}
    for par in tqdm(hyper_parameters):
        tuning_Duel_DQN = dueling_dqn(fc1_units = par[0], fc2_units = par[1], QNetwork = QNetwork, seed = 0)
        returns = tuning_Duel_DQN.run()
        regret = [upper_limit - r for r in returns]
        dictionary[par] = np.sum(np.array(regret))
    return dictionary, min(dictionary.keys(), key = lambda x : dictionary[x]) # Returns the dictionary and the pair with minimum regret
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Tuning of Parameters
# - Tuned for Hidden Layer nodes (fc1_nodes, fc2_nodes) = (128, 64), (64, 32), (32, 16), (16, 8)

# %%
dict_1_1, opt_par_1_1 = tuning()
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Episode number 1, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 2, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 3, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 4, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 5, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 6, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 7, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 8, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 9, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 10, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 11, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 12, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 13, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 14, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 15, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 16, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 17, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 18, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 19, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 20, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 21, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 22, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 23, and it's corresponding return is -280.0, average rewards : -490.4347826086956
# Episode number 24, and it's corresponding return is -500.0, average rewards : -490.8333333333333
# Episode number 25, and it's corresponding return is -488.0, average rewards : -490.72
# Episode number 26, and it's corresponding return is -438.0, average rewards : -488.6923076923077
# Episode number 27, and it's corresponding return is -415.0, average rewards : -485.962962962963
# Episode number 28, and it's corresponding return is -353.0, average rewards : -481.2142857142857
# Episode number 29, and it's corresponding return is -424.0, average rewards : -479.2413793103448
# Episode number 30, and it's corresponding return is -500.0, average rewards : -479.93333333333334
# Episode number 31, and it's corresponding return is -500.0, average rewards : -480.5806451612903
# Episode number 32, and it's corresponding return is -410.0, average rewards : -478.375
# Episode number 33, and it's corresponding return is -500.0, average rewards : -479.030303030303
# Episode number 34, and it's corresponding return is -496.0, average rewards : -479.52941176470586
# Episode number 35, and it's corresponding return is -351.0, average rewards : -475.85714285714283
# Episode number 36, and it's corresponding return is -375.0, average rewards : -473.05555555555554
# Episode number 37, and it's corresponding return is -406.0, average rewards : -471.2432432432432
# Episode number 38, and it's corresponding return is -450.0, average rewards : -470.6842105263158
# Episode number 39, and it's corresponding return is -408.0, average rewards : -469.0769230769231
# Episode number 40, and it's corresponding return is -500.0, average rewards : -469.85
# Episode number 41, and it's corresponding return is -270.0, average rewards : -464.9756097560976
# Episode number 42, and it's corresponding return is -500.0, average rewards : -465.8095238095238
# Episode number 43, and it's corresponding return is -326.0, average rewards : -462.5581395348837
# Episode number 44, and it's corresponding return is -352.0, average rewards : -460.04545454545456
# Episode number 45, and it's corresponding return is -272.0, average rewards : -455.8666666666667
# Episode number 46, and it's corresponding return is -486.0, average rewards : -456.5217391304348
# Episode number 47, and it's corresponding return is -319.0, average rewards : -453.59574468085106
# Episode number 48, and it's corresponding return is -361.0, average rewards : -451.6666666666667
# Episode number 49, and it's corresponding return is -326.0, average rewards : -449.1020408163265
# Episode number 50, and it's corresponding return is -350.0, average rewards : -447.12
# Episode number 51, and it's corresponding return is -196.0, average rewards : -442.19607843137254
# Episode number 52, and it's corresponding return is -270.0, average rewards : -438.88461538461536
# Episode number 53, and it's corresponding return is -251.0, average rewards : -435.33962264150944
# Episode number 54, and it's corresponding return is -275.0, average rewards : -432.3703703703704
# Episode number 55, and it's corresponding return is -364.0, average rewards : -431.1272727272727
# Episode number 56, and it's corresponding return is -400.0, average rewards : -430.57142857142856
# Episode number 57, and it's corresponding return is -286.0, average rewards : -428.03508771929825
# Episode number 58, and it's corresponding return is -254.0, average rewards : -425.0344827586207
# Episode number 59, and it's corresponding return is -246.0, average rewards : -422.0
# Episode number 60, and it's corresponding return is -283.0, average rewards : -419.68333333333334
# Episode number 61, and it's corresponding return is -286.0, average rewards : -417.4918032786885
# Episode number 62, and it's corresponding return is -287.0, average rewards : -415.38709677419354
# Episode number 63, and it's corresponding return is -201.0, average rewards : -411.984126984127
# Episode number 64, and it's corresponding return is -208.0, average rewards : -408.796875
# Episode number 65, and it's corresponding return is -258.0, average rewards : -406.4769230769231
# Episode number 66, and it's corresponding return is -250.0, average rewards : -404.1060606060606
# Episode number 67, and it's corresponding return is -173.0, average rewards : -400.65671641791045
# Episode number 68, and it's corresponding return is -208.0, average rewards : -397.8235294117647
# Episode number 69, and it's corresponding return is -306.0, average rewards : -396.4927536231884
# Episode number 70, and it's corresponding return is -257.0, average rewards : -394.5
# Episode number 71, and it's corresponding return is -202.0, average rewards : -391.7887323943662
# Episode number 72, and it's corresponding return is -234.0, average rewards : -389.59722222222223
# Episode number 73, and it's corresponding return is -209.0, average rewards : -387.1232876712329
# Episode number 74, and it's corresponding return is -218.0, average rewards : -384.8378378378378
# Episode number 75, and it's corresponding return is -335.0, average rewards : -384.17333333333335
# Episode number 76, and it's corresponding return is -271.0, average rewards : -382.6842105263158
# Episode number 77, and it's corresponding return is -202.0, average rewards : -380.3376623376623
# Episode number 78, and it's corresponding return is -268.0, average rewards : -378.8974358974359
# Episode number 79, and it's corresponding return is -500.0, average rewards : -380.43037974683546
# Episode number 80, and it's corresponding return is -264.0, average rewards : -378.975
# Episode number 81, and it's corresponding return is -222.0, average rewards : -377.037037037037
# Episode number 82, and it's corresponding return is -192.0, average rewards : -374.780487804878
# Episode number 83, and it's corresponding return is -219.0, average rewards : -372.90361445783134
# Episode number 84, and it's corresponding return is -236.0, average rewards : -371.2738095238095
# Episode number 85, and it's corresponding return is -170.0, average rewards : -368.90588235294115
# Episode number 86, and it's corresponding return is -159.0, average rewards : -366.4651162790698
# Episode number 87, and it's corresponding return is -161.0, average rewards : -364.1034482758621
# Episode number 88, and it's corresponding return is -242.0, average rewards : -362.71590909090907
# Episode number 89, and it's corresponding return is -241.0, average rewards : -361.34831460674155
# Episode number 90, and it's corresponding return is -137.0, average rewards : -358.85555555555555
# Episode number 91, and it's corresponding return is -250.0, average rewards : -357.65934065934067
# Episode number 92, and it's corresponding return is -159.0, average rewards : -355.5
# Episode number 93, and it's corresponding return is -229.0, average rewards : -354.13978494623655
# Episode number 94, and it's corresponding return is -207.0, average rewards : -352.5744680851064
# Episode number 95, and it's corresponding return is -220.0, average rewards : -351.17894736842106
# Episode number 96, and it's corresponding return is -239.0, average rewards : -350.0104166666667
# Episode number 97, and it's corresponding return is -464.0, average rewards : -351.1855670103093
# Episode number 98, and it's corresponding return is -209.0, average rewards : -349.734693877551
# Episode number 99, and it's corresponding return is -179.0, average rewards : -348.010101010101
# Episode number 100, and it's corresponding return is -205.0, average rewards : -346.58
# Episode number 101, and it's corresponding return is -195.0, average rewards : -343.53
# Episode number 102, and it's corresponding return is -164.0, average rewards : -340.17
# Episode number 103, and it's corresponding return is -191.0, average rewards : -337.08
# Episode number 104, and it's corresponding return is -190.0, average rewards : -333.98
# Episode number 105, and it's corresponding return is -176.0, average rewards : -330.74
# Episode number 106, and it's corresponding return is -246.0, average rewards : -328.2
# Episode number 107, and it's corresponding return is -190.0, average rewards : -325.1
# Episode number 108, and it's corresponding return is -168.0, average rewards : -321.78
# Episode number 109, and it's corresponding return is -189.0, average rewards : -318.67
# Episode number 110, and it's corresponding return is -213.0, average rewards : -315.8
# Episode number 111, and it's corresponding return is -182.0, average rewards : -312.62
# Episode number 112, and it's corresponding return is -199.0, average rewards : -309.61
# Episode number 113, and it's corresponding return is -166.0, average rewards : -306.27
# Episode number 114, and it's corresponding return is -171.0, average rewards : -302.98
# Episode number 115, and it's corresponding return is -130.0, average rewards : -299.28
# Episode number 116, and it's corresponding return is -168.0, average rewards : -295.96
# Episode number 117, and it's corresponding return is -147.0, average rewards : -292.43
# Episode number 118, and it's corresponding return is -190.0, average rewards : -289.33
# Episode number 119, and it's corresponding return is -165.0, average rewards : -285.98
# Episode number 120, and it's corresponding return is -139.0, average rewards : -282.37
# Episode number 121, and it's corresponding return is -212.0, average rewards : -279.49
# Episode number 122, and it's corresponding return is -125.0, average rewards : -275.74
# Episode number 123, and it's corresponding return is -160.0, average rewards : -274.54
# Episode number 124, and it's corresponding return is -142.0, average rewards : -270.96
# Episode number 125, and it's corresponding return is -142.0, average rewards : -267.5
# Episode number 126, and it's corresponding return is -168.0, average rewards : -264.8
# Episode number 127, and it's corresponding return is -160.0, average rewards : -262.25
# Episode number 128, and it's corresponding return is -111.0, average rewards : -259.83
# Episode number 129, and it's corresponding return is -159.0, average rewards : -257.18
# Episode number 130, and it's corresponding return is -160.0, average rewards : -253.78
# Episode number 131, and it's corresponding return is -156.0, average rewards : -250.34
# Episode number 132, and it's corresponding return is -196.0, average rewards : -248.2
# Episode number 133, and it's corresponding return is -160.0, average rewards : -244.8
# Episode number 134, and it's corresponding return is -136.0, average rewards : -241.2
# Episode number 135, and it's corresponding return is -162.0, average rewards : -239.31
# Episode number 136, and it's corresponding return is -139.0, average rewards : -236.95
# Episode number 137, and it's corresponding return is -169.0, average rewards : -234.58
# Episode number 138, and it's corresponding return is -188.0, average rewards : -231.96
# Episode number 139, and it's corresponding return is -129.0, average rewards : -229.17
# Episode number 140, and it's corresponding return is -150.0, average rewards : -225.67
# Episode number 141, and it's corresponding return is -153.0, average rewards : -224.5
# Episode number 142, and it's corresponding return is -177.0, average rewards : -221.27
# Episode number 143, and it's corresponding return is -172.0, average rewards : -219.73
# Episode number 144, and it's corresponding return is -112.0, average rewards : -217.33
# Episode number 145, and it's corresponding return is -140.0, average rewards : -216.01
# Episode number 146, and it's corresponding return is -153.0, average rewards : -212.68
# Episode number 147, and it's corresponding return is -102.0, average rewards : -210.51
# Episode number 148, and it's corresponding return is -125.0, average rewards : -208.15
# Episode number 149, and it's corresponding return is -129.0, average rewards : -206.18
# Episode number 150, and it's corresponding return is -120.0, average rewards : -203.88
# Episode number 151, and it's corresponding return is -155.0, average rewards : -203.47
# Episode number 152, and it's corresponding return is -110.0, average rewards : -201.87
# Episode number 153, and it's corresponding return is -156.0, average rewards : -200.92
# Episode number 154, and it's corresponding return is -151.0, average rewards : -199.68
# Episode number 155, and it's corresponding return is -144.0, average rewards : -197.48
# Episode number 156, and it's corresponding return is -182.0, average rewards : -195.3
# Episode number 157, and it's corresponding return is -193.0, average rewards : -194.37
# Episode number 158, and it's corresponding return is -153.0, average rewards : -193.36
# Episode number 159, and it's corresponding return is -175.0, average rewards : -192.65
# Episode number 160, and it's corresponding return is -149.0, average rewards : -191.31
# Episode number 161, and it's corresponding return is -141.0, average rewards : -189.86
# Episode number 162, and it's corresponding return is -148.0, average rewards : -188.47
# Episode number 163, and it's corresponding return is -102.0, average rewards : -187.48
# Episode number 164, and it's corresponding return is -210.0, average rewards : -187.5
# Episode number 165, and it's corresponding return is -90.0, average rewards : -185.82
# Episode number 166, and it's corresponding return is -167.0, average rewards : -184.99
# Episode number 167, and it's corresponding return is -99.0, average rewards : -184.25
# Episode number 168, and it's corresponding return is -182.0, average rewards : -183.99
# Episode number 169, and it's corresponding return is -122.0, average rewards : -182.15
# Episode number 170, and it's corresponding return is -126.0, average rewards : -180.84
# Episode number 171, and it's corresponding return is -111.0, average rewards : -179.93
# Episode number 172, and it's corresponding return is -134.0, average rewards : -178.93
# Episode number 173, and it's corresponding return is -134.0, average rewards : -178.18
# Episode number 174, and it's corresponding return is -112.0, average rewards : -177.12
# Episode number 175, and it's corresponding return is -169.0, average rewards : -175.46
# Episode number 176, and it's corresponding return is -149.0, average rewards : -174.24
# Episode number 177, and it's corresponding return is -192.0, average rewards : -174.14
# Episode number 178, and it's corresponding return is -97.0, average rewards : -172.43
# Episode number 179, and it's corresponding return is -133.0, average rewards : -168.76
# Episode number 180, and it's corresponding return is -132.0, average rewards : -167.44
# Episode number 181, and it's corresponding return is -118.0, average rewards : -166.4
# Episode number 182, and it's corresponding return is -110.0, average rewards : -165.58
# Episode number 183, and it's corresponding return is -88.0, average rewards : -164.27
# Episode number 184, and it's corresponding return is -111.0, average rewards : -163.02
# Episode number 185, and it's corresponding return is -130.0, average rewards : -162.62
# Episode number 186, and it's corresponding return is -141.0, average rewards : -162.44
# Episode number 187, and it's corresponding return is -176.0, average rewards : -162.59
# Episode number 188, and it's corresponding return is -81.0, average rewards : -160.98
# Episode number 189, and it's corresponding return is -104.0, average rewards : -159.61
# Episode number 190, and it's corresponding return is -94.0, average rewards : -159.18
# Episode number 191, and it's corresponding return is -142.0, average rewards : -158.1
# Episode number 192, and it's corresponding return is -117.0, average rewards : -157.68
# Episode number 193, and it's corresponding return is -120.0, average rewards : -156.59
# Episode number 194, and it's corresponding return is -125.0, average rewards : -155.77
# Episode number 195, and it's corresponding return is -113.0, average rewards : -154.7
# Episode number 196, and it's corresponding return is -126.0, average rewards : -153.57
# Episode number 197, and it's corresponding return is -134.0, average rewards : -150.27
# Episode number 198, and it's corresponding return is -116.0, average rewards : -149.34
# Episode number 199, and it's corresponding return is -146.0, average rewards : -149.01
# Episode number 200, and it's corresponding return is -131.0, average rewards : -148.27
# Episode number 201, and it's corresponding return is -117.0, average rewards : -147.49
# Episode number 202, and it's corresponding return is -78.0, average rewards : -146.63
# Episode number 203, and it's corresponding return is -139.0, average rewards : -146.11
# Episode number 204, and it's corresponding return is -121.0, average rewards : -145.42
# Episode number 205, and it's corresponding return is -100.0, average rewards : -144.66
# Episode number 206, and it's corresponding return is -146.0, average rewards : -143.66
# Episode number 207, and it's corresponding return is -126.0, average rewards : -143.02
# Episode number 208, and it's corresponding return is -155.0, average rewards : -142.89
# Episode number 209, and it's corresponding return is -105.0, average rewards : -142.05
# Episode number 210, and it's corresponding return is -102.0, average rewards : -140.94
# Episode number 211, and it's corresponding return is -109.0, average rewards : -140.21
# Episode number 212, and it's corresponding return is -103.0, average rewards : -139.25
# Episode number 213, and it's corresponding return is -95.0, average rewards : -138.54
# Episode number 214, and it's corresponding return is -102.0, average rewards : -137.85
# Episode number 215, and it's corresponding return is -72.0, average rewards : -137.27
# Episode number 216, and it's corresponding return is -120.0, average rewards : -136.79
# Episode number 217, and it's corresponding return is -261.0, average rewards : -137.93
# Episode number 218, and it's corresponding return is -94.0, average rewards : -136.97
# Episode number 219, and it's corresponding return is -119.0, average rewards : -136.51
# Episode number 220, and it's corresponding return is -94.0, average rewards : -136.06
# Episode number 221, and it's corresponding return is -151.0, average rewards : -135.45
# Episode number 222, and it's corresponding return is -119.0, average rewards : -135.39
# Episode number 223, and it's corresponding return is -115.0, average rewards : -134.94
# Episode number 224, and it's corresponding return is -124.0, average rewards : -134.76
# Episode number 225, and it's corresponding return is -205.0, average rewards : -135.39
# Episode number 226, and it's corresponding return is -147.0, average rewards : -135.18
# Episode number 227, and it's corresponding return is -108.0, average rewards : -134.66
# Episode number 228, and it's corresponding return is -100.0, average rewards : -134.55
# Episode number 229, and it's corresponding return is -131.0, average rewards : -134.27
# Episode number 230, and it's corresponding return is -125.0, average rewards : -133.92
# Episode number 231, and it's corresponding return is -98.0, average rewards : -133.34
# Episode number 232, and it's corresponding return is -119.0, average rewards : -132.57
# Episode number 233, and it's corresponding return is -118.0, average rewards : -132.15
# Episode number 234, and it's corresponding return is -110.0, average rewards : -131.89
# Episode number 235, and it's corresponding return is -127.0, average rewards : -131.54
# Episode number 236, and it's corresponding return is -121.0, average rewards : -131.36
# Episode number 237, and it's corresponding return is -106.0, average rewards : -130.73
# Episode number 238, and it's corresponding return is -93.0, average rewards : -129.78
# Episode number 239, and it's corresponding return is -133.0, average rewards : -129.82
# Episode number 240, and it's corresponding return is -97.0, average rewards : -129.29
# Episode number 241, and it's corresponding return is -109.0, average rewards : -128.85
# Episode number 242, and it's corresponding return is -104.0, average rewards : -128.12
# Episode number 243, and it's corresponding return is -96.0, average rewards : -127.36
# Episode number 244, and it's corresponding return is -97.0, average rewards : -127.21
# Episode number 245, and it's corresponding return is -117.0, average rewards : -126.98
# Episode number 246, and it's corresponding return is -100.0, average rewards : -126.45
# Episode number 247, and it's corresponding return is -111.0, average rewards : -126.54
# Episode number 248, and it's corresponding return is -91.0, average rewards : -126.2
# Episode number 249, and it's corresponding return is -98.0, average rewards : -125.89
# Episode number 250, and it's corresponding return is -120.0, average rewards : -125.89
# Episode number 251, and it's corresponding return is -105.0, average rewards : -125.39
# Episode number 252, and it's corresponding return is -100.0, average rewards : -125.29
# Episode number 253, and it's corresponding return is -88.0, average rewards : -124.61
# Episode number 254, and it's corresponding return is -91.0, average rewards : -124.01
# Episode number 255, and it's corresponding return is -102.0, average rewards : -123.59
# Episode number 256, and it's corresponding return is -117.0, average rewards : -122.94
# Episode number 257, and it's corresponding return is -112.0, average rewards : -122.13
# Episode number 258, and it's corresponding return is -127.0, average rewards : -121.87
# Episode number 259, and it's corresponding return is -110.0, average rewards : -121.22
# Episode number 260, and it's corresponding return is -270.0, average rewards : -122.43
# Episode number 261, and it's corresponding return is -115.0, average rewards : -122.17
# Episode number 262, and it's corresponding return is -88.0, average rewards : -121.57
# Episode number 263, and it's corresponding return is -103.0, average rewards : -121.58
# Episode number 264, and it's corresponding return is -120.0, average rewards : -120.68
# Episode number 265, and it's corresponding return is -74.0, average rewards : -120.52
# Episode number 266, and it's corresponding return is -116.0, average rewards : -120.01
# Episode number 267, and it's corresponding return is -108.0, average rewards : -120.1
# Episode number 268, and it's corresponding return is -95.0, average rewards : -119.23
# Episode number 269, and it's corresponding return is -132.0, average rewards : -119.33
# Episode number 270, and it's corresponding return is -112.0, average rewards : -119.19
# Episode number 271, and it's corresponding return is -91.0, average rewards : -118.99
# Episode number 272, and it's corresponding return is -108.0, average rewards : -118.73
# Episode number 273, and it's corresponding return is -100.0, average rewards : -118.39
# Episode number 274, and it's corresponding return is -124.0, average rewards : -118.51
# Episode number 275, and it's corresponding return is -92.0, average rewards : -117.74
# Episode number 276, and it's corresponding return is -134.0, average rewards : -117.59
# Episode number 277, and it's corresponding return is -119.0, average rewards : -116.86
# Episode number 278, and it's corresponding return is -96.0, average rewards : -116.85
# Episode number 279, and it's corresponding return is -106.0, average rewards : -116.58
# Episode number 280, and it's corresponding return is -120.0, average rewards : -116.46
# Episode number 281, and it's corresponding return is -109.0, average rewards : -116.37
# Episode number 282, and it's corresponding return is -116.0, average rewards : -116.43
# Episode number 283, and it's corresponding return is -112.0, average rewards : -116.67
# Episode number 284, and it's corresponding return is -127.0, average rewards : -116.83
# Episode number 285, and it's corresponding return is -133.0, average rewards : -116.86
# Episode number 286, and it's corresponding return is -101.0, average rewards : -116.46
# Episode number 287, and it's corresponding return is -98.0, average rewards : -115.68
# Episode number 288, and it's corresponding return is -105.0, average rewards : -115.92
# Episode number 289, and it's corresponding return is -76.0, average rewards : -115.64
# Episode number 290, and it's corresponding return is -134.0, average rewards : -116.04
# Episode number 291, and it's corresponding return is -105.0, average rewards : -115.67
# Episode number 292, and it's corresponding return is -106.0, average rewards : -115.56
# Episode number 293, and it's corresponding return is -67.0, average rewards : -115.03
# Episode number 294, and it's corresponding return is -89.0, average rewards : -114.67
# Episode number 295, and it's corresponding return is -93.0, average rewards : -114.47
# Episode number 296, and it's corresponding return is -90.0, average rewards : -114.11
# Episode number 297, and it's corresponding return is -103.0, average rewards : -113.8
# Episode number 298, and it's corresponding return is -90.0, average rewards : -113.54
# Episode number 299, and it's corresponding return is -151.0, average rewards : -113.59
# Episode number 300, and it's corresponding return is -106.0, average rewards : -113.34
# Episode number 301, and it's corresponding return is -89.0, average rewards : -113.06
# Episode number 302, and it's corresponding return is -115.0, average rewards : -113.43
# Episode number 303, and it's corresponding return is -84.0, average rewards : -112.88
# Episode number 304, and it's corresponding return is -106.0, average rewards : -112.73
# Episode number 305, and it's corresponding return is -112.0, average rewards : -112.85
# Episode number 306, and it's corresponding return is -110.0, average rewards : -112.49
# Episode number 307, and it's corresponding return is -77.0, average rewards : -112.0
# Episode number 308, and it's corresponding return is -133.0, average rewards : -111.78
# Episode number 309, and it's corresponding return is -97.0, average rewards : -111.7
# Episode number 310, and it's corresponding return is -122.0, average rewards : -111.9
# Episode number 311, and it's corresponding return is -78.0, average rewards : -111.59
# Episode number 312, and it's corresponding return is -112.0, average rewards : -111.68
# Episode number 313, and it's corresponding return is -79.0, average rewards : -111.52
# Episode number 314, and it's corresponding return is -103.0, average rewards : -111.53
# Episode number 315, and it's corresponding return is -106.0, average rewards : -111.87
# Episode number 316, and it's corresponding return is -87.0, average rewards : -111.54
# Episode number 317, and it's corresponding return is -94.0, average rewards : -109.87
# Episode number 318, and it's corresponding return is -95.0, average rewards : -109.88
# Episode number 319, and it's corresponding return is -104.0, average rewards : -109.73
# Episode number 320, and it's corresponding return is -88.0, average rewards : -109.67
# Episode number 321, and it's corresponding return is -127.0, average rewards : -109.43
# Episode number 322, and it's corresponding return is -168.0, average rewards : -109.92
# Episode number 323, and it's corresponding return is -120.0, average rewards : -109.97
# Episode number 324, and it's corresponding return is -81.0, average rewards : -109.54
# Episode number 325, and it's corresponding return is -91.0, average rewards : -108.4
# Episode number 326, and it's corresponding return is -99.0, average rewards : -107.92
# Episode number 327, and it's corresponding return is -88.0, average rewards : -107.72
# Episode number 328, and it's corresponding return is -110.0, average rewards : -107.82
# Episode number 329, and it's corresponding return is -93.0, average rewards : -107.44
# Episode number 330, and it's corresponding return is -118.0, average rewards : -107.37
# Episode number 331, and it's corresponding return is -101.0, average rewards : -107.4
# Episode number 332, and it's corresponding return is -112.0, average rewards : -107.33
# Episode number 333, and it's corresponding return is -89.0, average rewards : -107.04
# Episode number 334, and it's corresponding return is -82.0, average rewards : -106.76
# Episode number 335, and it's corresponding return is -103.0, average rewards : -106.52
# Episode number 336, and it's corresponding return is -88.0, average rewards : -106.19
# Episode number 337, and it's corresponding return is -91.0, average rewards : -106.04
# Episode number 338, and it's corresponding return is -104.0, average rewards : -106.15
# Episode number 339, and it's corresponding return is -91.0, average rewards : -105.73
# Episode number 340, and it's corresponding return is -92.0, average rewards : -105.68
# Episode number 341, and it's corresponding return is -100.0, average rewards : -105.59
# Episode number 342, and it's corresponding return is -87.0, average rewards : -105.42
# Episode number 343, and it's corresponding return is -115.0, average rewards : -105.61
# Episode number 344, and it's corresponding return is -101.0, average rewards : -105.65
# Episode number 345, and it's corresponding return is -131.0, average rewards : -105.79
# Episode number 346, and it's corresponding return is -111.0, average rewards : -105.9
# Episode number 347, and it's corresponding return is -71.0, average rewards : -105.5
# Episode number 348, and it's corresponding return is -113.0, average rewards : -105.72
# Episode number 349, and it's corresponding return is -92.0, average rewards : -105.66
# Episode number 350, and it's corresponding return is -83.0, average rewards : -105.29
# Episode number 351, and it's corresponding return is -90.0, average rewards : -105.14
# Episode number 352, and it's corresponding return is -86.0, average rewards : -105.0
# Episode number 353, and it's corresponding return is -105.0, average rewards : -105.17
# Episode number 354, and it's corresponding return is -84.0, average rewards : -105.1
# Episode number 355, and it's corresponding return is -114.0, average rewards : -105.22
# Episode number 356, and it's corresponding return is -92.0, average rewards : -104.97
# Episode number 357, and it's corresponding return is -97.0, average rewards : -104.82
# Episode number 358, and it's corresponding return is -115.0, average rewards : -104.7
# Episode number 359, and it's corresponding return is -94.0, average rewards : -104.54
# Episode number 360, and it's corresponding return is -106.0, average rewards : -102.9
# Episode number 361, and it's corresponding return is -82.0, average rewards : -102.57
# Episode number 362, and it's corresponding return is -81.0, average rewards : -102.5
# Episode number 363, and it's corresponding return is -122.0, average rewards : -102.69
# Episode number 364, and it's corresponding return is -98.0, average rewards : -102.47
# Episode number 365, and it's corresponding return is -84.0, average rewards : -102.57
# Episode number 366, and it's corresponding return is -86.0, average rewards : -102.27
# Episode number 367, and it's corresponding return is -76.0, average rewards : -101.95
# Episode number 368, and it's corresponding return is -108.0, average rewards : -102.08
# Episode number 369, and it's corresponding return is -102.0, average rewards : -101.78
# Episode number 370, and it's corresponding return is -128.0, average rewards : -101.94
# Episode number 371, and it's corresponding return is -221.0, average rewards : -103.24
# Episode number 372, and it's corresponding return is -86.0, average rewards : -103.02
# Episode number 373, and it's corresponding return is -89.0, average rewards : -102.91
# Episode number 374, and it's corresponding return is -114.0, average rewards : -102.81
# Episode number 375, and it's corresponding return is -82.0, average rewards : -102.71
# Episode number 376, and it's corresponding return is -103.0, average rewards : -102.4
# Episode number 377, and it's corresponding return is -100.0, average rewards : -102.21
# Episode number 378, and it's corresponding return is -126.0, average rewards : -102.51
# Episode number 379, and it's corresponding return is -107.0, average rewards : -102.52
# Episode number 380, and it's corresponding return is -122.0, average rewards : -102.54
# Episode number 381, and it's corresponding return is -103.0, average rewards : -102.48
# Episode number 382, and it's corresponding return is -98.0, average rewards : -102.3
# Episode number 383, and it's corresponding return is -67.0, average rewards : -101.85
# Episode number 384, and it's corresponding return is -99.0, average rewards : -101.57
# Episode number 385, and it's corresponding return is -104.0, average rewards : -101.28
# Episode number 386, and it's corresponding return is -76.0, average rewards : -101.03
# Episode number 387, and it's corresponding return is -124.0, average rewards : -101.29
# Episode number 388, and it's corresponding return is -77.0, average rewards : -101.01
# Episode number 389, and it's corresponding return is -79.0, average rewards : -101.04
# Episode number 390, and it's corresponding return is -100.0, average rewards : -100.7
# Episode number 391, and it's corresponding return is -77.0, average rewards : -100.42
# Episode number 392, and it's corresponding return is -101.0, average rewards : -100.37
# Episode number 393, and it's corresponding return is -151.0, average rewards : -101.21
# Episode number 394, and it's corresponding return is -112.0, average rewards : -101.44
# Episode number 395, and it's corresponding return is -100.0, average rewards : -101.51
# Episode number 396, and it's corresponding return is -96.0, average rewards : -101.57
# Episode number 397, and it's corresponding return is -69.0, average rewards : -101.23
# Episode number 398, and it's corresponding return is -90.0, average rewards : -101.23
# Episode number 399, and it's corresponding return is -76.0, average rewards : -100.48
# Episode number 400, and it's corresponding return is -113.0, average rewards : -100.55
# Episode number 401, and it's corresponding return is -84.0, average rewards : -100.5
# Episode number 402, and it's corresponding return is -119.0, average rewards : -100.54
# Episode number 403, and it's corresponding return is -82.0, average rewards : -100.52
# Episode number 404, and it's corresponding return is -89.0, average rewards : -100.35
# Episode number 405, and it's corresponding return is -90.0, average rewards : -100.13
# Episode number 406, and it's corresponding return is -83.0, average rewards : -99.86
# Episode number 407, and it's corresponding return is -82.0, average rewards : -99.91
# Episode number 408, and it's corresponding return is -98.0, average rewards : -99.56
# Episode number 409, and it's corresponding return is -96.0, average rewards : -99.55
# Episode number 410, and it's corresponding return is -91.0, average rewards : -99.24
# Episode number 411, and it's corresponding return is -92.0, average rewards : -99.38
# Episode number 412, and it's corresponding return is -101.0, average rewards : -99.27
# Episode number 413, and it's corresponding return is -91.0, average rewards : -99.39
# Episode number 414, and it's corresponding return is -103.0, average rewards : -99.39
# Episode number 415, and it's corresponding return is -87.0, average rewards : -99.2
# Episode number 416, and it's corresponding return is -78.0, average rewards : -99.11
# Episode number 417, and it's corresponding return is -92.0, average rewards : -99.09
# Episode number 418, and it's corresponding return is -90.0, average rewards : -99.04
# Episode number 419, and it's corresponding return is -95.0, average rewards : -98.95
# Episode number 420, and it's corresponding return is -84.0, average rewards : -98.91
# Episode number 421, and it's corresponding return is -91.0, average rewards : -98.55
# Episode number 422, and it's corresponding return is -80.0, average rewards : -97.67
# Episode number 423, and it's corresponding return is -90.0, average rewards : -97.37
# Episode number 424, and it's corresponding return is -89.0, average rewards : -97.45
# Episode number 425, and it's corresponding return is -88.0, average rewards : -97.42
# Episode number 426, and it's corresponding return is -100.0, average rewards : -97.43
# Episode number 427, and it's corresponding return is -77.0, average rewards : -97.32
# Episode number 428, and it's corresponding return is -66.0, average rewards : -96.88
# Episode number 429, and it's corresponding return is -90.0, average rewards : -96.85
# Episode number 430, and it's corresponding return is -63.0, average rewards : -96.3
# Episode number 431, and it's corresponding return is -103.0, average rewards : -96.32
# Episode number 432, and it's corresponding return is -96.0, average rewards : -96.16
# Episode number 433, and it's corresponding return is -86.0, average rewards : -96.13
# Episode number 434, and it's corresponding return is -67.0, average rewards : -95.98
# Episode number 435, and it's corresponding return is -86.0, average rewards : -95.81
# Episode number 436, and it's corresponding return is -80.0, average rewards : -95.73
# Episode number 437, and it's corresponding return is -101.0, average rewards : -95.83
# Episode number 438, and it's corresponding return is -94.0, average rewards : -95.73
# Episode number 439, and it's corresponding return is -90.0, average rewards : -95.72
# Episode number 440, and it's corresponding return is -112.0, average rewards : -95.92
# Episode number 441, and it's corresponding return is -117.0, average rewards : -96.09
# Episode number 442, and it's corresponding return is -101.0, average rewards : -96.23
# Episode number 443, and it's corresponding return is -77.0, average rewards : -95.85
# Episode number 444, and it's corresponding return is -105.0, average rewards : -95.89
# Episode number 445, and it's corresponding return is -91.0, average rewards : -95.49
# Episode number 446, and it's corresponding return is -84.0, average rewards : -95.22
# Episode number 447, and it's corresponding return is -73.0, average rewards : -95.24
# Episode number 448, and it's corresponding return is -109.0, average rewards : -95.2
# Episode number 449, and it's corresponding return is -84.0, average rewards : -95.12
# Episode number 450, and it's corresponding return is -103.0, average rewards : -95.32
# Episode number 451, and it's corresponding return is -112.0, average rewards : -95.54
# Episode number 452, and it's corresponding return is -106.0, average rewards : -95.74
# Episode number 453, and it's corresponding return is -91.0, average rewards : -95.6
# Episode number 454, and it's corresponding return is -78.0, average rewards : -95.54
# Episode number 455, and it's corresponding return is -89.0, average rewards : -95.29
# Episode number 456, and it's corresponding return is -92.0, average rewards : -95.29
# Episode number 457, and it's corresponding return is -128.0, average rewards : -95.6
# Episode number 458, and it's corresponding return is -95.0, average rewards : -95.4
# Episode number 459, and it's corresponding return is -99.0, average rewards : -95.45
# Episode number 460, and it's corresponding return is -93.0, average rewards : -95.32
# Episode number 461, and it's corresponding return is -76.0, average rewards : -95.26
# Episode number 462, and it's corresponding return is -105.0, average rewards : -95.5
# Episode number 463, and it's corresponding return is -93.0, average rewards : -95.21
# Episode number 464, and it's corresponding return is -116.0, average rewards : -95.39
# Episode number 465, and it's corresponding return is -92.0, average rewards : -95.47
# Episode number 466, and it's corresponding return is -63.0, average rewards : -95.24
# Episode number 467, and it's corresponding return is -93.0, average rewards : -95.41
# Episode number 468, and it's corresponding return is -94.0, average rewards : -95.27
# Episode number 469, and it's corresponding return is -133.0, average rewards : -95.58
# Episode number 470, and it's corresponding return is -95.0, average rewards : -95.25
# Episode number 471, and it's corresponding return is -87.0, average rewards : -93.91
# Episode number 472, and it's corresponding return is -104.0, average rewards : -94.09
# Episode number 473, and it's corresponding return is -85.0, average rewards : -94.05
# Episode number 474, and it's corresponding return is -108.0, average rewards : -93.99
# Episode number 475, and it's corresponding return is -82.0, average rewards : -93.99
# Episode number 476, and it's corresponding return is -90.0, average rewards : -93.86
# Episode number 477, and it's corresponding return is -101.0, average rewards : -93.87
# Episode number 478, and it's corresponding return is -89.0, average rewards : -93.5
# Episode number 479, and it's corresponding return is -79.0, average rewards : -93.22
# Episode number 480, and it's corresponding return is -150.0, average rewards : -93.5
# Episode number 481, and it's corresponding return is -69.0, average rewards : -93.16
# Episode number 482, and it's corresponding return is -94.0, average rewards : -93.12
# Episode number 483, and it's corresponding return is -89.0, average rewards : -93.34
# Episode number 484, and it's corresponding return is -109.0, average rewards : -93.44
# Episode number 485, and it's corresponding return is -82.0, average rewards : -93.22
# Episode number 486, and it's corresponding return is -74.0, average rewards : -93.2
# Episode number 487, and it's corresponding return is -114.0, average rewards : -93.1
# Episode number 488, and it's corresponding return is -106.0, average rewards : -93.39
# Episode number 489, and it's corresponding return is -90.0, average rewards : -93.5
# Episode number 490, and it's corresponding return is -140.0, average rewards : -93.9
# Episode number 491, and it's corresponding return is -137.0, average rewards : -94.5
# Episode number 492, and it's corresponding return is -97.0, average rewards : -94.46
# Episode number 493, and it's corresponding return is -74.0, average rewards : -93.69
# Episode number 494, and it's corresponding return is -84.0, average rewards : -93.41
# Episode number 495, and it's corresponding return is -97.0, average rewards : -93.38
# Episode number 496, and it's corresponding return is -70.0, average rewards : -93.12
# Episode number 497, and it's corresponding return is -102.0, average rewards : -93.45
# Episode number 498, and it's corresponding return is -89.0, average rewards : -93.44
# Episode number 499, and it's corresponding return is -74.0, average rewards : -93.42
# Episode number 500, and it's corresponding return is -82.0, average rewards : -93.11
# Episode number 501, and it's corresponding return is -91.0, average rewards : -93.18
# Episode number 502, and it's corresponding return is -78.0, average rewards : -92.77
# Episode number 503, and it's corresponding return is -85.0, average rewards : -92.8
# Episode number 504, and it's corresponding return is -79.0, average rewards : -92.7
# Episode number 505, and it's corresponding return is -84.0, average rewards : -92.64
# Episode number 506, and it's corresponding return is -90.0, average rewards : -92.71
# Episode number 507, and it's corresponding return is -91.0, average rewards : -92.8
# Episode number 508, and it's corresponding return is -78.0, average rewards : -92.6
# Episode number 509, and it's corresponding return is -86.0, average rewards : -92.5
# Episode number 510, and it's corresponding return is -75.0, average rewards : -92.34
# Episode number 511, and it's corresponding return is -101.0, average rewards : -92.43
# Episode number 512, and it's corresponding return is -69.0, average rewards : -92.11
# Episode number 513, and it's corresponding return is -82.0, average rewards : -92.02
# Episode number 514, and it's corresponding return is -105.0, average rewards : -92.04
# Episode number 515, and it's corresponding return is -93.0, average rewards : -92.1
# Episode number 516, and it's corresponding return is -82.0, average rewards : -92.14
# Episode number 517, and it's corresponding return is -98.0, average rewards : -92.2
# Episode number 518, and it's corresponding return is -70.0, average rewards : -92.0
# Episode number 519, and it's corresponding return is -62.0, average rewards : -91.67
# Episode number 520, and it's corresponding return is -92.0, average rewards : -91.75
# Episode number 521, and it's corresponding return is -79.0, average rewards : -91.63
# Episode number 522, and it's corresponding return is -63.0, average rewards : -91.46
# Episode number 523, and it's corresponding return is -85.0, average rewards : -91.41
# Episode number 524, and it's corresponding return is -103.0, average rewards : -91.55
# Episode number 525, and it's corresponding return is -81.0, average rewards : -91.48
# Episode number 526, and it's corresponding return is -99.0, average rewards : -91.47
# Episode number 527, and it's corresponding return is -107.0, average rewards : -91.77
# Episode number 528, and it's corresponding return is -70.0, average rewards : -91.81
# Episode number 529, and it's corresponding return is -84.0, average rewards : -91.75
# Episode number 530, and it's corresponding return is -62.0, average rewards : -91.74
# Episode number 531, and it's corresponding return is -101.0, average rewards : -91.72
# Episode number 532, and it's corresponding return is -68.0, average rewards : -91.44
# Episode number 533, and it's corresponding return is -83.0, average rewards : -91.41
# Episode number 534, and it's corresponding return is -76.0, average rewards : -91.5
# Episode number 535, and it's corresponding return is -109.0, average rewards : -91.73
# Episode number 536, and it's corresponding return is -89.0, average rewards : -91.82
# Episode number 537, and it's corresponding return is -90.0, average rewards : -91.71
# Episode number 538, and it's corresponding return is -86.0, average rewards : -91.63
# Episode number 539, and it's corresponding return is -96.0, average rewards : -91.69
# Episode number 540, and it's corresponding return is -69.0, average rewards : -91.26
# Episode number 541, and it's corresponding return is -109.0, average rewards : -91.18
# Episode number 542, and it's corresponding return is -90.0, average rewards : -91.07
# Episode number 543, and it's corresponding return is -78.0, average rewards : -91.08
# Episode number 544, and it's corresponding return is -73.0, average rewards : -90.76
# Episode number 545, and it's corresponding return is -105.0, average rewards : -90.9
# Episode number 546, and it's corresponding return is -84.0, average rewards : -90.9
# Episode number 547, and it's corresponding return is -78.0, average rewards : -90.95
# Episode number 548, and it's corresponding return is -144.0, average rewards : -91.3
# ...
# Episode number 814, and it's corresponding return is -173.0, average rewards : -85.35
# Episode number 815, and it's corresponding return is -70.0, average rewards : -85.35
# Episode number 816, and it's corresponding return is -84.0, average rewards : -85.42
# Episode number 817, and it's corresponding return is -96.0, average rewards : -85.6
# Episode number 818, and it's corresponding return is -77.0, average rewards : -85.62
# Episode number 819, and it's corresponding return is -71.0, average rewards : -85.65
# Episode number 820, and it's corresponding return is -69.0, average rewards : -85.5
# Episode number 821, and it's corresponding return is -97.0, average rewards : -85.8
# Episode number 822, and it's corresponding return is -70.0, average rewards : -85.8
# Episode number 823, and it's corresponding return is -70.0, average rewards : -85.6
# Episode number 824, and it's corresponding return is -76.0, average rewards : -85.26
# Episode number 825, and it's corresponding return is -76.0, average rewards : -85.17
# Episode number 826, and it's corresponding return is -62.0, average rewards : -84.88
# Episode number 827, and it's corresponding return is -78.0, average rewards : -84.87
# Episode number 828, and it's corresponding return is -78.0, average rewards : -84.97
# Episode number 829, and it's corresponding return is -76.0, average rewards : -84.82
# Episode number 830, and it's corresponding return is -146.0, average rewards : -85.52
# Episode number 831, and it's corresponding return is -119.0, average rewards : -85.87
# Episode number 832, and it's corresponding return is -94.0, average rewards : -86.15
# Episode number 833, and it's corresponding return is -82.0, average rewards : -85.95
# Episode number 834, and it's corresponding return is -95.0, average rewards : -85.92
# Episode number 835, and it's corresponding return is -107.0, average rewards : -86.3
# Episode number 836, and it's corresponding return is -78.0, average rewards : -86.14
# Episode number 837, and it's corresponding return is -75.0, average rewards : -86.02
# Episode number 838, and it's corresponding return is -69.0, average rewards : -86.03
# Episode number 839, and it's corresponding return is -76.0, average rewards : -86.11
# Episode number 840, and it's corresponding return is -76.0, average rewards : -86.19
# Episode number 841, and it's corresponding return is -108.0, average rewards : -86.6
# Episode number 842, and it's corresponding return is -74.0, average rewards : -86.28
# Episode number 843, and it's corresponding return is -76.0, average rewards : -86.01
# Episode number 844, and it's corresponding return is -96.0, average rewards : -86.15
# Episode number 845, and it's corresponding return is -105.0, average rewards : -86.52
# Episode number 846, and it's corresponding return is -93.0, average rewards : -86.7
# Episode number 847, and it's corresponding return is -93.0, average rewards : -86.92
# Episode number 848, and it's corresponding return is -70.0, average rewards : -86.77
# Episode number 849, and it's corresponding return is -84.0, average rewards : -86.8
# Episode number 850, and it's corresponding return is -95.0, average rewards : -86.82
# Episode number 851, and it's corresponding return is -69.0, average rewards : -86.54
# Episode number 852, and it's corresponding return is -90.0, average rewards : -86.46
# Episode number 853, and it's corresponding return is -70.0, average rewards : -86.26
# Episode number 854, and it's corresponding return is -93.0, average rewards : -86.3
# Episode number 855, and it's corresponding return is -77.0, average rewards : -86.14
# Episode number 856, and it's corresponding return is -76.0, average rewards : -86.15
# Episode number 857, and it's corresponding return is -70.0, average rewards : -86.16
# Episode number 858, and it's corresponding return is -83.0, average rewards : -85.83
# Episode number 859, and it's corresponding return is -94.0, average rewards : -85.98
# Episode number 860, and it's corresponding return is -63.0, average rewards : -85.76
# Episode number 861, and it's corresponding return is -100.0, average rewards : -86.07
# Episode number 862, and it's corresponding return is -153.0, average rewards : -86.9
# Episode number 863, and it's corresponding return is -69.0, average rewards : -86.93
# Episode number 864, and it's corresponding return is -76.0, average rewards : -86.93
# Episode number 865, and it's corresponding return is -94.0, average rewards : -87.11
# Episode number 866, and it's corresponding return is -79.0, average rewards : -87.2
# Episode number 867, and it's corresponding return is -128.0, average rewards : -87.7
# Episode number 868, and it's corresponding return is -77.0, average rewards : -87.6
# Episode number 869, and it's corresponding return is -77.0, average rewards : -87.43
# Episode number 870, and it's corresponding return is -71.0, average rewards : -87.39
# Episode number 871, and it's corresponding return is -71.0, average rewards : -87.06
# Episode number 872, and it's corresponding return is -81.0, average rewards : -86.96
# Episode number 873, and it's corresponding return is -93.0, average rewards : -87.01
# Episode number 874, and it's corresponding return is -80.0, average rewards : -87.02
# Episode number 875, and it's corresponding return is -72.0, average rewards : -86.74
# Episode number 876, and it's corresponding return is -89.0, average rewards : -86.42
# Episode number 877, and it's corresponding return is -81.0, average rewards : -85.71
# Episode number 878, and it's corresponding return is -77.0, average rewards : -85.79
# Episode number 879, and it's corresponding return is -73.0, average rewards : -85.55
# Episode number 880, and it's corresponding return is -97.0, average rewards : -85.78
# Episode number 881, and it's corresponding return is -94.0, average rewards : -85.98
# Episode number 882, and it's corresponding return is -95.0, average rewards : -86.16
# Episode number 883, and it's corresponding return is -70.0, average rewards : -85.98
# Episode number 884, and it's corresponding return is -96.0, average rewards : -86.19
# Episode number 885, and it's corresponding return is -70.0, average rewards : -86.2
# Episode number 886, and it's corresponding return is -91.0, average rewards : -86.32
# Episode number 887, and it's corresponding return is -151.0, average rewards : -87.09
# Episode number 888, and it's corresponding return is -79.0, average rewards : -86.88
# Episode number 889, and it's corresponding return is -76.0, average rewards : -86.66
# Episode number 890, and it's corresponding return is -107.0, average rewards : -86.96
# Episode number 891, and it's corresponding return is -83.0, average rewards : -87.08
# Episode number 892, and it's corresponding return is -70.0, average rewards : -86.98
# Episode number 893, and it's corresponding return is -97.0, average rewards : -87.26
# Episode number 894, and it's corresponding return is -71.0, average rewards : -87.06
# Episode number 895, and it's corresponding return is -75.0, average rewards : -86.87
# Episode number 896, and it's corresponding return is -84.0, average rewards : -86.96
# Episode number 897, and it's corresponding return is -69.0, average rewards : -86.95
# Episode number 898, and it's corresponding return is -100.0, average rewards : -86.96
# Episode number 899, and it's corresponding return is -69.0, average rewards : -86.97
# Episode number 900, and it's corresponding return is -80.0, average rewards : -86.83
# Episode number 901, and it's corresponding return is -87.0, average rewards : -86.87
# Episode number 902, and it's corresponding return is -70.0, average rewards : -86.59
# Episode number 903, and it's corresponding return is -70.0, average rewards : -86.36
# Episode number 904, and it's corresponding return is -109.0, average rewards : -86.48
# Episode number 905, and it's corresponding return is -86.0, average rewards : -86.49
# Episode number 906, and it's corresponding return is -91.0, average rewards : -86.56
# Episode number 907, and it's corresponding return is -91.0, average rewards : -86.16
# Episode number 908, and it's corresponding return is -71.0, average rewards : -86.17
# Episode number 909, and it's corresponding return is -70.0, average rewards : -85.83
# Episode number 910, and it's corresponding return is -98.0, average rewards : -86.06
# Episode number 911, and it's corresponding return is -76.0, average rewards : -85.87
# Episode number 912, and it's corresponding return is -75.0, average rewards : -85.66
# Episode number 913, and it's corresponding return is -80.0, average rewards : -85.58
# Episode number 914, and it's corresponding return is -69.0, average rewards : -84.54
# Episode number 915, and it's corresponding return is -103.0, average rewards : -84.87
# Episode number 916, and it's corresponding return is -92.0, average rewards : -84.95
# Episode number 917, and it's corresponding return is -144.0, average rewards : -85.43
# Episode number 918, and it's corresponding return is -76.0, average rewards : -85.42
# Episode number 919, and it's corresponding return is -70.0, average rewards : -85.41
# Episode number 920, and it's corresponding return is -78.0, average rewards : -85.5
# Episode number 921, and it's corresponding return is -95.0, average rewards : -85.48
# Episode number 922, and it's corresponding return is -72.0, average rewards : -85.5
# Episode number 923, and it's corresponding return is -76.0, average rewards : -85.56
# Episode number 924, and it's corresponding return is -76.0, average rewards : -85.56
# Episode number 925, and it's corresponding return is -63.0, average rewards : -85.43
# Episode number 926, and it's corresponding return is -80.0, average rewards : -85.61
# Episode number 927, and it's corresponding return is -69.0, average rewards : -85.52
# Episode number 928, and it's corresponding return is -70.0, average rewards : -85.44
# Episode number 929, and it's corresponding return is -86.0, average rewards : -85.54
# Episode number 930, and it's corresponding return is -175.0, average rewards : -85.83
# Episode number 931, and it's corresponding return is -78.0, average rewards : -85.42
# Episode number 932, and it's corresponding return is -78.0, average rewards : -85.26
# Episode number 933, and it's corresponding return is -99.0, average rewards : -85.43
# Episode number 934, and it's corresponding return is -76.0, average rewards : -85.24
# Episode number 935, and it's corresponding return is -75.0, average rewards : -84.92
# Episode number 936, and it's corresponding return is -72.0, average rewards : -84.86
# Episode number 937, and it's corresponding return is -170.0, average rewards : -85.81
# Episode number 938, and it's corresponding return is -95.0, average rewards : -86.07
# Episode number 939, and it's corresponding return is -98.0, average rewards : -86.29
# Episode number 940, and it's corresponding return is -90.0, average rewards : -86.43
# Episode number 941, and it's corresponding return is -71.0, average rewards : -86.06
# Episode number 942, and it's corresponding return is -90.0, average rewards : -86.22
# Episode number 943, and it's corresponding return is -71.0, average rewards : -86.17
# Episode number 944, and it's corresponding return is -138.0, average rewards : -86.59
# Episode number 945, and it's corresponding return is -80.0, average rewards : -86.34
# Episode number 946, and it's corresponding return is -75.0, average rewards : -86.16
# Episode number 947, and it's corresponding return is -76.0, average rewards : -85.99
# Episode number 948, and it's corresponding return is -90.0, average rewards : -86.19
# Episode number 949, and it's corresponding return is -81.0, average rewards : -86.16
# Episode number 950, and it's corresponding return is -83.0, average rewards : -86.04
# Episode number 951, and it's corresponding return is -97.0, average rewards : -86.32
# Episode number 952, and it's corresponding return is -77.0, average rewards : -86.19
# Episode number 953, and it's corresponding return is -72.0, average rewards : -86.21
# Episode number 954, and it's corresponding return is -78.0, average rewards : -86.06
# Episode number 955, and it's corresponding return is -77.0, average rewards : -86.06
# Episode number 956, and it's corresponding return is -78.0, average rewards : -86.08
# Episode number 957, and it's corresponding return is -92.0, average rewards : -86.3
# Episode number 958, and it's corresponding return is -76.0, average rewards : -86.23
# Episode number 959, and it's corresponding return is -99.0, average rewards : -86.28
# Episode number 960, and it's corresponding return is -72.0, average rewards : -86.37
# Episode number 961, and it's corresponding return is -78.0, average rewards : -86.15
# Episode number 962, and it's corresponding return is -79.0, average rewards : -85.41
# Episode number 963, and it's corresponding return is -83.0, average rewards : -85.55
# Episode number 964, and it's corresponding return is -82.0, average rewards : -85.61
# Episode number 965, and it's corresponding return is -69.0, average rewards : -85.36
# Episode number 966, and it's corresponding return is -81.0, average rewards : -85.38
# Episode number 967, and it's corresponding return is -84.0, average rewards : -84.94
# Episode number 968, and it's corresponding return is -102.0, average rewards : -85.19
# Episode number 969, and it's corresponding return is -124.0, average rewards : -85.66
# Episode number 970, and it's corresponding return is -97.0, average rewards : -85.92
# Episode number 971, and it's corresponding return is -212.0, average rewards : -87.33
# Episode number 972, and it's corresponding return is -92.0, average rewards : -87.44
# Episode number 973, and it's corresponding return is -102.0, average rewards : -87.53
# Episode number 974, and it's corresponding return is -79.0, average rewards : -87.52
# Episode number 975, and it's corresponding return is -72.0, average rewards : -87.52
# Episode number 976, and it's corresponding return is -72.0, average rewards : -87.35
# Episode number 977, and it's corresponding return is -71.0, average rewards : -87.25
# Episode number 978, and it's corresponding return is -80.0, average rewards : -87.28
# Episode number 979, and it's corresponding return is -104.0, average rewards : -87.59
# Episode number 980, and it's corresponding return is -99.0, average rewards : -87.61
# Episode number 981, and it's corresponding return is -82.0, average rewards : -87.49
# Episode number 982, and it's corresponding return is -94.0, average rewards : -87.48
# Episode number 983, and it's corresponding return is -120.0, average rewards : -87.98
# Episode number 984, and it's corresponding return is -85.0, average rewards : -87.87
# Episode number 985, and it's corresponding return is -142.0, average rewards : -88.59
# Episode number 986, and it's corresponding return is -95.0, average rewards : -88.63
# Episode number 987, and it's corresponding return is -71.0, average rewards : -87.83
# Episode number 988, and it's corresponding return is -117.0, average rewards : -88.21
# Episode number 989, and it's corresponding return is -71.0, average rewards : -88.16
# Episode number 990, and it's corresponding return is -77.0, average rewards : -87.86
# Episode number 991, and it's corresponding return is -96.0, average rewards : -87.99
# Episode number 992, and it's corresponding return is -77.0, average rewards : -88.06
# Episode number 993, and it's corresponding return is -85.0, average rewards : -87.94
# Episode number 994, and it's corresponding return is -73.0, average rewards : -87.96
# Episode number 995, and it's corresponding return is -102.0, average rewards : -88.23
# Episode number 996, and it's corresponding return is -170.0, average rewards : -89.09
# Episode number 997, and it's corresponding return is -76.0, average rewards : -89.16
# Episode number 998, and it's corresponding return is -87.0, average rewards : -89.03
# Episode number 999, and it's corresponding return is -90.0, average rewards : -89.24
# 100%|██████████| 4/4 [34:24<00:00, 516.14s/it]
# Episode number 1000, and it's corresponding return is -201.0, average rewards : -90.45

# %%
print(f"The parameters and their corresponding regrets {dict_1_1}")
# Out:
# The parameters and their corresponding regrets {(128, 64): 121784.0, (64, 32): 120723.0, (32, 16): 126476.0, (16, 8): 126001.0}

# %%
print(f"The optimal parameters : {opt_par_1_1}")
# Out:
# The optimal parameters : (64, 32)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Parameters and their corresponding ID :
# - (128, 64) : 1
# - (64, 32) : 2
# - (32, 16) : 3
# - (16, 8) : 4

# %%
y = list(dict_1_1.values())
x = [1, 2, 3, 4]
plt.plot(x, y)
plt.title("Parameter's id vs their regret")
plt.xlabel("Parameter's id")
plt.ylabel("Regret")
plt.show()
