# %% [markdown]
# ### Importing Modules

# %%
import numpy as np
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from collections import namedtuple, deque
import datetime

import gym
from gym.wrappers.record_video import RecordVideo

import glob
import io
import base64

import matplotlib.pyplot as plt

# %% [markdown]
# ### Defining the two game environments

# %%
#Defining Environments

#Environment 2

env2 = gym.make("CartPole-v1")
env2.seed(0)

env2_state_shape = env2.observation_space.shape[0]
env2_no_of_actions = env2.action_space.n

env2_state = env2.reset()


# Note For both Environments
# For choosing actions :
# action = env.action_space.sample()

# For step :
# next_state, reward, done, info = env.step(action)
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(

# %% [markdown]
# ### Defining the two Neural networks required

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

BUFFER_SIZE = int(1e5)
BATCH_SIZE = 128
GAMMA = 0.99
LR = 5e-4
UPDATE_EVERY = 40

class QNetwork1(nn.Module):
  def __init__(self, state_size, action_size, seed, fc1_units = 64, fc2_units = 32):
    super(QNetwork1, self).__init__()
    self.seed = torch.manual_seed(seed)                                               # Making the initialization of weights the same all the time
    self.fc1 = nn.Linear(state_size, fc1_units)
    self.fc2 = nn.Linear(fc1_units, fc2_units)
    self.V = nn.Linear(fc2_units, 1)
    self.A = nn.Linear(fc2_units, action_size)

  def forward(self, state):
    x = F.relu(self.fc1(state))
    x = F.relu(self.fc2(x))
    V = self.V(x)
    A = self.A(x)
    return V + A - A.mean()

class QNetwork2(nn.Module):
  def __init__(self, state_size, action_size, seed, fc1_units = 64, fc2_units = 32):
    super(QNetwork2, self).__init__()
    self.seed = torch.manual_seed(seed)
    self.fc1 = nn.Linear(state_size, fc1_units)
    self.fc2 = nn.Linear(fc1_units, fc2_units)
    self.V = nn.Linear(fc2_units, 1)
    self.A = nn.Linear(fc2_units, action_size)

  def forward(self, state):
    x = F.relu(self.fc1(state))
    x = F.relu(self.fc2(x))
    V = self.V(x)
    A = self.A(x)
    return V + A - A.max()

# %% [markdown]
# ### Class for Replay buffer

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class ReplayBuffer:
  def __init__(self, action_size, buffer_size, batch_size, seed):
    self.action_size = action_size
    self.memory = deque(maxlen = buffer_size)                                                                       # Memory that stores experiences
    self.batch_size = batch_size                                                                                    # Stores batch size for sampling
    self.experience = namedtuple('Experience', field_names = ["state", "action", "reward", "next_state", "done"])   # Named Tuple that is used to store experience
    self.seed = random.seed(seed)

  def add(self, state, action, reward, next_state, done):                                                         # Function for adding experiences in memory
    e = self.experience(state, action, reward, next_state, done)
    self.memory.append(e)

  def sample(self):                                                                                               # Sampling experiences randomly
    experiences = random.sample(self.memory, k = self.batch_size)

    states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
    actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(device)
    rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
    next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
    dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)

    return (states, actions, rewards, next_states, dones)

  def __len__(self):
    return len(self.memory)

# %% [markdown]
# ### Defining tutorial agent, where it learns and acts according to the policy

# %%
class TutorialAgent():
  def __init__(self, state_size, action_size, seed, fc1_units, fc2_units, tau = 0.1, QNetwork = QNetwork1):
    self.state_size = state_size
    self.action_size = action_size
    self.seed = random.seed(seed)

    self.qnetwork_local = QNetwork(state_size, action_size, seed, fc1_units, fc2_units).to(device)                  # Local network
    self.qnetwork_target = QNetwork(state_size, action_size, seed, fc1_units, fc2_units).to(device)                 # Target network
    self.optimizer = optim.Adam(self.qnetwork_local.parameters(), lr = LR)

    self.memory = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, seed)         # To store experiences and sample

    self.t_step = 0                                                                # For maintaining a count of when to update Target Q network
    self.tau = tau                                                                 # Parameter for updating Target Q network using Polyak updation

  def step(self, state, action, reward, next_state, done):
    self.memory.add(state, action, reward, next_state, done)

    if len(self.memory) >= BATCH_SIZE:
      experiences = self.memory.sample()
      self.learn(experiences)

    self.t_step = (self.t_step + 1) % UPDATE_EVERY
    if self.t_step == 0:
      self.qnetwork_target.load_state_dict(self.qnetwork_local.state_dict())

  def act(self, state, eps = 0.0):
    state = torch.from_numpy(state).float().unsqueeze(0).to(device)                           # Conveting the numpy array to a torch tensor

    self.qnetwork_local.eval()                                                     # The model is set to evaluating
    with torch.no_grad():                                                          # Evaluation is done without taking gradients
      action_values = self.qnetwork_local(state)                                   # The Q values are obtained
    self.qnetwork_local.train()                                                    # The model is set to training

    if random.random() > eps:                                                      # Implementing of Epsilon greedy policy
      return np.argmax(action_values.cpu().data.numpy())
    else:
      return random.choice(np.arange(self.action_size))

  def learn(self, experiences):
    states, actions, rewards, next_states, dones = experiences
    Q_targets_next = self.qnetwork_target(next_states).detach().max(1)[0].unsqueeze(1)
    Q_targets = rewards + GAMMA * Q_targets_next * (1 - dones)
    Q_current = self.qnetwork_local(states).gather(1, actions)

    loss = F.mse_loss(Q_targets, Q_current)

    self.optimizer.zero_grad()
    loss.backward()

    for param in self.qnetwork_local.parameters():                                 # Gradient clipping
      param.grad.data.clamp_(-1, 1)                                                # For preventing exploding gradient situation

    self.optimizer.step()

# %% [markdown]
# ### A class for running Dueling DQN

# %%
class dueling_dqn:
  def __init__(self, fc1_units, fc2_units, env = env2, QNetwork = QNetwork1, tau = 0.1, seed = 0):
    self.env = env
    self.state_shape = env.observation_space.shape[0]
    self.action_space = env.action_space.n
    self.agent = TutorialAgent(self.state_shape, self.action_space, seed, fc1_units, fc2_units, tau = tau, QNetwork = QNetwork)

  def run(self, n_episodes = 500, max_t = 500, eps_start = 1.0, eps_end = 0.01, eps_decay = 0.995):
    returns = deque()
    scores = deque(maxlen = 100)
    eps = eps_start
    for i in range(1, n_episodes + 1):
      state = self.env.reset()
      ep_reward = 0
      rewards = deque()
      while True:
        action = self.agent.act(state, eps)
        next_state, reward, done, _ = self.env.step(action)
        self.agent.step(state, action, reward, next_state, done)
        state = next_state
        ep_reward += reward
        rewards.append(reward)

        if done:
          break
      eps = max(eps_end, eps_decay * eps)
      scores.append(ep_reward)
      R = 0
      for r in list(rewards):
        R = r + R
      print(f"Episode number {i}, and it's corresponding return is {R}, average rewards : {np.mean(scores)}")
      returns.append(R)
    return list(returns)

# %% [markdown]
# ### Tuning of Parameters
# - Tuned for Hidden Layer nodes (fc1_nodes, fc2_nodes) = (128, 64), (64, 32), (32, 16), (16, 8)

# %%
from tqdm import tqdm
def tuning(env = env2, QNetwork = QNetwork1):
    upper_limit = 500
    hyper_parameters = [(128, 64), (64, 32), (32, 16), (16, 8)]
    dictionary = {}
    for par in tqdm(hyper_parameters):
        tuning_Duel_DQN = dueling_dqn(fc1_units = par[0], fc2_units = par[1], QNetwork = QNetwork, seed = 0)
        returns = tuning_Duel_DQN.run()
        regret = [upper_limit - r for r in returns]
        dictionary[par] = np.sum(np.array(regret))
    return dictionary, min(dictionary.keys(), key = lambda x : dictionary[x]) # Returns the dictionary and the pair with minimum regret

# %%
dict_2_1, opt_par_2_1 = tuning()
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode number 1, and it's corresponding return is 14.0, average rewards : 14.0
# Episode number 2, and it's corresponding return is 18.0, average rewards : 16.0
# Episode number 3, and it's corresponding return is 11.0, average rewards : 14.333333333333334
# Episode number 4, and it's corresponding return is 21.0, average rewards : 16.0
# Episode number 5, and it's corresponding return is 18.0, average rewards : 16.4
# Episode number 6, and it's corresponding return is 32.0, average rewards : 19.0
# Episode number 7, and it's corresponding return is 14.0, average rewards : 18.285714285714285
# Episode number 8, and it's corresponding return is 22.0, average rewards : 18.75
# Episode number 9, and it's corresponding return is 18.0, average rewards : 18.666666666666668
# Episode number 10, and it's corresponding return is 26.0, average rewards : 19.4
# Episode number 11, and it's corresponding return is 26.0, average rewards : 20.0
# Episode number 12, and it's corresponding return is 16.0, average rewards : 19.666666666666668
# Episode number 13, and it's corresponding return is 10.0, average rewards : 18.923076923076923
# Episode number 14, and it's corresponding return is 13.0, average rewards : 18.5
# Episode number 15, and it's corresponding return is 16.0, average rewards : 18.333333333333332
# Episode number 16, and it's corresponding return is 41.0, average rewards : 19.75
# Episode number 17, and it's corresponding return is 20.0, average rewards : 19.764705882352942
# Episode number 18, and it's corresponding return is 25.0, average rewards : 20.055555555555557
# Episode number 19, and it's corresponding return is 41.0, average rewards : 21.157894736842106
# Episode number 20, and it's corresponding return is 12.0, average rewards : 20.7
# Episode number 21, and it's corresponding return is 19.0, average rewards : 20.61904761904762
# Episode number 22, and it's corresponding return is 11.0, average rewards : 20.181818181818183
# Episode number 23, and it's corresponding return is 21.0, average rewards : 20.217391304347824
# Episode number 24, and it's corresponding return is 15.0, average rewards : 20.0
# Episode number 25, and it's corresponding return is 15.0, average rewards : 19.8
# Episode number 26, and it's corresponding return is 12.0, average rewards : 19.5
# Episode number 27, and it's corresponding return is 34.0, average rewards : 20.037037037037038
# Episode number 28, and it's corresponding return is 15.0, average rewards : 19.857142857142858
# Episode number 29, and it's corresponding return is 9.0, average rewards : 19.482758620689655
# Episode number 30, and it's corresponding return is 28.0, average rewards : 19.766666666666666
# Episode number 31, and it's corresponding return is 47.0, average rewards : 20.64516129032258
# Episode number 32, and it's corresponding return is 24.0, average rewards : 20.75
# Episode number 33, and it's corresponding return is 13.0, average rewards : 20.515151515151516
# Episode number 34, and it's corresponding return is 11.0, average rewards : 20.235294117647058
# Episode number 35, and it's corresponding return is 25.0, average rewards : 20.37142857142857
# Episode number 36, and it's corresponding return is 21.0, average rewards : 20.38888888888889
# Episode number 37, and it's corresponding return is 18.0, average rewards : 20.324324324324323
# Episode number 38, and it's corresponding return is 34.0, average rewards : 20.68421052631579
# Episode number 39, and it's corresponding return is 39.0, average rewards : 21.153846153846153
# Episode number 40, and it's corresponding return is 15.0, average rewards : 21.0
# Episode number 41, and it's corresponding return is 29.0, average rewards : 21.195121951219512
# Episode number 42, and it's corresponding return is 23.0, average rewards : 21.238095238095237
# Episode number 43, and it's corresponding return is 30.0, average rewards : 21.441860465116278
# Episode number 44, and it's corresponding return is 58.0, average rewards : 22.272727272727273
# Episode number 45, and it's corresponding return is 41.0, average rewards : 22.68888888888889
# Episode number 46, and it's corresponding return is 78.0, average rewards : 23.891304347826086
# Episode number 47, and it's corresponding return is 21.0, average rewards : 23.829787234042552
# Episode number 48, and it's corresponding return is 18.0, average rewards : 23.708333333333332
# Episode number 49, and it's corresponding return is 65.0, average rewards : 24.551020408163264
# Episode number 50, and it's corresponding return is 45.0, average rewards : 24.96
# Episode number 51, and it's corresponding return is 49.0, average rewards : 25.431372549019606
# Episode number 52, and it's corresponding return is 67.0, average rewards : 26.23076923076923
# Episode number 53, and it's corresponding return is 11.0, average rewards : 25.943396226415093
# Episode number 54, and it's corresponding return is 19.0, average rewards : 25.814814814814813
# Episode number 55, and it's corresponding return is 47.0, average rewards : 26.2
# Episode number 56, and it's corresponding return is 33.0, average rewards : 26.321428571428573
# Episode number 57, and it's corresponding return is 21.0, average rewards : 26.228070175438596
# Episode number 58, and it's corresponding return is 40.0, average rewards : 26.46551724137931
# Episode number 59, and it's corresponding return is 86.0, average rewards : 27.47457627118644
# Episode number 60, and it's corresponding return is 50.0, average rewards : 27.85
# Episode number 61, and it's corresponding return is 61.0, average rewards : 28.39344262295082
# Episode number 62, and it's corresponding return is 91.0, average rewards : 29.403225806451612
# Episode number 63, and it's corresponding return is 16.0, average rewards : 29.19047619047619
# Episode number 64, and it's corresponding return is 35.0, average rewards : 29.28125
# Episode number 65, and it's corresponding return is 15.0, average rewards : 29.06153846153846
# Episode number 66, and it's corresponding return is 29.0, average rewards : 29.060606060606062
# Episode number 67, and it's corresponding return is 49.0, average rewards : 29.35820895522388
# Episode number 68, and it's corresponding return is 52.0, average rewards : 29.691176470588236
# Episode number 69, and it's corresponding return is 105.0, average rewards : 30.782608695652176
# Episode number 70, and it's corresponding return is 37.0, average rewards : 30.87142857142857
# Episode number 71, and it's corresponding return is 88.0, average rewards : 31.676056338028168
# Episode number 72, and it's corresponding return is 60.0, average rewards : 32.06944444444444
# Episode number 73, and it's corresponding return is 77.0, average rewards : 32.68493150684932
# Episode number 74, and it's corresponding return is 16.0, average rewards : 32.45945945945946
# Episode number 75, and it's corresponding return is 163.0, average rewards : 34.2
# Episode number 76, and it's corresponding return is 14.0, average rewards : 33.93421052631579
# Episode number 77, and it's corresponding return is 54.0, average rewards : 34.1948051948052
# Episode number 78, and it's corresponding return is 115.0, average rewards : 35.23076923076923
# Episode number 79, and it's corresponding return is 81.0, average rewards : 35.81012658227848
# Episode number 80, and it's corresponding return is 164.0, average rewards : 37.4125
# Episode number 81, and it's corresponding return is 43.0, average rewards : 37.48148148148148
# Episode number 82, and it's corresponding return is 54.0, average rewards : 37.68292682926829
# Episode number 83, and it's corresponding return is 26.0, average rewards : 37.54216867469879
# Episode number 84, and it's corresponding return is 99.0, average rewards : 38.273809523809526
# Episode number 85, and it's corresponding return is 57.0, average rewards : 38.49411764705882
# Episode number 86, and it's corresponding return is 84.0, average rewards : 39.02325581395349
# Episode number 87, and it's corresponding return is 70.0, average rewards : 39.37931034482759
# Episode number 88, and it's corresponding return is 111.0, average rewards : 40.19318181818182
# Episode number 89, and it's corresponding return is 23.0, average rewards : 40.0
# Episode number 90, and it's corresponding return is 49.0, average rewards : 40.1
# Episode number 91, and it's corresponding return is 107.0, average rewards : 40.83516483516483
# Episode number 92, and it's corresponding return is 38.0, average rewards : 40.80434782608695
# Episode number 93, and it's corresponding return is 54.0, average rewards : 40.946236559139784
# Episode number 94, and it's corresponding return is 14.0, average rewards : 40.659574468085104
# Episode number 95, and it's corresponding return is 76.0, average rewards : 41.03157894736842
# Episode number 96, and it's corresponding return is 25.0, average rewards : 40.864583333333336
# Episode number 97, and it's corresponding return is 119.0, average rewards : 41.670103092783506
# Episode number 98, and it's corresponding return is 108.0, average rewards : 42.3469387755102
# Episode number 99, and it's corresponding return is 117.0, average rewards : 43.101010101010104
# Episode number 100, and it's corresponding return is 52.0, average rewards : 43.19
# Episode number 101, and it's corresponding return is 127.0, average rewards : 44.32
# Episode number 102, and it's corresponding return is 132.0, average rewards : 45.46
# Episode number 103, and it's corresponding return is 224.0, average rewards : 47.59
# Episode number 104, and it's corresponding return is 48.0, average rewards : 47.86
# Episode number 105, and it's corresponding return is 28.0, average rewards : 47.96
# Episode number 106, and it's corresponding return is 22.0, average rewards : 47.86
# Episode number 107, and it's corresponding return is 55.0, average rewards : 48.27
# Episode number 108, and it's corresponding return is 95.0, average rewards : 49.0
# Episode number 109, and it's corresponding return is 111.0, average rewards : 49.93
# Episode number 110, and it's corresponding return is 52.0, average rewards : 50.19
# Episode number 111, and it's corresponding return is 90.0, average rewards : 50.83
# Episode number 112, and it's corresponding return is 24.0, average rewards : 50.91
# Episode number 113, and it's corresponding return is 87.0, average rewards : 51.68
# Episode number 114, and it's corresponding return is 67.0, average rewards : 52.22
# Episode number 115, and it's corresponding return is 50.0, average rewards : 52.56
# Episode number 116, and it's corresponding return is 222.0, average rewards : 54.37
# Episode number 117, and it's corresponding return is 193.0, average rewards : 56.1
# Episode number 118, and it's corresponding return is 80.0, average rewards : 56.65
# Episode number 119, and it's corresponding return is 141.0, average rewards : 57.65
# Episode number 120, and it's corresponding return is 138.0, average rewards : 58.91
# Episode number 121, and it's corresponding return is 172.0, average rewards : 60.44
# Episode number 122, and it's corresponding return is 103.0, average rewards : 61.36
# Episode number 123, and it's corresponding return is 157.0, average rewards : 62.72
# Episode number 124, and it's corresponding return is 14.0, average rewards : 62.71
# Episode number 125, and it's corresponding return is 86.0, average rewards : 63.42
# Episode number 126, and it's corresponding return is 131.0, average rewards : 64.61
# Episode number 127, and it's corresponding return is 179.0, average rewards : 66.06
# Episode number 128, and it's corresponding return is 115.0, average rewards : 67.06
# Episode number 129, and it's corresponding return is 166.0, average rewards : 68.63
# Episode number 130, and it's corresponding return is 103.0, average rewards : 69.38
# Episode number 131, and it's corresponding return is 95.0, average rewards : 69.86
# Episode number 132, and it's corresponding return is 113.0, average rewards : 70.75
# Episode number 133, and it's corresponding return is 258.0, average rewards : 73.2
# Episode number 134, and it's corresponding return is 195.0, average rewards : 75.04
# Episode number 135, and it's corresponding return is 173.0, average rewards : 76.52
# Episode number 136, and it's corresponding return is 112.0, average rewards : 77.43
# Episode number 137, and it's corresponding return is 49.0, average rewards : 77.74
# Episode number 138, and it's corresponding return is 256.0, average rewards : 79.96
# Episode number 139, and it's corresponding return is 180.0, average rewards : 81.37
# Episode number 140, and it's corresponding return is 19.0, average rewards : 81.41
# Episode number 141, and it's corresponding return is 31.0, average rewards : 81.43
# Episode number 142, and it's corresponding return is 76.0, average rewards : 81.96
# Episode number 143, and it's corresponding return is 122.0, average rewards : 82.88
# Episode number 144, and it's corresponding return is 54.0, average rewards : 82.84
# Episode number 145, and it's corresponding return is 142.0, average rewards : 83.85
# Episode number 146, and it's corresponding return is 31.0, average rewards : 83.38
# Episode number 147, and it's corresponding return is 180.0, average rewards : 84.97
# Episode number 148, and it's corresponding return is 23.0, average rewards : 85.02
# Episode number 149, and it's corresponding return is 156.0, average rewards : 85.93
# Episode number 150, and it's corresponding return is 71.0, average rewards : 86.19
# Episode number 151, and it's corresponding return is 225.0, average rewards : 87.95
# Episode number 152, and it's corresponding return is 215.0, average rewards : 89.43
# Episode number 153, and it's corresponding return is 138.0, average rewards : 90.7
# Episode number 154, and it's corresponding return is 121.0, average rewards : 91.72
# Episode number 155, and it's corresponding return is 15.0, average rewards : 91.4
# Episode number 156, and it's corresponding return is 188.0, average rewards : 92.95
# Episode number 157, and it's corresponding return is 82.0, average rewards : 93.56
# Episode number 158, and it's corresponding return is 68.0, average rewards : 93.84
# Episode number 159, and it's corresponding return is 195.0, average rewards : 94.93
# Episode number 160, and it's corresponding return is 167.0, average rewards : 96.1
# Episode number 161, and it's corresponding return is 204.0, average rewards : 97.53
# Episode number 162, and it's corresponding return is 66.0, average rewards : 97.28
# Episode number 163, and it's corresponding return is 151.0, average rewards : 98.63
# Episode number 164, and it's corresponding return is 55.0, average rewards : 98.83
# Episode number 165, and it's corresponding return is 60.0, average rewards : 99.28
# Episode number 166, and it's corresponding return is 142.0, average rewards : 100.41
# Episode number 167, and it's corresponding return is 21.0, average rewards : 100.13
# Episode number 168, and it's corresponding return is 185.0, average rewards : 101.46
# Episode number 169, and it's corresponding return is 205.0, average rewards : 102.46
# Episode number 170, and it's corresponding return is 158.0, average rewards : 103.67
# Episode number 171, and it's corresponding return is 106.0, average rewards : 103.85
# Episode number 172, and it's corresponding return is 184.0, average rewards : 105.09
# Episode number 173, and it's corresponding return is 324.0, average rewards : 107.56
# Episode number 174, and it's corresponding return is 177.0, average rewards : 109.17
# Episode number 175, and it's corresponding return is 201.0, average rewards : 109.55
# Episode number 176, and it's corresponding return is 129.0, average rewards : 110.7
# Episode number 177, and it's corresponding return is 36.0, average rewards : 110.52
# Episode number 178, and it's corresponding return is 140.0, average rewards : 110.77
# Episode number 179, and it's corresponding return is 37.0, average rewards : 110.33
# Episode number 180, and it's corresponding return is 65.0, average rewards : 109.34
# Episode number 181, and it's corresponding return is 167.0, average rewards : 110.58
# Episode number 182, and it's corresponding return is 146.0, average rewards : 111.5
# Episode number 183, and it's corresponding return is 129.0, average rewards : 112.53
# Episode number 184, and it's corresponding return is 118.0, average rewards : 112.72
# Episode number 185, and it's corresponding return is 39.0, average rewards : 112.54
# Episode number 186, and it's corresponding return is 189.0, average rewards : 113.59
# Episode number 187, and it's corresponding return is 230.0, average rewards : 115.19
# Episode number 188, and it's corresponding return is 169.0, average rewards : 115.77
# Episode number 189, and it's corresponding return is 230.0, average rewards : 117.84
# Episode number 190, and it's corresponding return is 195.0, average rewards : 119.3
# Episode number 191, and it's corresponding return is 151.0, average rewards : 119.74
# Episode number 192, and it's corresponding return is 49.0, average rewards : 119.85
# Episode number 193, and it's corresponding return is 92.0, average rewards : 120.23
# Episode number 194, and it's corresponding return is 157.0, average rewards : 121.66
# Episode number 195, and it's corresponding return is 236.0, average rewards : 123.26
# Episode number 196, and it's corresponding return is 224.0, average rewards : 125.25
# Episode number 197, and it's corresponding return is 164.0, average rewards : 125.7
# Episode number 198, and it's corresponding return is 135.0, average rewards : 125.97
# Episode number 199, and it's corresponding return is 87.0, average rewards : 125.67
# Episode number 200, and it's corresponding return is 164.0, average rewards : 126.79
# Episode number 201, and it's corresponding return is 188.0, average rewards : 127.4
# Episode number 202, and it's corresponding return is 203.0, average rewards : 128.11
# Episode number 203, and it's corresponding return is 287.0, average rewards : 128.74
# Episode number 204, and it's corresponding return is 67.0, average rewards : 128.93
# Episode number 205, and it's corresponding return is 188.0, average rewards : 130.53
# Episode number 206, and it's corresponding return is 255.0, average rewards : 132.86
# Episode number 207, and it's corresponding return is 181.0, average rewards : 134.12
# Episode number 208, and it's corresponding return is 167.0, average rewards : 134.84
# Episode number 209, and it's corresponding return is 166.0, average rewards : 135.39
# Episode number 210, and it's corresponding return is 195.0, average rewards : 136.82
# Episode number 211, and it's corresponding return is 262.0, average rewards : 138.54
# Episode number 212, and it's corresponding return is 94.0, average rewards : 139.24
# Episode number 213, and it's corresponding return is 146.0, average rewards : 139.83
# Episode number 214, and it's corresponding return is 199.0, average rewards : 141.15
# Episode number 215, and it's corresponding return is 135.0, average rewards : 142.0
# Episode number 216, and it's corresponding return is 176.0, average rewards : 141.54
# Episode number 217, and it's corresponding return is 166.0, average rewards : 141.27
# Episode number 218, and it's corresponding return is 198.0, average rewards : 142.45
# Episode number 219, and it's corresponding return is 25.0, average rewards : 141.29
# Episode number 220, and it's corresponding return is 142.0, average rewards : 141.33
# Episode number 221, and it's corresponding return is 277.0, average rewards : 142.38
# Episode number 222, and it's corresponding return is 232.0, average rewards : 143.67
# Episode number 223, and it's corresponding return is 207.0, average rewards : 144.17
# Episode number 224, and it's corresponding return is 161.0, average rewards : 145.64
# Episode number 225, and it's corresponding return is 162.0, average rewards : 146.4
# Episode number 226, and it's corresponding return is 196.0, average rewards : 147.05
# Episode number 227, and it's corresponding return is 288.0, average rewards : 148.14
# Episode number 228, and it's corresponding return is 164.0, average rewards : 148.63
# Episode number 229, and it's corresponding return is 179.0, average rewards : 148.76
# Episode number 230, and it's corresponding return is 187.0, average rewards : 149.6
# Episode number 231, and it's corresponding return is 263.0, average rewards : 151.28
# Episode number 232, and it's corresponding return is 147.0, average rewards : 151.62
# Episode number 233, and it's corresponding return is 161.0, average rewards : 150.65
# Episode number 234, and it's corresponding return is 178.0, average rewards : 150.48
# Episode number 235, and it's corresponding return is 165.0, average rewards : 150.4
# Episode number 236, and it's corresponding return is 274.0, average rewards : 152.02
# Episode number 237, and it's corresponding return is 170.0, average rewards : 153.23
# Episode number 238, and it's corresponding return is 224.0, average rewards : 152.91
# Episode number 239, and it's corresponding return is 234.0, average rewards : 153.45
# Episode number 240, and it's corresponding return is 190.0, average rewards : 155.16
# Episode number 241, and it's corresponding return is 92.0, average rewards : 155.77
# Episode number 242, and it's corresponding return is 274.0, average rewards : 157.75
# Episode number 243, and it's corresponding return is 329.0, average rewards : 159.82
# Episode number 244, and it's corresponding return is 175.0, average rewards : 161.03
# Episode number 245, and it's corresponding return is 149.0, average rewards : 161.1
# Episode number 246, and it's corresponding return is 307.0, average rewards : 163.86
# Episode number 247, and it's corresponding return is 258.0, average rewards : 164.64
# Episode number 248, and it's corresponding return is 257.0, average rewards : 166.98
# Episode number 249, and it's corresponding return is 186.0, average rewards : 167.28
# Episode number 250, and it's corresponding return is 257.0, average rewards : 169.14
# Episode number 251, and it's corresponding return is 325.0, average rewards : 170.14
# Episode number 252, and it's corresponding return is 148.0, average rewards : 169.47
# Episode number 253, and it's corresponding return is 190.0, average rewards : 169.99
# Episode number 254, and it's corresponding return is 330.0, average rewards : 172.08
# Episode number 255, and it's corresponding return is 203.0, average rewards : 173.96
# Episode number 256, and it's corresponding return is 169.0, average rewards : 173.77
# Episode number 257, and it's corresponding return is 21.0, average rewards : 173.16
# Episode number 258, and it's corresponding return is 261.0, average rewards : 175.09
# Episode number 259, and it's corresponding return is 227.0, average rewards : 175.41
# Episode number 260, and it's corresponding return is 147.0, average rewards : 175.21
# Episode number 261, and it's corresponding return is 231.0, average rewards : 175.48
# Episode number 262, and it's corresponding return is 163.0, average rewards : 176.45
# Episode number 263, and it's corresponding return is 349.0, average rewards : 178.43
# Episode number 264, and it's corresponding return is 205.0, average rewards : 179.93
# Episode number 265, and it's corresponding return is 252.0, average rewards : 181.85
# Episode number 266, and it's corresponding return is 181.0, average rewards : 182.24
# Episode number 267, and it's corresponding return is 356.0, average rewards : 185.59
# Episode number 268, and it's corresponding return is 216.0, average rewards : 185.9
# Episode number 269, and it's corresponding return is 231.0, average rewards : 186.16
# Episode number 270, and it's corresponding return is 315.0, average rewards : 187.73
# Episode number 271, and it's corresponding return is 355.0, average rewards : 190.22
# Episode number 272, and it's corresponding return is 247.0, average rewards : 190.85
# Episode number 273, and it's corresponding return is 202.0, average rewards : 189.63
# Episode number 274, and it's corresponding return is 195.0, average rewards : 189.81
# Episode number 275, and it's corresponding return is 150.0, average rewards : 189.3
# Episode number 276, and it's corresponding return is 428.0, average rewards : 192.29
# Episode number 277, and it's corresponding return is 229.0, average rewards : 194.22
# Episode number 278, and it's corresponding return is 353.0, average rewards : 196.35
# Episode number 279, and it's corresponding return is 471.0, average rewards : 200.69
# Episode number 280, and it's corresponding return is 321.0, average rewards : 203.25
# Episode number 281, and it's corresponding return is 313.0, average rewards : 204.71
# Episode number 282, and it's corresponding return is 500.0, average rewards : 208.25
# Episode number 283, and it's corresponding return is 337.0, average rewards : 210.33
# Episode number 284, and it's corresponding return is 244.0, average rewards : 211.59
# Episode number 285, and it's corresponding return is 313.0, average rewards : 214.33
# Episode number 286, and it's corresponding return is 236.0, average rewards : 214.8
# Episode number 287, and it's corresponding return is 423.0, average rewards : 216.73
# Episode number 288, and it's corresponding return is 485.0, average rewards : 219.89
# Episode number 289, and it's corresponding return is 297.0, average rewards : 220.56
# Episode number 290, and it's corresponding return is 347.0, average rewards : 222.08
# Episode number 291, and it's corresponding return is 334.0, average rewards : 223.91
# Episode number 292, and it's corresponding return is 301.0, average rewards : 226.43
# Episode number 293, and it's corresponding return is 386.0, average rewards : 229.37
# Episode number 294, and it's corresponding return is 500.0, average rewards : 232.8
# Episode number 295, and it's corresponding return is 407.0, average rewards : 234.51
# Episode number 296, and it's corresponding return is 500.0, average rewards : 237.27
# Episode number 297, and it's corresponding return is 452.0, average rewards : 240.15
# Episode number 298, and it's corresponding return is 428.0, average rewards : 243.08
# Episode number 299, and it's corresponding return is 500.0, average rewards : 247.21
# Episode number 300, and it's corresponding return is 500.0, average rewards : 250.57
# Episode number 301, and it's corresponding return is 500.0, average rewards : 253.69
# Episode number 302, and it's corresponding return is 500.0, average rewards : 256.66
# Episode number 303, and it's corresponding return is 329.0, average rewards : 257.08
# Episode number 304, and it's corresponding return is 500.0, average rewards : 261.41
# Episode number 305, and it's corresponding return is 500.0, average rewards : 264.53
# Episode number 306, and it's corresponding return is 500.0, average rewards : 266.98
# Episode number 307, and it's corresponding return is 98.0, average rewards : 266.15
# Episode number 308, and it's corresponding return is 500.0, average rewards : 269.48
# Episode number 309, and it's corresponding return is 500.0, average rewards : 272.82
# Episode number 310, and it's corresponding return is 500.0, average rewards : 275.87
# Episode number 311, and it's corresponding return is 500.0, average rewards : 278.25
# Episode number 312, and it's corresponding return is 500.0, average rewards : 282.31
# Episode number 313, and it's corresponding return is 500.0, average rewards : 285.85
# Episode number 314, and it's corresponding return is 500.0, average rewards : 288.86
# Episode number 315, and it's corresponding return is 500.0, average rewards : 292.51
# Episode number 316, and it's corresponding return is 500.0, average rewards : 295.75
# Episode number 317, and it's corresponding return is 500.0, average rewards : 299.09
# Episode number 318, and it's corresponding return is 500.0, average rewards : 302.11
# Episode number 319, and it's corresponding return is 500.0, average rewards : 306.86
# Episode number 320, and it's corresponding return is 500.0, average rewards : 310.44
# Episode number 321, and it's corresponding return is 500.0, average rewards : 312.67
# Episode number 322, and it's corresponding return is 500.0, average rewards : 315.35
# Episode number 323, and it's corresponding return is 500.0, average rewards : 318.28
# Episode number 324, and it's corresponding return is 500.0, average rewards : 321.67
# Episode number 325, and it's corresponding return is 500.0, average rewards : 325.05
# Episode number 326, and it's corresponding return is 500.0, average rewards : 328.09
# Episode number 327, and it's corresponding return is 500.0, average rewards : 330.21
# Episode number 328, and it's corresponding return is 500.0, average rewards : 333.57
# Episode number 329, and it's corresponding return is 500.0, average rewards : 336.78
# Episode number 330, and it's corresponding return is 500.0, average rewards : 339.91
# Episode number 331, and it's corresponding return is 500.0, average rewards : 342.28
# Episode number 332, and it's corresponding return is 500.0, average rewards : 345.81
# Episode number 333, and it's corresponding return is 228.0, average rewards : 346.48
# Episode number 334, and it's corresponding return is 500.0, average rewards : 349.7
# Episode number 335, and it's corresponding return is 500.0, average rewards : 353.05
# Episode number 336, and it's corresponding return is 500.0, average rewards : 355.31
# Episode number 337, and it's corresponding return is 500.0, average rewards : 358.61
# Episode number 338, and it's corresponding return is 500.0, average rewards : 361.37
# Episode number 339, and it's corresponding return is 500.0, average rewards : 364.03
# Episode number 340, and it's corresponding return is 500.0, average rewards : 367.13
# Episode number 341, and it's corresponding return is 500.0, average rewards : 371.21
# Episode number 342, and it's corresponding return is 500.0, average rewards : 373.47
# Episode number 343, and it's corresponding return is 500.0, average rewards : 375.18
# Episode number 344, and it's corresponding return is 500.0, average rewards : 378.43
# Episode number 345, and it's corresponding return is 17.0, average rewards : 377.11
# Episode number 346, and it's corresponding return is 500.0, average rewards : 379.04
# Episode number 347, and it's corresponding return is 11.0, average rewards : 376.57
# Episode number 348, and it's corresponding return is 11.0, average rewards : 374.11
# Episode number 349, and it's corresponding return is 12.0, average rewards : 372.37
# Episode number 350, and it's corresponding return is 12.0, average rewards : 369.92
# Episode number 351, and it's corresponding return is 12.0, average rewards : 366.79
# Episode number 352, and it's corresponding return is 12.0, average rewards : 365.43
# Episode number 353, and it's corresponding return is 11.0, average rewards : 363.64
# Episode number 354, and it's corresponding return is 11.0, average rewards : 360.45
# Episode number 355, and it's corresponding return is 11.0, average rewards : 358.53
# Episode number 356, and it's corresponding return is 12.0, average rewards : 356.96
# Episode number 357, and it's corresponding return is 13.0, average rewards : 356.88
# Episode number 358, and it's corresponding return is 10.0, average rewards : 354.37
# Episode number 359, and it's corresponding return is 11.0, average rewards : 352.21
# Episode number 360, and it's corresponding return is 12.0, average rewards : 350.86
# Episode number 361, and it's corresponding return is 11.0, average rewards : 348.66
# Episode number 362, and it's corresponding return is 16.0, average rewards : 347.19
# Episode number 363, and it's corresponding return is 11.0, average rewards : 343.81
# Episode number 364, and it's corresponding return is 11.0, average rewards : 341.87
# Episode number 365, and it's corresponding return is 11.0, average rewards : 339.46
# Episode number 366, and it's corresponding return is 10.0, average rewards : 337.75
# Episode number 367, and it's corresponding return is 10.0, average rewards : 334.29
# Episode number 368, and it's corresponding return is 11.0, average rewards : 332.24
# Episode number 369, and it's corresponding return is 10.0, average rewards : 330.03
# Episode number 370, and it's corresponding return is 10.0, average rewards : 326.98
# Episode number 371, and it's corresponding return is 13.0, average rewards : 323.56
# Episode number 372, and it's corresponding return is 11.0, average rewards : 321.2
# Episode number 373, and it's corresponding return is 10.0, average rewards : 319.28
# Episode number 374, and it's corresponding return is 11.0, average rewards : 317.44
# Episode number 375, and it's corresponding return is 12.0, average rewards : 316.06
# Episode number 376, and it's corresponding return is 10.0, average rewards : 311.88
# Episode number 377, and it's corresponding return is 10.0, average rewards : 309.69
# Episode number 378, and it's corresponding return is 14.0, average rewards : 306.3
# Episode number 379, and it's corresponding return is 11.0, average rewards : 301.7
# Episode number 380, and it's corresponding return is 11.0, average rewards : 298.6
# Episode number 381, and it's corresponding return is 11.0, average rewards : 295.58
# Episode number 382, and it's corresponding return is 10.0, average rewards : 290.68
# Episode number 383, and it's corresponding return is 10.0, average rewards : 287.41
# Episode number 384, and it's corresponding return is 11.0, average rewards : 285.08
# Episode number 385, and it's corresponding return is 9.0, average rewards : 282.04
# Episode number 386, and it's corresponding return is 10.0, average rewards : 279.78
# Episode number 387, and it's corresponding return is 11.0, average rewards : 275.66
# Episode number 388, and it's corresponding return is 9.0, average rewards : 270.9
# Episode number 389, and it's corresponding return is 11.0, average rewards : 268.04
# Episode number 390, and it's corresponding return is 11.0, average rewards : 264.68
# Episode number 391, and it's corresponding return is 15.0, average rewards : 261.49
# Episode number 392, and it's corresponding return is 9.0, average rewards : 258.57
# Episode number 393, and it's corresponding return is 10.0, average rewards : 254.81
# Episode number 394, and it's corresponding return is 10.0, average rewards : 249.91
# Episode number 395, and it's corresponding return is 11.0, average rewards : 245.95
# Episode number 396, and it's corresponding return is 10.0, average rewards : 241.05
# Episode number 397, and it's corresponding return is 10.0, average rewards : 236.63
# Episode number 398, and it's corresponding return is 10.0, average rewards : 232.45
# Episode number 399, and it's corresponding return is 13.0, average rewards : 227.58
# Episode number 400, and it's corresponding return is 11.0, average rewards : 222.69
# Episode number 401, and it's corresponding return is 11.0, average rewards : 217.8
# Episode number 402, and it's corresponding return is 10.0, average rewards : 212.9
# Episode number 403, and it's corresponding return is 12.0, average rewards : 209.73
# Episode number 404, and it's corresponding return is 13.0, average rewards : 204.86
# Episode number 405, and it's corresponding return is 12.0, average rewards : 199.98
# Episode number 406, and it's corresponding return is 13.0, average rewards : 195.11
# Episode number 407, and it's corresponding return is 10.0, average rewards : 194.23
# Episode number 408, and it's corresponding return is 12.0, average rewards : 189.35
# Episode number 409, and it's corresponding return is 11.0, average rewards : 184.46
# Episode number 410, and it's corresponding return is 11.0, average rewards : 179.57
# Episode number 411, and it's corresponding return is 11.0, average rewards : 174.68
# Episode number 412, and it's corresponding return is 12.0, average rewards : 169.8
# Episode number 413, and it's corresponding return is 11.0, average rewards : 164.91
# Episode number 414, and it's corresponding return is 10.0, average rewards : 160.01
# Episode number 415, and it's corresponding return is 11.0, average rewards : 155.12
# Episode number 416, and it's corresponding return is 14.0, average rewards : 150.26
# Episode number 417, and it's corresponding return is 10.0, average rewards : 145.36
# Episode number 418, and it's corresponding return is 9.0, average rewards : 140.45
# Episode number 419, and it's corresponding return is 11.0, average rewards : 135.56
# Episode number 420, and it's corresponding return is 10.0, average rewards : 130.66
# Episode number 421, and it's corresponding return is 11.0, average rewards : 125.77
# Episode number 422, and it's corresponding return is 9.0, average rewards : 120.86
# Episode number 423, and it's corresponding return is 15.0, average rewards : 116.01
# Episode number 424, and it's corresponding return is 9.0, average rewards : 111.1
# Episode number 425, and it's corresponding return is 11.0, average rewards : 106.21
# Episode number 426, and it's corresponding return is 12.0, average rewards : 101.33
# Episode number 427, and it's corresponding return is 11.0, average rewards : 96.44
# Episode number 428, and it's corresponding return is 9.0, average rewards : 91.53
# Episode number 429, and it's corresponding return is 10.0, average rewards : 86.63
# Episode number 430, and it's corresponding return is 9.0, average rewards : 81.72
# Episode number 431, and it's corresponding return is 13.0, average rewards : 76.85
# Episode number 432, and it's corresponding return is 9.0, average rewards : 71.94
# Episode number 433, and it's corresponding return is 12.0, average rewards : 69.78
# Episode number 434, and it's corresponding return is 11.0, average rewards : 64.89
# Episode number 435, and it's corresponding return is 11.0, average rewards : 60.0
# Episode number 436, and it's corresponding return is 11.0, average rewards : 55.11
# Episode number 437, and it's corresponding return is 10.0, average rewards : 50.21
# Episode number 438, and it's corresponding return is 11.0, average rewards : 45.32
# Episode number 439, and it's corresponding return is 11.0, average rewards : 40.43
# Episode number 440, and it's corresponding return is 10.0, average rewards : 35.53
# Episode number 441, and it's corresponding return is 13.0, average rewards : 30.66
# Episode number 442, and it's corresponding return is 12.0, average rewards : 25.78
# Episode number 443, and it's corresponding return is 10.0, average rewards : 20.88
# Episode number 444, and it's corresponding return is 12.0, average rewards : 16.0
# Episode number 445, and it's corresponding return is 13.0, average rewards : 15.96
# Episode number 446, and it's corresponding return is 11.0, average rewards : 11.07
# Episode number 447, and it's corresponding return is 10.0, average rewards : 11.06
# Episode number 448, and it's corresponding return is 11.0, average rewards : 11.06
# Episode number 449, and it's corresponding return is 11.0, average rewards : 11.05
# Episode number 450, and it's corresponding return is 11.0, average rewards : 11.04
# Episode number 451, and it's corresponding return is 17.0, average rewards : 11.09
# Episode number 452, and it's corresponding return is 10.0, average rewards : 11.07
# Episode number 453, and it's corresponding return is 11.0, average rewards : 11.07
# Episode number 454, and it's corresponding return is 10.0, average rewards : 11.06
# Episode number 455, and it's corresponding return is 10.0, average rewards : 11.05
# Episode number 456, and it's corresponding return is 11.0, average rewards : 11.04
# Episode number 457, and it's corresponding return is 14.0, average rewards : 11.05
# Episode number 458, and it's corresponding return is 13.0, average rewards : 11.08
# Episode number 459, and it's corresponding return is 11.0, average rewards : 11.08
# Episode number 460, and it's corresponding return is 12.0, average rewards : 11.08
# Episode number 461, and it's corresponding return is 11.0, average rewards : 11.08
# Episode number 462, and it's corresponding return is 12.0, average rewards : 11.04
# Episode number 463, and it's corresponding return is 10.0, average rewards : 11.03
# Episode number 464, and it's corresponding return is 10.0, average rewards : 11.02
# Episode number 465, and it's corresponding return is 11.0, average rewards : 11.02
# Episode number 466, and it's corresponding return is 12.0, average rewards : 11.04
# Episode number 467, and it's corresponding return is 12.0, average rewards : 11.06
# Episode number 468, and it's corresponding return is 13.0, average rewards : 11.08
# Episode number 469, and it's corresponding return is 11.0, average rewards : 11.09
# Episode number 470, and it's corresponding return is 13.0, average rewards : 11.12
# Episode number 471, and it's corresponding return is 15.0, average rewards : 11.14
# Episode number 472, and it's corresponding return is 13.0, average rewards : 11.16
# Episode number 473, and it's corresponding return is 12.0, average rewards : 11.18
# Episode number 474, and it's corresponding return is 14.0, average rewards : 11.21
# Episode number 475, and it's corresponding return is 11.0, average rewards : 11.2
# Episode number 476, and it's corresponding return is 13.0, average rewards : 11.23
# Episode number 477, and it's corresponding return is 14.0, average rewards : 11.27
# Episode number 478, and it's corresponding return is 14.0, average rewards : 11.27
# Episode number 479, and it's corresponding return is 15.0, average rewards : 11.31
# Episode number 480, and it's corresponding return is 18.0, average rewards : 11.38
# Episode number 481, and it's corresponding return is 17.0, average rewards : 11.44
# Episode number 482, and it's corresponding return is 18.0, average rewards : 11.52
# Episode number 483, and it's corresponding return is 19.0, average rewards : 11.61
# Episode number 484, and it's corresponding return is 500.0, average rewards : 16.5
# Episode number 485, and it's corresponding return is 500.0, average rewards : 21.41
# Episode number 486, and it's corresponding return is 500.0, average rewards : 26.31
# Episode number 487, and it's corresponding return is 500.0, average rewards : 31.2
# Episode number 488, and it's corresponding return is 500.0, average rewards : 36.11
# Episode number 489, and it's corresponding return is 500.0, average rewards : 41.0
# Episode number 490, and it's corresponding return is 500.0, average rewards : 45.89
# Episode number 491, and it's corresponding return is 500.0, average rewards : 50.74
# Episode number 492, and it's corresponding return is 500.0, average rewards : 55.65
# Episode number 493, and it's corresponding return is 500.0, average rewards : 60.55
# Episode number 494, and it's corresponding return is 500.0, average rewards : 65.45
# Episode number 495, and it's corresponding return is 500.0, average rewards : 70.34
# Episode number 496, and it's corresponding return is 500.0, average rewards : 75.24
# Episode number 497, and it's corresponding return is 426.0, average rewards : 79.4
# Episode number 498, and it's corresponding return is 274.0, average rewards : 82.04
# Episode number 499, and it's corresponding return is 12.0, average rewards : 82.03
#  25%|██▌       | 1/4 [07:11<21:34, 431.46s/it]
# Episode number 500, and it's corresponding return is 227.0, average rewards : 84.19
# Episode number 1, and it's corresponding return is 16.0, average rewards : 16.0
# Episode number 2, and it's corresponding return is 26.0, average rewards : 21.0
# Episode number 3, and it's corresponding return is 27.0, average rewards : 23.0
# Episode number 4, and it's corresponding return is 49.0, average rewards : 29.5
# Episode number 5, and it's corresponding return is 15.0, average rewards : 26.6
# Episode number 6, and it's corresponding return is 16.0, average rewards : 24.833333333333332
# Episode number 7, and it's corresponding return is 18.0, average rewards : 23.857142857142858
# Episode number 8, and it's corresponding return is 21.0, average rewards : 23.5
# Episode number 9, and it's corresponding return is 25.0, average rewards : 23.666666666666668
# Episode number 10, and it's corresponding return is 36.0, average rewards : 24.9
# Episode number 11, and it's corresponding return is 10.0, average rewards : 23.545454545454547
# Episode number 12, and it's corresponding return is 35.0, average rewards : 24.5
# Episode number 13, and it's corresponding return is 19.0, average rewards : 24.076923076923077
# Episode number 14, and it's corresponding return is 41.0, average rewards : 25.285714285714285
# Episode number 15, and it's corresponding return is 37.0, average rewards : 26.066666666666666
# Episode number 16, and it's corresponding return is 24.0, average rewards : 25.9375
# Episode number 17, and it's corresponding return is 30.0, average rewards : 26.176470588235293
# Episode number 18, and it's corresponding return is 17.0, average rewards : 25.666666666666668
# Episode number 19, and it's corresponding return is 11.0, average rewards : 24.894736842105264
# Episode number 20, and it's corresponding return is 20.0, average rewards : 24.65
# Episode number 21, and it's corresponding return is 10.0, average rewards : 23.952380952380953
# Episode number 22, and it's corresponding return is 19.0, average rewards : 23.727272727272727
# Episode number 23, and it's corresponding return is 17.0, average rewards : 23.434782608695652
# Episode number 24, and it's corresponding return is 16.0, average rewards : 23.125
# Episode number 25, and it's corresponding return is 24.0, average rewards : 23.16
# Episode number 26, and it's corresponding return is 15.0, average rewards : 22.846153846153847
# Episode number 27, and it's corresponding return is 29.0, average rewards : 23.074074074074073
# Episode number 28, and it's corresponding return is 15.0, average rewards : 22.785714285714285
# Episode number 29, and it's corresponding return is 22.0, average rewards : 22.75862068965517
# Episode number 30, and it's corresponding return is 22.0, average rewards : 22.733333333333334
# Episode number 31, and it's corresponding return is 11.0, average rewards : 22.35483870967742
# Episode number 32, and it's corresponding return is 30.0, average rewards : 22.59375
# Episode number 33, and it's corresponding return is 27.0, average rewards : 22.727272727272727
# Episode number 34, and it's corresponding return is 66.0, average rewards : 24.0
# Episode number 35, and it's corresponding return is 30.0, average rewards : 24.17142857142857
# Episode number 36, and it's corresponding return is 22.0, average rewards : 24.11111111111111
# Episode number 37, and it's corresponding return is 94.0, average rewards : 26.0
# Episode number 38, and it's corresponding return is 11.0, average rewards : 25.605263157894736
# Episode number 39, and it's corresponding return is 28.0, average rewards : 25.666666666666668
# Episode number 40, and it's corresponding return is 33.0, average rewards : 25.85
# Episode number 41, and it's corresponding return is 18.0, average rewards : 25.658536585365855
# Episode number 42, and it's corresponding return is 34.0, average rewards : 25.857142857142858
# Episode number 43, and it's corresponding return is 49.0, average rewards : 26.3953488372093
# Episode number 44, and it's corresponding return is 27.0, average rewards : 26.40909090909091
# Episode number 45, and it's corresponding return is 28.0, average rewards : 26.444444444444443
# Episode number 46, and it's corresponding return is 55.0, average rewards : 27.065217391304348
# Episode number 47, and it's corresponding return is 11.0, average rewards : 26.72340425531915
# Episode number 48, and it's corresponding return is 59.0, average rewards : 27.395833333333332
# Episode number 49, and it's corresponding return is 48.0, average rewards : 27.816326530612244
# Episode number 50, and it's corresponding return is 15.0, average rewards : 27.56
# Episode number 51, and it's corresponding return is 12.0, average rewards : 27.254901960784313
# Episode number 52, and it's corresponding return is 43.0, average rewards : 27.557692307692307
# Episode number 53, and it's corresponding return is 58.0, average rewards : 28.132075471698112
# Episode number 54, and it's corresponding return is 25.0, average rewards : 28.074074074074073
# ...
# Episode number 311, and it's corresponding return is 205.0, average rewards : 141.49
# Episode number 312, and it's corresponding return is 96.0, average rewards : 141.93
# Episode number 313, and it's corresponding return is 93.0, average rewards : 141.41
# Episode number 314, and it's corresponding return is 197.0, average rewards : 142.46
# Episode number 315, and it's corresponding return is 188.0, average rewards : 143.29
# Episode number 316, and it's corresponding return is 209.0, average rewards : 144.74
# Episode number 317, and it's corresponding return is 160.0, average rewards : 145.42
# Episode number 318, and it's corresponding return is 143.0, average rewards : 145.98
# Episode number 319, and it's corresponding return is 146.0, average rewards : 146.86
# Episode number 320, and it's corresponding return is 153.0, average rewards : 147.42
# Episode number 321, and it's corresponding return is 154.0, average rewards : 148.3
# Episode number 322, and it's corresponding return is 152.0, average rewards : 149.24
# Episode number 323, and it's corresponding return is 156.0, average rewards : 150.04
# Episode number 324, and it's corresponding return is 126.0, average rewards : 150.05
# Episode number 325, and it's corresponding return is 145.0, average rewards : 150.66
# Episode number 326, and it's corresponding return is 147.0, average rewards : 151.83
# Episode number 327, and it's corresponding return is 159.0, average rewards : 152.3
# Episode number 328, and it's corresponding return is 143.0, average rewards : 151.98
# Episode number 329, and it's corresponding return is 131.0, average rewards : 152.43
# Episode number 330, and it's corresponding return is 151.0, average rewards : 153.05
# Episode number 331, and it's corresponding return is 162.0, average rewards : 153.65
# Episode number 332, and it's corresponding return is 206.0, average rewards : 154.62
# Episode number 333, and it's corresponding return is 190.0, average rewards : 154.18
# Episode number 334, and it's corresponding return is 237.0, average rewards : 155.56
# Episode number 335, and it's corresponding return is 239.0, average rewards : 156.98
# Episode number 336, and it's corresponding return is 141.0, average rewards : 157.62
# Episode number 337, and it's corresponding return is 480.0, average rewards : 161.46
# Episode number 338, and it's corresponding return is 500.0, average rewards : 165.18
# Episode number 339, and it's corresponding return is 500.0, average rewards : 168.39
# Episode number 340, and it's corresponding return is 279.0, average rewards : 169.83
# Episode number 341, and it's corresponding return is 214.0, average rewards : 169.82
# Episode number 342, and it's corresponding return is 192.0, average rewards : 170.34
# Episode number 343, and it's corresponding return is 190.0, average rewards : 170.33
# Episode number 344, and it's corresponding return is 133.0, average rewards : 170.07
# Episode number 345, and it's corresponding return is 145.0, average rewards : 169.0
# Episode number 346, and it's corresponding return is 80.0, average rewards : 167.39
# Episode number 347, and it's corresponding return is 128.0, average rewards : 167.22
# Episode number 348, and it's corresponding return is 119.0, average rewards : 166.5
# Episode number 349, and it's corresponding return is 138.0, average rewards : 165.54
# Episode number 350, and it's corresponding return is 151.0, average rewards : 165.63
# Episode number 351, and it's corresponding return is 132.0, average rewards : 164.97
# Episode number 352, and it's corresponding return is 126.0, average rewards : 164.84
# Episode number 353, and it's corresponding return is 121.0, average rewards : 164.52
# Episode number 354, and it's corresponding return is 144.0, average rewards : 164.06
# Episode number 355, and it's corresponding return is 121.0, average rewards : 163.99
# Episode number 356, and it's corresponding return is 120.0, average rewards : 163.61
# Episode number 357, and it's corresponding return is 18.0, average rewards : 162.44
# Episode number 358, and it's corresponding return is 107.0, average rewards : 161.61
# Episode number 359, and it's corresponding return is 14.0, average rewards : 160.02
# Episode number 360, and it's corresponding return is 108.0, average rewards : 159.8
# Episode number 361, and it's corresponding return is 10.0, average rewards : 158.02
# Episode number 362, and it's corresponding return is 12.0, average rewards : 156.05
# Episode number 363, and it's corresponding return is 10.0, average rewards : 154.84
# Episode number 364, and it's corresponding return is 12.0, average rewards : 152.15
# Episode number 365, and it's corresponding return is 115.0, average rewards : 151.42
# Episode number 366, and it's corresponding return is 10.0, average rewards : 149.13
# Episode number 367, and it's corresponding return is 11.0, average rewards : 147.04
# Episode number 368, and it's corresponding return is 9.0, average rewards : 146.07
# Episode number 369, and it's corresponding return is 10.0, average rewards : 144.51
# Episode number 370, and it's corresponding return is 106.0, average rewards : 144.24
# Episode number 371, and it's corresponding return is 10.0, average rewards : 142.2
# Episode number 372, and it's corresponding return is 111.0, average rewards : 141.66
# Episode number 373, and it's corresponding return is 9.0, average rewards : 140.42
# Episode number 374, and it's corresponding return is 129.0, average rewards : 140.48
# Episode number 375, and it's corresponding return is 10.0, average rewards : 139.29
# Episode number 376, and it's corresponding return is 9.0, average rewards : 137.96
# Episode number 377, and it's corresponding return is 12.0, average rewards : 137.13
# Episode number 378, and it's corresponding return is 12.0, average rewards : 135.8
# Episode number 379, and it's corresponding return is 10.0, average rewards : 134.68
# Episode number 380, and it's corresponding return is 12.0, average rewards : 133.69
# Episode number 381, and it's corresponding return is 15.0, average rewards : 132.79
# Episode number 382, and it's corresponding return is 12.0, average rewards : 131.72
# Episode number 383, and it's corresponding return is 10.0, average rewards : 130.82
# Episode number 384, and it's corresponding return is 12.0, average rewards : 129.93
# Episode number 385, and it's corresponding return is 10.0, average rewards : 128.85
# Episode number 386, and it's corresponding return is 10.0, average rewards : 128.2
# Episode number 387, and it's corresponding return is 10.0, average rewards : 127.22
# Episode number 388, and it's corresponding return is 9.0, average rewards : 126.43
# Episode number 389, and it's corresponding return is 9.0, average rewards : 125.29
# Episode number 390, and it's corresponding return is 9.0, average rewards : 123.91
# Episode number 391, and it's corresponding return is 8.0, average rewards : 122.87
# Episode number 392, and it's corresponding return is 11.0, average rewards : 121.59
# Episode number 393, and it's corresponding return is 10.0, average rewards : 120.14
# Episode number 394, and it's corresponding return is 10.0, average rewards : 118.37
# Episode number 395, and it's corresponding return is 13.0, average rewards : 117.09
# Episode number 396, and it's corresponding return is 12.0, average rewards : 115.67
# Episode number 397, and it's corresponding return is 10.0, average rewards : 114.42
# Episode number 398, and it's corresponding return is 9.0, average rewards : 113.22
# Episode number 399, and it's corresponding return is 12.0, average rewards : 111.88
# Episode number 400, and it's corresponding return is 11.0, average rewards : 110.62
# Episode number 401, and it's corresponding return is 12.0, average rewards : 109.14
# Episode number 402, and it's corresponding return is 10.0, average rewards : 107.59
# Episode number 403, and it's corresponding return is 12.0, average rewards : 105.34
# Episode number 404, and it's corresponding return is 10.0, average rewards : 103.89
# Episode number 405, and it's corresponding return is 10.0, average rewards : 102.09
# Episode number 406, and it's corresponding return is 10.0, average rewards : 101.86
# Episode number 407, and it's corresponding return is 9.0, average rewards : 100.08
# Episode number 408, and it's corresponding return is 10.0, average rewards : 97.6
# Episode number 409, and it's corresponding return is 10.0, average rewards : 96.67
# Episode number 410, and it's corresponding return is 9.0, average rewards : 94.32
# Episode number 411, and it's corresponding return is 12.0, average rewards : 92.39
# Episode number 412, and it's corresponding return is 9.0, average rewards : 91.52
# Episode number 413, and it's corresponding return is 11.0, average rewards : 90.7
# Episode number 414, and it's corresponding return is 9.0, average rewards : 88.82
# Episode number 415, and it's corresponding return is 9.0, average rewards : 87.03
# Episode number 416, and it's corresponding return is 10.0, average rewards : 85.04
# Episode number 417, and it's corresponding return is 8.0, average rewards : 83.52
# Episode number 418, and it's corresponding return is 10.0, average rewards : 82.19
# Episode number 419, and it's corresponding return is 11.0, average rewards : 80.84
# Episode number 420, and it's corresponding return is 9.0, average rewards : 79.4
# Episode number 421, and it's corresponding return is 13.0, average rewards : 77.99
# Episode number 422, and it's corresponding return is 10.0, average rewards : 76.57
# Episode number 423, and it's corresponding return is 11.0, average rewards : 75.12
# Episode number 424, and it's corresponding return is 9.0, average rewards : 73.95
# Episode number 425, and it's corresponding return is 11.0, average rewards : 72.61
# Episode number 426, and it's corresponding return is 11.0, average rewards : 71.25
# Episode number 427, and it's corresponding return is 10.0, average rewards : 69.76
# Episode number 428, and it's corresponding return is 9.0, average rewards : 68.42
# Episode number 429, and it's corresponding return is 12.0, average rewards : 67.23
# Episode number 430, and it's corresponding return is 10.0, average rewards : 65.82
# Episode number 431, and it's corresponding return is 11.0, average rewards : 64.31
# Episode number 432, and it's corresponding return is 9.0, average rewards : 62.34
# Episode number 433, and it's corresponding return is 10.0, average rewards : 60.54
# Episode number 434, and it's corresponding return is 10.0, average rewards : 58.27
# Episode number 435, and it's corresponding return is 11.0, average rewards : 55.99
# Episode number 436, and it's corresponding return is 14.0, average rewards : 54.72
# Episode number 437, and it's corresponding return is 10.0, average rewards : 50.02
# Episode number 438, and it's corresponding return is 9.0, average rewards : 45.11
# Episode number 439, and it's corresponding return is 9.0, average rewards : 40.2
# Episode number 440, and it's corresponding return is 10.0, average rewards : 37.51
# Episode number 441, and it's corresponding return is 10.0, average rewards : 35.47
# Episode number 442, and it's corresponding return is 9.0, average rewards : 33.64
# Episode number 443, and it's corresponding return is 11.0, average rewards : 31.85
# Episode number 444, and it's corresponding return is 9.0, average rewards : 30.61
# Episode number 445, and it's corresponding return is 11.0, average rewards : 29.27
# Episode number 446, and it's corresponding return is 9.0, average rewards : 28.56
# Episode number 447, and it's corresponding return is 10.0, average rewards : 27.38
# Episode number 448, and it's corresponding return is 10.0, average rewards : 26.29
# Episode number 449, and it's corresponding return is 13.0, average rewards : 25.04
# Episode number 450, and it's corresponding return is 171.0, average rewards : 25.24
# Episode number 451, and it's corresponding return is 10.0, average rewards : 24.02
# Episode number 452, and it's corresponding return is 10.0, average rewards : 22.86
# Episode number 453, and it's corresponding return is 9.0, average rewards : 21.74
# Episode number 454, and it's corresponding return is 14.0, average rewards : 20.44
# Episode number 455, and it's corresponding return is 10.0, average rewards : 19.33
# Episode number 456, and it's corresponding return is 13.0, average rewards : 18.26
# Episode number 457, and it's corresponding return is 11.0, average rewards : 18.19
# Episode number 458, and it's corresponding return is 13.0, average rewards : 17.25
# Episode number 459, and it's corresponding return is 9.0, average rewards : 17.2
# Episode number 460, and it's corresponding return is 11.0, average rewards : 16.23
# Episode number 461, and it's corresponding return is 10.0, average rewards : 16.23
# Episode number 462, and it's corresponding return is 13.0, average rewards : 16.24
# Episode number 463, and it's corresponding return is 9.0, average rewards : 16.23
# Episode number 464, and it's corresponding return is 9.0, average rewards : 16.2
# Episode number 465, and it's corresponding return is 500.0, average rewards : 20.05
# Episode number 466, and it's corresponding return is 67.0, average rewards : 20.62
# Episode number 467, and it's corresponding return is 83.0, average rewards : 21.34
# Episode number 468, and it's corresponding return is 68.0, average rewards : 21.93
# Episode number 469, and it's corresponding return is 64.0, average rewards : 22.47
# Episode number 470, and it's corresponding return is 82.0, average rewards : 22.23
# Episode number 471, and it's corresponding return is 48.0, average rewards : 22.61
# Episode number 472, and it's corresponding return is 76.0, average rewards : 22.26
# Episode number 473, and it's corresponding return is 88.0, average rewards : 23.05
# Episode number 474, and it's corresponding return is 51.0, average rewards : 22.27
# Episode number 475, and it's corresponding return is 61.0, average rewards : 22.78
# Episode number 476, and it's corresponding return is 54.0, average rewards : 23.23
# Episode number 477, and it's corresponding return is 147.0, average rewards : 24.58
# Episode number 478, and it's corresponding return is 34.0, average rewards : 24.8
# Episode number 479, and it's corresponding return is 39.0, average rewards : 25.09
# Episode number 480, and it's corresponding return is 37.0, average rewards : 25.34
# Episode number 481, and it's corresponding return is 29.0, average rewards : 25.48
# Episode number 482, and it's corresponding return is 63.0, average rewards : 25.99
# Episode number 483, and it's corresponding return is 49.0, average rewards : 26.38
# Episode number 484, and it's corresponding return is 33.0, average rewards : 26.59
# Episode number 485, and it's corresponding return is 31.0, average rewards : 26.8
# Episode number 486, and it's corresponding return is 35.0, average rewards : 27.05
# Episode number 487, and it's corresponding return is 40.0, average rewards : 27.35
# Episode number 488, and it's corresponding return is 44.0, average rewards : 27.7
# Episode number 489, and it's corresponding return is 31.0, average rewards : 27.92
# Episode number 490, and it's corresponding return is 35.0, average rewards : 28.18
# Episode number 491, and it's corresponding return is 38.0, average rewards : 28.48
# Episode number 492, and it's corresponding return is 37.0, average rewards : 28.74
# Episode number 493, and it's corresponding return is 35.0, average rewards : 28.99
# Episode number 494, and it's corresponding return is 27.0, average rewards : 29.16
# Episode number 495, and it's corresponding return is 37.0, average rewards : 29.4
# Episode number 496, and it's corresponding return is 37.0, average rewards : 29.65
# Episode number 497, and it's corresponding return is 33.0, average rewards : 29.88
# Episode number 498, and it's corresponding return is 33.0, average rewards : 30.12
# Episode number 499, and it's corresponding return is 41.0, average rewards : 30.41
# 100%|██████████| 4/4 [27:44<00:00, 416.18s/it]
# Episode number 500, and it's corresponding return is 34.0, average rewards : 30.64

# %%
print(f"The parameters and their corresponding regrets {dict_2_1}")
# Out:
# The parameters and their corresponding regrets {(128, 64): 177257.0, (64, 32): 124798.0, (32, 16): 186635.0, (16, 8): 216543.0}

# %%
print(f"The optimal parameters : {opt_par_2_1}")
# Out:
# The optimal parameters : (64, 32)

# %% [markdown]
# Parameters and their corresponding ID :
# - (128, 64) : 1
# - (64, 32) : 2
# - (32, 16) : 3
# - (16, 8) : 4

# %%
y = list(dict_2_1.values())
x = [1, 2, 3, 4]
plt.plot(x, y)
plt.title("Parameter's id vs their regret")
plt.xlabel("Parameter's id")
plt.ylabel("Regret")
plt.show()
