# %% [markdown]
# ### Importing Modules

# %%
import numpy as np
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from collections import namedtuple, deque
import datetime

import gym
from gym.wrappers.record_video import RecordVideo

import glob
import io
import base64

import matplotlib.pyplot as plt

# %% [markdown]
# ### Defining the two game environments

# %%
#Defining Environments

#Environment 1

env1 = gym.make("Acrobot-v1")
env1.seed(0)

env1_state_shape = env1.observation_space.shape[0]
env1_no_of_actions = env1.action_space.n

env1_state = env1.reset()


#Environment 2

env2 = gym.make("CartPole-v1")
env2.seed(0)

env2_state_shape = env2.observation_space.shape[0]
env2_no_of_actions = env2.action_space.n

env2_state = env2.reset()


# Note For both Environments
# For choosing actions :
# action = env.action_space.sample()

# For step :
# next_state, reward, done, info = env.step(action)
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/core.py:256: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed)` instead.
#   deprecation(

# %% [markdown]
# ### Defining the two Neural networks required

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

BUFFER_SIZE = int(1e5)
BATCH_SIZE = 64       # Need to be learnt?
GAMMA = 0.99
LR = 5e-4             # Need to be learnt
UPDATE_EVERY = 20

class QNetwork1(nn.Module):
  def __init__(self, state_size, action_size, seed, fc1_units = 64, fc2_units = 32):
    super(QNetwork1, self).__init__()
    self.seed = torch.manual_seed(seed)                                               # Making the initialization of weights the same all the time
    self.fc1 = nn.Linear(state_size, fc1_units)
    self.fc2 = nn.Linear(fc1_units, fc2_units)
    self.V = nn.Linear(fc2_units, 1)
    self.A = nn.Linear(fc2_units, action_size)

  def forward(self, state):
    x = F.relu(self.fc1(state))
    x = F.relu(self.fc2(x))
    V = self.V(x)
    A = self.A(x)
    return V + A - A.mean()

class QNetwork2(nn.Module):
  def __init__(self, state_size, action_size, seed, fc1_units = 64, fc2_units = 32):
    super(QNetwork2, self).__init__()
    self.seed = torch.manual_seed(seed)
    self.fc1 = nn.Linear(state_size, fc1_units)
    self.fc2 = nn.Linear(fc1_units, fc2_units)
    self.V = nn.Linear(fc2_units, 1)
    self.A = nn.Linear(fc2_units, action_size)

  def forward(self, state):
    x = F.relu(self.fc1(state))
    x = F.relu(self.fc2(x))
    V = self.V(x)
    A = self.A(x)
    return V + A - A.max()

# %% [markdown]
# ### Class for Replay buffer

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class ReplayBuffer:
  def __init__(self, action_size, buffer_size, batch_size, seed):
    self.action_size = action_size
    self.memory = deque(maxlen = buffer_size)                                                                       # Memory that stores experiences
    self.batch_size = batch_size                                                                                    # Stores batch size for sampling
    self.experience = namedtuple('Experience', field_names = ["state", "action", "reward", "next_state", "done"])   # Named Tuple that is used to store experience
    self.seed = random.seed(seed)

  def add(self, state, action, reward, next_state, done):                                                         # Function for adding experiences in memory
    e = self.experience(state, action, reward, next_state, done)
    self.memory.append(e)

  def sample(self):                                                                                               # Sampling experiences randomly
    experiences = random.sample(self.memory, k = self.batch_size)

    states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
    actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(device)
    rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
    next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
    dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)

    return (states, actions, rewards, next_states, dones)

  def __len__(self):
    return len(self.memory)

# %% [markdown]
# ### Defining tutorial agent, where it learns and acts according to the policy

# %%
class TutorialAgent():
  def __init__(self, state_size, action_size, seed, tau = 0.1, QNetwork = QNetwork1):
    self.state_size = state_size
    self.action_size = action_size
    self.seed = random.seed(seed)

    self.qnetwork_local = QNetwork(state_size, action_size, seed).to(device)                  # Local network
    self.qnetwork_target = QNetwork(state_size, action_size, seed).to(device)                 # Target network
    self.optimizer = optim.Adam(self.qnetwork_local.parameters(), lr = LR)

    self.memory = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, seed)         # To store experiences and sample

    self.t_step = 0                                                                # For maintaining a count of when to update Target Q network
    self.tau = tau                                                                 # Parameter for updating Target Q network using Polyak updation

  def step(self, state, action, reward, next_state, done):
    self.memory.add(state, action, reward, next_state, done)

    if len(self.memory) >= BATCH_SIZE:
      experiences = self.memory.sample()
      self.learn(experiences)

    self.t_step = (self.t_step + 1) % UPDATE_EVERY
    if self.t_step == 0:
      for (name1, par1), (name2, par2) in zip(self.qnetwork_local.state_dict().items(), self.qnetwork_target.state_dict().items()):
        par2.copy_(self.tau * par1 + (1 - self.tau) * par2)                        # Polyak update

  def act(self, state, eps = 0.0):
    state = torch.from_numpy(state).float().unsqueeze(0).to(device)                           # Conveting the numpy array to a torch tensor

    self.qnetwork_local.eval()                                                     # The model is set to evaluating
    with torch.no_grad():                                                          # Evaluation is done without taking gradients
      action_values = self.qnetwork_local(state)                                   # The Q values are obtained
    self.qnetwork_local.train()                                                    # The model is set to training

    if random.random() > eps:                                                      # Implementing of Epsilon greedy policy
      return np.argmax(action_values.cpu().data.numpy())
    else:
      return random.choice(np.arange(self.action_size))

  def learn(self, experiences):
    states, actions, rewards, next_states, dones = experiences
    Q_targets_next = self.qnetwork_target(next_states).detach().max(1)[0].unsqueeze(1)
    Q_targets = rewards + GAMMA * Q_targets_next * (1 - dones)
    Q_current = self.qnetwork_local(states).gather(1, actions)

    loss = F.mse_loss(Q_current, Q_targets)

    self.optimizer.zero_grad()
    loss.backward()

    for param in self.qnetwork_local.parameters():                                 # Gradient clipping
      param.grad.data.clamp_(-1, 1)                                                # For preventing exploding gradient situation

    self.optimizer.step()

# %% [markdown]
# ### A class for running Dueling DQN

# %%
class dueling_dqn:
  def __init__(self, env = env1, QNetwork = QNetwork1, tau = 0.1, seed = 0):
    self.env = env
    self.state_shape = env.observation_space.shape[0]
    self.action_space = env.action_space.n
    self.agent = TutorialAgent(state_size = self.state_shape, action_size = self.action_space, seed = seed, tau = tau, QNetwork = QNetwork)

  def run(self, n_episodes = 1000, max_t = 500, eps_start = 1.0, eps_end = 0.01, eps_decay = 0.995):
    returns = deque()
    scores = deque(maxlen = 100)
    eps = eps_start
    for i in range(1, n_episodes + 1):
      state = self.env.reset()
      ep_reward = 0
      rewards = deque()
      while True:
        action = self.agent.act(state, eps)
        next_state, reward, done, _ = self.env.step(action)
        self.agent.step(state, action, reward, next_state, done)
        state = next_state
        ep_reward += reward
        rewards.append(reward)

        if done:
          break
      eps = max(eps_end, eps_decay * eps)
      scores.append(ep_reward)
      R = 0
      for r in list(rewards):
        R = r + R
      print(f"Episode number {i}, and it's corresponding return is {R}, average rewards : {np.mean(scores)}")
      returns.append(R)
    return list(returns)

# %% [markdown]
# ### Running of Acrobot - v1 with Type - 1 Dueling DQN

# %%
list_returns_env_1_type_1 = deque()
for i in range(5):
  print(f"The iteration number is : {i + 1}")
  env_1_type_1 = dueling_dqn(env = env1, QNetwork = QNetwork1, seed = i)
  returns_env_1_type_1 = env_1_type_1.run(n_episodes = 1000)
  list_returns_env_1_type_1.append(returns_env_1_type_1)
  print(f"The iteration {i + 1} ended")
# Out:
# Streaming output truncated to the last 5000 lines.
# Episode number 10, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 11, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 12, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 13, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 14, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 15, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 16, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 17, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 18, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 19, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 20, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 21, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 22, and it's corresponding return is -435.0, average rewards : -497.04545454545456
# Episode number 23, and it's corresponding return is -303.0, average rewards : -488.60869565217394
# Episode number 24, and it's corresponding return is -375.0, average rewards : -483.875
# Episode number 25, and it's corresponding return is -500.0, average rewards : -484.52
# Episode number 26, and it's corresponding return is -456.0, average rewards : -483.4230769230769
# Episode number 27, and it's corresponding return is -434.0, average rewards : -481.5925925925926
# Episode number 28, and it's corresponding return is -500.0, average rewards : -482.25
# Episode number 29, and it's corresponding return is -500.0, average rewards : -482.86206896551727
# Episode number 30, and it's corresponding return is -473.0, average rewards : -482.53333333333336
# Episode number 31, and it's corresponding return is -500.0, average rewards : -483.0967741935484
# Episode number 32, and it's corresponding return is -360.0, average rewards : -479.25
# Episode number 33, and it's corresponding return is -495.0, average rewards : -479.72727272727275
# Episode number 34, and it's corresponding return is -242.0, average rewards : -472.7352941176471
# Episode number 35, and it's corresponding return is -307.0, average rewards : -468.0
# Episode number 36, and it's corresponding return is -399.0, average rewards : -466.0833333333333
# Episode number 37, and it's corresponding return is -484.0, average rewards : -466.56756756756755
# Episode number 38, and it's corresponding return is -345.0, average rewards : -463.36842105263156
# Episode number 39, and it's corresponding return is -319.0, average rewards : -459.6666666666667
# Episode number 40, and it's corresponding return is -343.0, average rewards : -456.75
# Episode number 41, and it's corresponding return is -243.0, average rewards : -451.5365853658537
# Episode number 42, and it's corresponding return is -392.0, average rewards : -450.1190476190476
# Episode number 43, and it's corresponding return is -396.0, average rewards : -448.86046511627904
# Episode number 44, and it's corresponding return is -364.0, average rewards : -446.9318181818182
# Episode number 45, and it's corresponding return is -307.0, average rewards : -443.8222222222222
# Episode number 46, and it's corresponding return is -269.0, average rewards : -440.0217391304348
# Episode number 47, and it's corresponding return is -456.0, average rewards : -440.36170212765956
# Episode number 48, and it's corresponding return is -360.0, average rewards : -438.6875
# Episode number 49, and it's corresponding return is -286.0, average rewards : -435.57142857142856
# Episode number 50, and it's corresponding return is -238.0, average rewards : -431.62
# Episode number 51, and it's corresponding return is -296.0, average rewards : -428.96078431372547
# Episode number 52, and it's corresponding return is -319.0, average rewards : -426.84615384615387
# Episode number 53, and it's corresponding return is -268.0, average rewards : -423.8490566037736
# Episode number 54, and it's corresponding return is -175.0, average rewards : -419.24074074074076
# Episode number 55, and it's corresponding return is -244.0, average rewards : -416.05454545454546
# Episode number 56, and it's corresponding return is -141.0, average rewards : -411.14285714285717
# Episode number 57, and it's corresponding return is -244.0, average rewards : -408.2105263157895
# Episode number 58, and it's corresponding return is -280.0, average rewards : -406.0
# Episode number 59, and it's corresponding return is -246.0, average rewards : -403.2881355932203
# Episode number 60, and it's corresponding return is -215.0, average rewards : -400.15
# Episode number 61, and it's corresponding return is -294.0, average rewards : -398.40983606557376
# Episode number 62, and it's corresponding return is -222.0, average rewards : -395.56451612903226
# Episode number 63, and it's corresponding return is -267.0, average rewards : -393.5238095238095
# Episode number 64, and it's corresponding return is -330.0, average rewards : -392.53125
# Episode number 65, and it's corresponding return is -188.0, average rewards : -389.38461538461536
# Episode number 66, and it's corresponding return is -235.0, average rewards : -387.04545454545456
# Episode number 67, and it's corresponding return is -211.0, average rewards : -384.4179104477612
# Episode number 68, and it's corresponding return is -268.0, average rewards : -382.70588235294116
# Episode number 69, and it's corresponding return is -257.0, average rewards : -380.8840579710145
# Episode number 70, and it's corresponding return is -312.0, average rewards : -379.9
# Episode number 71, and it's corresponding return is -235.0, average rewards : -377.85915492957747
# Episode number 72, and it's corresponding return is -251.0, average rewards : -376.09722222222223
# Episode number 73, and it's corresponding return is -271.0, average rewards : -374.6575342465753
# Episode number 74, and it's corresponding return is -223.0, average rewards : -372.6081081081081
# Episode number 75, and it's corresponding return is -239.0, average rewards : -370.82666666666665
# Episode number 76, and it's corresponding return is -201.0, average rewards : -368.5921052631579
# Episode number 77, and it's corresponding return is -218.0, average rewards : -366.6363636363636
# Episode number 78, and it's corresponding return is -225.0, average rewards : -364.8205128205128
# Episode number 79, and it's corresponding return is -190.0, average rewards : -362.60759493670884
# Episode number 80, and it's corresponding return is -252.0, average rewards : -361.225
# Episode number 81, and it's corresponding return is -244.0, average rewards : -359.77777777777777
# Episode number 82, and it's corresponding return is -232.0, average rewards : -358.219512195122
# Episode number 83, and it's corresponding return is -344.0, average rewards : -358.04819277108436
# Episode number 84, and it's corresponding return is -162.0, average rewards : -355.7142857142857
# Episode number 85, and it's corresponding return is -172.0, average rewards : -353.5529411764706
# Episode number 86, and it's corresponding return is -215.0, average rewards : -351.9418604651163
# Episode number 87, and it's corresponding return is -139.0, average rewards : -349.4942528735632
# Episode number 88, and it's corresponding return is -217.0, average rewards : -347.9886363636364
# Episode number 89, and it's corresponding return is -202.0, average rewards : -346.34831460674155
# Episode number 90, and it's corresponding return is -200.0, average rewards : -344.72222222222223
# Episode number 91, and it's corresponding return is -180.0, average rewards : -342.9120879120879
# Episode number 92, and it's corresponding return is -125.0, average rewards : -340.54347826086956
# Episode number 93, and it's corresponding return is -152.0, average rewards : -338.51612903225805
# Episode number 94, and it's corresponding return is -234.0, average rewards : -337.40425531914894
# Episode number 95, and it's corresponding return is -230.0, average rewards : -336.2736842105263
# Episode number 96, and it's corresponding return is -233.0, average rewards : -335.1979166666667
# Episode number 97, and it's corresponding return is -134.0, average rewards : -333.12371134020617
# Episode number 98, and it's corresponding return is -189.0, average rewards : -331.6530612244898
# Episode number 99, and it's corresponding return is -213.0, average rewards : -330.45454545454544
# Episode number 100, and it's corresponding return is -149.0, average rewards : -328.64
# Episode number 101, and it's corresponding return is -142.0, average rewards : -325.06
# Episode number 102, and it's corresponding return is -148.0, average rewards : -321.54
# Episode number 103, and it's corresponding return is -199.0, average rewards : -318.53
# Episode number 104, and it's corresponding return is -137.0, average rewards : -314.9
# Episode number 105, and it's corresponding return is -197.0, average rewards : -311.87
# Episode number 106, and it's corresponding return is -209.0, average rewards : -308.96
# Episode number 107, and it's corresponding return is -500.0, average rewards : -308.96
# Episode number 108, and it's corresponding return is -176.0, average rewards : -305.72
# Episode number 109, and it's corresponding return is -172.0, average rewards : -302.44
# Episode number 110, and it's corresponding return is -182.0, average rewards : -299.26
# Episode number 111, and it's corresponding return is -143.0, average rewards : -295.69
# Episode number 112, and it's corresponding return is -136.0, average rewards : -292.05
# Episode number 113, and it's corresponding return is -157.0, average rewards : -288.62
# Episode number 114, and it's corresponding return is -500.0, average rewards : -288.62
# Episode number 115, and it's corresponding return is -149.0, average rewards : -285.11
# Episode number 116, and it's corresponding return is -329.0, average rewards : -283.4
# Episode number 117, and it's corresponding return is -179.0, average rewards : -280.19
# Episode number 118, and it's corresponding return is -241.0, average rewards : -277.6
# Episode number 119, and it's corresponding return is -158.0, average rewards : -274.18
# Episode number 120, and it's corresponding return is -138.0, average rewards : -270.56
# Episode number 121, and it's corresponding return is -142.0, average rewards : -266.98
# Episode number 122, and it's corresponding return is -151.0, average rewards : -264.14
# Episode number 123, and it's corresponding return is -160.0, average rewards : -262.71
# Episode number 124, and it's corresponding return is -189.0, average rewards : -260.85
# Episode number 125, and it's corresponding return is -115.0, average rewards : -257.0
# Episode number 126, and it's corresponding return is -253.0, average rewards : -254.97
# Episode number 127, and it's corresponding return is -146.0, average rewards : -252.09
# Episode number 128, and it's corresponding return is -126.0, average rewards : -248.35
# Episode number 129, and it's corresponding return is -133.0, average rewards : -244.68
# Episode number 130, and it's corresponding return is -127.0, average rewards : -241.22
# Episode number 131, and it's corresponding return is -171.0, average rewards : -237.93
# Episode number 132, and it's corresponding return is -96.0, average rewards : -235.29
# Episode number 133, and it's corresponding return is -156.0, average rewards : -231.9
# Episode number 134, and it's corresponding return is -118.0, average rewards : -230.66
# Episode number 135, and it's corresponding return is -105.0, average rewards : -228.64
# Episode number 136, and it's corresponding return is -136.0, average rewards : -226.01
# Episode number 137, and it's corresponding return is -178.0, average rewards : -222.95
# Episode number 138, and it's corresponding return is -497.0, average rewards : -224.47
# Episode number 139, and it's corresponding return is -181.0, average rewards : -223.09
# Episode number 140, and it's corresponding return is -132.0, average rewards : -220.98
# Episode number 141, and it's corresponding return is -137.0, average rewards : -219.92
# Episode number 142, and it's corresponding return is -185.0, average rewards : -217.85
# Episode number 143, and it's corresponding return is -166.0, average rewards : -215.55
# Episode number 144, and it's corresponding return is -178.0, average rewards : -213.69
# Episode number 145, and it's corresponding return is -164.0, average rewards : -212.26
# Episode number 146, and it's corresponding return is -218.0, average rewards : -211.75
# Episode number 147, and it's corresponding return is -138.0, average rewards : -208.57
# Episode number 148, and it's corresponding return is -106.0, average rewards : -206.03
# Episode number 149, and it's corresponding return is -158.0, average rewards : -204.75
# Episode number 150, and it's corresponding return is -159.0, average rewards : -203.96
# Episode number 151, and it's corresponding return is -189.0, average rewards : -202.89
# Episode number 152, and it's corresponding return is -125.0, average rewards : -200.95
# Episode number 153, and it's corresponding return is -140.0, average rewards : -199.67
# Episode number 154, and it's corresponding return is -140.0, average rewards : -199.32
# Episode number 155, and it's corresponding return is -129.0, average rewards : -198.17
# Episode number 156, and it's corresponding return is -263.0, average rewards : -199.39
# Episode number 157, and it's corresponding return is -141.0, average rewards : -198.36
# Episode number 158, and it's corresponding return is -117.0, average rewards : -196.73
# Episode number 159, and it's corresponding return is -136.0, average rewards : -195.63
# Episode number 160, and it's corresponding return is -155.0, average rewards : -195.03
# Episode number 161, and it's corresponding return is -84.0, average rewards : -192.93
# Episode number 162, and it's corresponding return is -142.0, average rewards : -192.13
# Episode number 163, and it's corresponding return is -161.0, average rewards : -191.07
# Episode number 164, and it's corresponding return is -110.0, average rewards : -188.87
# Episode number 165, and it's corresponding return is -140.0, average rewards : -188.39
# Episode number 166, and it's corresponding return is -95.0, average rewards : -186.99
# Episode number 167, and it's corresponding return is -188.0, average rewards : -186.76
# Episode number 168, and it's corresponding return is -136.0, average rewards : -185.44
# Episode number 169, and it's corresponding return is -160.0, average rewards : -184.47
# Episode number 170, and it's corresponding return is -126.0, average rewards : -182.61
# Episode number 171, and it's corresponding return is -109.0, average rewards : -181.35
# Episode number 172, and it's corresponding return is -134.0, average rewards : -180.18
# Episode number 173, and it's corresponding return is -111.0, average rewards : -178.58
# Episode number 174, and it's corresponding return is -136.0, average rewards : -177.71
# Episode number 175, and it's corresponding return is -156.0, average rewards : -176.88
# Episode number 176, and it's corresponding return is -154.0, average rewards : -176.41
# Episode number 177, and it's corresponding return is -108.0, average rewards : -175.31
# Episode number 178, and it's corresponding return is -150.0, average rewards : -174.56
# Episode number 179, and it's corresponding return is -111.0, average rewards : -173.77
# Episode number 180, and it's corresponding return is -125.0, average rewards : -172.5
# Episode number 181, and it's corresponding return is -123.0, average rewards : -171.29
# Episode number 182, and it's corresponding return is -98.0, average rewards : -169.95
# Episode number 183, and it's corresponding return is -109.0, average rewards : -167.6
# Episode number 184, and it's corresponding return is -121.0, average rewards : -167.19
# Episode number 185, and it's corresponding return is -118.0, average rewards : -166.65
# Episode number 186, and it's corresponding return is -161.0, average rewards : -166.11
# Episode number 187, and it's corresponding return is -95.0, average rewards : -165.67
# Episode number 188, and it's corresponding return is -88.0, average rewards : -164.38
# Episode number 189, and it's corresponding return is -124.0, average rewards : -163.6
# Episode number 190, and it's corresponding return is -163.0, average rewards : -163.23
# Episode number 191, and it's corresponding return is -174.0, average rewards : -163.17
# Episode number 192, and it's corresponding return is -129.0, average rewards : -163.21
# Episode number 193, and it's corresponding return is -101.0, average rewards : -162.7
# Episode number 194, and it's corresponding return is -128.0, average rewards : -161.64
# Episode number 195, and it's corresponding return is -102.0, average rewards : -160.36
# Episode number 196, and it's corresponding return is -143.0, average rewards : -159.46
# Episode number 197, and it's corresponding return is -159.0, average rewards : -159.71
# Episode number 198, and it's corresponding return is -106.0, average rewards : -158.88
# Episode number 199, and it's corresponding return is -92.0, average rewards : -157.67
# Episode number 200, and it's corresponding return is -136.0, average rewards : -157.54
# Episode number 201, and it's corresponding return is -127.0, average rewards : -157.39
# Episode number 202, and it's corresponding return is -100.0, average rewards : -156.91
# Episode number 203, and it's corresponding return is -108.0, average rewards : -156.0
# Episode number 204, and it's corresponding return is -149.0, average rewards : -156.12
# Episode number 205, and it's corresponding return is -142.0, average rewards : -155.57
# Episode number 206, and it's corresponding return is -127.0, average rewards : -154.75
# Episode number 207, and it's corresponding return is -127.0, average rewards : -151.02
# Episode number 208, and it's corresponding return is -139.0, average rewards : -150.65
# Episode number 209, and it's corresponding return is -121.0, average rewards : -150.14
# Episode number 210, and it's corresponding return is -141.0, average rewards : -149.73
# Episode number 211, and it's corresponding return is -113.0, average rewards : -149.43
# Episode number 212, and it's corresponding return is -95.0, average rewards : -149.02
# Episode number 213, and it's corresponding return is -134.0, average rewards : -148.79
# Episode number 214, and it's corresponding return is -172.0, average rewards : -145.51
# Episode number 215, and it's corresponding return is -110.0, average rewards : -145.12
# Episode number 216, and it's corresponding return is -149.0, average rewards : -143.32
# Episode number 217, and it's corresponding return is -138.0, average rewards : -142.91
# Episode number 218, and it's corresponding return is -143.0, average rewards : -141.93
# Episode number 219, and it's corresponding return is -100.0, average rewards : -141.35
# Episode number 220, and it's corresponding return is -131.0, average rewards : -141.28
# Episode number 221, and it's corresponding return is -111.0, average rewards : -140.97
# Episode number 222, and it's corresponding return is -354.0, average rewards : -143.0
# Episode number 223, and it's corresponding return is -113.0, average rewards : -142.53
# Episode number 224, and it's corresponding return is -98.0, average rewards : -141.62
# Episode number 225, and it's corresponding return is -131.0, average rewards : -141.78
# Episode number 226, and it's corresponding return is -90.0, average rewards : -140.15
# Episode number 227, and it's corresponding return is -89.0, average rewards : -139.58
# Episode number 228, and it's corresponding return is -159.0, average rewards : -139.91
# Episode number 229, and it's corresponding return is -105.0, average rewards : -139.63
# Episode number 230, and it's corresponding return is -127.0, average rewards : -139.63
# Episode number 231, and it's corresponding return is -126.0, average rewards : -139.18
# Episode number 232, and it's corresponding return is -115.0, average rewards : -139.37
# Episode number 233, and it's corresponding return is -100.0, average rewards : -138.81
# Episode number 234, and it's corresponding return is -106.0, average rewards : -138.69
# Episode number 235, and it's corresponding return is -91.0, average rewards : -138.55
# Episode number 236, and it's corresponding return is -154.0, average rewards : -138.73
# Episode number 237, and it's corresponding return is -157.0, average rewards : -138.52
# Episode number 238, and it's corresponding return is -107.0, average rewards : -134.62
# Episode number 239, and it's corresponding return is -101.0, average rewards : -133.82
# Episode number 240, and it's corresponding return is -111.0, average rewards : -133.61
# Episode number 241, and it's corresponding return is -110.0, average rewards : -133.34
# Episode number 242, and it's corresponding return is -74.0, average rewards : -132.23
# Episode number 243, and it's corresponding return is -134.0, average rewards : -131.91
# Episode number 244, and it's corresponding return is -113.0, average rewards : -131.26
# Episode number 245, and it's corresponding return is -183.0, average rewards : -131.45
# Episode number 246, and it's corresponding return is -116.0, average rewards : -130.43
# Episode number 247, and it's corresponding return is -133.0, average rewards : -130.38
# Episode number 248, and it's corresponding return is -94.0, average rewards : -130.26
# Episode number 249, and it's corresponding return is -160.0, average rewards : -130.28
# Episode number 250, and it's corresponding return is -117.0, average rewards : -129.86
# Episode number 251, and it's corresponding return is -97.0, average rewards : -128.94
# Episode number 252, and it's corresponding return is -102.0, average rewards : -128.71
# Episode number 253, and it's corresponding return is -135.0, average rewards : -128.66
# Episode number 254, and it's corresponding return is -100.0, average rewards : -128.26
# Episode number 255, and it's corresponding return is -125.0, average rewards : -128.22
# Episode number 256, and it's corresponding return is -104.0, average rewards : -126.63
# Episode number 257, and it's corresponding return is -120.0, average rewards : -126.42
# Episode number 258, and it's corresponding return is -135.0, average rewards : -126.6
# Episode number 259, and it's corresponding return is -101.0, average rewards : -126.25
# Episode number 260, and it's corresponding return is -84.0, average rewards : -125.54
# Episode number 261, and it's corresponding return is -83.0, average rewards : -125.53
# Episode number 262, and it's corresponding return is -121.0, average rewards : -125.32
# Episode number 263, and it's corresponding return is -98.0, average rewards : -124.69
# Episode number 264, and it's corresponding return is -114.0, average rewards : -124.73
# Episode number 265, and it's corresponding return is -90.0, average rewards : -124.23
# Episode number 266, and it's corresponding return is -113.0, average rewards : -124.41
# Episode number 267, and it's corresponding return is -96.0, average rewards : -123.49
# Episode number 268, and it's corresponding return is -100.0, average rewards : -123.13
# Episode number 269, and it's corresponding return is -120.0, average rewards : -122.73
# Episode number 270, and it's corresponding return is -111.0, average rewards : -122.58
# Episode number 271, and it's corresponding return is -121.0, average rewards : -122.7
# Episode number 272, and it's corresponding return is -137.0, average rewards : -122.73
# Episode number 273, and it's corresponding return is -106.0, average rewards : -122.68
# Episode number 274, and it's corresponding return is -103.0, average rewards : -122.35
# Episode number 275, and it's corresponding return is -112.0, average rewards : -121.91
# Episode number 276, and it's corresponding return is -132.0, average rewards : -121.69
# Episode number 277, and it's corresponding return is -131.0, average rewards : -121.92
# Episode number 278, and it's corresponding return is -107.0, average rewards : -121.49
# Episode number 279, and it's corresponding return is -107.0, average rewards : -121.45
# Episode number 280, and it's corresponding return is -100.0, average rewards : -121.2
# Episode number 281, and it's corresponding return is -94.0, average rewards : -120.91
# Episode number 282, and it's corresponding return is -91.0, average rewards : -120.84
# Episode number 283, and it's corresponding return is -126.0, average rewards : -121.01
# Episode number 284, and it's corresponding return is -107.0, average rewards : -120.87
# Episode number 285, and it's corresponding return is -150.0, average rewards : -121.19
# Episode number 286, and it's corresponding return is -96.0, average rewards : -120.54
# Episode number 287, and it's corresponding return is -128.0, average rewards : -120.87
# Episode number 288, and it's corresponding return is -130.0, average rewards : -121.29
# Episode number 289, and it's corresponding return is -93.0, average rewards : -120.98
# Episode number 290, and it's corresponding return is -87.0, average rewards : -120.22
# Episode number 291, and it's corresponding return is -109.0, average rewards : -119.57
# Episode number 292, and it's corresponding return is -82.0, average rewards : -119.1
# Episode number 293, and it's corresponding return is -90.0, average rewards : -118.99
# Episode number 294, and it's corresponding return is -116.0, average rewards : -118.87
# Episode number 295, and it's corresponding return is -75.0, average rewards : -118.6
# Episode number 296, and it's corresponding return is -90.0, average rewards : -118.07
# Episode number 297, and it's corresponding return is -83.0, average rewards : -117.31
# Episode number 298, and it's corresponding return is -123.0, average rewards : -117.48
# Episode number 299, and it's corresponding return is -90.0, average rewards : -117.46
# Episode number 300, and it's corresponding return is -107.0, average rewards : -117.17
# Episode number 301, and it's corresponding return is -93.0, average rewards : -116.83
# Episode number 302, and it's corresponding return is -134.0, average rewards : -117.17
# Episode number 303, and it's corresponding return is -104.0, average rewards : -117.13
# Episode number 304, and it's corresponding return is -86.0, average rewards : -116.5
# Episode number 305, and it's corresponding return is -87.0, average rewards : -115.95
# Episode number 306, and it's corresponding return is -109.0, average rewards : -115.77
# Episode number 307, and it's corresponding return is -97.0, average rewards : -115.47
# Episode number 308, and it's corresponding return is -83.0, average rewards : -114.91
# Episode number 309, and it's corresponding return is -83.0, average rewards : -114.53
# Episode number 310, and it's corresponding return is -99.0, average rewards : -114.11
# Episode number 311, and it's corresponding return is -111.0, average rewards : -114.09
# Episode number 312, and it's corresponding return is -109.0, average rewards : -114.23
# Episode number 313, and it's corresponding return is -78.0, average rewards : -113.67
# Episode number 314, and it's corresponding return is -78.0, average rewards : -112.73
# Episode number 315, and it's corresponding return is -118.0, average rewards : -112.81
# Episode number 316, and it's corresponding return is -108.0, average rewards : -112.4
# Episode number 317, and it's corresponding return is -106.0, average rewards : -112.08
# Episode number 318, and it's corresponding return is -136.0, average rewards : -112.01
# Episode number 319, and it's corresponding return is -84.0, average rewards : -111.85
# Episode number 320, and it's corresponding return is -110.0, average rewards : -111.64
# Episode number 321, and it's corresponding return is -86.0, average rewards : -111.39
# Episode number 322, and it's corresponding return is -150.0, average rewards : -109.35
# Episode number 323, and it's corresponding return is -109.0, average rewards : -109.31
# Episode number 324, and it's corresponding return is -80.0, average rewards : -109.13
# Episode number 325, and it's corresponding return is -83.0, average rewards : -108.65
# Episode number 326, and it's corresponding return is -88.0, average rewards : -108.63
# Episode number 327, and it's corresponding return is -94.0, average rewards : -108.68
# Episode number 328, and it's corresponding return is -100.0, average rewards : -108.09
# Episode number 329, and it's corresponding return is -139.0, average rewards : -108.43
# Episode number 330, and it's corresponding return is -101.0, average rewards : -108.17
# Episode number 331, and it's corresponding return is -79.0, average rewards : -107.7
# Episode number 332, and it's corresponding return is -87.0, average rewards : -107.42
# Episode number 333, and it's corresponding return is -101.0, average rewards : -107.43
# Episode number 334, and it's corresponding return is -85.0, average rewards : -107.22
# Episode number 335, and it's corresponding return is -69.0, average rewards : -107.0
# Episode number 336, and it's corresponding return is -89.0, average rewards : -106.35
# Episode number 337, and it's corresponding return is -104.0, average rewards : -105.82
# Episode number 338, and it's corresponding return is -101.0, average rewards : -105.76
# Episode number 339, and it's corresponding return is -113.0, average rewards : -105.88
# Episode number 340, and it's corresponding return is -95.0, average rewards : -105.72
# Episode number 341, and it's corresponding return is -74.0, average rewards : -105.36
# Episode number 342, and it's corresponding return is -93.0, average rewards : -105.55
# Episode number 343, and it's corresponding return is -68.0, average rewards : -104.89
# Episode number 344, and it's corresponding return is -111.0, average rewards : -104.87
# Episode number 345, and it's corresponding return is -103.0, average rewards : -104.07
# Episode number 346, and it's corresponding return is -94.0, average rewards : -103.85
# Episode number 347, and it's corresponding return is -100.0, average rewards : -103.52
# Episode number 348, and it's corresponding return is -97.0, average rewards : -103.55
# Episode number 349, and it's corresponding return is -83.0, average rewards : -102.78
# Episode number 350, and it's corresponding return is -103.0, average rewards : -102.64
# Episode number 351, and it's corresponding return is -84.0, average rewards : -102.51
# Episode number 352, and it's corresponding return is -107.0, average rewards : -102.56
# Episode number 353, and it's corresponding return is -105.0, average rewards : -102.26
# Episode number 354, and it's corresponding return is -78.0, average rewards : -102.04
# Episode number 355, and it's corresponding return is -76.0, average rewards : -101.55
# Episode number 356, and it's corresponding return is -91.0, average rewards : -101.42
# Episode number 357, and it's corresponding return is -112.0, average rewards : -101.34
# Episode number 358, and it's corresponding return is -88.0, average rewards : -100.87
# Episode number 359, and it's corresponding return is -82.0, average rewards : -100.68
# Episode number 360, and it's corresponding return is -77.0, average rewards : -100.61
# Episode number 361, and it's corresponding return is -88.0, average rewards : -100.66
# Episode number 362, and it's corresponding return is -134.0, average rewards : -100.79
# Episode number 363, and it's corresponding return is -72.0, average rewards : -100.53
# Episode number 364, and it's corresponding return is -77.0, average rewards : -100.16
# Episode number 365, and it's corresponding return is -108.0, average rewards : -100.34
# Episode number 366, and it's corresponding return is -92.0, average rewards : -100.13
# Episode number 367, and it's corresponding return is -86.0, average rewards : -100.03
# Episode number 368, and it's corresponding return is -89.0, average rewards : -99.92
# Episode number 369, and it's corresponding return is -111.0, average rewards : -99.83
# Episode number 370, and it's corresponding return is -122.0, average rewards : -99.94
# Episode number 371, and it's corresponding return is -84.0, average rewards : -99.57
# Episode number 372, and it's corresponding return is -77.0, average rewards : -98.97
# Episode number 373, and it's corresponding return is -77.0, average rewards : -98.68
# Episode number 374, and it's corresponding return is -84.0, average rewards : -98.49
# Episode number 375, and it's corresponding return is -78.0, average rewards : -98.15
# Episode number 376, and it's corresponding return is -92.0, average rewards : -97.75
# Episode number 377, and it's corresponding return is -91.0, average rewards : -97.35
# Episode number 378, and it's corresponding return is -79.0, average rewards : -97.07
# Episode number 379, and it's corresponding return is -124.0, average rewards : -97.24
# Episode number 380, and it's corresponding return is -97.0, average rewards : -97.21
# Episode number 381, and it's corresponding return is -101.0, average rewards : -97.28
# Episode number 382, and it's corresponding return is -111.0, average rewards : -97.48
# Episode number 383, and it's corresponding return is -81.0, average rewards : -97.03
# Episode number 384, and it's corresponding return is -71.0, average rewards : -96.67
# Episode number 385, and it's corresponding return is -116.0, average rewards : -96.33
# Episode number 386, and it's corresponding return is -81.0, average rewards : -96.18
# Episode number 387, and it's corresponding return is -79.0, average rewards : -95.69
# Episode number 388, and it's corresponding return is -87.0, average rewards : -95.26
# Episode number 389, and it's corresponding return is -90.0, average rewards : -95.23
# Episode number 390, and it's corresponding return is -91.0, average rewards : -95.27
# Episode number 391, and it's corresponding return is -138.0, average rewards : -95.56
# Episode number 392, and it's corresponding return is -113.0, average rewards : -95.87
# Episode number 393, and it's corresponding return is -101.0, average rewards : -95.98
# Episode number 394, and it's corresponding return is -62.0, average rewards : -95.44
# Episode number 395, and it's corresponding return is -87.0, average rewards : -95.56
# Episode number 396, and it's corresponding return is -106.0, average rewards : -95.72
# Episode number 397, and it's corresponding return is -88.0, average rewards : -95.77
# Episode number 398, and it's corresponding return is -96.0, average rewards : -95.5
# Episode number 399, and it's corresponding return is -89.0, average rewards : -95.49
# Episode number 400, and it's corresponding return is -102.0, average rewards : -95.44
# Episode number 401, and it's corresponding return is -97.0, average rewards : -95.48
# Episode number 402, and it's corresponding return is -79.0, average rewards : -94.93
# Episode number 403, and it's corresponding return is -75.0, average rewards : -94.64
# Episode number 404, and it's corresponding return is -82.0, average rewards : -94.6
# Episode number 405, and it's corresponding return is -79.0, average rewards : -94.52
# Episode number 406, and it's corresponding return is -68.0, average rewards : -94.11
# Episode number 407, and it's corresponding return is -107.0, average rewards : -94.21
# Episode number 408, and it's corresponding return is -91.0, average rewards : -94.29
# Episode number 409, and it's corresponding return is -74.0, average rewards : -94.2
# Episode number 410, and it's corresponding return is -91.0, average rewards : -94.12
# Episode number 411, and it's corresponding return is -90.0, average rewards : -93.91
# Episode number 412, and it's corresponding return is -89.0, average rewards : -93.71
# Episode number 413, and it's corresponding return is -101.0, average rewards : -93.94
# Episode number 414, and it's corresponding return is -96.0, average rewards : -94.12
# Episode number 415, and it's corresponding return is -109.0, average rewards : -94.03
# Episode number 416, and it's corresponding return is -101.0, average rewards : -93.96
# Episode number 417, and it's corresponding return is -84.0, average rewards : -93.74
# Episode number 418, and it's corresponding return is -78.0, average rewards : -93.16
# Episode number 419, and it's corresponding return is -89.0, average rewards : -93.21
# Episode number 420, and it's corresponding return is -140.0, average rewards : -93.51
# Episode number 421, and it's corresponding return is -106.0, average rewards : -93.71
# Episode number 422, and it's corresponding return is -122.0, average rewards : -93.43
# Episode number 423, and it's corresponding return is -116.0, average rewards : -93.5
# Episode number 424, and it's corresponding return is -83.0, average rewards : -93.53
# Episode number 425, and it's corresponding return is -108.0, average rewards : -93.78
# Episode number 426, and it's corresponding return is -120.0, average rewards : -94.1
# Episode number 427, and it's corresponding return is -107.0, average rewards : -94.23
# Episode number 428, and it's corresponding return is -82.0, average rewards : -94.05
# Episode number 429, and it's corresponding return is -69.0, average rewards : -93.35
# Episode number 430, and it's corresponding return is -62.0, average rewards : -92.96
# Episode number 431, and it's corresponding return is -82.0, average rewards : -92.99
# Episode number 432, and it's corresponding return is -98.0, average rewards : -93.1
# Episode number 433, and it's corresponding return is -83.0, average rewards : -92.92
# Episode number 434, and it's corresponding return is -121.0, average rewards : -93.28
# Episode number 435, and it's corresponding return is -101.0, average rewards : -93.6
# Episode number 436, and it's corresponding return is -94.0, average rewards : -93.65
# Episode number 437, and it's corresponding return is -70.0, average rewards : -93.31
# Episode number 438, and it's corresponding return is -90.0, average rewards : -93.2
# Episode number 439, and it's corresponding return is -85.0, average rewards : -92.92
# Episode number 440, and it's corresponding return is -69.0, average rewards : -92.66
# Episode number 441, and it's corresponding return is -88.0, average rewards : -92.8
# Episode number 442, and it's corresponding return is -109.0, average rewards : -92.96
# Episode number 443, and it's corresponding return is -94.0, average rewards : -93.22
# Episode number 444, and it's corresponding return is -84.0, average rewards : -92.95
# Episode number 445, and it's corresponding return is -62.0, average rewards : -92.54
# Episode number 446, and it's corresponding return is -80.0, average rewards : -92.4
# Episode number 447, and it's corresponding return is -120.0, average rewards : -92.6
# Episode number 448, and it's corresponding return is -114.0, average rewards : -92.77
# Episode number 449, and it's corresponding return is -78.0, average rewards : -92.72
# Episode number 450, and it's corresponding return is -77.0, average rewards : -92.46
# Episode number 451, and it's corresponding return is -82.0, average rewards : -92.44
# Episode number 452, and it's corresponding return is -80.0, average rewards : -92.17
# Episode number 453, and it's corresponding return is -99.0, average rewards : -92.11
# Episode number 454, and it's corresponding return is -62.0, average rewards : -91.95
# Episode number 455, and it's corresponding return is -77.0, average rewards : -91.96
# Episode number 456, and it's corresponding return is -82.0, average rewards : -91.87
# Episode number 457, and it's corresponding return is -87.0, average rewards : -91.62
# Episode number 458, and it's corresponding return is -93.0, average rewards : -91.67
# Episode number 459, and it's corresponding return is -89.0, average rewards : -91.74
# Episode number 460, and it's corresponding return is -92.0, average rewards : -91.89
# Episode number 461, and it's corresponding return is -74.0, average rewards : -91.75
# Episode number 462, and it's corresponding return is -74.0, average rewards : -91.15
# Episode number 463, and it's corresponding return is -61.0, average rewards : -91.04
# Episode number 464, and it's corresponding return is -100.0, average rewards : -91.27
# Episode number 465, and it's corresponding return is -81.0, average rewards : -91.0
# Episode number 466, and it's corresponding return is -69.0, average rewards : -90.77
# Episode number 467, and it's corresponding return is -109.0, average rewards : -91.0
# Episode number 468, and it's corresponding return is -73.0, average rewards : -90.84
# Episode number 469, and it's corresponding return is -97.0, average rewards : -90.7
# Episode number 470, and it's corresponding return is -103.0, average rewards : -90.51
# Episode number 471, and it's corresponding return is -91.0, average rewards : -90.58
# Episode number 472, and it's corresponding return is -82.0, average rewards : -90.63
# Episode number 473, and it's corresponding return is -85.0, average rewards : -90.71
# Episode number 474, and it's corresponding return is -62.0, average rewards : -90.49
# Episode number 475, and it's corresponding return is -71.0, average rewards : -90.42
# Episode number 476, and it's corresponding return is -93.0, average rewards : -90.43
# Episode number 477, and it's corresponding return is -91.0, average rewards : -90.43
# Episode number 478, and it's corresponding return is -86.0, average rewards : -90.5
# Episode number 479, and it's corresponding return is -83.0, average rewards : -90.09
# Episode number 480, and it's corresponding return is -92.0, average rewards : -90.04
# Episode number 481, and it's corresponding return is -73.0, average rewards : -89.76
# Episode number 482, and it's corresponding return is -94.0, average rewards : -89.59
# Episode number 483, and it's corresponding return is -85.0, average rewards : -89.63
# Episode number 484, and it's corresponding return is -62.0, average rewards : -89.54
# Episode number 485, and it's corresponding return is -82.0, average rewards : -89.2
# Episode number 486, and it's corresponding return is -107.0, average rewards : -89.46
# Episode number 487, and it's corresponding return is -78.0, average rewards : -89.45
# Episode number 488, and it's corresponding return is -105.0, average rewards : -89.63
# Episode number 489, and it's corresponding return is -84.0, average rewards : -89.57
# Episode number 490, and it's corresponding return is -99.0, average rewards : -89.65
# Episode number 491, and it's corresponding return is -115.0, average rewards : -89.42
# Episode number 492, and it's corresponding return is -84.0, average rewards : -89.13
# Episode number 493, and it's corresponding return is -104.0, average rewards : -89.16
# Episode number 494, and it's corresponding return is -108.0, average rewards : -89.62
# Episode number 495, and it's corresponding return is -103.0, average rewards : -89.78
# Episode number 496, and it's corresponding return is -89.0, average rewards : -89.61
# Episode number 497, and it's corresponding return is -70.0, average rewards : -89.43
# Episode number 498, and it's corresponding return is -104.0, average rewards : -89.51
# Episode number 499, and it's corresponding return is -145.0, average rewards : -90.07
# Episode number 500, and it's corresponding return is -94.0, average rewards : -89.99
# Episode number 501, and it's corresponding return is -90.0, average rewards : -89.92
# Episode number 502, and it's corresponding return is -92.0, average rewards : -90.05
# Episode number 503, and it's corresponding return is -91.0, average rewards : -90.21
# Episode number 504, and it's corresponding return is -85.0, average rewards : -90.24
# Episode number 505, and it's corresponding return is -83.0, average rewards : -90.28
# Episode number 506, and it's corresponding return is -90.0, average rewards : -90.5
# Episode number 507, and it's corresponding return is -91.0, average rewards : -90.34
# Episode number 508, and it's corresponding return is -85.0, average rewards : -90.28
# Episode number 509, and it's corresponding return is -80.0, average rewards : -90.34
# Episode number 510, and it's corresponding return is -74.0, average rewards : -90.17
# Episode number 511, and it's corresponding return is -70.0, average rewards : -89.97
# Episode number 512, and it's corresponding return is -68.0, average rewards : -89.76
# Episode number 513, and it's corresponding return is -95.0, average rewards : -89.7
# Episode number 514, and it's corresponding return is -83.0, average rewards : -89.57
# Episode number 515, and it's corresponding return is -91.0, average rewards : -89.39
# Episode number 516, and it's corresponding return is -85.0, average rewards : -89.23
# Episode number 517, and it's corresponding return is -77.0, average rewards : -89.16
# Episode number 518, and it's corresponding return is -100.0, average rewards : -89.38
# Episode number 519, and it's corresponding return is -62.0, average rewards : -89.11
# Episode number 520, and it's corresponding return is -82.0, average rewards : -88.53
# Episode number 521, and it's corresponding return is -70.0, average rewards : -88.17
# Episode number 522, and it's corresponding return is -83.0, average rewards : -87.78
# Episode number 523, and it's corresponding return is -89.0, average rewards : -87.51
# Episode number 524, and it's corresponding return is -101.0, average rewards : -87.69
# Episode number 525, and it's corresponding return is -62.0, average rewards : -87.23
# Episode number 526, and it's corresponding return is -95.0, average rewards : -86.98
# Episode number 527, and it's corresponding return is -77.0, average rewards : -86.68
# Episode number 528, and it's corresponding return is -86.0, average rewards : -86.72
# Episode number 529, and it's corresponding return is -90.0, average rewards : -86.93
# Episode number 530, and it's corresponding return is -93.0, average rewards : -87.24
# Episode number 531, and it's corresponding return is -91.0, average rewards : -87.33
# Episode number 532, and it's corresponding return is -106.0, average rewards : -87.41
# Episode number 533, and it's corresponding return is -94.0, average rewards : -87.52
# Episode number 534, and it's corresponding return is -81.0, average rewards : -87.12
# Episode number 535, and it's corresponding return is -87.0, average rewards : -86.98
# Episode number 536, and it's corresponding return is -62.0, average rewards : -86.66
# Episode number 537, and it's corresponding return is -96.0, average rewards : -86.92
# Episode number 538, and it's corresponding return is -69.0, average rewards : -86.71
# Episode number 539, and it's corresponding return is -92.0, average rewards : -86.78
# Episode number 540, and it's corresponding return is -94.0, average rewards : -87.03
# Episode number 541, and it's corresponding return is -83.0, average rewards : -86.98
# Episode number 542, and it's corresponding return is -91.0, average rewards : -86.8
# Episode number 543, and it's corresponding return is -95.0, average rewards : -86.81
# Episode number 544, and it's corresponding return is -95.0, average rewards : -86.92
# Episode number 545, and it's corresponding return is -88.0, average rewards : -87.18
# Episode number 546, and it's corresponding return is -87.0, average rewards : -87.25
# Episode number 547, and it's corresponding return is -85.0, average rewards : -86.9
# Episode number 548, and it's corresponding return is -78.0, average rewards : -86.54
# Episode number 549, and it's corresponding return is -79.0, average rewards : -86.55
# Episode number 550, and it's corresponding return is -139.0, average rewards : -87.17
# Episode number 551, and it's corresponding return is -77.0, average rewards : -87.12
# Episode number 552, and it's corresponding return is -79.0, average rewards : -87.11
# Episode number 553, and it's corresponding return is -101.0, average rewards : -87.13
# Episode number 554, and it's corresponding return is -104.0, average rewards : -87.55
# Episode number 555, and it's corresponding return is -103.0, average rewards : -87.81
# Episode number 556, and it's corresponding return is -80.0, average rewards : -87.79
# Episode number 557, and it's corresponding return is -103.0, average rewards : -87.95
# ...
# Episode number 814, and it's corresponding return is -104.0, average rewards : -85.01
# Episode number 815, and it's corresponding return is -73.0, average rewards : -85.0
# Episode number 816, and it's corresponding return is -74.0, average rewards : -84.82
# Episode number 817, and it's corresponding return is -83.0, average rewards : -84.84
# Episode number 818, and it's corresponding return is -121.0, average rewards : -85.04
# Episode number 819, and it's corresponding return is -86.0, average rewards : -85.2
# Episode number 820, and it's corresponding return is -87.0, average rewards : -85.38
# Episode number 821, and it's corresponding return is -71.0, average rewards : -85.16
# Episode number 822, and it's corresponding return is -74.0, average rewards : -85.22
# Episode number 823, and it's corresponding return is -92.0, average rewards : -85.23
# Episode number 824, and it's corresponding return is -77.0, average rewards : -85.14
# Episode number 825, and it's corresponding return is -74.0, average rewards : -85.14
# Episode number 826, and it's corresponding return is -75.0, average rewards : -85.07
# Episode number 827, and it's corresponding return is -224.0, average rewards : -86.26
# Episode number 828, and it's corresponding return is -89.0, average rewards : -86.54
# Episode number 829, and it's corresponding return is -80.0, average rewards : -86.07
# Episode number 830, and it's corresponding return is -80.0, average rewards : -85.95
# Episode number 831, and it's corresponding return is -70.0, average rewards : -85.93
# Episode number 832, and it's corresponding return is -81.0, average rewards : -85.31
# Episode number 833, and it's corresponding return is -80.0, average rewards : -85.16
# Episode number 834, and it's corresponding return is -90.0, average rewards : -85.37
# Episode number 835, and it's corresponding return is -93.0, average rewards : -85.56
# Episode number 836, and it's corresponding return is -126.0, average rewards : -85.93
# Episode number 837, and it's corresponding return is -81.0, average rewards : -86.13
# Episode number 838, and it's corresponding return is -86.0, average rewards : -86.19
# Episode number 839, and it's corresponding return is -73.0, average rewards : -86.13
# Episode number 840, and it's corresponding return is -105.0, average rewards : -86.49
# Episode number 841, and it's corresponding return is -89.0, average rewards : -86.77
# Episode number 842, and it's corresponding return is -92.0, average rewards : -86.87
# Episode number 843, and it's corresponding return is -175.0, average rewards : -87.79
# Episode number 844, and it's corresponding return is -69.0, average rewards : -87.59
# Episode number 845, and it's corresponding return is -92.0, average rewards : -87.62
# Episode number 846, and it's corresponding return is -123.0, average rewards : -87.91
# Episode number 847, and it's corresponding return is -93.0, average rewards : -87.97
# Episode number 848, and it's corresponding return is -74.0, average rewards : -87.77
# Episode number 849, and it's corresponding return is -74.0, average rewards : -87.61
# Episode number 850, and it's corresponding return is -68.0, average rewards : -87.31
# Episode number 851, and it's corresponding return is -70.0, average rewards : -87.26
# Episode number 852, and it's corresponding return is -91.0, average rewards : -86.93
# Episode number 853, and it's corresponding return is -80.0, average rewards : -87.04
# Episode number 854, and it's corresponding return is -77.0, average rewards : -86.99
# Episode number 855, and it's corresponding return is -70.0, average rewards : -86.89
# Episode number 856, and it's corresponding return is -72.0, average rewards : -86.56
# Episode number 857, and it's corresponding return is -92.0, average rewards : -86.79
# Episode number 858, and it's corresponding return is -77.0, average rewards : -86.8
# Episode number 859, and it's corresponding return is -80.0, average rewards : -86.91
# Episode number 860, and it's corresponding return is -67.0, average rewards : -86.85
# Episode number 861, and it's corresponding return is -68.0, average rewards : -86.75
# Episode number 862, and it's corresponding return is -73.0, average rewards : -86.49
# Episode number 863, and it's corresponding return is -82.0, average rewards : -86.48
# Episode number 864, and it's corresponding return is -69.0, average rewards : -86.48
# Episode number 865, and it's corresponding return is -95.0, average rewards : -86.63
# Episode number 866, and it's corresponding return is -93.0, average rewards : -86.82
# Episode number 867, and it's corresponding return is -81.0, average rewards : -86.87
# Episode number 868, and it's corresponding return is -91.0, average rewards : -86.85
# Episode number 869, and it's corresponding return is -60.0, average rewards : -86.84
# Episode number 870, and it's corresponding return is -84.0, average rewards : -86.76
# Episode number 871, and it's corresponding return is -75.0, average rewards : -86.83
# Episode number 872, and it's corresponding return is -75.0, average rewards : -86.68
# Episode number 873, and it's corresponding return is -73.0, average rewards : -86.61
# Episode number 874, and it's corresponding return is -73.0, average rewards : -86.67
# Episode number 875, and it's corresponding return is -68.0, average rewards : -86.68
# Episode number 876, and it's corresponding return is -84.0, average rewards : -86.71
# Episode number 877, and it's corresponding return is -69.0, average rewards : -86.73
# Episode number 878, and it's corresponding return is -75.0, average rewards : -86.22
# Episode number 879, and it's corresponding return is -76.0, average rewards : -86.18
# Episode number 880, and it's corresponding return is -92.0, average rewards : -86.18
# Episode number 881, and it's corresponding return is -70.0, average rewards : -86.12
# Episode number 882, and it's corresponding return is -96.0, average rewards : -86.14
# Episode number 883, and it's corresponding return is -106.0, average rewards : -86.31
# Episode number 884, and it's corresponding return is -88.0, average rewards : -86.51
# Episode number 885, and it's corresponding return is -86.0, average rewards : -86.38
# Episode number 886, and it's corresponding return is -93.0, average rewards : -86.26
# Episode number 887, and it's corresponding return is -87.0, average rewards : -86.45
# Episode number 888, and it's corresponding return is -79.0, average rewards : -86.34
# Episode number 889, and it's corresponding return is -77.0, average rewards : -86.21
# Episode number 890, and it's corresponding return is -95.0, average rewards : -86.35
# Episode number 891, and it's corresponding return is -79.0, average rewards : -86.36
# Episode number 892, and it's corresponding return is -93.0, average rewards : -86.25
# Episode number 893, and it's corresponding return is -93.0, average rewards : -86.49
# Episode number 894, and it's corresponding return is -95.0, average rewards : -86.76
# Episode number 895, and it's corresponding return is -83.0, average rewards : -86.86
# Episode number 896, and it's corresponding return is -98.0, average rewards : -87.14
# Episode number 897, and it's corresponding return is -115.0, average rewards : -87.18
# Episode number 898, and it's corresponding return is -70.0, average rewards : -86.96
# Episode number 899, and it's corresponding return is -79.0, average rewards : -87.0
# Episode number 900, and it's corresponding return is -70.0, average rewards : -86.86
# Episode number 901, and it's corresponding return is -69.0, average rewards : -86.64
# Episode number 902, and it's corresponding return is -72.0, average rewards : -86.44
# Episode number 903, and it's corresponding return is -69.0, average rewards : -85.74
# Episode number 904, and it's corresponding return is -94.0, average rewards : -85.7
# Episode number 905, and it's corresponding return is -89.0, average rewards : -85.65
# Episode number 906, and it's corresponding return is -95.0, average rewards : -85.69
# Episode number 907, and it's corresponding return is -74.0, average rewards : -85.6
# Episode number 908, and it's corresponding return is -61.0, average rewards : -85.23
# Episode number 909, and it's corresponding return is -76.0, average rewards : -84.86
# Episode number 910, and it's corresponding return is -86.0, average rewards : -84.99
# Episode number 911, and it's corresponding return is -79.0, average rewards : -84.99
# Episode number 912, and it's corresponding return is -91.0, average rewards : -85.23
# Episode number 913, and it's corresponding return is -76.0, average rewards : -85.13
# Episode number 914, and it's corresponding return is -75.0, average rewards : -84.84
# Episode number 915, and it's corresponding return is -94.0, average rewards : -85.05
# Episode number 916, and it's corresponding return is -70.0, average rewards : -85.01
# Episode number 917, and it's corresponding return is -76.0, average rewards : -84.94
# Episode number 918, and it's corresponding return is -88.0, average rewards : -84.61
# Episode number 919, and it's corresponding return is -74.0, average rewards : -84.49
# Episode number 920, and it's corresponding return is -77.0, average rewards : -84.39
# Episode number 921, and it's corresponding return is -60.0, average rewards : -84.28
# Episode number 922, and it's corresponding return is -69.0, average rewards : -84.23
# Episode number 923, and it's corresponding return is -61.0, average rewards : -83.92
# Episode number 924, and it's corresponding return is -84.0, average rewards : -83.99
# Episode number 925, and it's corresponding return is -76.0, average rewards : -84.01
# Episode number 926, and it's corresponding return is -96.0, average rewards : -84.22
# Episode number 927, and it's corresponding return is -74.0, average rewards : -82.72
# Episode number 928, and it's corresponding return is -73.0, average rewards : -82.56
# Episode number 929, and it's corresponding return is -61.0, average rewards : -82.37
# Episode number 930, and it's corresponding return is -69.0, average rewards : -82.26
# Episode number 931, and it's corresponding return is -68.0, average rewards : -82.24
# Episode number 932, and it's corresponding return is -94.0, average rewards : -82.37
# Episode number 933, and it's corresponding return is -70.0, average rewards : -82.27
# Episode number 934, and it's corresponding return is -88.0, average rewards : -82.25
# Episode number 935, and it's corresponding return is -73.0, average rewards : -82.05
# Episode number 936, and it's corresponding return is -110.0, average rewards : -81.89
# Episode number 937, and it's corresponding return is -190.0, average rewards : -82.98
# Episode number 938, and it's corresponding return is -77.0, average rewards : -82.89
# Episode number 939, and it's corresponding return is -90.0, average rewards : -83.06
# Episode number 940, and it's corresponding return is -92.0, average rewards : -82.93
# Episode number 941, and it's corresponding return is -69.0, average rewards : -82.73
# Episode number 942, and it's corresponding return is -87.0, average rewards : -82.68
# Episode number 943, and it's corresponding return is -67.0, average rewards : -81.6
# Episode number 944, and it's corresponding return is -81.0, average rewards : -81.72
# Episode number 945, and it's corresponding return is -136.0, average rewards : -82.16
# Episode number 946, and it's corresponding return is -92.0, average rewards : -81.85
# Episode number 947, and it's corresponding return is -102.0, average rewards : -81.94
# Episode number 948, and it's corresponding return is -71.0, average rewards : -81.91
# Episode number 949, and it's corresponding return is -98.0, average rewards : -82.15
# Episode number 950, and it's corresponding return is -76.0, average rewards : -82.23
# Episode number 951, and it's corresponding return is -74.0, average rewards : -82.27
# Episode number 952, and it's corresponding return is -70.0, average rewards : -82.06
# Episode number 953, and it's corresponding return is -85.0, average rewards : -82.11
# Episode number 954, and it's corresponding return is -61.0, average rewards : -81.95
# Episode number 955, and it's corresponding return is -108.0, average rewards : -82.33
# Episode number 956, and it's corresponding return is -78.0, average rewards : -82.39
# Episode number 957, and it's corresponding return is -93.0, average rewards : -82.4
# Episode number 958, and it's corresponding return is -196.0, average rewards : -83.59
# Episode number 959, and it's corresponding return is -75.0, average rewards : -83.54
# Episode number 960, and it's corresponding return is -92.0, average rewards : -83.79
# Episode number 961, and it's corresponding return is -70.0, average rewards : -83.81
# Episode number 962, and it's corresponding return is -88.0, average rewards : -83.96
# Episode number 963, and it's corresponding return is -69.0, average rewards : -83.83
# Episode number 964, and it's corresponding return is -136.0, average rewards : -84.5
# Episode number 965, and it's corresponding return is -81.0, average rewards : -84.36
# Episode number 966, and it's corresponding return is -92.0, average rewards : -84.35
# Episode number 967, and it's corresponding return is -72.0, average rewards : -84.26
# Episode number 968, and it's corresponding return is -62.0, average rewards : -83.97
# Episode number 969, and it's corresponding return is -69.0, average rewards : -84.06
# Episode number 970, and it's corresponding return is -81.0, average rewards : -84.03
# Episode number 971, and it's corresponding return is -83.0, average rewards : -84.11
# Episode number 972, and it's corresponding return is -71.0, average rewards : -84.07
# Episode number 973, and it's corresponding return is -149.0, average rewards : -84.83
# Episode number 974, and it's corresponding return is -81.0, average rewards : -84.91
# Episode number 975, and it's corresponding return is -74.0, average rewards : -84.97
# Episode number 976, and it's corresponding return is -125.0, average rewards : -85.38
# Episode number 977, and it's corresponding return is -122.0, average rewards : -85.91
# Episode number 978, and it's corresponding return is -85.0, average rewards : -86.01
# Episode number 979, and it's corresponding return is -69.0, average rewards : -85.94
# Episode number 980, and it's corresponding return is -70.0, average rewards : -85.72
# Episode number 981, and it's corresponding return is -113.0, average rewards : -86.15
# Episode number 982, and it's corresponding return is -84.0, average rewards : -86.03
# Episode number 983, and it's corresponding return is -79.0, average rewards : -85.76
# Episode number 984, and it's corresponding return is -78.0, average rewards : -85.66
# Episode number 985, and it's corresponding return is -75.0, average rewards : -85.55
# Episode number 986, and it's corresponding return is -74.0, average rewards : -85.36
# Episode number 987, and it's corresponding return is -69.0, average rewards : -85.18
# Episode number 988, and it's corresponding return is -80.0, average rewards : -85.19
# Episode number 989, and it's corresponding return is -159.0, average rewards : -86.01
# Episode number 990, and it's corresponding return is -97.0, average rewards : -86.03
# Episode number 991, and it's corresponding return is -94.0, average rewards : -86.18
# Episode number 992, and it's corresponding return is -79.0, average rewards : -86.04
# Episode number 993, and it's corresponding return is -79.0, average rewards : -85.9
# Episode number 994, and it's corresponding return is -79.0, average rewards : -85.74
# Episode number 995, and it's corresponding return is -70.0, average rewards : -85.61
# Episode number 996, and it's corresponding return is -84.0, average rewards : -85.47
# Episode number 997, and it's corresponding return is -74.0, average rewards : -85.06
# Episode number 998, and it's corresponding return is -94.0, average rewards : -85.3
# Episode number 999, and it's corresponding return is -77.0, average rewards : -85.28
# Episode number 1000, and it's corresponding return is -95.0, average rewards : -85.53
# The iteration 5 ended

# %% [markdown]
# ### Running of Acrobot - v1 with Type - 2 Dueling DQN

# %%
list_returns_env_1_type_2 = deque()
for i in range(5):
  print(f"The iteration number is : {i + 1}")
  env_1_type_2 = dueling_dqn(env = env1, QNetwork = QNetwork2, seed = i)
  returns_env_1_type_2 = env_1_type_2.run(n_episodes = 1000)
  list_returns_env_1_type_2.append(returns_env_1_type_2)
  print(f"The iteration {i + 1} ended")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Streaming output truncated to the last 5000 lines.
# Episode number 10, and it's corresponding return is -500.0, average rewards : -485.4
# Episode number 11, and it's corresponding return is -419.0, average rewards : -479.3636363636364
# Episode number 12, and it's corresponding return is -500.0, average rewards : -481.0833333333333
# Episode number 13, and it's corresponding return is -500.0, average rewards : -482.53846153846155
# Episode number 14, and it's corresponding return is -500.0, average rewards : -483.7857142857143
# Episode number 15, and it's corresponding return is -500.0, average rewards : -484.8666666666667
# Episode number 16, and it's corresponding return is -500.0, average rewards : -485.8125
# Episode number 17, and it's corresponding return is -500.0, average rewards : -486.6470588235294
# Episode number 18, and it's corresponding return is -500.0, average rewards : -487.3888888888889
# Episode number 19, and it's corresponding return is -500.0, average rewards : -488.05263157894734
# Episode number 20, and it's corresponding return is -500.0, average rewards : -488.65
# Episode number 21, and it's corresponding return is -500.0, average rewards : -489.1904761904762
# Episode number 22, and it's corresponding return is -500.0, average rewards : -489.6818181818182
# Episode number 23, and it's corresponding return is -500.0, average rewards : -490.1304347826087
# Episode number 24, and it's corresponding return is -387.0, average rewards : -485.8333333333333
# Episode number 25, and it's corresponding return is -500.0, average rewards : -486.4
# Episode number 26, and it's corresponding return is -500.0, average rewards : -486.9230769230769
# Episode number 27, and it's corresponding return is -500.0, average rewards : -487.4074074074074
# Episode number 28, and it's corresponding return is -500.0, average rewards : -487.85714285714283
# Episode number 29, and it's corresponding return is -500.0, average rewards : -488.2758620689655
# Episode number 30, and it's corresponding return is -352.0, average rewards : -483.73333333333335
# Episode number 31, and it's corresponding return is -381.0, average rewards : -480.4193548387097
# Episode number 32, and it's corresponding return is -500.0, average rewards : -481.03125
# Episode number 33, and it's corresponding return is -500.0, average rewards : -481.6060606060606
# Episode number 34, and it's corresponding return is -334.0, average rewards : -477.2647058823529
# Episode number 35, and it's corresponding return is -255.0, average rewards : -470.9142857142857
# Episode number 36, and it's corresponding return is -500.0, average rewards : -471.72222222222223
# Episode number 37, and it's corresponding return is -500.0, average rewards : -472.4864864864865
# Episode number 38, and it's corresponding return is -500.0, average rewards : -473.2105263157895
# Episode number 39, and it's corresponding return is -445.0, average rewards : -472.4871794871795
# Episode number 40, and it's corresponding return is -500.0, average rewards : -473.175
# Episode number 41, and it's corresponding return is -477.0, average rewards : -473.2682926829268
# Episode number 42, and it's corresponding return is -500.0, average rewards : -473.9047619047619
# Episode number 43, and it's corresponding return is -313.0, average rewards : -470.16279069767444
# Episode number 44, and it's corresponding return is -500.0, average rewards : -470.84090909090907
# Episode number 45, and it's corresponding return is -352.0, average rewards : -468.2
# Episode number 46, and it's corresponding return is -500.0, average rewards : -468.89130434782606
# Episode number 47, and it's corresponding return is -383.0, average rewards : -467.06382978723406
# Episode number 48, and it's corresponding return is -500.0, average rewards : -467.75
# Episode number 49, and it's corresponding return is -444.0, average rewards : -467.265306122449
# Episode number 50, and it's corresponding return is -500.0, average rewards : -467.92
# Episode number 51, and it's corresponding return is -399.0, average rewards : -466.5686274509804
# Episode number 52, and it's corresponding return is -453.0, average rewards : -466.3076923076923
# Episode number 53, and it's corresponding return is -401.0, average rewards : -465.07547169811323
# Episode number 54, and it's corresponding return is -298.0, average rewards : -461.98148148148147
# Episode number 55, and it's corresponding return is -342.0, average rewards : -459.8
# Episode number 56, and it's corresponding return is -414.0, average rewards : -458.98214285714283
# Episode number 57, and it's corresponding return is -330.0, average rewards : -456.719298245614
# Episode number 58, and it's corresponding return is -498.0, average rewards : -457.4310344827586
# Episode number 59, and it's corresponding return is -262.0, average rewards : -454.1186440677966
# Episode number 60, and it's corresponding return is -221.0, average rewards : -450.23333333333335
# Episode number 61, and it's corresponding return is -360.0, average rewards : -448.75409836065575
# Episode number 62, and it's corresponding return is -426.0, average rewards : -448.38709677419354
# Episode number 63, and it's corresponding return is -220.0, average rewards : -444.76190476190476
# Episode number 64, and it's corresponding return is -279.0, average rewards : -442.171875
# Episode number 65, and it's corresponding return is -210.0, average rewards : -438.6
# Episode number 66, and it's corresponding return is -291.0, average rewards : -436.3636363636364
# Episode number 67, and it's corresponding return is -234.0, average rewards : -433.34328358208955
# Episode number 68, and it's corresponding return is -419.0, average rewards : -433.13235294117646
# Episode number 69, and it's corresponding return is -334.0, average rewards : -431.69565217391306
# Episode number 70, and it's corresponding return is -307.0, average rewards : -429.9142857142857
# Episode number 71, and it's corresponding return is -163.0, average rewards : -426.15492957746477
# Episode number 72, and it's corresponding return is -238.0, average rewards : -423.5416666666667
# Episode number 73, and it's corresponding return is -287.0, average rewards : -421.67123287671234
# Episode number 74, and it's corresponding return is -206.0, average rewards : -418.7567567567568
# Episode number 75, and it's corresponding return is -291.0, average rewards : -417.05333333333334
# Episode number 76, and it's corresponding return is -257.0, average rewards : -414.94736842105266
# Episode number 77, and it's corresponding return is -300.0, average rewards : -413.45454545454544
# Episode number 78, and it's corresponding return is -231.0, average rewards : -411.11538461538464
# Episode number 79, and it's corresponding return is -240.0, average rewards : -408.9493670886076
# Episode number 80, and it's corresponding return is -292.0, average rewards : -407.4875
# Episode number 81, and it's corresponding return is -226.0, average rewards : -405.24691358024694
# Episode number 82, and it's corresponding return is -215.0, average rewards : -402.9268292682927
# Episode number 83, and it's corresponding return is -193.0, average rewards : -400.3975903614458
# Episode number 84, and it's corresponding return is -274.0, average rewards : -398.89285714285717
# Episode number 85, and it's corresponding return is -246.0, average rewards : -397.09411764705885
# Episode number 86, and it's corresponding return is -266.0, average rewards : -395.56976744186045
# Episode number 87, and it's corresponding return is -171.0, average rewards : -392.98850574712645
# Episode number 88, and it's corresponding return is -248.0, average rewards : -391.34090909090907
# Episode number 89, and it's corresponding return is -226.0, average rewards : -389.4831460674157
# Episode number 90, and it's corresponding return is -252.0, average rewards : -387.9555555555556
# Episode number 91, and it's corresponding return is -264.0, average rewards : -386.5934065934066
# Episode number 92, and it's corresponding return is -215.0, average rewards : -384.7282608695652
# Episode number 93, and it's corresponding return is -245.0, average rewards : -383.2258064516129
# Episode number 94, and it's corresponding return is -500.0, average rewards : -384.468085106383
# Episode number 95, and it's corresponding return is -215.0, average rewards : -382.6842105263158
# Episode number 96, and it's corresponding return is -211.0, average rewards : -380.8958333333333
# Episode number 97, and it's corresponding return is -179.0, average rewards : -378.8144329896907
# Episode number 98, and it's corresponding return is -190.0, average rewards : -376.88775510204084
# Episode number 99, and it's corresponding return is -148.0, average rewards : -374.57575757575756
# Episode number 100, and it's corresponding return is -175.0, average rewards : -372.58
# Episode number 101, and it's corresponding return is -269.0, average rewards : -370.27
# Episode number 102, and it's corresponding return is -187.0, average rewards : -367.14
# Episode number 103, and it's corresponding return is -164.0, average rewards : -363.78
# Episode number 104, and it's corresponding return is -269.0, average rewards : -361.47
# Episode number 105, and it's corresponding return is -137.0, average rewards : -359.3
# Episode number 106, and it's corresponding return is -167.0, average rewards : -355.97
# Episode number 107, and it's corresponding return is -168.0, average rewards : -352.65
# Episode number 108, and it's corresponding return is -141.0, average rewards : -349.06
# Episode number 109, and it's corresponding return is -240.0, average rewards : -346.46
# Episode number 110, and it's corresponding return is -261.0, average rewards : -344.07
# Episode number 111, and it's corresponding return is -156.0, average rewards : -341.44
# Episode number 112, and it's corresponding return is -177.0, average rewards : -338.21
# Episode number 113, and it's corresponding return is -162.0, average rewards : -334.83
# Episode number 114, and it's corresponding return is -482.0, average rewards : -334.65
# Episode number 115, and it's corresponding return is -208.0, average rewards : -331.73
# Episode number 116, and it's corresponding return is -119.0, average rewards : -327.92
# Episode number 117, and it's corresponding return is -173.0, average rewards : -324.65
# Episode number 118, and it's corresponding return is -216.0, average rewards : -321.81
# Episode number 119, and it's corresponding return is -178.0, average rewards : -318.59
# Episode number 120, and it's corresponding return is -257.0, average rewards : -316.16
# Episode number 121, and it's corresponding return is -157.0, average rewards : -312.73
# Episode number 122, and it's corresponding return is -147.0, average rewards : -309.2
# Episode number 123, and it's corresponding return is -134.0, average rewards : -305.54
# Episode number 124, and it's corresponding return is -210.0, average rewards : -303.77
# Episode number 125, and it's corresponding return is -166.0, average rewards : -300.43
# Episode number 126, and it's corresponding return is -288.0, average rewards : -298.31
# Episode number 127, and it's corresponding return is -154.0, average rewards : -294.85
# Episode number 128, and it's corresponding return is -241.0, average rewards : -292.26
# Episode number 129, and it's corresponding return is -147.0, average rewards : -288.73
# Episode number 130, and it's corresponding return is -154.0, average rewards : -286.75
# Episode number 131, and it's corresponding return is -169.0, average rewards : -284.63
# Episode number 132, and it's corresponding return is -188.0, average rewards : -281.51
# Episode number 133, and it's corresponding return is -204.0, average rewards : -278.55
# Episode number 134, and it's corresponding return is -216.0, average rewards : -277.37
# Episode number 135, and it's corresponding return is -192.0, average rewards : -276.74
# Episode number 136, and it's corresponding return is -214.0, average rewards : -273.88
# Episode number 137, and it's corresponding return is -166.0, average rewards : -270.54
# Episode number 138, and it's corresponding return is -500.0, average rewards : -270.54
# Episode number 139, and it's corresponding return is -221.0, average rewards : -268.3
# Episode number 140, and it's corresponding return is -116.0, average rewards : -264.46
# Episode number 141, and it's corresponding return is -157.0, average rewards : -261.26
# Episode number 142, and it's corresponding return is -155.0, average rewards : -257.81
# Episode number 143, and it's corresponding return is -210.0, average rewards : -256.78
# Episode number 144, and it's corresponding return is -166.0, average rewards : -253.44
# Episode number 145, and it's corresponding return is -154.0, average rewards : -251.46
# Episode number 146, and it's corresponding return is -132.0, average rewards : -247.78
# Episode number 147, and it's corresponding return is -150.0, average rewards : -245.45
# Episode number 148, and it's corresponding return is -138.0, average rewards : -241.83
# Episode number 149, and it's corresponding return is -181.0, average rewards : -239.2
# Episode number 150, and it's corresponding return is -116.0, average rewards : -235.36
# Episode number 151, and it's corresponding return is -152.0, average rewards : -232.89
# Episode number 152, and it's corresponding return is -147.0, average rewards : -229.83
# Episode number 153, and it's corresponding return is -166.0, average rewards : -227.48
# Episode number 154, and it's corresponding return is -200.0, average rewards : -226.5
# Episode number 155, and it's corresponding return is -102.0, average rewards : -224.1
# Episode number 156, and it's corresponding return is -129.0, average rewards : -221.25
# Episode number 157, and it's corresponding return is -122.0, average rewards : -219.17
# Episode number 158, and it's corresponding return is -193.0, average rewards : -216.12
# Episode number 159, and it's corresponding return is -168.0, average rewards : -215.18
# Episode number 160, and it's corresponding return is -200.0, average rewards : -214.97
# Episode number 161, and it's corresponding return is -182.0, average rewards : -213.19
# Episode number 162, and it's corresponding return is -118.0, average rewards : -210.11
# Episode number 163, and it's corresponding return is -113.0, average rewards : -209.04
# Episode number 164, and it's corresponding return is -79.0, average rewards : -207.04
# Episode number 165, and it's corresponding return is -188.0, average rewards : -206.82
# Episode number 166, and it's corresponding return is -179.0, average rewards : -205.7
# Episode number 167, and it's corresponding return is -464.0, average rewards : -208.0
# Episode number 168, and it's corresponding return is -152.0, average rewards : -205.33
# Episode number 169, and it's corresponding return is -162.0, average rewards : -203.61
# Episode number 170, and it's corresponding return is -151.0, average rewards : -202.05
# Episode number 171, and it's corresponding return is -114.0, average rewards : -201.56
# Episode number 172, and it's corresponding return is -140.0, average rewards : -200.58
# Episode number 173, and it's corresponding return is -131.0, average rewards : -199.02
# Episode number 174, and it's corresponding return is -138.0, average rewards : -198.34
# Episode number 175, and it's corresponding return is -111.0, average rewards : -196.54
# Episode number 176, and it's corresponding return is -141.0, average rewards : -195.38
# Episode number 177, and it's corresponding return is -167.0, average rewards : -194.05
# Episode number 178, and it's corresponding return is -148.0, average rewards : -193.22
# Episode number 179, and it's corresponding return is -173.0, average rewards : -192.55
# Episode number 180, and it's corresponding return is -130.0, average rewards : -190.93
# Episode number 181, and it's corresponding return is -154.0, average rewards : -190.21
# Episode number 182, and it's corresponding return is -135.0, average rewards : -189.41
# Episode number 183, and it's corresponding return is -129.0, average rewards : -188.77
# Episode number 184, and it's corresponding return is -124.0, average rewards : -187.27
# Episode number 185, and it's corresponding return is -153.0, average rewards : -186.34
# Episode number 186, and it's corresponding return is -290.0, average rewards : -186.58
# Episode number 187, and it's corresponding return is -104.0, average rewards : -185.91
# Episode number 188, and it's corresponding return is -131.0, average rewards : -184.74
# Episode number 189, and it's corresponding return is -139.0, average rewards : -183.87
# Episode number 190, and it's corresponding return is -132.0, average rewards : -182.67
# Episode number 191, and it's corresponding return is -150.0, average rewards : -181.53
# Episode number 192, and it's corresponding return is -110.0, average rewards : -180.48
# Episode number 193, and it's corresponding return is -115.0, average rewards : -179.18
# Episode number 194, and it's corresponding return is -90.0, average rewards : -175.08
# Episode number 195, and it's corresponding return is -144.0, average rewards : -174.37
# Episode number 196, and it's corresponding return is -197.0, average rewards : -174.23
# Episode number 197, and it's corresponding return is -130.0, average rewards : -173.74
# Episode number 198, and it's corresponding return is -140.0, average rewards : -173.24
# Episode number 199, and it's corresponding return is -112.0, average rewards : -172.88
# Episode number 200, and it's corresponding return is -138.0, average rewards : -172.51
# Episode number 201, and it's corresponding return is -153.0, average rewards : -171.35
# Episode number 202, and it's corresponding return is -150.0, average rewards : -170.98
# Episode number 203, and it's corresponding return is -112.0, average rewards : -170.46
# Episode number 204, and it's corresponding return is -116.0, average rewards : -168.93
# Episode number 205, and it's corresponding return is -108.0, average rewards : -168.64
# Episode number 206, and it's corresponding return is -109.0, average rewards : -168.06
# Episode number 207, and it's corresponding return is -140.0, average rewards : -167.78
# Episode number 208, and it's corresponding return is -92.0, average rewards : -167.29
# Episode number 209, and it's corresponding return is -115.0, average rewards : -166.04
# Episode number 210, and it's corresponding return is -101.0, average rewards : -164.44
# Episode number 211, and it's corresponding return is -88.0, average rewards : -163.76
# Episode number 212, and it's corresponding return is -171.0, average rewards : -163.7
# Episode number 213, and it's corresponding return is -104.0, average rewards : -163.12
# Episode number 214, and it's corresponding return is -305.0, average rewards : -161.35
# Episode number 215, and it's corresponding return is -92.0, average rewards : -160.19
# Episode number 216, and it's corresponding return is -111.0, average rewards : -160.11
# Episode number 217, and it's corresponding return is -128.0, average rewards : -159.66
# Episode number 218, and it's corresponding return is -95.0, average rewards : -158.45
# Episode number 219, and it's corresponding return is -107.0, average rewards : -157.74
# Episode number 220, and it's corresponding return is -93.0, average rewards : -156.1
# Episode number 221, and it's corresponding return is -114.0, average rewards : -155.67
# Episode number 222, and it's corresponding return is -116.0, average rewards : -155.36
# Episode number 223, and it's corresponding return is -96.0, average rewards : -154.98
# Episode number 224, and it's corresponding return is -91.0, average rewards : -153.79
# Episode number 225, and it's corresponding return is -280.0, average rewards : -154.93
# Episode number 226, and it's corresponding return is -132.0, average rewards : -153.37
# Episode number 227, and it's corresponding return is -145.0, average rewards : -153.28
# Episode number 228, and it's corresponding return is -133.0, average rewards : -152.2
# Episode number 229, and it's corresponding return is -90.0, average rewards : -151.63
# Episode number 230, and it's corresponding return is -377.0, average rewards : -153.86
# Episode number 231, and it's corresponding return is -97.0, average rewards : -153.14
# Episode number 232, and it's corresponding return is -114.0, average rewards : -152.4
# Episode number 233, and it's corresponding return is -107.0, average rewards : -151.43
# Episode number 234, and it's corresponding return is -151.0, average rewards : -150.78
# Episode number 235, and it's corresponding return is -154.0, average rewards : -150.4
# Episode number 236, and it's corresponding return is -89.0, average rewards : -149.15
# Episode number 237, and it's corresponding return is -79.0, average rewards : -148.28
# Episode number 238, and it's corresponding return is -115.0, average rewards : -144.43
# Episode number 239, and it's corresponding return is -121.0, average rewards : -143.43
# Episode number 240, and it's corresponding return is -133.0, average rewards : -143.6
# Episode number 241, and it's corresponding return is -74.0, average rewards : -142.77
# Episode number 242, and it's corresponding return is -87.0, average rewards : -142.09
# Episode number 243, and it's corresponding return is -103.0, average rewards : -141.02
# Episode number 244, and it's corresponding return is -99.0, average rewards : -140.35
# Episode number 245, and it's corresponding return is -94.0, average rewards : -139.75
# Episode number 246, and it's corresponding return is -143.0, average rewards : -139.86
# Episode number 247, and it's corresponding return is -98.0, average rewards : -139.34
# Episode number 248, and it's corresponding return is -97.0, average rewards : -138.93
# Episode number 249, and it's corresponding return is -389.0, average rewards : -141.01
# Episode number 250, and it's corresponding return is -119.0, average rewards : -141.04
# Episode number 251, and it's corresponding return is -84.0, average rewards : -140.36
# Episode number 252, and it's corresponding return is -116.0, average rewards : -140.05
# Episode number 253, and it's corresponding return is -137.0, average rewards : -139.76
# Episode number 254, and it's corresponding return is -88.0, average rewards : -138.64
# Episode number 255, and it's corresponding return is -103.0, average rewards : -138.65
# Episode number 256, and it's corresponding return is -141.0, average rewards : -138.77
# Episode number 257, and it's corresponding return is -110.0, average rewards : -138.65
# Episode number 258, and it's corresponding return is -95.0, average rewards : -137.67
# Episode number 259, and it's corresponding return is -101.0, average rewards : -137.0
# Episode number 260, and it's corresponding return is -110.0, average rewards : -136.1
# Episode number 261, and it's corresponding return is -89.0, average rewards : -135.17
# Episode number 262, and it's corresponding return is -117.0, average rewards : -135.16
# Episode number 263, and it's corresponding return is -103.0, average rewards : -135.06
# Episode number 264, and it's corresponding return is -130.0, average rewards : -135.57
# Episode number 265, and it's corresponding return is -124.0, average rewards : -134.93
# Episode number 266, and it's corresponding return is -90.0, average rewards : -134.04
# Episode number 267, and it's corresponding return is -119.0, average rewards : -130.59
# Episode number 268, and it's corresponding return is -123.0, average rewards : -130.3
# Episode number 269, and it's corresponding return is -121.0, average rewards : -129.89
# Episode number 270, and it's corresponding return is -129.0, average rewards : -129.67
# Episode number 271, and it's corresponding return is -118.0, average rewards : -129.71
# Episode number 272, and it's corresponding return is -123.0, average rewards : -129.54
# Episode number 273, and it's corresponding return is -165.0, average rewards : -129.88
# Episode number 274, and it's corresponding return is -120.0, average rewards : -129.7
# Episode number 275, and it's corresponding return is -133.0, average rewards : -129.92
# Episode number 276, and it's corresponding return is -221.0, average rewards : -130.72
# Episode number 277, and it's corresponding return is -83.0, average rewards : -129.88
# Episode number 278, and it's corresponding return is -201.0, average rewards : -130.41
# Episode number 279, and it's corresponding return is -105.0, average rewards : -129.73
# Episode number 280, and it's corresponding return is -113.0, average rewards : -129.56
# Episode number 281, and it's corresponding return is -105.0, average rewards : -129.07
# Episode number 282, and it's corresponding return is -106.0, average rewards : -128.78
# Episode number 283, and it's corresponding return is -93.0, average rewards : -128.42
# Episode number 284, and it's corresponding return is -128.0, average rewards : -128.46
# Episode number 285, and it's corresponding return is -102.0, average rewards : -127.95
# Episode number 286, and it's corresponding return is -124.0, average rewards : -126.29
# Episode number 287, and it's corresponding return is -99.0, average rewards : -126.24
# Episode number 288, and it's corresponding return is -94.0, average rewards : -125.87
# Episode number 289, and it's corresponding return is -108.0, average rewards : -125.56
# Episode number 290, and it's corresponding return is -92.0, average rewards : -125.16
# Episode number 291, and it's corresponding return is -128.0, average rewards : -124.94
# Episode number 292, and it's corresponding return is -144.0, average rewards : -125.28
# Episode number 293, and it's corresponding return is -84.0, average rewards : -124.97
# Episode number 294, and it's corresponding return is -87.0, average rewards : -124.94
# Episode number 295, and it's corresponding return is -90.0, average rewards : -124.4
# Episode number 296, and it's corresponding return is -130.0, average rewards : -123.73
# Episode number 297, and it's corresponding return is -93.0, average rewards : -123.36
# Episode number 298, and it's corresponding return is -83.0, average rewards : -122.79
# Episode number 299, and it's corresponding return is -90.0, average rewards : -122.57
# Episode number 300, and it's corresponding return is -82.0, average rewards : -122.01
# Episode number 301, and it's corresponding return is -111.0, average rewards : -121.59
# Episode number 302, and it's corresponding return is -127.0, average rewards : -121.36
# Episode number 303, and it's corresponding return is -93.0, average rewards : -121.17
# Episode number 304, and it's corresponding return is -82.0, average rewards : -120.83
# Episode number 305, and it's corresponding return is -97.0, average rewards : -120.72
# Episode number 306, and it's corresponding return is -114.0, average rewards : -120.77
# Episode number 307, and it's corresponding return is -71.0, average rewards : -120.08
# Episode number 308, and it's corresponding return is -108.0, average rewards : -120.24
# Episode number 309, and it's corresponding return is -111.0, average rewards : -120.2
# Episode number 310, and it's corresponding return is -120.0, average rewards : -120.39
# Episode number 311, and it's corresponding return is -127.0, average rewards : -120.78
# Episode number 312, and it's corresponding return is -118.0, average rewards : -120.25
# Episode number 313, and it's corresponding return is -310.0, average rewards : -122.31
# Episode number 314, and it's corresponding return is -89.0, average rewards : -120.15
# Episode number 315, and it's corresponding return is -166.0, average rewards : -120.89
# Episode number 316, and it's corresponding return is -104.0, average rewards : -120.82
# Episode number 317, and it's corresponding return is -122.0, average rewards : -120.76
# Episode number 318, and it's corresponding return is -87.0, average rewards : -120.68
# Episode number 319, and it's corresponding return is -170.0, average rewards : -121.31
# Episode number 320, and it's corresponding return is -106.0, average rewards : -121.44
# Episode number 321, and it's corresponding return is -81.0, average rewards : -121.11
# Episode number 322, and it's corresponding return is -87.0, average rewards : -120.82
# Episode number 323, and it's corresponding return is -140.0, average rewards : -121.26
# Episode number 324, and it's corresponding return is -86.0, average rewards : -121.21
# Episode number 325, and it's corresponding return is -145.0, average rewards : -119.86
# Episode number 326, and it's corresponding return is -75.0, average rewards : -119.29
# Episode number 327, and it's corresponding return is -99.0, average rewards : -118.83
# Episode number 328, and it's corresponding return is -105.0, average rewards : -118.55
# Episode number 329, and it's corresponding return is -88.0, average rewards : -118.53
# Episode number 330, and it's corresponding return is -211.0, average rewards : -116.87
# Episode number 331, and it's corresponding return is -124.0, average rewards : -117.14
# Episode number 332, and it's corresponding return is -116.0, average rewards : -117.16
# Episode number 333, and it's corresponding return is -127.0, average rewards : -117.36
# Episode number 334, and it's corresponding return is -103.0, average rewards : -116.88
# Episode number 335, and it's corresponding return is -107.0, average rewards : -116.41
# Episode number 336, and it's corresponding return is -142.0, average rewards : -116.94
# Episode number 337, and it's corresponding return is -94.0, average rewards : -117.09
# Episode number 338, and it's corresponding return is -118.0, average rewards : -117.12
# Episode number 339, and it's corresponding return is -79.0, average rewards : -116.7
# Episode number 340, and it's corresponding return is -112.0, average rewards : -116.49
# Episode number 341, and it's corresponding return is -75.0, average rewards : -116.5
# Episode number 342, and it's corresponding return is -107.0, average rewards : -116.7
# Episode number 343, and it's corresponding return is -116.0, average rewards : -116.83
# Episode number 344, and it's corresponding return is -80.0, average rewards : -116.64
# Episode number 345, and it's corresponding return is -83.0, average rewards : -116.53
# Episode number 346, and it's corresponding return is -109.0, average rewards : -116.19
# Episode number 347, and it's corresponding return is -83.0, average rewards : -116.04
# Episode number 348, and it's corresponding return is -87.0, average rewards : -115.94
# Episode number 349, and it's corresponding return is -93.0, average rewards : -112.98
# Episode number 350, and it's corresponding return is -84.0, average rewards : -112.63
# Episode number 351, and it's corresponding return is -117.0, average rewards : -112.96
# Episode number 352, and it's corresponding return is -85.0, average rewards : -112.65
# Episode number 353, and it's corresponding return is -116.0, average rewards : -112.44
# Episode number 354, and it's corresponding return is -95.0, average rewards : -112.51
# Episode number 355, and it's corresponding return is -112.0, average rewards : -112.6
# Episode number 356, and it's corresponding return is -98.0, average rewards : -112.17
# Episode number 357, and it's corresponding return is -100.0, average rewards : -112.07
# Episode number 358, and it's corresponding return is -118.0, average rewards : -112.3
# Episode number 359, and it's corresponding return is -210.0, average rewards : -113.39
# Episode number 360, and it's corresponding return is -88.0, average rewards : -113.17
# Episode number 361, and it's corresponding return is -95.0, average rewards : -113.23
# Episode number 362, and it's corresponding return is -107.0, average rewards : -113.13
# Episode number 363, and it's corresponding return is -100.0, average rewards : -113.1
# Episode number 364, and it's corresponding return is -113.0, average rewards : -112.93
# Episode number 365, and it's corresponding return is -110.0, average rewards : -112.79
# Episode number 366, and it's corresponding return is -94.0, average rewards : -112.83
# Episode number 367, and it's corresponding return is -76.0, average rewards : -112.4
# Episode number 368, and it's corresponding return is -94.0, average rewards : -112.11
# Episode number 369, and it's corresponding return is -253.0, average rewards : -113.43
# Episode number 370, and it's corresponding return is -87.0, average rewards : -113.01
# Episode number 371, and it's corresponding return is -103.0, average rewards : -112.86
# Episode number 372, and it's corresponding return is -113.0, average rewards : -112.76
# Episode number 373, and it's corresponding return is -114.0, average rewards : -112.25
# Episode number 374, and it's corresponding return is -101.0, average rewards : -112.06
# Episode number 375, and it's corresponding return is -115.0, average rewards : -111.88
# Episode number 376, and it's corresponding return is -121.0, average rewards : -110.88
# Episode number 377, and it's corresponding return is -97.0, average rewards : -111.02
# Episode number 378, and it's corresponding return is -95.0, average rewards : -109.96
# Episode number 379, and it's corresponding return is -100.0, average rewards : -109.91
# Episode number 380, and it's corresponding return is -93.0, average rewards : -109.71
# Episode number 381, and it's corresponding return is -96.0, average rewards : -109.62
# Episode number 382, and it's corresponding return is -103.0, average rewards : -109.59
# Episode number 383, and it's corresponding return is -99.0, average rewards : -109.65
# Episode number 384, and it's corresponding return is -112.0, average rewards : -109.49
# Episode number 385, and it's corresponding return is -84.0, average rewards : -109.31
# Episode number 386, and it's corresponding return is -121.0, average rewards : -109.28
# Episode number 387, and it's corresponding return is -114.0, average rewards : -109.43
# Episode number 388, and it's corresponding return is -90.0, average rewards : -109.39
# Episode number 389, and it's corresponding return is -128.0, average rewards : -109.59
# Episode number 390, and it's corresponding return is -174.0, average rewards : -110.41
# Episode number 391, and it's corresponding return is -85.0, average rewards : -109.98
# Episode number 392, and it's corresponding return is -83.0, average rewards : -109.37
# Episode number 393, and it's corresponding return is -80.0, average rewards : -109.33
# Episode number 394, and it's corresponding return is -88.0, average rewards : -109.34
# Episode number 395, and it's corresponding return is -99.0, average rewards : -109.43
# Episode number 396, and it's corresponding return is -68.0, average rewards : -108.81
# Episode number 397, and it's corresponding return is -78.0, average rewards : -108.66
# Episode number 398, and it's corresponding return is -83.0, average rewards : -108.66
# Episode number 399, and it's corresponding return is -115.0, average rewards : -108.91
# Episode number 400, and it's corresponding return is -95.0, average rewards : -109.04
# Episode number 401, and it's corresponding return is -127.0, average rewards : -109.2
# Episode number 402, and it's corresponding return is -108.0, average rewards : -109.01
# Episode number 403, and it's corresponding return is -89.0, average rewards : -108.97
# Episode number 404, and it's corresponding return is -80.0, average rewards : -108.95
# Episode number 405, and it's corresponding return is -137.0, average rewards : -109.35
# Episode number 406, and it's corresponding return is -90.0, average rewards : -109.11
# Episode number 407, and it's corresponding return is -101.0, average rewards : -109.41
# Episode number 408, and it's corresponding return is -108.0, average rewards : -109.41
# Episode number 409, and it's corresponding return is -127.0, average rewards : -109.57
# Episode number 410, and it's corresponding return is -101.0, average rewards : -109.38
# Episode number 411, and it's corresponding return is -76.0, average rewards : -108.87
# Episode number 412, and it's corresponding return is -78.0, average rewards : -108.47
# Episode number 413, and it's corresponding return is -79.0, average rewards : -106.16
# Episode number 414, and it's corresponding return is -109.0, average rewards : -106.36
# Episode number 415, and it's corresponding return is -123.0, average rewards : -105.93
# Episode number 416, and it's corresponding return is -118.0, average rewards : -106.07
# Episode number 417, and it's corresponding return is -83.0, average rewards : -105.68
# Episode number 418, and it's corresponding return is -118.0, average rewards : -105.99
# Episode number 419, and it's corresponding return is -86.0, average rewards : -105.15
# Episode number 420, and it's corresponding return is -89.0, average rewards : -104.98
# Episode number 421, and it's corresponding return is -119.0, average rewards : -105.36
# Episode number 422, and it's corresponding return is -91.0, average rewards : -105.4
# Episode number 423, and it's corresponding return is -78.0, average rewards : -104.78
# Episode number 424, and it's corresponding return is -110.0, average rewards : -105.02
# Episode number 425, and it's corresponding return is -107.0, average rewards : -104.64
# Episode number 426, and it's corresponding return is -85.0, average rewards : -104.74
# Episode number 427, and it's corresponding return is -77.0, average rewards : -104.52
# Episode number 428, and it's corresponding return is -110.0, average rewards : -104.57
# Episode number 429, and it's corresponding return is -116.0, average rewards : -104.85
# Episode number 430, and it's corresponding return is -133.0, average rewards : -104.07
# Episode number 431, and it's corresponding return is -108.0, average rewards : -103.91
# Episode number 432, and it's corresponding return is -84.0, average rewards : -103.59
# Episode number 433, and it's corresponding return is -73.0, average rewards : -103.05
# Episode number 434, and it's corresponding return is -82.0, average rewards : -102.84
# Episode number 435, and it's corresponding return is -69.0, average rewards : -102.46
# Episode number 436, and it's corresponding return is -126.0, average rewards : -102.3
# Episode number 437, and it's corresponding return is -89.0, average rewards : -102.25
# Episode number 438, and it's corresponding return is -92.0, average rewards : -101.99
# Episode number 439, and it's corresponding return is -106.0, average rewards : -102.26
# Episode number 440, and it's corresponding return is -132.0, average rewards : -102.46
# Episode number 441, and it's corresponding return is -100.0, average rewards : -102.71
# Episode number 442, and it's corresponding return is -131.0, average rewards : -102.95
# Episode number 443, and it's corresponding return is -84.0, average rewards : -102.63
# Episode number 444, and it's corresponding return is -119.0, average rewards : -103.02
# Episode number 445, and it's corresponding return is -113.0, average rewards : -103.32
# Episode number 446, and it's corresponding return is -88.0, average rewards : -103.11
# Episode number 447, and it's corresponding return is -86.0, average rewards : -103.14
# Episode number 448, and it's corresponding return is -99.0, average rewards : -103.26
# Episode number 449, and it's corresponding return is -111.0, average rewards : -103.44
# Episode number 450, and it's corresponding return is -84.0, average rewards : -103.44
# Episode number 451, and it's corresponding return is -90.0, average rewards : -103.17
# Episode number 452, and it's corresponding return is -78.0, average rewards : -103.1
# Episode number 453, and it's corresponding return is -128.0, average rewards : -103.22
# Episode number 454, and it's corresponding return is -105.0, average rewards : -103.32
# Episode number 455, and it's corresponding return is -167.0, average rewards : -103.87
# Episode number 456, and it's corresponding return is -76.0, average rewards : -103.65
# Episode number 457, and it's corresponding return is -103.0, average rewards : -103.68
# Episode number 458, and it's corresponding return is -127.0, average rewards : -103.77
# Episode number 459, and it's corresponding return is -105.0, average rewards : -102.72
# Episode number 460, and it's corresponding return is -94.0, average rewards : -102.78
# Episode number 461, and it's corresponding return is -124.0, average rewards : -103.07
# Episode number 462, and it's corresponding return is -85.0, average rewards : -102.85
# Episode number 463, and it's corresponding return is -108.0, average rewards : -102.93
# Episode number 464, and it's corresponding return is -103.0, average rewards : -102.83
# Episode number 465, and it's corresponding return is -116.0, average rewards : -102.89
# Episode number 466, and it's corresponding return is -94.0, average rewards : -102.89
# Episode number 467, and it's corresponding return is -77.0, average rewards : -102.9
# Episode number 468, and it's corresponding return is -169.0, average rewards : -103.65
# Episode number 469, and it's corresponding return is -98.0, average rewards : -102.1
# Episode number 470, and it's corresponding return is -110.0, average rewards : -102.33
# Episode number 471, and it's corresponding return is -89.0, average rewards : -102.19
# Episode number 472, and it's corresponding return is -99.0, average rewards : -102.05
# Episode number 473, and it's corresponding return is -102.0, average rewards : -101.93
# Episode number 474, and it's corresponding return is -69.0, average rewards : -101.61
# Episode number 475, and it's corresponding return is -82.0, average rewards : -101.28
# Episode number 476, and it's corresponding return is -103.0, average rewards : -101.1
# Episode number 477, and it's corresponding return is -74.0, average rewards : -100.87
# Episode number 478, and it's corresponding return is -142.0, average rewards : -101.34
# Episode number 479, and it's corresponding return is -80.0, average rewards : -101.14
# Episode number 480, and it's corresponding return is -122.0, average rewards : -101.43
# Episode number 481, and it's corresponding return is -86.0, average rewards : -101.33
# Episode number 482, and it's corresponding return is -94.0, average rewards : -101.24
# Episode number 483, and it's corresponding return is -112.0, average rewards : -101.37
# Episode number 484, and it's corresponding return is -97.0, average rewards : -101.22
# Episode number 485, and it's corresponding return is -105.0, average rewards : -101.43
# Episode number 486, and it's corresponding return is -87.0, average rewards : -101.09
# Episode number 487, and it's corresponding return is -102.0, average rewards : -100.97
# Episode number 488, and it's corresponding return is -119.0, average rewards : -101.26
# Episode number 489, and it's corresponding return is -71.0, average rewards : -100.69
# Episode number 490, and it's corresponding return is -155.0, average rewards : -100.5
# Episode number 491, and it's corresponding return is -105.0, average rewards : -100.7
# Episode number 492, and it's corresponding return is -151.0, average rewards : -101.38
# Episode number 493, and it's corresponding return is -94.0, average rewards : -101.52
# Episode number 494, and it's corresponding return is -137.0, average rewards : -102.01
# Episode number 495, and it's corresponding return is -104.0, average rewards : -102.06
# Episode number 496, and it's corresponding return is -79.0, average rewards : -102.17
# Episode number 497, and it's corresponding return is -111.0, average rewards : -102.5
# Episode number 498, and it's corresponding return is -103.0, average rewards : -102.7
# Episode number 499, and it's corresponding return is -75.0, average rewards : -102.3
# Episode number 500, and it's corresponding return is -112.0, average rewards : -102.47
# Episode number 501, and it's corresponding return is -94.0, average rewards : -102.14
# Episode number 502, and it's corresponding return is -99.0, average rewards : -102.05
# Episode number 503, and it's corresponding return is -90.0, average rewards : -102.06
# Episode number 504, and it's corresponding return is -103.0, average rewards : -102.29
# Episode number 505, and it's corresponding return is -92.0, average rewards : -101.84
# Episode number 506, and it's corresponding return is -106.0, average rewards : -102.0
# Episode number 507, and it's corresponding return is -93.0, average rewards : -101.92
# Episode number 508, and it's corresponding return is -101.0, average rewards : -101.85
# Episode number 509, and it's corresponding return is -89.0, average rewards : -101.47
# Episode number 510, and it's corresponding return is -141.0, average rewards : -101.87
# Episode number 511, and it's corresponding return is -139.0, average rewards : -102.5
# Episode number 512, and it's corresponding return is -86.0, average rewards : -102.58
# Episode number 513, and it's corresponding return is -70.0, average rewards : -102.49
# Episode number 514, and it's corresponding return is -97.0, average rewards : -102.37
# Episode number 515, and it's corresponding return is -85.0, average rewards : -101.99
# Episode number 516, and it's corresponding return is -154.0, average rewards : -102.35
# Episode number 517, and it's corresponding return is -100.0, average rewards : -102.52
# Episode number 518, and it's corresponding return is -125.0, average rewards : -102.59
# Episode number 519, and it's corresponding return is -92.0, average rewards : -102.65
# Episode number 520, and it's corresponding return is -70.0, average rewards : -102.46
# Episode number 521, and it's corresponding return is -102.0, average rewards : -102.29
# Episode number 522, and it's corresponding return is -89.0, average rewards : -102.27
# Episode number 523, and it's corresponding return is -102.0, average rewards : -102.51
# Episode number 524, and it's corresponding return is -70.0, average rewards : -102.11
# Episode number 525, and it's corresponding return is -91.0, average rewards : -101.95
# Episode number 526, and it's corresponding return is -100.0, average rewards : -102.1
# Episode number 527, and it's corresponding return is -90.0, average rewards : -102.23
# Episode number 528, and it's corresponding return is -87.0, average rewards : -102.0
# Episode number 529, and it's corresponding return is -72.0, average rewards : -101.56
# Episode number 530, and it's corresponding return is -102.0, average rewards : -101.25
# Episode number 531, and it's corresponding return is -100.0, average rewards : -101.17
# Episode number 532, and it's corresponding return is -111.0, average rewards : -101.44
# Episode number 533, and it's corresponding return is -84.0, average rewards : -101.55
# Episode number 534, and it's corresponding return is -99.0, average rewards : -101.72
# Episode number 535, and it's corresponding return is -88.0, average rewards : -101.91
# Episode number 536, and it's corresponding return is -99.0, average rewards : -101.64
# Episode number 537, and it's corresponding return is -83.0, average rewards : -101.58
# Episode number 538, and it's corresponding return is -128.0, average rewards : -101.94
# Episode number 539, and it's corresponding return is -81.0, average rewards : -101.69
# Episode number 540, and it's corresponding return is -85.0, average rewards : -101.22
# Episode number 541, and it's corresponding return is -84.0, average rewards : -101.06
# Episode number 542, and it's corresponding return is -100.0, average rewards : -100.75
# Episode number 543, and it's corresponding return is -73.0, average rewards : -100.64
# Episode number 544, and it's corresponding return is -104.0, average rewards : -100.49
# Episode number 545, and it's corresponding return is -75.0, average rewards : -100.11
# Episode number 546, and it's corresponding return is -102.0, average rewards : -100.25
# Episode number 547, and it's corresponding return is -99.0, average rewards : -100.38
# Episode number 548, and it's corresponding return is -85.0, average rewards : -100.24
# Episode number 549, and it's corresponding return is -108.0, average rewards : -100.21
# ...
# Episode number 814, and it's corresponding return is -90.0, average rewards : -88.57
# Episode number 815, and it's corresponding return is -74.0, average rewards : -88.53
# Episode number 816, and it's corresponding return is -70.0, average rewards : -88.27
# Episode number 817, and it's corresponding return is -81.0, average rewards : -87.89
# Episode number 818, and it's corresponding return is -70.0, average rewards : -87.9
# Episode number 819, and it's corresponding return is -116.0, average rewards : -88.14
# Episode number 820, and it's corresponding return is -76.0, average rewards : -83.9
# Episode number 821, and it's corresponding return is -85.0, average rewards : -84.05
# Episode number 822, and it's corresponding return is -78.0, average rewards : -83.79
# Episode number 823, and it's corresponding return is -92.0, average rewards : -83.78
# Episode number 824, and it's corresponding return is -74.0, average rewards : -83.82
# Episode number 825, and it's corresponding return is -133.0, average rewards : -84.06
# Episode number 826, and it's corresponding return is -69.0, average rewards : -83.92
# Episode number 827, and it's corresponding return is -82.0, average rewards : -83.93
# Episode number 828, and it's corresponding return is -81.0, average rewards : -84.04
# Episode number 829, and it's corresponding return is -71.0, average rewards : -84.07
# Episode number 830, and it's corresponding return is -84.0, average rewards : -84.18
# Episode number 831, and it's corresponding return is -75.0, average rewards : -84.21
# Episode number 832, and it's corresponding return is -83.0, average rewards : -84.11
# Episode number 833, and it's corresponding return is -91.0, average rewards : -84.34
# Episode number 834, and it's corresponding return is -68.0, average rewards : -84.06
# Episode number 835, and it's corresponding return is -94.0, average rewards : -84.22
# Episode number 836, and it's corresponding return is -142.0, average rewards : -84.69
# Episode number 837, and it's corresponding return is -74.0, average rewards : -84.64
# Episode number 838, and it's corresponding return is -90.0, average rewards : -84.67
# Episode number 839, and it's corresponding return is -94.0, average rewards : -84.92
# Episode number 840, and it's corresponding return is -98.0, average rewards : -84.97
# Episode number 841, and it's corresponding return is -114.0, average rewards : -85.11
# Episode number 842, and it's corresponding return is -74.0, average rewards : -84.89
# Episode number 843, and it's corresponding return is -94.0, average rewards : -85.05
# Episode number 844, and it's corresponding return is -91.0, average rewards : -84.86
# Episode number 845, and it's corresponding return is -121.0, average rewards : -85.15
# Episode number 846, and it's corresponding return is -70.0, average rewards : -84.96
# Episode number 847, and it's corresponding return is -75.0, average rewards : -85.02
# Episode number 848, and it's corresponding return is -97.0, average rewards : -85.16
# Episode number 849, and it's corresponding return is -68.0, average rewards : -84.87
# Episode number 850, and it's corresponding return is -77.0, average rewards : -83.81
# Episode number 851, and it's corresponding return is -117.0, average rewards : -84.03
# Episode number 852, and it's corresponding return is -67.0, average rewards : -83.92
# Episode number 853, and it's corresponding return is -78.0, average rewards : -84.08
# Episode number 854, and it's corresponding return is -63.0, average rewards : -83.88
# Episode number 855, and it's corresponding return is -78.0, average rewards : -83.77
# Episode number 856, and it's corresponding return is -68.0, average rewards : -83.73
# Episode number 857, and it's corresponding return is -92.0, average rewards : -83.91
# Episode number 858, and it's corresponding return is -75.0, average rewards : -83.82
# Episode number 859, and it's corresponding return is -77.0, average rewards : -83.98
# Episode number 860, and it's corresponding return is -61.0, average rewards : -83.73
# Episode number 861, and it's corresponding return is -178.0, average rewards : -84.82
# Episode number 862, and it's corresponding return is -75.0, average rewards : -84.87
# Episode number 863, and it's corresponding return is -91.0, average rewards : -85.16
# Episode number 864, and it's corresponding return is -69.0, average rewards : -85.22
# Episode number 865, and it's corresponding return is -69.0, average rewards : -85.29
# Episode number 866, and it's corresponding return is -91.0, average rewards : -85.57
# Episode number 867, and it's corresponding return is -128.0, average rewards : -85.92
# Episode number 868, and it's corresponding return is -104.0, average rewards : -86.03
# Episode number 869, and it's corresponding return is -93.0, average rewards : -86.21
# Episode number 870, and it's corresponding return is -74.0, average rewards : -86.25
# Episode number 871, and it's corresponding return is -70.0, average rewards : -86.19
# Episode number 872, and it's corresponding return is -105.0, average rewards : -86.45
# Episode number 873, and it's corresponding return is -77.0, average rewards : -86.45
# Episode number 874, and it's corresponding return is -73.0, average rewards : -85.89
# Episode number 875, and it's corresponding return is -75.0, average rewards : -86.02
# Episode number 876, and it's corresponding return is -77.0, average rewards : -85.97
# Episode number 877, and it's corresponding return is -72.0, average rewards : -85.84
# Episode number 878, and it's corresponding return is -85.0, average rewards : -86.0
# Episode number 879, and it's corresponding return is -61.0, average rewards : -85.77
# Episode number 880, and it's corresponding return is -118.0, average rewards : -86.13
# Episode number 881, and it's corresponding return is -68.0, average rewards : -85.82
# Episode number 882, and it's corresponding return is -69.0, average rewards : -85.51
# Episode number 883, and it's corresponding return is -62.0, average rewards : -85.13
# Episode number 884, and it's corresponding return is -91.0, average rewards : -85.29
# Episode number 885, and it's corresponding return is -91.0, average rewards : -85.39
# Episode number 886, and it's corresponding return is -75.0, average rewards : -85.3
# Episode number 887, and it's corresponding return is -68.0, average rewards : -84.54
# Episode number 888, and it's corresponding return is -90.0, average rewards : -84.68
# Episode number 889, and it's corresponding return is -95.0, average rewards : -84.71
# Episode number 890, and it's corresponding return is -72.0, average rewards : -84.65
# Episode number 891, and it's corresponding return is -70.0, average rewards : -84.47
# Episode number 892, and it's corresponding return is -78.0, average rewards : -84.34
# Episode number 893, and it's corresponding return is -91.0, average rewards : -84.39
# Episode number 894, and it's corresponding return is -95.0, average rewards : -84.59
# Episode number 895, and it's corresponding return is -70.0, average rewards : -84.53
# Episode number 896, and it's corresponding return is -88.0, average rewards : -84.5
# Episode number 897, and it's corresponding return is -62.0, average rewards : -84.15
# Episode number 898, and it's corresponding return is -90.0, average rewards : -84.3
# Episode number 899, and it's corresponding return is -62.0, average rewards : -84.14
# Episode number 900, and it's corresponding return is -83.0, average rewards : -84.28
# Episode number 901, and it's corresponding return is -128.0, average rewards : -84.88
# Episode number 902, and it's corresponding return is -93.0, average rewards : -85.06
# Episode number 903, and it's corresponding return is -94.0, average rewards : -84.89
# Episode number 904, and it's corresponding return is -94.0, average rewards : -85.1
# Episode number 905, and it's corresponding return is -88.0, average rewards : -85.12
# Episode number 906, and it's corresponding return is -85.0, average rewards : -85.05
# Episode number 907, and it's corresponding return is -86.0, average rewards : -85.07
# Episode number 908, and it's corresponding return is -66.0, average rewards : -84.71
# Episode number 909, and it's corresponding return is -61.0, average rewards : -84.64
# Episode number 910, and it's corresponding return is -85.0, average rewards : -84.55
# Episode number 911, and it's corresponding return is -74.0, average rewards : -84.52
# Episode number 912, and it's corresponding return is -68.0, average rewards : -84.43
# Episode number 913, and it's corresponding return is -69.0, average rewards : -84.38
# Episode number 914, and it's corresponding return is -82.0, average rewards : -84.3
# Episode number 915, and it's corresponding return is -191.0, average rewards : -85.47
# Episode number 916, and it's corresponding return is -71.0, average rewards : -85.48
# Episode number 917, and it's corresponding return is -70.0, average rewards : -85.37
# Episode number 918, and it's corresponding return is -92.0, average rewards : -85.59
# Episode number 919, and it's corresponding return is -105.0, average rewards : -85.48
# Episode number 920, and it's corresponding return is -91.0, average rewards : -85.63
# Episode number 921, and it's corresponding return is -81.0, average rewards : -85.59
# Episode number 922, and it's corresponding return is -69.0, average rewards : -85.5
# Episode number 923, and it's corresponding return is -97.0, average rewards : -85.55
# Episode number 924, and it's corresponding return is -70.0, average rewards : -85.51
# Episode number 925, and it's corresponding return is -80.0, average rewards : -84.98
# Episode number 926, and it's corresponding return is -69.0, average rewards : -84.98
# Episode number 927, and it's corresponding return is -68.0, average rewards : -84.84
# Episode number 928, and it's corresponding return is -75.0, average rewards : -84.78
# Episode number 929, and it's corresponding return is -98.0, average rewards : -85.05
# Episode number 930, and it's corresponding return is -82.0, average rewards : -85.03
# Episode number 931, and it's corresponding return is -86.0, average rewards : -85.14
# Episode number 932, and it's corresponding return is -86.0, average rewards : -85.17
# Episode number 933, and it's corresponding return is -81.0, average rewards : -85.07
# Episode number 934, and it's corresponding return is -92.0, average rewards : -85.31
# Episode number 935, and it's corresponding return is -105.0, average rewards : -85.42
# Episode number 936, and it's corresponding return is -68.0, average rewards : -84.68
# Episode number 937, and it's corresponding return is -92.0, average rewards : -84.86
# Episode number 938, and it's corresponding return is -90.0, average rewards : -84.86
# Episode number 939, and it's corresponding return is -72.0, average rewards : -84.64
# Episode number 940, and it's corresponding return is -96.0, average rewards : -84.62
# Episode number 941, and it's corresponding return is -92.0, average rewards : -84.4
# Episode number 942, and it's corresponding return is -105.0, average rewards : -84.71
# Episode number 943, and it's corresponding return is -76.0, average rewards : -84.53
# Episode number 944, and it's corresponding return is -100.0, average rewards : -84.62
# Episode number 945, and it's corresponding return is -76.0, average rewards : -84.17
# Episode number 946, and it's corresponding return is -103.0, average rewards : -84.5
# Episode number 947, and it's corresponding return is -82.0, average rewards : -84.57
# Episode number 948, and it's corresponding return is -84.0, average rewards : -84.44
# Episode number 949, and it's corresponding return is -76.0, average rewards : -84.52
# Episode number 950, and it's corresponding return is -95.0, average rewards : -84.7
# Episode number 951, and it's corresponding return is -95.0, average rewards : -84.48
# Episode number 952, and it's corresponding return is -90.0, average rewards : -84.71
# Episode number 953, and it's corresponding return is -75.0, average rewards : -84.68
# Episode number 954, and it's corresponding return is -101.0, average rewards : -85.06
# Episode number 955, and it's corresponding return is -93.0, average rewards : -85.21
# Episode number 956, and it's corresponding return is -268.0, average rewards : -87.21
# Episode number 957, and it's corresponding return is -92.0, average rewards : -87.21
# Episode number 958, and it's corresponding return is -74.0, average rewards : -87.2
# Episode number 959, and it's corresponding return is -69.0, average rewards : -87.12
# Episode number 960, and it's corresponding return is -69.0, average rewards : -87.2
# Episode number 961, and it's corresponding return is -62.0, average rewards : -86.04
# Episode number 962, and it's corresponding return is -75.0, average rewards : -86.04
# Episode number 963, and it's corresponding return is -75.0, average rewards : -85.88
# Episode number 964, and it's corresponding return is -96.0, average rewards : -86.15
# Episode number 965, and it's corresponding return is -94.0, average rewards : -86.4
# Episode number 966, and it's corresponding return is -102.0, average rewards : -86.51
# Episode number 967, and it's corresponding return is -101.0, average rewards : -86.24
# Episode number 968, and it's corresponding return is -85.0, average rewards : -86.05
# Episode number 969, and it's corresponding return is -73.0, average rewards : -85.85
# Episode number 970, and it's corresponding return is -70.0, average rewards : -85.81
# Episode number 971, and it's corresponding return is -75.0, average rewards : -85.86
# Episode number 972, and it's corresponding return is -69.0, average rewards : -85.5
# Episode number 973, and it's corresponding return is -95.0, average rewards : -85.68
# Episode number 974, and it's corresponding return is -80.0, average rewards : -85.75
# Episode number 975, and it's corresponding return is -85.0, average rewards : -85.85
# Episode number 976, and it's corresponding return is -82.0, average rewards : -85.9
# Episode number 977, and it's corresponding return is -106.0, average rewards : -86.24
# Episode number 978, and it's corresponding return is -70.0, average rewards : -86.09
# Episode number 979, and it's corresponding return is -69.0, average rewards : -86.17
# Episode number 980, and it's corresponding return is -68.0, average rewards : -85.67
# Episode number 981, and it's corresponding return is -89.0, average rewards : -85.88
# Episode number 982, and it's corresponding return is -77.0, average rewards : -85.96
# Episode number 983, and it's corresponding return is -85.0, average rewards : -86.19
# Episode number 984, and it's corresponding return is -97.0, average rewards : -86.25
# Episode number 985, and it's corresponding return is -94.0, average rewards : -86.28
# Episode number 986, and it's corresponding return is -68.0, average rewards : -86.21
# Episode number 987, and it's corresponding return is -81.0, average rewards : -86.34
# Episode number 988, and it's corresponding return is -74.0, average rewards : -86.18
# Episode number 989, and it's corresponding return is -61.0, average rewards : -85.84
# Episode number 990, and it's corresponding return is -60.0, average rewards : -85.72
# Episode number 991, and it's corresponding return is -90.0, average rewards : -85.92
# Episode number 992, and it's corresponding return is -70.0, average rewards : -85.84
# Episode number 993, and it's corresponding return is -98.0, average rewards : -85.91
# Episode number 994, and it's corresponding return is -68.0, average rewards : -85.64
# Episode number 995, and it's corresponding return is -69.0, average rewards : -85.63
# Episode number 996, and it's corresponding return is -80.0, average rewards : -85.55
# Episode number 997, and it's corresponding return is -68.0, average rewards : -85.61
# Episode number 998, and it's corresponding return is -132.0, average rewards : -86.03
# Episode number 999, and it's corresponding return is -74.0, average rewards : -86.15
# Episode number 1000, and it's corresponding return is -69.0, average rewards : -86.01
# The iteration 5 ended

# %% [markdown]
# ### Plot for Acrobot - v1 with Type - 1 and 2 Dueling DQN comparison

# %%
n_episodes = np.arange(len(list(list_returns_env_1_type_1)[0]))
avg_returns_env1_type_1 = np.mean(list(list_returns_env_1_type_1), 0)
std_returns_env1_type_1 = np.std(list(list_returns_env_1_type_1), 0)
avg_returns_env1_type_2 = np.mean(list(list_returns_env_1_type_2), 0)
std_returns_env1_type_2 = np.std(list(list_returns_env_1_type_2), 0)
plt.plot(n_episodes, avg_returns_env1_type_1, color = '#FF0000', label = "Type 1")
plt.plot(n_episodes, avg_returns_env1_type_2, color = '#0000FF', label = "Type 2")
plt.fill_between(n_episodes, avg_returns_env1_type_1 - std_returns_env1_type_1, avg_returns_env1_type_1 + std_returns_env1_type_1, color = '#FF474C')
plt.fill_between(n_episodes, avg_returns_env1_type_2 - std_returns_env1_type_2, avg_returns_env1_type_2 + std_returns_env1_type_2, color = '#ADD8E6')
plt.title("Dueling DQN for Acrobot-v1")
plt.xlabel("Number of episodes")
plt.ylabel("Episodic return averaged over 5 runs")
plt.legend()
plt.show()
