# %% [markdown]
# ### Importing Modules

# %%
import numpy as np
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.distributions import Categorical

from collections import namedtuple, deque
import datetime

import gym
from gym.wrappers.record_video import RecordVideo


import matplotlib.pyplot as plt

# %% [markdown]
# ### Defining the two game environments

# %%
#Defining Environments
#Environment 1

env1 = gym.make("Acrobot-v1")
#env1.seed(0)

env1_state_shape = env1.observation_space.shape[0]
env1_no_of_actions = env1.action_space.n

env1_state = env1.reset(seed = 0)


#Environment 2

env2 = gym.make("CartPole-v1")
#env2.seed(0)

env2_state_shape = env2.observation_space.shape[0]
env2_no_of_actions = env2.action_space.n

env2_state = env2.reset(seed = 0)


# Note For both Environments
# For choosing actions :
# action = env.action_space.sample()

# For step :
# next_state, reward, done, info = env.step(action)
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
SavedAction = namedtuple('SavedAction', ['log_prob', 'value'])
Transitions = namedtuple('Transitions', ['state', 'action', 'reward', 'next_state'])

class Policy(nn.Module):
  def __init__(self, state_size, action_size, seed, fc1_units = 128, fc2_units = 64):
    super(Policy, self).__init__()
    self.seed = torch.manual_seed(seed)
    self.fc1 = nn.Linear(state_size, fc1_units)
    self.fc2 = nn.Linear(fc1_units, fc2_units)
    self.PI = nn.Linear(fc2_units, action_size)
  def forward(self, x):
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    PI = F.softmax(self.PI(x), dim = -1)
    return PI

class Value(nn.Module):
  def __init__(self, state_size, seed, fc1_units = 128, fc2_units = 64):
    super(Value, self).__init__()
    self.fc1 = nn.Linear(state_size, fc1_units)
    self.fc2 = nn.Linear(fc1_units, fc2_units)
    self.V = nn.Linear(fc2_units, 1)
  def forward(self, x):
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    V = self.V(x)
    return V

# %%
class MC_Reinforce:
  def __init__(self, env, parameters, seed, id, Policy = Policy, Value = Value, gamma = 0.99, lr = 5e-4):
    self.env = env
    self.fc1, self.fc2 = parameters
    self.gamma = gamma
    self.lr = lr
    self.seed = seed
    self.id = id                             # id = 1 : Type 1, id = 2 : Type 2
    self.state_size = env.observation_space.shape[0]
    self.action_size = env.action_space.n
    self.Policy = Policy(self.state_size, self.action_size, self.seed, self.fc1, self.fc2)
    self.Value = Value(self.state_size, self.seed, self.fc1, self.fc2)
    self.Policy_optimizer = optim.Adam(self.Policy.parameters(), lr = lr)
    self.Value_optimizer = optim.Adam(self.Value.parameters(), lr = lr)
    self.eps = np.finfo(np.float32).eps.item()

  def select_action(self, state):
    state = torch.from_numpy(state).float()
    pi = self.Policy(state)
    m = Categorical(pi)
    action = m.sample()
    return action

  def train(self, n_episodes = 1000):
    ep_returns = deque()
    scores = deque(maxlen = 100)
    for i in range(1, n_episodes + 1):
      state = self.env.reset()
      ep_reward = 0
      rewards = []
      transitions = []
      while True:
        action = self.select_action(state)
        next_state, reward, done, _ = self.env.step(action.item())
        transitions.append([state, action, reward, next_state])
        rewards.append(reward)
        ep_reward += reward
        if done:
          break
        state = next_state
      policy_losses = []
      value_losses = []
      returns = []
      R = 0
      for r in rewards[::-1]:
        R = r + self.gamma * R
        returns.insert(0, R)
      for j in range(len(transitions)):
        transition = transitions[j]
        return_1 = returns[j]
        state, action, reward, next_state = transition
        state = torch.from_numpy(state).float()
        next_state = torch.from_numpy(next_state).float()
        pi = self.Policy(state)
        m = Categorical(pi)
        if self.id == 1:
          policy_losses.append(- m.log_prob(action) * (return_1))
        else:
          policy_losses.append(- m.log_prob(action) * (return_1 - self.Value(state)))
        value_losses.append(F.mse_loss(reward + self.gamma * self.Value(next_state), self.Value(state)))
      p_loss = torch.stack(policy_losses).sum()
      v_loss = torch.stack(value_losses).sum()
      self.Policy_optimizer.zero_grad()
      p_loss.backward()
      self.Policy_optimizer.step()
      if self.id == 2:
        self.Value_optimizer.zero_grad()
        v_loss.backward()
        self.Value_optimizer.step()
      scores.append(ep_reward)
      R = 0
      for r in rewards:
        R = r + R
      print(f"Episode number {i}, and it's corresponding return is {R}, average rewards : {np.mean(scores)}")
      ep_returns.append(R)
    return list(ep_returns)

# %%
returns_1_1_5runs = []
for seed in [0,1,2,3,4]:
    MC_1_1 = MC_Reinforce(env1, (128, 64), 0, 1)
    returns_1_1 = MC_1_1.train(1000)
    returns_1_1_5runs.append(returns_1_1)
returns_1_1_5runs = np.array(returns_1_1_5runs)
# Out:
# Episode number 1, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 2, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 3, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 4, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 5, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 6, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 7, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 8, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 9, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 10, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 11, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 12, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 13, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 14, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 15, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 16, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 17, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 18, and it's corresponding return is -412.0, average rewards : -495.1111111111111
# Episode number 19, and it's corresponding return is -500.0, average rewards : -495.36842105263156
# Episode number 20, and it's corresponding return is -500.0, average rewards : -495.6
# Episode number 21, and it's corresponding return is -500.0, average rewards : -495.8095238095238
# Episode number 22, and it's corresponding return is -500.0, average rewards : -496.0
# Episode number 23, and it's corresponding return is -346.0, average rewards : -489.4782608695652
# Episode number 24, and it's corresponding return is -500.0, average rewards : -489.9166666666667
# Episode number 25, and it's corresponding return is -488.0, average rewards : -489.84
# Episode number 26, and it's corresponding return is -253.0, average rewards : -480.7307692307692
# Episode number 27, and it's corresponding return is -427.0, average rewards : -478.74074074074076
# Episode number 28, and it's corresponding return is -391.0, average rewards : -475.60714285714283
# Episode number 29, and it's corresponding return is -500.0, average rewards : -476.44827586206895
# Episode number 30, and it's corresponding return is -435.0, average rewards : -475.06666666666666
# Episode number 31, and it's corresponding return is -361.0, average rewards : -471.38709677419354
# Episode number 32, and it's corresponding return is -470.0, average rewards : -471.34375
# Episode number 33, and it's corresponding return is -476.0, average rewards : -471.4848484848485
# Episode number 34, and it's corresponding return is -500.0, average rewards : -472.3235294117647
# Episode number 35, and it's corresponding return is -500.0, average rewards : -473.1142857142857
# Episode number 36, and it's corresponding return is -500.0, average rewards : -473.8611111111111
# Episode number 37, and it's corresponding return is -500.0, average rewards : -474.56756756756755
# Episode number 38, and it's corresponding return is -500.0, average rewards : -475.2368421052632
# Episode number 39, and it's corresponding return is -500.0, average rewards : -475.87179487179486
# Episode number 40, and it's corresponding return is -402.0, average rewards : -474.025
# Episode number 41, and it's corresponding return is -204.0, average rewards : -467.4390243902439
# Episode number 42, and it's corresponding return is -500.0, average rewards : -468.2142857142857
# Episode number 43, and it's corresponding return is -500.0, average rewards : -468.95348837209303
# Episode number 44, and it's corresponding return is -391.0, average rewards : -467.1818181818182
# Episode number 45, and it's corresponding return is -500.0, average rewards : -467.9111111111111
# Episode number 46, and it's corresponding return is -500.0, average rewards : -468.60869565217394
# Episode number 47, and it's corresponding return is -474.0, average rewards : -468.72340425531917
# Episode number 48, and it's corresponding return is -325.0, average rewards : -465.7291666666667
# Episode number 49, and it's corresponding return is -494.0, average rewards : -466.3061224489796
# Episode number 50, and it's corresponding return is -500.0, average rewards : -466.98
# Episode number 51, and it's corresponding return is -500.0, average rewards : -467.62745098039215
# Episode number 52, and it's corresponding return is -500.0, average rewards : -468.25
# Episode number 53, and it's corresponding return is -483.0, average rewards : -468.52830188679246
# Episode number 54, and it's corresponding return is -500.0, average rewards : -469.1111111111111
# Episode number 55, and it's corresponding return is -500.0, average rewards : -469.6727272727273
# Episode number 56, and it's corresponding return is -500.0, average rewards : -470.2142857142857
# Episode number 57, and it's corresponding return is -386.0, average rewards : -468.7368421052632
# Episode number 58, and it's corresponding return is -500.0, average rewards : -469.2758620689655
# Episode number 59, and it's corresponding return is -500.0, average rewards : -469.79661016949154
# Episode number 60, and it's corresponding return is -500.0, average rewards : -470.3
# Episode number 61, and it's corresponding return is -433.0, average rewards : -469.6885245901639
# Episode number 62, and it's corresponding return is -447.0, average rewards : -469.3225806451613
# Episode number 63, and it's corresponding return is -468.0, average rewards : -469.3015873015873
# Episode number 64, and it's corresponding return is -365.0, average rewards : -467.671875
# Episode number 65, and it's corresponding return is -343.0, average rewards : -465.75384615384615
# Episode number 66, and it's corresponding return is -276.0, average rewards : -462.8787878787879
# Episode number 67, and it's corresponding return is -428.0, average rewards : -462.35820895522386
# Episode number 68, and it's corresponding return is -500.0, average rewards : -462.9117647058824
# Episode number 69, and it's corresponding return is -487.0, average rewards : -463.2608695652174
# Episode number 70, and it's corresponding return is -354.0, average rewards : -461.7
# Episode number 71, and it's corresponding return is -316.0, average rewards : -459.6478873239437
# Episode number 72, and it's corresponding return is -329.0, average rewards : -457.8333333333333
# Episode number 73, and it's corresponding return is -500.0, average rewards : -458.4109589041096
# Episode number 74, and it's corresponding return is -457.0, average rewards : -458.3918918918919
# Episode number 75, and it's corresponding return is -290.0, average rewards : -456.14666666666665
# Episode number 76, and it's corresponding return is -255.0, average rewards : -453.5
# Episode number 77, and it's corresponding return is -336.0, average rewards : -451.97402597402595
# Episode number 78, and it's corresponding return is -252.0, average rewards : -449.4102564102564
# Episode number 79, and it's corresponding return is -360.0, average rewards : -448.27848101265823
# Episode number 80, and it's corresponding return is -353.0, average rewards : -447.0875
# Episode number 81, and it's corresponding return is -500.0, average rewards : -447.74074074074076
# Episode number 82, and it's corresponding return is -486.0, average rewards : -448.2073170731707
# Episode number 83, and it's corresponding return is -330.0, average rewards : -446.7831325301205
# Episode number 84, and it's corresponding return is -232.0, average rewards : -444.2261904761905
# Episode number 85, and it's corresponding return is -327.0, average rewards : -442.84705882352944
# Episode number 86, and it's corresponding return is -299.0, average rewards : -441.1744186046512
# Episode number 87, and it's corresponding return is -457.0, average rewards : -441.35632183908046
# Episode number 88, and it's corresponding return is -395.0, average rewards : -440.82954545454544
# Episode number 89, and it's corresponding return is -362.0, average rewards : -439.9438202247191
# Episode number 90, and it's corresponding return is -442.0, average rewards : -439.96666666666664
# Episode number 91, and it's corresponding return is -223.0, average rewards : -437.5824175824176
# Episode number 92, and it's corresponding return is -388.0, average rewards : -437.04347826086956
# Episode number 93, and it's corresponding return is -310.0, average rewards : -435.6774193548387
# Episode number 94, and it's corresponding return is -315.0, average rewards : -434.3936170212766
# Episode number 95, and it's corresponding return is -393.0, average rewards : -433.9578947368421
# Episode number 96, and it's corresponding return is -293.0, average rewards : -432.4895833333333
# Episode number 97, and it's corresponding return is -349.0, average rewards : -431.62886597938143
# Episode number 98, and it's corresponding return is -337.0, average rewards : -430.66326530612247
# Episode number 99, and it's corresponding return is -349.0, average rewards : -429.83838383838383
# Episode number 100, and it's corresponding return is -261.0, average rewards : -428.15
# Episode number 101, and it's corresponding return is -241.0, average rewards : -425.56
# Episode number 102, and it's corresponding return is -414.0, average rewards : -424.7
# Episode number 103, and it's corresponding return is -346.0, average rewards : -423.16
# Episode number 104, and it's corresponding return is -355.0, average rewards : -421.71
# Episode number 105, and it's corresponding return is -395.0, average rewards : -420.66
# Episode number 106, and it's corresponding return is -316.0, average rewards : -418.82
# Episode number 107, and it's corresponding return is -405.0, average rewards : -417.87
# Episode number 108, and it's corresponding return is -500.0, average rewards : -417.87
# Episode number 109, and it's corresponding return is -387.0, average rewards : -416.74
# Episode number 110, and it's corresponding return is -310.0, average rewards : -414.84
# Episode number 111, and it's corresponding return is -306.0, average rewards : -412.9
# Episode number 112, and it's corresponding return is -336.0, average rewards : -411.26
# Episode number 113, and it's corresponding return is -287.0, average rewards : -409.13
# Episode number 114, and it's corresponding return is -303.0, average rewards : -407.16
# Episode number 115, and it's corresponding return is -277.0, average rewards : -404.93
# Episode number 116, and it's corresponding return is -412.0, average rewards : -404.05
# Episode number 117, and it's corresponding return is -314.0, average rewards : -402.19
# Episode number 118, and it's corresponding return is -467.0, average rewards : -402.74
# Episode number 119, and it's corresponding return is -256.0, average rewards : -400.3
# Episode number 120, and it's corresponding return is -384.0, average rewards : -399.14
# Episode number 121, and it's corresponding return is -225.0, average rewards : -396.39
# Episode number 122, and it's corresponding return is -187.0, average rewards : -393.26
# Episode number 123, and it's corresponding return is -260.0, average rewards : -392.4
# Episode number 124, and it's corresponding return is -184.0, average rewards : -389.24
# Episode number 125, and it's corresponding return is -196.0, average rewards : -386.32
# Episode number 126, and it's corresponding return is -367.0, average rewards : -387.46
# Episode number 127, and it's corresponding return is -231.0, average rewards : -385.5
# Episode number 128, and it's corresponding return is -270.0, average rewards : -384.29
# Episode number 129, and it's corresponding return is -193.0, average rewards : -381.22
# Episode number 130, and it's corresponding return is -224.0, average rewards : -379.11
# Episode number 131, and it's corresponding return is -208.0, average rewards : -377.58
# Episode number 132, and it's corresponding return is -344.0, average rewards : -376.32
# Episode number 133, and it's corresponding return is -366.0, average rewards : -375.22
# Episode number 134, and it's corresponding return is -205.0, average rewards : -372.27
# Episode number 135, and it's corresponding return is -194.0, average rewards : -369.21
# Episode number 136, and it's corresponding return is -195.0, average rewards : -366.16
# Episode number 137, and it's corresponding return is -299.0, average rewards : -364.15
# Episode number 138, and it's corresponding return is -203.0, average rewards : -361.18
# Episode number 139, and it's corresponding return is -181.0, average rewards : -357.99
# Episode number 140, and it's corresponding return is -266.0, average rewards : -356.63
# Episode number 141, and it's corresponding return is -366.0, average rewards : -358.25
# Episode number 142, and it's corresponding return is -359.0, average rewards : -356.84
# Episode number 143, and it's corresponding return is -222.0, average rewards : -354.06
# Episode number 144, and it's corresponding return is -329.0, average rewards : -353.44
# Episode number 145, and it's corresponding return is -274.0, average rewards : -351.18
# Episode number 146, and it's corresponding return is -246.0, average rewards : -348.64
# Episode number 147, and it's corresponding return is -191.0, average rewards : -345.81
# Episode number 148, and it's corresponding return is -335.0, average rewards : -345.91
# Episode number 149, and it's corresponding return is -226.0, average rewards : -343.23
# Episode number 150, and it's corresponding return is -188.0, average rewards : -340.11
# Episode number 151, and it's corresponding return is -184.0, average rewards : -336.95
# Episode number 152, and it's corresponding return is -175.0, average rewards : -333.7
# Episode number 153, and it's corresponding return is -246.0, average rewards : -331.33
# Episode number 154, and it's corresponding return is -202.0, average rewards : -328.35
# Episode number 155, and it's corresponding return is -242.0, average rewards : -325.77
# Episode number 156, and it's corresponding return is -164.0, average rewards : -322.41
# Episode number 157, and it's corresponding return is -178.0, average rewards : -320.33
# Episode number 158, and it's corresponding return is -197.0, average rewards : -317.3
# Episode number 159, and it's corresponding return is -236.0, average rewards : -314.66
# Episode number 160, and it's corresponding return is -258.0, average rewards : -312.24
# Episode number 161, and it's corresponding return is -252.0, average rewards : -310.43
# Episode number 162, and it's corresponding return is -224.0, average rewards : -308.2
# Episode number 163, and it's corresponding return is -244.0, average rewards : -305.96
# Episode number 164, and it's corresponding return is -267.0, average rewards : -304.98
# Episode number 165, and it's corresponding return is -185.0, average rewards : -303.4
# Episode number 166, and it's corresponding return is -234.0, average rewards : -302.98
# Episode number 167, and it's corresponding return is -234.0, average rewards : -301.04
# Episode number 168, and it's corresponding return is -199.0, average rewards : -298.03
# Episode number 169, and it's corresponding return is -213.0, average rewards : -295.29
# Episode number 170, and it's corresponding return is -202.0, average rewards : -293.77
# Episode number 171, and it's corresponding return is -248.0, average rewards : -293.09
# Episode number 172, and it's corresponding return is -238.0, average rewards : -292.18
# Episode number 173, and it's corresponding return is -198.0, average rewards : -289.16
# Episode number 174, and it's corresponding return is -292.0, average rewards : -287.51
# Episode number 175, and it's corresponding return is -214.0, average rewards : -286.75
# Episode number 176, and it's corresponding return is -226.0, average rewards : -286.46
# Episode number 177, and it's corresponding return is -259.0, average rewards : -285.69
# Episode number 178, and it's corresponding return is -208.0, average rewards : -285.25
# Episode number 179, and it's corresponding return is -145.0, average rewards : -283.1
# Episode number 180, and it's corresponding return is -251.0, average rewards : -282.08
# Episode number 181, and it's corresponding return is -210.0, average rewards : -279.18
# Episode number 182, and it's corresponding return is -250.0, average rewards : -276.82
# Episode number 183, and it's corresponding return is -254.0, average rewards : -276.06
# Episode number 184, and it's corresponding return is -204.0, average rewards : -275.78
# Episode number 185, and it's corresponding return is -275.0, average rewards : -275.26
# Episode number 186, and it's corresponding return is -260.0, average rewards : -274.87
# Episode number 187, and it's corresponding return is -322.0, average rewards : -273.52
# Episode number 188, and it's corresponding return is -175.0, average rewards : -271.32
# Episode number 189, and it's corresponding return is -219.0, average rewards : -269.89
# Episode number 190, and it's corresponding return is -316.0, average rewards : -268.63
# Episode number 191, and it's corresponding return is -450.0, average rewards : -270.9
# Episode number 192, and it's corresponding return is -216.0, average rewards : -269.18
# Episode number 193, and it's corresponding return is -208.0, average rewards : -268.16
# Episode number 194, and it's corresponding return is -316.0, average rewards : -268.17
# Episode number 195, and it's corresponding return is -267.0, average rewards : -266.91
# Episode number 196, and it's corresponding return is -202.0, average rewards : -266.0
# Episode number 197, and it's corresponding return is -221.0, average rewards : -264.72
# Episode number 198, and it's corresponding return is -192.0, average rewards : -263.27
# Episode number 199, and it's corresponding return is -186.0, average rewards : -261.64
# Episode number 200, and it's corresponding return is -229.0, average rewards : -261.32
# Episode number 201, and it's corresponding return is -154.0, average rewards : -260.45
# Episode number 202, and it's corresponding return is -198.0, average rewards : -258.29
# Episode number 203, and it's corresponding return is -260.0, average rewards : -257.43
# Episode number 204, and it's corresponding return is -226.0, average rewards : -256.14
# Episode number 205, and it's corresponding return is -163.0, average rewards : -253.82
# Episode number 206, and it's corresponding return is -180.0, average rewards : -252.46
# Episode number 207, and it's corresponding return is -169.0, average rewards : -250.1
# Episode number 208, and it's corresponding return is -175.0, average rewards : -246.85
# Episode number 209, and it's corresponding return is -253.0, average rewards : -245.51
# Episode number 210, and it's corresponding return is -198.0, average rewards : -244.39
# Episode number 211, and it's corresponding return is -250.0, average rewards : -243.83
# Episode number 212, and it's corresponding return is -175.0, average rewards : -242.22
# Episode number 213, and it's corresponding return is -192.0, average rewards : -241.27
# Episode number 214, and it's corresponding return is -206.0, average rewards : -240.3
# Episode number 215, and it's corresponding return is -159.0, average rewards : -239.12
# Episode number 216, and it's corresponding return is -253.0, average rewards : -237.53
# Episode number 217, and it's corresponding return is -147.0, average rewards : -235.86
# Episode number 218, and it's corresponding return is -165.0, average rewards : -232.84
# Episode number 219, and it's corresponding return is -160.0, average rewards : -231.88
# Episode number 220, and it's corresponding return is -156.0, average rewards : -229.6
# Episode number 221, and it's corresponding return is -214.0, average rewards : -229.49
# Episode number 222, and it's corresponding return is -133.0, average rewards : -228.95
# Episode number 223, and it's corresponding return is -181.0, average rewards : -228.16
# Episode number 224, and it's corresponding return is -299.0, average rewards : -229.31
# Episode number 225, and it's corresponding return is -196.0, average rewards : -229.31
# Episode number 226, and it's corresponding return is -235.0, average rewards : -227.99
# Episode number 227, and it's corresponding return is -205.0, average rewards : -227.73
# Episode number 228, and it's corresponding return is -162.0, average rewards : -226.65
# Episode number 229, and it's corresponding return is -202.0, average rewards : -226.74
# Episode number 230, and it's corresponding return is -158.0, average rewards : -226.08
# Episode number 231, and it's corresponding return is -207.0, average rewards : -226.07
# Episode number 232, and it's corresponding return is -274.0, average rewards : -225.37
# Episode number 233, and it's corresponding return is -206.0, average rewards : -223.77
# Episode number 234, and it's corresponding return is -225.0, average rewards : -223.97
# Episode number 235, and it's corresponding return is -206.0, average rewards : -224.09
# Episode number 236, and it's corresponding return is -178.0, average rewards : -223.92
# Episode number 237, and it's corresponding return is -202.0, average rewards : -222.95
# Episode number 238, and it's corresponding return is -158.0, average rewards : -222.5
# Episode number 239, and it's corresponding return is -247.0, average rewards : -223.16
# Episode number 240, and it's corresponding return is -175.0, average rewards : -222.25
# Episode number 241, and it's corresponding return is -186.0, average rewards : -220.45
# Episode number 242, and it's corresponding return is -220.0, average rewards : -219.06
# Episode number 243, and it's corresponding return is -181.0, average rewards : -218.65
# Episode number 244, and it's corresponding return is -155.0, average rewards : -216.91
# Episode number 245, and it's corresponding return is -181.0, average rewards : -215.98
# Episode number 246, and it's corresponding return is -152.0, average rewards : -215.04
# Episode number 247, and it's corresponding return is -162.0, average rewards : -214.75
# Episode number 248, and it's corresponding return is -225.0, average rewards : -213.65
# Episode number 249, and it's corresponding return is -197.0, average rewards : -213.36
# Episode number 250, and it's corresponding return is -148.0, average rewards : -212.96
# Episode number 251, and it's corresponding return is -258.0, average rewards : -213.7
# Episode number 252, and it's corresponding return is -147.0, average rewards : -213.42
# Episode number 253, and it's corresponding return is -116.0, average rewards : -212.12
# Episode number 254, and it's corresponding return is -144.0, average rewards : -211.54
# Episode number 255, and it's corresponding return is -194.0, average rewards : -211.06
# Episode number 256, and it's corresponding return is -148.0, average rewards : -210.9
# Episode number 257, and it's corresponding return is -179.0, average rewards : -210.91
# Episode number 258, and it's corresponding return is -231.0, average rewards : -211.25
# Episode number 259, and it's corresponding return is -168.0, average rewards : -210.57
# Episode number 260, and it's corresponding return is -186.0, average rewards : -209.85
# Episode number 261, and it's corresponding return is -155.0, average rewards : -208.88
# Episode number 262, and it's corresponding return is -177.0, average rewards : -208.41
# Episode number 263, and it's corresponding return is -293.0, average rewards : -208.9
# Episode number 264, and it's corresponding return is -132.0, average rewards : -207.55
# Episode number 265, and it's corresponding return is -157.0, average rewards : -207.27
# Episode number 266, and it's corresponding return is -180.0, average rewards : -206.73
# Episode number 267, and it's corresponding return is -157.0, average rewards : -205.96
# Episode number 268, and it's corresponding return is -114.0, average rewards : -205.11
# Episode number 269, and it's corresponding return is -169.0, average rewards : -204.67
# Episode number 270, and it's corresponding return is -142.0, average rewards : -204.07
# Episode number 271, and it's corresponding return is -153.0, average rewards : -203.12
# Episode number 272, and it's corresponding return is -130.0, average rewards : -202.04
# Episode number 273, and it's corresponding return is -157.0, average rewards : -201.63
# Episode number 274, and it's corresponding return is -175.0, average rewards : -200.46
# Episode number 275, and it's corresponding return is -134.0, average rewards : -199.66
# Episode number 276, and it's corresponding return is -142.0, average rewards : -198.82
# Episode number 277, and it's corresponding return is -121.0, average rewards : -197.44
# Episode number 278, and it's corresponding return is -128.0, average rewards : -196.64
# Episode number 279, and it's corresponding return is -121.0, average rewards : -196.4
# Episode number 280, and it's corresponding return is -164.0, average rewards : -195.53
# Episode number 281, and it's corresponding return is -178.0, average rewards : -195.21
# Episode number 282, and it's corresponding return is -248.0, average rewards : -195.19
# Episode number 283, and it's corresponding return is -148.0, average rewards : -194.13
# Episode number 284, and it's corresponding return is -126.0, average rewards : -193.35
# Episode number 285, and it's corresponding return is -187.0, average rewards : -192.47
# Episode number 286, and it's corresponding return is -190.0, average rewards : -191.77
# Episode number 287, and it's corresponding return is -145.0, average rewards : -190.0
# Episode number 288, and it's corresponding return is -329.0, average rewards : -191.54
# Episode number 289, and it's corresponding return is -309.0, average rewards : -192.44
# Episode number 290, and it's corresponding return is -202.0, average rewards : -191.3
# Episode number 291, and it's corresponding return is -149.0, average rewards : -188.29
# Episode number 292, and it's corresponding return is -179.0, average rewards : -187.92
# Episode number 293, and it's corresponding return is -220.0, average rewards : -188.04
# Episode number 294, and it's corresponding return is -169.0, average rewards : -186.57
# Episode number 295, and it's corresponding return is -216.0, average rewards : -186.06
# Episode number 296, and it's corresponding return is -221.0, average rewards : -186.25
# Episode number 297, and it's corresponding return is -266.0, average rewards : -186.7
# Episode number 298, and it's corresponding return is -198.0, average rewards : -186.76
# Episode number 299, and it's corresponding return is -248.0, average rewards : -187.38
# Episode number 300, and it's corresponding return is -227.0, average rewards : -187.36
# Episode number 301, and it's corresponding return is -176.0, average rewards : -187.58
# Episode number 302, and it's corresponding return is -126.0, average rewards : -186.86
# Episode number 303, and it's corresponding return is -141.0, average rewards : -185.67
# Episode number 304, and it's corresponding return is -273.0, average rewards : -186.14
# Episode number 305, and it's corresponding return is -154.0, average rewards : -186.05
# Episode number 306, and it's corresponding return is -173.0, average rewards : -185.98
# Episode number 307, and it's corresponding return is -161.0, average rewards : -185.9
# Episode number 308, and it's corresponding return is -133.0, average rewards : -185.48
# Episode number 309, and it's corresponding return is -127.0, average rewards : -184.22
# Episode number 310, and it's corresponding return is -203.0, average rewards : -184.27
# Episode number 311, and it's corresponding return is -164.0, average rewards : -183.41
# Episode number 312, and it's corresponding return is -257.0, average rewards : -184.23
# Episode number 313, and it's corresponding return is -309.0, average rewards : -185.4
# Episode number 314, and it's corresponding return is -168.0, average rewards : -185.02
# Episode number 315, and it's corresponding return is -169.0, average rewards : -185.12
# Episode number 316, and it's corresponding return is -223.0, average rewards : -184.82
# Episode number 317, and it's corresponding return is -140.0, average rewards : -184.75
# Episode number 318, and it's corresponding return is -171.0, average rewards : -184.81
# Episode number 319, and it's corresponding return is -182.0, average rewards : -185.03
# Episode number 320, and it's corresponding return is -200.0, average rewards : -185.47
# Episode number 321, and it's corresponding return is -152.0, average rewards : -184.85
# Episode number 322, and it's corresponding return is -122.0, average rewards : -184.74
# Episode number 323, and it's corresponding return is -155.0, average rewards : -184.48
# Episode number 324, and it's corresponding return is -204.0, average rewards : -183.53
# Episode number 325, and it's corresponding return is -127.0, average rewards : -182.84
# Episode number 326, and it's corresponding return is -153.0, average rewards : -182.02
# Episode number 327, and it's corresponding return is -152.0, average rewards : -181.49
# Episode number 328, and it's corresponding return is -157.0, average rewards : -181.44
# Episode number 329, and it's corresponding return is -98.0, average rewards : -180.4
# Episode number 330, and it's corresponding return is -162.0, average rewards : -180.44
# Episode number 331, and it's corresponding return is -222.0, average rewards : -180.59
# Episode number 332, and it's corresponding return is -123.0, average rewards : -179.08
# Episode number 333, and it's corresponding return is -147.0, average rewards : -178.49
# Episode number 334, and it's corresponding return is -249.0, average rewards : -178.73
# Episode number 335, and it's corresponding return is -243.0, average rewards : -179.1
# Episode number 336, and it's corresponding return is -127.0, average rewards : -178.59
# Episode number 337, and it's corresponding return is -179.0, average rewards : -178.36
# Episode number 338, and it's corresponding return is -171.0, average rewards : -178.49
# Episode number 339, and it's corresponding return is -163.0, average rewards : -177.65
# Episode number 340, and it's corresponding return is -159.0, average rewards : -177.49
# Episode number 341, and it's corresponding return is -175.0, average rewards : -177.38
# Episode number 342, and it's corresponding return is -126.0, average rewards : -176.44
# Episode number 343, and it's corresponding return is -138.0, average rewards : -176.01
# Episode number 344, and it's corresponding return is -136.0, average rewards : -175.82
# Episode number 345, and it's corresponding return is -149.0, average rewards : -175.5
# Episode number 346, and it's corresponding return is -164.0, average rewards : -175.62
# Episode number 347, and it's corresponding return is -124.0, average rewards : -175.24
# Episode number 348, and it's corresponding return is -136.0, average rewards : -174.35
# Episode number 349, and it's corresponding return is -158.0, average rewards : -173.96
# Episode number 350, and it's corresponding return is -257.0, average rewards : -175.05
# Episode number 351, and it's corresponding return is -93.0, average rewards : -173.4
# Episode number 352, and it's corresponding return is -131.0, average rewards : -173.24
# Episode number 353, and it's corresponding return is -117.0, average rewards : -173.25
# Episode number 354, and it's corresponding return is -160.0, average rewards : -173.41
# Episode number 355, and it's corresponding return is -183.0, average rewards : -173.3
# Episode number 356, and it's corresponding return is -130.0, average rewards : -173.12
# Episode number 357, and it's corresponding return is -145.0, average rewards : -172.78
# Episode number 358, and it's corresponding return is -154.0, average rewards : -172.01
# Episode number 359, and it's corresponding return is -217.0, average rewards : -172.5
# Episode number 360, and it's corresponding return is -180.0, average rewards : -172.44
# Episode number 361, and it's corresponding return is -134.0, average rewards : -172.23
# Episode number 362, and it's corresponding return is -230.0, average rewards : -172.76
# Episode number 363, and it's corresponding return is -147.0, average rewards : -171.3
# Episode number 364, and it's corresponding return is -150.0, average rewards : -171.48
# Episode number 365, and it's corresponding return is -228.0, average rewards : -172.19
# Episode number 366, and it's corresponding return is -217.0, average rewards : -172.56
# Episode number 367, and it's corresponding return is -137.0, average rewards : -172.36
# Episode number 368, and it's corresponding return is -156.0, average rewards : -172.78
# Episode number 369, and it's corresponding return is -147.0, average rewards : -172.56
# Episode number 370, and it's corresponding return is -186.0, average rewards : -173.0
# Episode number 371, and it's corresponding return is -115.0, average rewards : -172.62
# Episode number 372, and it's corresponding return is -160.0, average rewards : -172.92
# Episode number 373, and it's corresponding return is -123.0, average rewards : -172.58
# Episode number 374, and it's corresponding return is -244.0, average rewards : -173.27
# Episode number 375, and it's corresponding return is -197.0, average rewards : -173.9
# Episode number 376, and it's corresponding return is -166.0, average rewards : -174.14
# Episode number 377, and it's corresponding return is -189.0, average rewards : -174.82
# Episode number 378, and it's corresponding return is -148.0, average rewards : -175.02
# Episode number 379, and it's corresponding return is -209.0, average rewards : -175.9
# Episode number 380, and it's corresponding return is -162.0, average rewards : -175.88
# Episode number 381, and it's corresponding return is -118.0, average rewards : -175.28
# Episode number 382, and it's corresponding return is -194.0, average rewards : -174.74
# Episode number 383, and it's corresponding return is -181.0, average rewards : -175.07
# Episode number 384, and it's corresponding return is -137.0, average rewards : -175.18
# Episode number 385, and it's corresponding return is -203.0, average rewards : -175.34
# Episode number 386, and it's corresponding return is -160.0, average rewards : -175.04
# Episode number 387, and it's corresponding return is -187.0, average rewards : -175.46
# Episode number 388, and it's corresponding return is -195.0, average rewards : -174.12
# Episode number 389, and it's corresponding return is -123.0, average rewards : -172.26
# Episode number 390, and it's corresponding return is -266.0, average rewards : -172.9
# Episode number 391, and it's corresponding return is -402.0, average rewards : -175.43
# Episode number 392, and it's corresponding return is -148.0, average rewards : -175.12
# Episode number 393, and it's corresponding return is -223.0, average rewards : -175.15
# Episode number 394, and it's corresponding return is -199.0, average rewards : -175.45
# Episode number 395, and it's corresponding return is -96.0, average rewards : -174.25
# Episode number 396, and it's corresponding return is -155.0, average rewards : -173.59
# Episode number 397, and it's corresponding return is -196.0, average rewards : -172.89
# Episode number 398, and it's corresponding return is -158.0, average rewards : -172.49
# Episode number 399, and it's corresponding return is -184.0, average rewards : -171.85
# Episode number 400, and it's corresponding return is -131.0, average rewards : -170.89
# Episode number 401, and it's corresponding return is -159.0, average rewards : -170.72
# Episode number 402, and it's corresponding return is -118.0, average rewards : -170.64
# Episode number 403, and it's corresponding return is -137.0, average rewards : -170.6
# Episode number 404, and it's corresponding return is -169.0, average rewards : -169.56
# Episode number 405, and it's corresponding return is -181.0, average rewards : -169.83
# Episode number 406, and it's corresponding return is -165.0, average rewards : -169.75
# Episode number 407, and it's corresponding return is -238.0, average rewards : -170.52
# Episode number 408, and it's corresponding return is -179.0, average rewards : -170.98
# Episode number 409, and it's corresponding return is -136.0, average rewards : -171.07
# Episode number 410, and it's corresponding return is -137.0, average rewards : -170.41
# Episode number 411, and it's corresponding return is -107.0, average rewards : -169.84
# Episode number 412, and it's corresponding return is -150.0, average rewards : -168.77
# Episode number 413, and it's corresponding return is -161.0, average rewards : -167.29
# Episode number 414, and it's corresponding return is -155.0, average rewards : -167.16
# Episode number 415, and it's corresponding return is -160.0, average rewards : -167.07
# Episode number 416, and it's corresponding return is -186.0, average rewards : -166.7
# Episode number 417, and it's corresponding return is -103.0, average rewards : -166.33
# Episode number 418, and it's corresponding return is -154.0, average rewards : -166.16
# Episode number 419, and it's corresponding return is -98.0, average rewards : -165.32
# Episode number 420, and it's corresponding return is -165.0, average rewards : -164.97
# Episode number 421, and it's corresponding return is -194.0, average rewards : -165.39
# Episode number 422, and it's corresponding return is -183.0, average rewards : -166.0
# Episode number 423, and it's corresponding return is -155.0, average rewards : -166.0
# Episode number 424, and it's corresponding return is -130.0, average rewards : -165.26
# Episode number 425, and it's corresponding return is -197.0, average rewards : -165.96
# Episode number 426, and it's corresponding return is -141.0, average rewards : -165.84
# Episode number 427, and it's corresponding return is -173.0, average rewards : -166.05
# Episode number 428, and it's corresponding return is -160.0, average rewards : -166.08
# Episode number 429, and it's corresponding return is -166.0, average rewards : -166.76
# Episode number 430, and it's corresponding return is -155.0, average rewards : -166.69
# Episode number 431, and it's corresponding return is -147.0, average rewards : -165.94
# Episode number 432, and it's corresponding return is -228.0, average rewards : -166.99
# Episode number 433, and it's corresponding return is -134.0, average rewards : -166.86
# Episode number 434, and it's corresponding return is -126.0, average rewards : -165.63
# Episode number 435, and it's corresponding return is -140.0, average rewards : -164.6
# Episode number 436, and it's corresponding return is -183.0, average rewards : -165.16
# Episode number 437, and it's corresponding return is -145.0, average rewards : -164.82
# Episode number 438, and it's corresponding return is -110.0, average rewards : -164.21
# Episode number 439, and it's corresponding return is -201.0, average rewards : -164.59
# Episode number 440, and it's corresponding return is -124.0, average rewards : -164.24
# Episode number 441, and it's corresponding return is -97.0, average rewards : -163.46
# Episode number 442, and it's corresponding return is -97.0, average rewards : -163.17
# Episode number 443, and it's corresponding return is -107.0, average rewards : -162.86
# Episode number 444, and it's corresponding return is -283.0, average rewards : -164.33
# Episode number 445, and it's corresponding return is -164.0, average rewards : -164.48
# Episode number 446, and it's corresponding return is -206.0, average rewards : -164.9
# Episode number 447, and it's corresponding return is -129.0, average rewards : -164.95
# Episode number 448, and it's corresponding return is -113.0, average rewards : -164.72
# Episode number 449, and it's corresponding return is -103.0, average rewards : -164.17
# Episode number 450, and it's corresponding return is -135.0, average rewards : -162.95
# Episode number 451, and it's corresponding return is -140.0, average rewards : -163.42
# Episode number 452, and it's corresponding return is -175.0, average rewards : -163.86
# Episode number 453, and it's corresponding return is -159.0, average rewards : -164.28
# Episode number 454, and it's corresponding return is -191.0, average rewards : -164.59
# Episode number 455, and it's corresponding return is -121.0, average rewards : -163.97
# Episode number 456, and it's corresponding return is -156.0, average rewards : -164.23
# Episode number 457, and it's corresponding return is -173.0, average rewards : -164.51
# Episode number 458, and it's corresponding return is -207.0, average rewards : -165.04
# Episode number 459, and it's corresponding return is -155.0, average rewards : -164.42
# Episode number 460, and it's corresponding return is -116.0, average rewards : -163.78
# Episode number 461, and it's corresponding return is -123.0, average rewards : -163.67
# Episode number 462, and it's corresponding return is -114.0, average rewards : -162.51
# Episode number 463, and it's corresponding return is -142.0, average rewards : -162.46
# Episode number 464, and it's corresponding return is -170.0, average rewards : -162.66
# Episode number 465, and it's corresponding return is -159.0, average rewards : -161.97
# Episode number 466, and it's corresponding return is -165.0, average rewards : -161.45
# Episode number 467, and it's corresponding return is -163.0, average rewards : -161.71
# Episode number 468, and it's corresponding return is -137.0, average rewards : -161.52
# Episode number 469, and it's corresponding return is -147.0, average rewards : -161.52
# Episode number 470, and it's corresponding return is -121.0, average rewards : -160.87
# Episode number 471, and it's corresponding return is -151.0, average rewards : -161.23
# Episode number 472, and it's corresponding return is -148.0, average rewards : -161.11
# Episode number 473, and it's corresponding return is -102.0, average rewards : -160.9
# Episode number 474, and it's corresponding return is -138.0, average rewards : -159.84
# Episode number 475, and it's corresponding return is -140.0, average rewards : -159.27
# Episode number 476, and it's corresponding return is -149.0, average rewards : -159.1
# Episode number 477, and it's corresponding return is -165.0, average rewards : -158.86
# Episode number 478, and it's corresponding return is -102.0, average rewards : -158.4
# Episode number 479, and it's corresponding return is -104.0, average rewards : -157.35
# Episode number 480, and it's corresponding return is -163.0, average rewards : -157.36
# Episode number 481, and it's corresponding return is -158.0, average rewards : -157.76
# Episode number 482, and it's corresponding return is -97.0, average rewards : -156.79
# Episode number 483, and it's corresponding return is -129.0, average rewards : -156.27
# Episode number 484, and it's corresponding return is -125.0, average rewards : -156.15
# Episode number 485, and it's corresponding return is -201.0, average rewards : -156.13
# Episode number 486, and it's corresponding return is -150.0, average rewards : -156.03
# Episode number 487, and it's corresponding return is -177.0, average rewards : -155.93
# Episode number 488, and it's corresponding return is -135.0, average rewards : -155.33
# Episode number 489, and it's corresponding return is -138.0, average rewards : -155.48
# Episode number 490, and it's corresponding return is -130.0, average rewards : -154.12
# Episode number 491, and it's corresponding return is -131.0, average rewards : -151.41
# Episode number 492, and it's corresponding return is -130.0, average rewards : -151.23
# Episode number 493, and it's corresponding return is -203.0, average rewards : -151.03
# Episode number 494, and it's corresponding return is -166.0, average rewards : -150.7
# Episode number 495, and it's corresponding return is -153.0, average rewards : -151.27
# Episode number 496, and it's corresponding return is -155.0, average rewards : -151.27
# Episode number 497, and it's corresponding return is -112.0, average rewards : -150.43
# Episode number 498, and it's corresponding return is -176.0, average rewards : -150.61
# Episode number 499, and it's corresponding return is -105.0, average rewards : -149.82
# Episode number 500, and it's corresponding return is -138.0, average rewards : -149.89
# Episode number 501, and it's corresponding return is -134.0, average rewards : -149.64
# Episode number 502, and it's corresponding return is -109.0, average rewards : -149.55
# Episode number 503, and it's corresponding return is -149.0, average rewards : -149.67
# Episode number 504, and it's corresponding return is -157.0, average rewards : -149.55
# Episode number 505, and it's corresponding return is -131.0, average rewards : -149.05
# Episode number 506, and it's corresponding return is -119.0, average rewards : -148.59
# Episode number 507, and it's corresponding return is -95.0, average rewards : -147.16
# Episode number 508, and it's corresponding return is -99.0, average rewards : -146.36
# Episode number 509, and it's corresponding return is -195.0, average rewards : -146.95
# Episode number 510, and it's corresponding return is -94.0, average rewards : -146.52
# Episode number 511, and it's corresponding return is -90.0, average rewards : -146.35
# Episode number 512, and it's corresponding return is -88.0, average rewards : -145.73
# Episode number 513, and it's corresponding return is -108.0, average rewards : -145.2
# Episode number 514, and it's corresponding return is -190.0, average rewards : -145.55
# Episode number 515, and it's corresponding return is -123.0, average rewards : -145.18
# Episode number 516, and it's corresponding return is -120.0, average rewards : -144.52
# Episode number 517, and it's corresponding return is -118.0, average rewards : -144.67
# Episode number 518, and it's corresponding return is -107.0, average rewards : -144.2
# Episode number 519, and it's corresponding return is -105.0, average rewards : -144.27
# Episode number 520, and it's corresponding return is -143.0, average rewards : -144.05
# Episode number 521, and it's corresponding return is -126.0, average rewards : -143.37
# Episode number 522, and it's corresponding return is -122.0, average rewards : -142.76
# Episode number 523, and it's corresponding return is -145.0, average rewards : -142.66
# Episode number 524, and it's corresponding return is -140.0, average rewards : -142.76
# Episode number 525, and it's corresponding return is -108.0, average rewards : -141.87
# Episode number 526, and it's corresponding return is -180.0, average rewards : -142.26
# Episode number 527, and it's corresponding return is -333.0, average rewards : -143.86
# Episode number 528, and it's corresponding return is -143.0, average rewards : -143.69
# Episode number 529, and it's corresponding return is -114.0, average rewards : -143.17
# Episode number 530, and it's corresponding return is -113.0, average rewards : -142.75
# Episode number 531, and it's corresponding return is -159.0, average rewards : -142.87
# Episode number 532, and it's corresponding return is -105.0, average rewards : -141.64
# Episode number 533, and it's corresponding return is -110.0, average rewards : -141.4
# Episode number 534, and it's corresponding return is -89.0, average rewards : -141.03
# Episode number 535, and it's corresponding return is -185.0, average rewards : -141.48
# Episode number 536, and it's corresponding return is -112.0, average rewards : -140.77
# Episode number 537, and it's corresponding return is -91.0, average rewards : -140.23
# Episode number 538, and it's corresponding return is -114.0, average rewards : -140.27
# Episode number 539, and it's corresponding return is -140.0, average rewards : -139.66
# Episode number 540, and it's corresponding return is -132.0, average rewards : -139.74
# Episode number 541, and it's corresponding return is -129.0, average rewards : -140.06
# Episode number 542, and it's corresponding return is -101.0, average rewards : -140.1
# Episode number 543, and it's corresponding return is -98.0, average rewards : -140.01
# Episode number 544, and it's corresponding return is -135.0, average rewards : -138.53
# ...
# Episode number 816, and it's corresponding return is -132.0, average rewards : -114.75
# Episode number 817, and it's corresponding return is -120.0, average rewards : -115.06
# Episode number 818, and it's corresponding return is -99.0, average rewards : -115.17
# Episode number 819, and it's corresponding return is -161.0, average rewards : -115.54
# Episode number 820, and it's corresponding return is -105.0, average rewards : -115.55
# Episode number 821, and it's corresponding return is -73.0, average rewards : -115.18
# Episode number 822, and it's corresponding return is -110.0, average rewards : -115.2
# Episode number 823, and it's corresponding return is -106.0, average rewards : -115.12
# Episode number 824, and it's corresponding return is -91.0, average rewards : -114.59
# Episode number 825, and it's corresponding return is -91.0, average rewards : -114.1
# Episode number 826, and it's corresponding return is -144.0, average rewards : -114.27
# Episode number 827, and it's corresponding return is -148.0, average rewards : -114.32
# Episode number 828, and it's corresponding return is -96.0, average rewards : -114.37
# Episode number 829, and it's corresponding return is -114.0, average rewards : -114.57
# Episode number 830, and it's corresponding return is -116.0, average rewards : -114.84
# Episode number 831, and it's corresponding return is -90.0, average rewards : -114.56
# Episode number 832, and it's corresponding return is -144.0, average rewards : -114.93
# Episode number 833, and it's corresponding return is -91.0, average rewards : -113.3
# Episode number 834, and it's corresponding return is -151.0, average rewards : -113.57
# Episode number 835, and it's corresponding return is -76.0, average rewards : -113.37
# Episode number 836, and it's corresponding return is -113.0, average rewards : -113.37
# Episode number 837, and it's corresponding return is -90.0, average rewards : -112.65
# Episode number 838, and it's corresponding return is -84.0, average rewards : -112.3
# Episode number 839, and it's corresponding return is -100.0, average rewards : -112.28
# Episode number 840, and it's corresponding return is -98.0, average rewards : -112.06
# Episode number 841, and it's corresponding return is -88.0, average rewards : -112.14
# Episode number 842, and it's corresponding return is -101.0, average rewards : -111.99
# Episode number 843, and it's corresponding return is -84.0, average rewards : -111.87
# Episode number 844, and it's corresponding return is -108.0, average rewards : -111.85
# Episode number 845, and it's corresponding return is -118.0, average rewards : -112.12
# Episode number 846, and it's corresponding return is -86.0, average rewards : -111.65
# Episode number 847, and it's corresponding return is -88.0, average rewards : -111.5
# Episode number 848, and it's corresponding return is -94.0, average rewards : -111.43
# Episode number 849, and it's corresponding return is -94.0, average rewards : -110.74
# Episode number 850, and it's corresponding return is -104.0, average rewards : -110.73
# Episode number 851, and it's corresponding return is -113.0, average rewards : -110.5
# Episode number 852, and it's corresponding return is -117.0, average rewards : -110.42
# Episode number 853, and it's corresponding return is -89.0, average rewards : -110.25
# Episode number 854, and it's corresponding return is -151.0, average rewards : -110.82
# Episode number 855, and it's corresponding return is -123.0, average rewards : -111.16
# Episode number 856, and it's corresponding return is -117.0, average rewards : -111.4
# Episode number 857, and it's corresponding return is -95.0, average rewards : -111.29
# Episode number 858, and it's corresponding return is -83.0, average rewards : -110.54
# Episode number 859, and it's corresponding return is -101.0, average rewards : -110.74
# Episode number 860, and it's corresponding return is -195.0, average rewards : -111.48
# Episode number 861, and it's corresponding return is -124.0, average rewards : -111.43
# Episode number 862, and it's corresponding return is -95.0, average rewards : -111.48
# Episode number 863, and it's corresponding return is -83.0, average rewards : -108.8
# Episode number 864, and it's corresponding return is -99.0, average rewards : -108.91
# Episode number 865, and it's corresponding return is -113.0, average rewards : -108.93
# Episode number 866, and it's corresponding return is -99.0, average rewards : -108.72
# Episode number 867, and it's corresponding return is -104.0, average rewards : -108.66
# Episode number 868, and it's corresponding return is -102.0, average rewards : -108.56
# Episode number 869, and it's corresponding return is -88.0, average rewards : -108.22
# Episode number 870, and it's corresponding return is -151.0, average rewards : -108.57
# Episode number 871, and it's corresponding return is -114.0, average rewards : -108.68
# Episode number 872, and it's corresponding return is -92.0, average rewards : -108.55
# Episode number 873, and it's corresponding return is -108.0, average rewards : -107.73
# Episode number 874, and it's corresponding return is -149.0, average rewards : -108.44
# Episode number 875, and it's corresponding return is -105.0, average rewards : -108.26
# Episode number 876, and it's corresponding return is -152.0, average rewards : -108.91
# Episode number 877, and it's corresponding return is -82.0, average rewards : -108.87
# Episode number 878, and it's corresponding return is -95.0, average rewards : -108.96
# Episode number 879, and it's corresponding return is -87.0, average rewards : -108.89
# Episode number 880, and it's corresponding return is -94.0, average rewards : -108.59
# Episode number 881, and it's corresponding return is -104.0, average rewards : -108.76
# Episode number 882, and it's corresponding return is -94.0, average rewards : -108.54
# Episode number 883, and it's corresponding return is -112.0, average rewards : -108.71
# Episode number 884, and it's corresponding return is -92.0, average rewards : -108.66
# Episode number 885, and it's corresponding return is -106.0, average rewards : -108.8
# Episode number 886, and it's corresponding return is -101.0, average rewards : -108.85
# Episode number 887, and it's corresponding return is -123.0, average rewards : -109.01
# Episode number 888, and it's corresponding return is -117.0, average rewards : -109.24
# Episode number 889, and it's corresponding return is -121.0, average rewards : -109.53
# Episode number 890, and it's corresponding return is -98.0, average rewards : -109.3
# Episode number 891, and it's corresponding return is -94.0, average rewards : -109.12
# Episode number 892, and it's corresponding return is -133.0, average rewards : -109.16
# Episode number 893, and it's corresponding return is -109.0, average rewards : -109.18
# Episode number 894, and it's corresponding return is -102.0, average rewards : -109.17
# Episode number 895, and it's corresponding return is -110.0, average rewards : -109.4
# Episode number 896, and it's corresponding return is -92.0, average rewards : -109.05
# Episode number 897, and it's corresponding return is -101.0, average rewards : -108.55
# Episode number 898, and it's corresponding return is -106.0, average rewards : -108.66
# Episode number 899, and it's corresponding return is -89.0, average rewards : -108.2
# Episode number 900, and it's corresponding return is -113.0, average rewards : -108.26
# Episode number 901, and it's corresponding return is -72.0, average rewards : -107.94
# Episode number 902, and it's corresponding return is -114.0, average rewards : -107.83
# Episode number 903, and it's corresponding return is -118.0, average rewards : -108.14
# Episode number 904, and it's corresponding return is -103.0, average rewards : -108.12
# Episode number 905, and it's corresponding return is -110.0, average rewards : -108.29
# Episode number 906, and it's corresponding return is -86.0, average rewards : -107.99
# Episode number 907, and it's corresponding return is -97.0, average rewards : -107.96
# Episode number 908, and it's corresponding return is -100.0, average rewards : -107.9
# Episode number 909, and it's corresponding return is -162.0, average rewards : -108.59
# Episode number 910, and it's corresponding return is -127.0, average rewards : -108.78
# Episode number 911, and it's corresponding return is -95.0, average rewards : -107.86
# Episode number 912, and it's corresponding return is -85.0, average rewards : -107.4
# Episode number 913, and it's corresponding return is -102.0, average rewards : -107.28
# Episode number 914, and it's corresponding return is -95.0, average rewards : -107.15
# Episode number 915, and it's corresponding return is -135.0, average rewards : -107.46
# Episode number 916, and it's corresponding return is -99.0, average rewards : -107.13
# Episode number 917, and it's corresponding return is -81.0, average rewards : -106.74
# Episode number 918, and it's corresponding return is -104.0, average rewards : -106.79
# Episode number 919, and it's corresponding return is -103.0, average rewards : -106.21
# Episode number 920, and it's corresponding return is -93.0, average rewards : -106.09
# Episode number 921, and it's corresponding return is -81.0, average rewards : -106.17
# Episode number 922, and it's corresponding return is -68.0, average rewards : -105.75
# Episode number 923, and it's corresponding return is -118.0, average rewards : -105.87
# Episode number 924, and it's corresponding return is -140.0, average rewards : -106.36
# Episode number 925, and it's corresponding return is -124.0, average rewards : -106.69
# Episode number 926, and it's corresponding return is -105.0, average rewards : -106.3
# Episode number 927, and it's corresponding return is -115.0, average rewards : -105.97
# Episode number 928, and it's corresponding return is -94.0, average rewards : -105.95
# Episode number 929, and it's corresponding return is -98.0, average rewards : -105.79
# Episode number 930, and it's corresponding return is -95.0, average rewards : -105.58
# Episode number 931, and it's corresponding return is -184.0, average rewards : -106.52
# Episode number 932, and it's corresponding return is -133.0, average rewards : -106.41
# Episode number 933, and it's corresponding return is -111.0, average rewards : -106.61
# Episode number 934, and it's corresponding return is -112.0, average rewards : -106.22
# Episode number 935, and it's corresponding return is -80.0, average rewards : -106.26
# Episode number 936, and it's corresponding return is -112.0, average rewards : -106.25
# Episode number 937, and it's corresponding return is -191.0, average rewards : -107.26
# Episode number 938, and it's corresponding return is -300.0, average rewards : -109.42
# Episode number 939, and it's corresponding return is -115.0, average rewards : -109.57
# Episode number 940, and it's corresponding return is -99.0, average rewards : -109.58
# Episode number 941, and it's corresponding return is -89.0, average rewards : -109.59
# Episode number 942, and it's corresponding return is -97.0, average rewards : -109.55
# Episode number 943, and it's corresponding return is -109.0, average rewards : -109.8
# Episode number 944, and it's corresponding return is -148.0, average rewards : -110.2
# Episode number 945, and it's corresponding return is -81.0, average rewards : -109.83
# Episode number 946, and it's corresponding return is -78.0, average rewards : -109.75
# Episode number 947, and it's corresponding return is -103.0, average rewards : -109.9
# Episode number 948, and it's corresponding return is -87.0, average rewards : -109.83
# Episode number 949, and it's corresponding return is -91.0, average rewards : -109.8
# Episode number 950, and it's corresponding return is -99.0, average rewards : -109.75
# Episode number 951, and it's corresponding return is -109.0, average rewards : -109.71
# Episode number 952, and it's corresponding return is -86.0, average rewards : -109.4
# Episode number 953, and it's corresponding return is -115.0, average rewards : -109.66
# Episode number 954, and it's corresponding return is -117.0, average rewards : -109.32
# Episode number 955, and it's corresponding return is -89.0, average rewards : -108.98
# Episode number 956, and it's corresponding return is -84.0, average rewards : -108.65
# Episode number 957, and it's corresponding return is -81.0, average rewards : -108.51
# Episode number 958, and it's corresponding return is -128.0, average rewards : -108.96
# Episode number 959, and it's corresponding return is -92.0, average rewards : -108.87
# Episode number 960, and it's corresponding return is -88.0, average rewards : -107.8
# Episode number 961, and it's corresponding return is -116.0, average rewards : -107.72
# Episode number 962, and it's corresponding return is -78.0, average rewards : -107.55
# Episode number 963, and it's corresponding return is -87.0, average rewards : -107.59
# Episode number 964, and it's corresponding return is -149.0, average rewards : -108.09
# Episode number 965, and it's corresponding return is -115.0, average rewards : -108.11
# Episode number 966, and it's corresponding return is -130.0, average rewards : -108.42
# Episode number 967, and it's corresponding return is -83.0, average rewards : -108.21
# Episode number 968, and it's corresponding return is -137.0, average rewards : -108.56
# Episode number 969, and it's corresponding return is -83.0, average rewards : -108.51
# Episode number 970, and it's corresponding return is -111.0, average rewards : -108.11
# Episode number 971, and it's corresponding return is -88.0, average rewards : -107.85
# Episode number 972, and it's corresponding return is -106.0, average rewards : -107.99
# Episode number 973, and it's corresponding return is -99.0, average rewards : -107.9
# Episode number 974, and it's corresponding return is -88.0, average rewards : -107.29
# Episode number 975, and it's corresponding return is -138.0, average rewards : -107.62
# Episode number 976, and it's corresponding return is -72.0, average rewards : -106.82
# Episode number 977, and it's corresponding return is -86.0, average rewards : -106.86
# Episode number 978, and it's corresponding return is -98.0, average rewards : -106.89
# Episode number 979, and it's corresponding return is -106.0, average rewards : -107.08
# Episode number 980, and it's corresponding return is -76.0, average rewards : -106.9
# Episode number 981, and it's corresponding return is -82.0, average rewards : -106.68
# Episode number 982, and it's corresponding return is -106.0, average rewards : -106.8
# Episode number 983, and it's corresponding return is -86.0, average rewards : -106.54
# Episode number 984, and it's corresponding return is -92.0, average rewards : -106.54
# Episode number 985, and it's corresponding return is -113.0, average rewards : -106.61
# Episode number 986, and it's corresponding return is -79.0, average rewards : -106.39
# Episode number 987, and it's corresponding return is -113.0, average rewards : -106.29
# Episode number 988, and it's corresponding return is -107.0, average rewards : -106.19
# Episode number 989, and it's corresponding return is -115.0, average rewards : -106.13
# Episode number 990, and it's corresponding return is -65.0, average rewards : -105.8
# Episode number 991, and it's corresponding return is -81.0, average rewards : -105.67
# Episode number 992, and it's corresponding return is -81.0, average rewards : -105.15
# Episode number 993, and it's corresponding return is -175.0, average rewards : -105.81
# Episode number 994, and it's corresponding return is -84.0, average rewards : -105.63
# Episode number 995, and it's corresponding return is -162.0, average rewards : -106.15
# Episode number 996, and it's corresponding return is -103.0, average rewards : -106.26
# Episode number 997, and it's corresponding return is -81.0, average rewards : -106.06
# Episode number 998, and it's corresponding return is -84.0, average rewards : -105.84
# Episode number 999, and it's corresponding return is -127.0, average rewards : -106.22
# Episode number 1000, and it's corresponding return is -97.0, average rewards : -106.06

# %%
returns_1_2_5runs = []
for seed in [0,1,2,3,4]:
    MC_1_2 = MC_Reinforce(env1, (128, 64), 0, 2)
    returns_1_2 = MC_1_2.train(1000)
    returns_1_2_5runs.append(returns_1_2)
returns_1_2_5runs = np.array(returns_1_2_5runs)
# Out:
# Episode number 1, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 2, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 3, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 4, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 5, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 6, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 7, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 8, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 9, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 10, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 11, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 12, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 13, and it's corresponding return is -500.0, average rewards : -500.0
# Episode number 14, and it's corresponding return is -289.0, average rewards : -484.92857142857144
# Episode number 15, and it's corresponding return is -500.0, average rewards : -485.93333333333334
# Episode number 16, and it's corresponding return is -500.0, average rewards : -486.8125
# Episode number 17, and it's corresponding return is -500.0, average rewards : -487.5882352941176
# Episode number 18, and it's corresponding return is -500.0, average rewards : -488.27777777777777
# Episode number 19, and it's corresponding return is -492.0, average rewards : -488.4736842105263
# Episode number 20, and it's corresponding return is -500.0, average rewards : -489.05
# Episode number 21, and it's corresponding return is -500.0, average rewards : -489.57142857142856
# Episode number 22, and it's corresponding return is -399.0, average rewards : -485.45454545454544
# Episode number 23, and it's corresponding return is -500.0, average rewards : -486.0869565217391
# Episode number 24, and it's corresponding return is -500.0, average rewards : -486.6666666666667
# Episode number 25, and it's corresponding return is -257.0, average rewards : -477.48
# Episode number 26, and it's corresponding return is -313.0, average rewards : -471.15384615384613
# Episode number 27, and it's corresponding return is -190.0, average rewards : -460.74074074074076
# Episode number 28, and it's corresponding return is -408.0, average rewards : -458.85714285714283
# Episode number 29, and it's corresponding return is -163.0, average rewards : -448.6551724137931
# Episode number 30, and it's corresponding return is -385.0, average rewards : -446.53333333333336
# Episode number 31, and it's corresponding return is -321.0, average rewards : -442.48387096774195
# Episode number 32, and it's corresponding return is -440.0, average rewards : -442.40625
# Episode number 33, and it's corresponding return is -500.0, average rewards : -444.1515151515151
# Episode number 34, and it's corresponding return is -376.0, average rewards : -442.1470588235294
# Episode number 35, and it's corresponding return is -301.0, average rewards : -438.1142857142857
# Episode number 36, and it's corresponding return is -386.0, average rewards : -436.6666666666667
# Episode number 37, and it's corresponding return is -436.0, average rewards : -436.64864864864865
# Episode number 38, and it's corresponding return is -500.0, average rewards : -438.3157894736842
# Episode number 39, and it's corresponding return is -476.0, average rewards : -439.28205128205127
# Episode number 40, and it's corresponding return is -359.0, average rewards : -437.275
# Episode number 41, and it's corresponding return is -415.0, average rewards : -436.7317073170732
# Episode number 42, and it's corresponding return is -500.0, average rewards : -438.23809523809524
# Episode number 43, and it's corresponding return is -500.0, average rewards : -439.6744186046512
# Episode number 44, and it's corresponding return is -276.0, average rewards : -435.95454545454544
# Episode number 45, and it's corresponding return is -349.0, average rewards : -434.02222222222224
# Episode number 46, and it's corresponding return is -289.0, average rewards : -430.8695652173913
# Episode number 47, and it's corresponding return is -232.0, average rewards : -426.63829787234044
# Episode number 48, and it's corresponding return is -237.0, average rewards : -422.6875
# Episode number 49, and it's corresponding return is -448.0, average rewards : -423.2040816326531
# Episode number 50, and it's corresponding return is -447.0, average rewards : -423.68
# Episode number 51, and it's corresponding return is -437.0, average rewards : -423.94117647058823
# Episode number 52, and it's corresponding return is -351.0, average rewards : -422.53846153846155
# Episode number 53, and it's corresponding return is -176.0, average rewards : -417.8867924528302
# Episode number 54, and it's corresponding return is -307.0, average rewards : -415.8333333333333
# Episode number 55, and it's corresponding return is -500.0, average rewards : -417.3636363636364
# Episode number 56, and it's corresponding return is -270.0, average rewards : -414.73214285714283
# Episode number 57, and it's corresponding return is -212.0, average rewards : -411.17543859649123
# Episode number 58, and it's corresponding return is -220.0, average rewards : -407.87931034482756
# Episode number 59, and it's corresponding return is -188.0, average rewards : -404.1525423728813
# Episode number 60, and it's corresponding return is -230.0, average rewards : -401.25
# Episode number 61, and it's corresponding return is -384.0, average rewards : -400.9672131147541
# Episode number 62, and it's corresponding return is -229.0, average rewards : -398.19354838709677
# Episode number 63, and it's corresponding return is -299.0, average rewards : -396.6190476190476
# Episode number 64, and it's corresponding return is -331.0, average rewards : -395.59375
# Episode number 65, and it's corresponding return is -231.0, average rewards : -393.0615384615385
# Episode number 66, and it's corresponding return is -210.0, average rewards : -390.2878787878788
# Episode number 67, and it's corresponding return is -273.0, average rewards : -388.53731343283584
# Episode number 68, and it's corresponding return is -206.0, average rewards : -385.8529411764706
# Episode number 69, and it's corresponding return is -168.0, average rewards : -382.69565217391306
# Episode number 70, and it's corresponding return is -213.0, average rewards : -380.27142857142854
# Episode number 71, and it's corresponding return is -139.0, average rewards : -376.8732394366197
# Episode number 72, and it's corresponding return is -190.0, average rewards : -374.27777777777777
# Episode number 73, and it's corresponding return is -313.0, average rewards : -373.43835616438355
# Episode number 74, and it's corresponding return is -190.0, average rewards : -370.9594594594595
# Episode number 75, and it's corresponding return is -357.0, average rewards : -370.7733333333333
# Episode number 76, and it's corresponding return is -288.0, average rewards : -369.6842105263158
# Episode number 77, and it's corresponding return is -256.0, average rewards : -368.2077922077922
# Episode number 78, and it's corresponding return is -286.0, average rewards : -367.15384615384613
# Episode number 79, and it's corresponding return is -240.0, average rewards : -365.54430379746833
# Episode number 80, and it's corresponding return is -320.0, average rewards : -364.975
# Episode number 81, and it's corresponding return is -259.0, average rewards : -363.6666666666667
# Episode number 82, and it's corresponding return is -122.0, average rewards : -360.719512195122
# Episode number 83, and it's corresponding return is -240.0, average rewards : -359.26506024096386
# Episode number 84, and it's corresponding return is -237.0, average rewards : -357.8095238095238
# Episode number 85, and it's corresponding return is -184.0, average rewards : -355.7647058823529
# Episode number 86, and it's corresponding return is -176.0, average rewards : -353.6744186046512
# Episode number 87, and it's corresponding return is -201.0, average rewards : -351.91954022988506
# Episode number 88, and it's corresponding return is -211.0, average rewards : -350.3181818181818
# Episode number 89, and it's corresponding return is -199.0, average rewards : -348.6179775280899
# Episode number 90, and it's corresponding return is -277.0, average rewards : -347.8222222222222
# Episode number 91, and it's corresponding return is -252.0, average rewards : -346.7692307692308
# Episode number 92, and it's corresponding return is -277.0, average rewards : -346.0108695652174
# Episode number 93, and it's corresponding return is -231.0, average rewards : -344.7741935483871
# Episode number 94, and it's corresponding return is -236.0, average rewards : -343.6170212765957
# Episode number 95, and it's corresponding return is -229.0, average rewards : -342.41052631578947
# Episode number 96, and it's corresponding return is -253.0, average rewards : -341.4791666666667
# Episode number 97, and it's corresponding return is -216.0, average rewards : -340.1855670103093
# Episode number 98, and it's corresponding return is -184.0, average rewards : -338.59183673469386
# Episode number 99, and it's corresponding return is -342.0, average rewards : -338.62626262626264
# Episode number 100, and it's corresponding return is -212.0, average rewards : -337.36
# Episode number 101, and it's corresponding return is -284.0, average rewards : -335.2
# Episode number 102, and it's corresponding return is -159.0, average rewards : -331.79
# Episode number 103, and it's corresponding return is -435.0, average rewards : -331.14
# Episode number 104, and it's corresponding return is -157.0, average rewards : -327.71
# Episode number 105, and it's corresponding return is -207.0, average rewards : -324.78
# Episode number 106, and it's corresponding return is -206.0, average rewards : -321.84
# Episode number 107, and it's corresponding return is -310.0, average rewards : -319.94
# Episode number 108, and it's corresponding return is -193.0, average rewards : -316.87
# Episode number 109, and it's corresponding return is -199.0, average rewards : -313.86
# Episode number 110, and it's corresponding return is -196.0, average rewards : -310.82
# Episode number 111, and it's corresponding return is -419.0, average rewards : -310.01
# Episode number 112, and it's corresponding return is -278.0, average rewards : -307.79
# Episode number 113, and it's corresponding return is -219.0, average rewards : -304.98
# Episode number 114, and it's corresponding return is -138.0, average rewards : -303.47
# Episode number 115, and it's corresponding return is -248.0, average rewards : -300.95
# Episode number 116, and it's corresponding return is -223.0, average rewards : -298.18
# Episode number 117, and it's corresponding return is -416.0, average rewards : -297.34
# Episode number 118, and it's corresponding return is -199.0, average rewards : -294.33
# Episode number 119, and it's corresponding return is -281.0, average rewards : -292.22
# Episode number 120, and it's corresponding return is -205.0, average rewards : -289.27
# Episode number 121, and it's corresponding return is -222.0, average rewards : -286.49
# Episode number 122, and it's corresponding return is -254.0, average rewards : -285.04
# Episode number 123, and it's corresponding return is -337.0, average rewards : -283.41
# Episode number 124, and it's corresponding return is -252.0, average rewards : -280.93
# Episode number 125, and it's corresponding return is -157.0, average rewards : -279.93
# Episode number 126, and it's corresponding return is -174.0, average rewards : -278.54
# Episode number 127, and it's corresponding return is -244.0, average rewards : -279.08
# Episode number 128, and it's corresponding return is -279.0, average rewards : -277.79
# Episode number 129, and it's corresponding return is -193.0, average rewards : -278.09
# Episode number 130, and it's corresponding return is -289.0, average rewards : -277.13
# Episode number 131, and it's corresponding return is -148.0, average rewards : -275.4
# Episode number 132, and it's corresponding return is -193.0, average rewards : -272.93
# Episode number 133, and it's corresponding return is -224.0, average rewards : -270.17
# Episode number 134, and it's corresponding return is -194.0, average rewards : -268.35
# Episode number 135, and it's corresponding return is -262.0, average rewards : -267.96
# Episode number 136, and it's corresponding return is -202.0, average rewards : -266.12
# Episode number 137, and it's corresponding return is -156.0, average rewards : -263.32
# Episode number 138, and it's corresponding return is -293.0, average rewards : -261.25
# Episode number 139, and it's corresponding return is -266.0, average rewards : -259.15
# Episode number 140, and it's corresponding return is -269.0, average rewards : -258.25
# Episode number 141, and it's corresponding return is -261.0, average rewards : -256.71
# Episode number 142, and it's corresponding return is -214.0, average rewards : -253.85
# Episode number 143, and it's corresponding return is -318.0, average rewards : -252.03
# Episode number 144, and it's corresponding return is -221.0, average rewards : -251.48
# Episode number 145, and it's corresponding return is -175.0, average rewards : -249.74
# Episode number 146, and it's corresponding return is -214.0, average rewards : -248.99
# Episode number 147, and it's corresponding return is -181.0, average rewards : -248.48
# Episode number 148, and it's corresponding return is -161.0, average rewards : -247.72
# Episode number 149, and it's corresponding return is -133.0, average rewards : -244.57
# Episode number 150, and it's corresponding return is -198.0, average rewards : -242.08
# Episode number 151, and it's corresponding return is -168.0, average rewards : -239.39
# Episode number 152, and it's corresponding return is -128.0, average rewards : -237.16
# Episode number 153, and it's corresponding return is -208.0, average rewards : -237.48
# Episode number 154, and it's corresponding return is -143.0, average rewards : -235.84
# Episode number 155, and it's corresponding return is -244.0, average rewards : -233.28
# Episode number 156, and it's corresponding return is -198.0, average rewards : -232.56
# Episode number 157, and it's corresponding return is -243.0, average rewards : -232.87
# Episode number 158, and it's corresponding return is -228.0, average rewards : -232.95
# Episode number 159, and it's corresponding return is -176.0, average rewards : -232.83
# Episode number 160, and it's corresponding return is -197.0, average rewards : -232.5
# Episode number 161, and it's corresponding return is -188.0, average rewards : -230.54
# Episode number 162, and it's corresponding return is -207.0, average rewards : -230.32
# Episode number 163, and it's corresponding return is -182.0, average rewards : -229.15
# Episode number 164, and it's corresponding return is -202.0, average rewards : -227.86
# Episode number 165, and it's corresponding return is -190.0, average rewards : -227.45
# Episode number 166, and it's corresponding return is -235.0, average rewards : -227.7
# Episode number 167, and it's corresponding return is -266.0, average rewards : -227.63
# Episode number 168, and it's corresponding return is -164.0, average rewards : -227.21
# Episode number 169, and it's corresponding return is -183.0, average rewards : -227.36
# Episode number 170, and it's corresponding return is -102.0, average rewards : -226.25
# Episode number 171, and it's corresponding return is -313.0, average rewards : -227.99
# Episode number 172, and it's corresponding return is -164.0, average rewards : -227.73
# Episode number 173, and it's corresponding return is -275.0, average rewards : -227.35
# Episode number 174, and it's corresponding return is -183.0, average rewards : -227.28
# Episode number 175, and it's corresponding return is -190.0, average rewards : -225.61
# Episode number 176, and it's corresponding return is -243.0, average rewards : -225.16
# Episode number 177, and it's corresponding return is -206.0, average rewards : -224.66
# Episode number 178, and it's corresponding return is -203.0, average rewards : -223.83
# Episode number 179, and it's corresponding return is -178.0, average rewards : -223.21
# Episode number 180, and it's corresponding return is -187.0, average rewards : -221.88
# Episode number 181, and it's corresponding return is -166.0, average rewards : -220.95
# Episode number 182, and it's corresponding return is -157.0, average rewards : -221.3
# Episode number 183, and it's corresponding return is -252.0, average rewards : -221.42
# Episode number 184, and it's corresponding return is -285.0, average rewards : -221.9
# Episode number 185, and it's corresponding return is -190.0, average rewards : -221.96
# Episode number 186, and it's corresponding return is -168.0, average rewards : -221.88
# Episode number 187, and it's corresponding return is -152.0, average rewards : -221.39
# Episode number 188, and it's corresponding return is -149.0, average rewards : -220.77
# Episode number 189, and it's corresponding return is -248.0, average rewards : -221.26
# Episode number 190, and it's corresponding return is -149.0, average rewards : -219.98
# Episode number 191, and it's corresponding return is -182.0, average rewards : -219.28
# Episode number 192, and it's corresponding return is -110.0, average rewards : -217.61
# Episode number 193, and it's corresponding return is -488.0, average rewards : -220.18
# Episode number 194, and it's corresponding return is -150.0, average rewards : -219.32
# Episode number 195, and it's corresponding return is -165.0, average rewards : -218.68
# Episode number 196, and it's corresponding return is -234.0, average rewards : -218.49
# Episode number 197, and it's corresponding return is -187.0, average rewards : -218.2
# Episode number 198, and it's corresponding return is -199.0, average rewards : -218.35
# Episode number 199, and it's corresponding return is -176.0, average rewards : -216.69
# Episode number 200, and it's corresponding return is -199.0, average rewards : -216.56
# Episode number 201, and it's corresponding return is -147.0, average rewards : -215.19
# Episode number 202, and it's corresponding return is -196.0, average rewards : -215.56
# Episode number 203, and it's corresponding return is -153.0, average rewards : -212.74
# Episode number 204, and it's corresponding return is -124.0, average rewards : -212.41
# Episode number 205, and it's corresponding return is -152.0, average rewards : -211.86
# Episode number 206, and it's corresponding return is -125.0, average rewards : -211.05
# Episode number 207, and it's corresponding return is -151.0, average rewards : -209.46
# Episode number 208, and it's corresponding return is -196.0, average rewards : -209.49
# Episode number 209, and it's corresponding return is -120.0, average rewards : -208.7
# Episode number 210, and it's corresponding return is -152.0, average rewards : -208.26
# Episode number 211, and it's corresponding return is -119.0, average rewards : -205.26
# Episode number 212, and it's corresponding return is -189.0, average rewards : -204.37
# Episode number 213, and it's corresponding return is -158.0, average rewards : -203.76
# Episode number 214, and it's corresponding return is -133.0, average rewards : -203.71
# Episode number 215, and it's corresponding return is -138.0, average rewards : -202.61
# Episode number 216, and it's corresponding return is -188.0, average rewards : -202.26
# Episode number 217, and it's corresponding return is -122.0, average rewards : -199.32
# Episode number 218, and it's corresponding return is -117.0, average rewards : -198.5
# Episode number 219, and it's corresponding return is -162.0, average rewards : -197.31
# Episode number 220, and it's corresponding return is -223.0, average rewards : -197.49
# Episode number 221, and it's corresponding return is -165.0, average rewards : -196.92
# Episode number 222, and it's corresponding return is -140.0, average rewards : -195.78
# Episode number 223, and it's corresponding return is -132.0, average rewards : -193.73
# Episode number 224, and it's corresponding return is -320.0, average rewards : -194.41
# Episode number 225, and it's corresponding return is -154.0, average rewards : -194.38
# Episode number 226, and it's corresponding return is -154.0, average rewards : -194.18
# Episode number 227, and it's corresponding return is -166.0, average rewards : -193.4
# Episode number 228, and it's corresponding return is -167.0, average rewards : -192.28
# Episode number 229, and it's corresponding return is -143.0, average rewards : -191.78
# Episode number 230, and it's corresponding return is -196.0, average rewards : -190.85
# Episode number 231, and it's corresponding return is -105.0, average rewards : -190.42
# Episode number 232, and it's corresponding return is -151.0, average rewards : -190.0
# Episode number 233, and it's corresponding return is -162.0, average rewards : -189.38
# Episode number 234, and it's corresponding return is -145.0, average rewards : -188.89
# Episode number 235, and it's corresponding return is -266.0, average rewards : -188.93
# Episode number 236, and it's corresponding return is -166.0, average rewards : -188.57
# Episode number 237, and it's corresponding return is -217.0, average rewards : -189.18
# Episode number 238, and it's corresponding return is -143.0, average rewards : -187.68
# Episode number 239, and it's corresponding return is -135.0, average rewards : -186.37
# Episode number 240, and it's corresponding return is -114.0, average rewards : -184.82
# Episode number 241, and it's corresponding return is -144.0, average rewards : -183.65
# Episode number 242, and it's corresponding return is -199.0, average rewards : -183.5
# Episode number 243, and it's corresponding return is -120.0, average rewards : -181.52
# Episode number 244, and it's corresponding return is -117.0, average rewards : -180.48
# Episode number 245, and it's corresponding return is -129.0, average rewards : -180.02
# Episode number 246, and it's corresponding return is -154.0, average rewards : -179.42
# Episode number 247, and it's corresponding return is -219.0, average rewards : -179.8
# Episode number 248, and it's corresponding return is -139.0, average rewards : -179.58
# Episode number 249, and it's corresponding return is -158.0, average rewards : -179.83
# Episode number 250, and it's corresponding return is -126.0, average rewards : -179.11
# Episode number 251, and it's corresponding return is -203.0, average rewards : -179.46
# Episode number 252, and it's corresponding return is -212.0, average rewards : -180.3
# Episode number 253, and it's corresponding return is -149.0, average rewards : -179.71
# Episode number 254, and it's corresponding return is -148.0, average rewards : -179.76
# Episode number 255, and it's corresponding return is -153.0, average rewards : -178.85
# Episode number 256, and it's corresponding return is -130.0, average rewards : -178.17
# Episode number 257, and it's corresponding return is -254.0, average rewards : -178.28
# Episode number 258, and it's corresponding return is -152.0, average rewards : -177.52
# Episode number 259, and it's corresponding return is -98.0, average rewards : -176.74
# Episode number 260, and it's corresponding return is -161.0, average rewards : -176.38
# Episode number 261, and it's corresponding return is -164.0, average rewards : -176.14
# Episode number 262, and it's corresponding return is -209.0, average rewards : -176.16
# Episode number 263, and it's corresponding return is -143.0, average rewards : -175.77
# Episode number 264, and it's corresponding return is -143.0, average rewards : -175.18
# Episode number 265, and it's corresponding return is -145.0, average rewards : -174.73
# Episode number 266, and it's corresponding return is -130.0, average rewards : -173.68
# Episode number 267, and it's corresponding return is -160.0, average rewards : -172.62
# Episode number 268, and it's corresponding return is -189.0, average rewards : -172.87
# Episode number 269, and it's corresponding return is -168.0, average rewards : -172.72
# Episode number 270, and it's corresponding return is -174.0, average rewards : -173.44
# Episode number 271, and it's corresponding return is -207.0, average rewards : -172.38
# Episode number 272, and it's corresponding return is -149.0, average rewards : -172.23
# Episode number 273, and it's corresponding return is -138.0, average rewards : -170.86
# Episode number 274, and it's corresponding return is -171.0, average rewards : -170.74
# Episode number 275, and it's corresponding return is -149.0, average rewards : -170.33
# Episode number 276, and it's corresponding return is -173.0, average rewards : -169.63
# Episode number 277, and it's corresponding return is -169.0, average rewards : -169.26
# Episode number 278, and it's corresponding return is -125.0, average rewards : -168.48
# Episode number 279, and it's corresponding return is -128.0, average rewards : -167.98
# Episode number 280, and it's corresponding return is -163.0, average rewards : -167.74
# Episode number 281, and it's corresponding return is -164.0, average rewards : -167.72
# Episode number 282, and it's corresponding return is -118.0, average rewards : -167.33
# Episode number 283, and it's corresponding return is -155.0, average rewards : -166.36
# Episode number 284, and it's corresponding return is -131.0, average rewards : -164.82
# Episode number 285, and it's corresponding return is -138.0, average rewards : -164.3
# Episode number 286, and it's corresponding return is -121.0, average rewards : -163.83
# Episode number 287, and it's corresponding return is -121.0, average rewards : -163.52
# Episode number 288, and it's corresponding return is -165.0, average rewards : -163.68
# Episode number 289, and it's corresponding return is -191.0, average rewards : -163.11
# Episode number 290, and it's corresponding return is -196.0, average rewards : -163.58
# Episode number 291, and it's corresponding return is -262.0, average rewards : -164.38
# Episode number 292, and it's corresponding return is -169.0, average rewards : -164.97
# Episode number 293, and it's corresponding return is -166.0, average rewards : -161.75
# Episode number 294, and it's corresponding return is -149.0, average rewards : -161.74
# Episode number 295, and it's corresponding return is -129.0, average rewards : -161.38
# Episode number 296, and it's corresponding return is -203.0, average rewards : -161.07
# Episode number 297, and it's corresponding return is -164.0, average rewards : -160.84
# Episode number 298, and it's corresponding return is -133.0, average rewards : -160.18
# Episode number 299, and it's corresponding return is -187.0, average rewards : -160.29
# Episode number 300, and it's corresponding return is -136.0, average rewards : -159.66
# Episode number 301, and it's corresponding return is -218.0, average rewards : -160.37
# Episode number 302, and it's corresponding return is -155.0, average rewards : -159.96
# Episode number 303, and it's corresponding return is -126.0, average rewards : -159.69
# Episode number 304, and it's corresponding return is -118.0, average rewards : -159.63
# Episode number 305, and it's corresponding return is -99.0, average rewards : -159.1
# Episode number 306, and it's corresponding return is -161.0, average rewards : -159.46
# Episode number 307, and it's corresponding return is -140.0, average rewards : -159.35
# Episode number 308, and it's corresponding return is -183.0, average rewards : -159.22
# Episode number 309, and it's corresponding return is -100.0, average rewards : -159.02
# Episode number 310, and it's corresponding return is -144.0, average rewards : -158.94
# Episode number 311, and it's corresponding return is -163.0, average rewards : -159.38
# Episode number 312, and it's corresponding return is -174.0, average rewards : -159.23
# Episode number 313, and it's corresponding return is -160.0, average rewards : -159.25
# Episode number 314, and it's corresponding return is -134.0, average rewards : -159.26
# Episode number 315, and it's corresponding return is -137.0, average rewards : -159.25
# Episode number 316, and it's corresponding return is -183.0, average rewards : -159.2
# Episode number 317, and it's corresponding return is -166.0, average rewards : -159.64
# Episode number 318, and it's corresponding return is -126.0, average rewards : -159.73
# Episode number 319, and it's corresponding return is -153.0, average rewards : -159.64
# Episode number 320, and it's corresponding return is -117.0, average rewards : -158.58
# Episode number 321, and it's corresponding return is -144.0, average rewards : -158.37
# Episode number 322, and it's corresponding return is -96.0, average rewards : -157.93
# Episode number 323, and it's corresponding return is -148.0, average rewards : -158.09
# Episode number 324, and it's corresponding return is -94.0, average rewards : -155.83
# Episode number 325, and it's corresponding return is -142.0, average rewards : -155.71
# Episode number 326, and it's corresponding return is -165.0, average rewards : -155.82
# Episode number 327, and it's corresponding return is -131.0, average rewards : -155.47
# Episode number 328, and it's corresponding return is -133.0, average rewards : -155.13
# Episode number 329, and it's corresponding return is -177.0, average rewards : -155.47
# Episode number 330, and it's corresponding return is -90.0, average rewards : -154.41
# Episode number 331, and it's corresponding return is -107.0, average rewards : -154.43
# Episode number 332, and it's corresponding return is -122.0, average rewards : -154.14
# Episode number 333, and it's corresponding return is -118.0, average rewards : -153.7
# Episode number 334, and it's corresponding return is -132.0, average rewards : -153.57
# Episode number 335, and it's corresponding return is -116.0, average rewards : -152.07
# Episode number 336, and it's corresponding return is -145.0, average rewards : -151.86
# Episode number 337, and it's corresponding return is -176.0, average rewards : -151.45
# Episode number 338, and it's corresponding return is -122.0, average rewards : -151.24
# Episode number 339, and it's corresponding return is -148.0, average rewards : -151.37
# Episode number 340, and it's corresponding return is -143.0, average rewards : -151.66
# Episode number 341, and it's corresponding return is -126.0, average rewards : -151.48
# Episode number 342, and it's corresponding return is -119.0, average rewards : -150.68
# Episode number 343, and it's corresponding return is -131.0, average rewards : -150.79
# Episode number 344, and it's corresponding return is -130.0, average rewards : -150.92
# Episode number 345, and it's corresponding return is -129.0, average rewards : -150.92
# Episode number 346, and it's corresponding return is -175.0, average rewards : -151.13
# Episode number 347, and it's corresponding return is -126.0, average rewards : -150.2
# Episode number 348, and it's corresponding return is -193.0, average rewards : -150.74
# Episode number 349, and it's corresponding return is -114.0, average rewards : -150.3
# Episode number 350, and it's corresponding return is -125.0, average rewards : -150.29
# Episode number 351, and it's corresponding return is -107.0, average rewards : -149.33
# Episode number 352, and it's corresponding return is -95.0, average rewards : -148.16
# Episode number 353, and it's corresponding return is -176.0, average rewards : -148.43
# Episode number 354, and it's corresponding return is -141.0, average rewards : -148.36
# Episode number 355, and it's corresponding return is -151.0, average rewards : -148.34
# Episode number 356, and it's corresponding return is -189.0, average rewards : -148.93
# Episode number 357, and it's corresponding return is -122.0, average rewards : -147.61
# Episode number 358, and it's corresponding return is -117.0, average rewards : -147.26
# Episode number 359, and it's corresponding return is -135.0, average rewards : -147.63
# Episode number 360, and it's corresponding return is -113.0, average rewards : -147.15
# Episode number 361, and it's corresponding return is -127.0, average rewards : -146.78
# Episode number 362, and it's corresponding return is -122.0, average rewards : -145.91
# Episode number 363, and it's corresponding return is -117.0, average rewards : -145.65
# Episode number 364, and it's corresponding return is -116.0, average rewards : -145.38
# Episode number 365, and it's corresponding return is -127.0, average rewards : -145.2
# Episode number 366, and it's corresponding return is -156.0, average rewards : -145.46
# Episode number 367, and it's corresponding return is -115.0, average rewards : -145.01
# Episode number 368, and it's corresponding return is -193.0, average rewards : -145.05
# Episode number 369, and it's corresponding return is -128.0, average rewards : -144.65
# Episode number 370, and it's corresponding return is -93.0, average rewards : -143.84
# Episode number 371, and it's corresponding return is -102.0, average rewards : -142.79
# Episode number 372, and it's corresponding return is -167.0, average rewards : -142.97
# Episode number 373, and it's corresponding return is -115.0, average rewards : -142.74
# Episode number 374, and it's corresponding return is -145.0, average rewards : -142.48
# Episode number 375, and it's corresponding return is -203.0, average rewards : -143.02
# Episode number 376, and it's corresponding return is -148.0, average rewards : -142.77
# Episode number 377, and it's corresponding return is -131.0, average rewards : -142.39
# Episode number 378, and it's corresponding return is -120.0, average rewards : -142.34
# Episode number 379, and it's corresponding return is -154.0, average rewards : -142.6
# Episode number 380, and it's corresponding return is -106.0, average rewards : -142.03
# Episode number 381, and it's corresponding return is -104.0, average rewards : -141.43
# Episode number 382, and it's corresponding return is -115.0, average rewards : -141.4
# Episode number 383, and it's corresponding return is -109.0, average rewards : -140.94
# Episode number 384, and it's corresponding return is -99.0, average rewards : -140.62
# Episode number 385, and it's corresponding return is -144.0, average rewards : -140.68
# Episode number 386, and it's corresponding return is -143.0, average rewards : -140.9
# Episode number 387, and it's corresponding return is -300.0, average rewards : -142.69
# Episode number 388, and it's corresponding return is -122.0, average rewards : -142.26
# Episode number 389, and it's corresponding return is -81.0, average rewards : -141.16
# Episode number 390, and it's corresponding return is -164.0, average rewards : -140.84
# Episode number 391, and it's corresponding return is -119.0, average rewards : -139.41
# Episode number 392, and it's corresponding return is -110.0, average rewards : -138.82
# Episode number 393, and it's corresponding return is -100.0, average rewards : -138.16
# Episode number 394, and it's corresponding return is -145.0, average rewards : -138.12
# Episode number 395, and it's corresponding return is -150.0, average rewards : -138.33
# Episode number 396, and it's corresponding return is -129.0, average rewards : -137.59
# Episode number 397, and it's corresponding return is -93.0, average rewards : -136.88
# Episode number 398, and it's corresponding return is -134.0, average rewards : -136.89
# Episode number 399, and it's corresponding return is -110.0, average rewards : -136.12
# Episode number 400, and it's corresponding return is -118.0, average rewards : -135.94
# Episode number 401, and it's corresponding return is -159.0, average rewards : -135.35
# Episode number 402, and it's corresponding return is -124.0, average rewards : -135.04
# Episode number 403, and it's corresponding return is -290.0, average rewards : -136.68
# Episode number 404, and it's corresponding return is -105.0, average rewards : -136.55
# Episode number 405, and it's corresponding return is -102.0, average rewards : -136.58
# Episode number 406, and it's corresponding return is -112.0, average rewards : -136.09
# Episode number 407, and it's corresponding return is -110.0, average rewards : -135.79
# Episode number 408, and it's corresponding return is -86.0, average rewards : -134.82
# Episode number 409, and it's corresponding return is -83.0, average rewards : -134.65
# Episode number 410, and it's corresponding return is -118.0, average rewards : -134.39
# Episode number 411, and it's corresponding return is -120.0, average rewards : -133.96
# Episode number 412, and it's corresponding return is -115.0, average rewards : -133.37
# Episode number 413, and it's corresponding return is -148.0, average rewards : -133.25
# Episode number 414, and it's corresponding return is -148.0, average rewards : -133.39
# Episode number 415, and it's corresponding return is -175.0, average rewards : -133.77
# Episode number 416, and it's corresponding return is -113.0, average rewards : -133.07
# Episode number 417, and it's corresponding return is -185.0, average rewards : -133.26
# Episode number 418, and it's corresponding return is -123.0, average rewards : -133.23
# Episode number 419, and it's corresponding return is -95.0, average rewards : -132.65
# Episode number 420, and it's corresponding return is -97.0, average rewards : -132.45
# Episode number 421, and it's corresponding return is -110.0, average rewards : -132.11
# Episode number 422, and it's corresponding return is -136.0, average rewards : -132.51
# Episode number 423, and it's corresponding return is -118.0, average rewards : -132.21
# Episode number 424, and it's corresponding return is -119.0, average rewards : -132.46
# Episode number 425, and it's corresponding return is -113.0, average rewards : -132.17
# Episode number 426, and it's corresponding return is -118.0, average rewards : -131.7
# Episode number 427, and it's corresponding return is -201.0, average rewards : -132.4
# Episode number 428, and it's corresponding return is -111.0, average rewards : -132.18
# Episode number 429, and it's corresponding return is -162.0, average rewards : -132.03
# Episode number 430, and it's corresponding return is -87.0, average rewards : -132.0
# Episode number 431, and it's corresponding return is -103.0, average rewards : -131.96
# Episode number 432, and it's corresponding return is -184.0, average rewards : -132.58
# Episode number 433, and it's corresponding return is -130.0, average rewards : -132.7
# Episode number 434, and it's corresponding return is -141.0, average rewards : -132.79
# Episode number 435, and it's corresponding return is -129.0, average rewards : -132.92
# Episode number 436, and it's corresponding return is -106.0, average rewards : -132.53
# Episode number 437, and it's corresponding return is -116.0, average rewards : -131.93
# Episode number 438, and it's corresponding return is -144.0, average rewards : -132.15
# Episode number 439, and it's corresponding return is -94.0, average rewards : -131.61
# Episode number 440, and it's corresponding return is -128.0, average rewards : -131.46
# Episode number 441, and it's corresponding return is -126.0, average rewards : -131.46
# Episode number 442, and it's corresponding return is -118.0, average rewards : -131.45
# Episode number 443, and it's corresponding return is -122.0, average rewards : -131.36
# Episode number 444, and it's corresponding return is -98.0, average rewards : -131.04
# Episode number 445, and it's corresponding return is -121.0, average rewards : -130.96
# Episode number 446, and it's corresponding return is -111.0, average rewards : -130.32
# Episode number 447, and it's corresponding return is -122.0, average rewards : -130.28
# Episode number 448, and it's corresponding return is -136.0, average rewards : -129.71
# Episode number 449, and it's corresponding return is -86.0, average rewards : -129.43
# Episode number 450, and it's corresponding return is -95.0, average rewards : -129.13
# Episode number 451, and it's corresponding return is -159.0, average rewards : -129.65
# Episode number 452, and it's corresponding return is -139.0, average rewards : -130.09
# Episode number 453, and it's corresponding return is -111.0, average rewards : -129.44
# Episode number 454, and it's corresponding return is -232.0, average rewards : -130.35
# Episode number 455, and it's corresponding return is -126.0, average rewards : -130.1
# Episode number 456, and it's corresponding return is -105.0, average rewards : -129.26
# Episode number 457, and it's corresponding return is -130.0, average rewards : -129.34
# Episode number 458, and it's corresponding return is -301.0, average rewards : -131.18
# Episode number 459, and it's corresponding return is -108.0, average rewards : -130.91
# Episode number 460, and it's corresponding return is -117.0, average rewards : -130.95
# Episode number 461, and it's corresponding return is -98.0, average rewards : -130.66
# Episode number 462, and it's corresponding return is -105.0, average rewards : -130.49
# Episode number 463, and it's corresponding return is -132.0, average rewards : -130.64
# Episode number 464, and it's corresponding return is -141.0, average rewards : -130.89
# Episode number 465, and it's corresponding return is -106.0, average rewards : -130.68
# Episode number 466, and it's corresponding return is -92.0, average rewards : -130.04
# Episode number 467, and it's corresponding return is -159.0, average rewards : -130.48
# Episode number 468, and it's corresponding return is -90.0, average rewards : -129.45
# Episode number 469, and it's corresponding return is -114.0, average rewards : -129.31
# Episode number 470, and it's corresponding return is -156.0, average rewards : -129.94
# Episode number 471, and it's corresponding return is -112.0, average rewards : -130.04
# Episode number 472, and it's corresponding return is -138.0, average rewards : -129.75
# Episode number 473, and it's corresponding return is -94.0, average rewards : -129.54
# Episode number 474, and it's corresponding return is -120.0, average rewards : -129.29
# Episode number 475, and it's corresponding return is -93.0, average rewards : -128.19
# Episode number 476, and it's corresponding return is -102.0, average rewards : -127.73
# Episode number 477, and it's corresponding return is -139.0, average rewards : -127.81
# Episode number 478, and it's corresponding return is -89.0, average rewards : -127.5
# Episode number 479, and it's corresponding return is -128.0, average rewards : -127.24
# Episode number 480, and it's corresponding return is -107.0, average rewards : -127.25
# Episode number 481, and it's corresponding return is -144.0, average rewards : -127.65
# Episode number 482, and it's corresponding return is -136.0, average rewards : -127.86
# Episode number 483, and it's corresponding return is -94.0, average rewards : -127.71
# Episode number 484, and it's corresponding return is -91.0, average rewards : -127.63
# Episode number 485, and it's corresponding return is -137.0, average rewards : -127.56
# Episode number 486, and it's corresponding return is -176.0, average rewards : -127.89
# Episode number 487, and it's corresponding return is -131.0, average rewards : -126.2
# Episode number 488, and it's corresponding return is -108.0, average rewards : -126.06
# Episode number 489, and it's corresponding return is -124.0, average rewards : -126.49
# Episode number 490, and it's corresponding return is -93.0, average rewards : -125.78
# Episode number 491, and it's corresponding return is -127.0, average rewards : -125.86
# Episode number 492, and it's corresponding return is -103.0, average rewards : -125.79
# Episode number 493, and it's corresponding return is -91.0, average rewards : -125.7
# Episode number 494, and it's corresponding return is -111.0, average rewards : -125.36
# Episode number 495, and it's corresponding return is -129.0, average rewards : -125.15
# Episode number 496, and it's corresponding return is -164.0, average rewards : -125.5
# Episode number 497, and it's corresponding return is -144.0, average rewards : -126.01
# Episode number 498, and it's corresponding return is -113.0, average rewards : -125.8
# Episode number 499, and it's corresponding return is -129.0, average rewards : -125.99
# Episode number 500, and it's corresponding return is -134.0, average rewards : -126.15
# Episode number 501, and it's corresponding return is -156.0, average rewards : -126.12
# Episode number 502, and it's corresponding return is -129.0, average rewards : -126.17
# Episode number 503, and it's corresponding return is -102.0, average rewards : -124.29
# Episode number 504, and it's corresponding return is -171.0, average rewards : -124.95
# Episode number 505, and it's corresponding return is -104.0, average rewards : -124.97
# Episode number 506, and it's corresponding return is -123.0, average rewards : -125.08
# Episode number 507, and it's corresponding return is -110.0, average rewards : -125.08
# Episode number 508, and it's corresponding return is -105.0, average rewards : -125.27
# Episode number 509, and it's corresponding return is -106.0, average rewards : -125.5
# Episode number 510, and it's corresponding return is -235.0, average rewards : -126.67
# Episode number 511, and it's corresponding return is -173.0, average rewards : -127.2
# Episode number 512, and it's corresponding return is -126.0, average rewards : -127.31
# Episode number 513, and it's corresponding return is -88.0, average rewards : -126.71
# Episode number 514, and it's corresponding return is -95.0, average rewards : -126.18
# Episode number 515, and it's corresponding return is -97.0, average rewards : -125.4
# Episode number 516, and it's corresponding return is -112.0, average rewards : -125.39
# Episode number 517, and it's corresponding return is -96.0, average rewards : -124.5
# Episode number 518, and it's corresponding return is -109.0, average rewards : -124.36
# Episode number 519, and it's corresponding return is -101.0, average rewards : -124.42
# Episode number 520, and it's corresponding return is -120.0, average rewards : -124.65
# Episode number 521, and it's corresponding return is -137.0, average rewards : -124.92
# Episode number 522, and it's corresponding return is -94.0, average rewards : -124.5
# Episode number 523, and it's corresponding return is -114.0, average rewards : -124.46
# Episode number 524, and it's corresponding return is -79.0, average rewards : -124.06
# Episode number 525, and it's corresponding return is -114.0, average rewards : -124.07
# Episode number 526, and it's corresponding return is -101.0, average rewards : -123.9
# Episode number 527, and it's corresponding return is -156.0, average rewards : -123.45
# Episode number 528, and it's corresponding return is -107.0, average rewards : -123.41
# Episode number 529, and it's corresponding return is -120.0, average rewards : -122.99
# Episode number 530, and it's corresponding return is -113.0, average rewards : -123.25
# Episode number 531, and it's corresponding return is -135.0, average rewards : -123.57
# Episode number 532, and it's corresponding return is -175.0, average rewards : -123.48
# Episode number 533, and it's corresponding return is -139.0, average rewards : -123.57
# Episode number 534, and it's corresponding return is -135.0, average rewards : -123.51
# Episode number 535, and it's corresponding return is -129.0, average rewards : -123.51
# Episode number 536, and it's corresponding return is -106.0, average rewards : -123.51
# Episode number 537, and it's corresponding return is -132.0, average rewards : -123.67
# Episode number 538, and it's corresponding return is -103.0, average rewards : -123.26
# Episode number 539, and it's corresponding return is -130.0, average rewards : -123.62
# Episode number 540, and it's corresponding return is -99.0, average rewards : -123.33
# Episode number 541, and it's corresponding return is -128.0, average rewards : -123.35
# Episode number 542, and it's corresponding return is -102.0, average rewards : -123.19
# Episode number 543, and it's corresponding return is -179.0, average rewards : -123.76
# ...
# Episode number 817, and it's corresponding return is -101.0, average rewards : -123.48
# Episode number 818, and it's corresponding return is -111.0, average rewards : -123.44
# Episode number 819, and it's corresponding return is -79.0, average rewards : -122.99
# Episode number 820, and it's corresponding return is -105.0, average rewards : -122.57
# Episode number 821, and it's corresponding return is -101.0, average rewards : -122.56
# Episode number 822, and it's corresponding return is -95.0, average rewards : -122.05
# Episode number 823, and it's corresponding return is -96.0, average rewards : -121.55
# Episode number 824, and it's corresponding return is -123.0, average rewards : -120.61
# Episode number 825, and it's corresponding return is -108.0, average rewards : -120.44
# Episode number 826, and it's corresponding return is -88.0, average rewards : -119.89
# Episode number 827, and it's corresponding return is -102.0, average rewards : -119.68
# Episode number 828, and it's corresponding return is -103.0, average rewards : -119.59
# Episode number 829, and it's corresponding return is -500.0, average rewards : -123.54
# Episode number 830, and it's corresponding return is -94.0, average rewards : -123.43
# Episode number 831, and it's corresponding return is -98.0, average rewards : -123.31
# Episode number 832, and it's corresponding return is -108.0, average rewards : -123.29
# Episode number 833, and it's corresponding return is -146.0, average rewards : -123.62
# Episode number 834, and it's corresponding return is -97.0, average rewards : -123.09
# Episode number 835, and it's corresponding return is -150.0, average rewards : -123.64
# Episode number 836, and it's corresponding return is -108.0, average rewards : -123.74
# Episode number 837, and it's corresponding return is -159.0, average rewards : -124.07
# Episode number 838, and it's corresponding return is -98.0, average rewards : -123.66
# Episode number 839, and it's corresponding return is -131.0, average rewards : -123.83
# Episode number 840, and it's corresponding return is -107.0, average rewards : -123.37
# Episode number 841, and it's corresponding return is -136.0, average rewards : -122.78
# Episode number 842, and it's corresponding return is -188.0, average rewards : -123.36
# Episode number 843, and it's corresponding return is -108.0, average rewards : -123.25
# Episode number 844, and it's corresponding return is -128.0, average rewards : -123.24
# Episode number 845, and it's corresponding return is -102.0, average rewards : -123.29
# Episode number 846, and it's corresponding return is -109.0, average rewards : -123.03
# Episode number 847, and it's corresponding return is -126.0, average rewards : -123.03
# Episode number 848, and it's corresponding return is -82.0, average rewards : -122.81
# Episode number 849, and it's corresponding return is -113.0, average rewards : -122.66
# Episode number 850, and it's corresponding return is -93.0, average rewards : -122.48
# Episode number 851, and it's corresponding return is -93.0, average rewards : -122.55
# Episode number 852, and it's corresponding return is -105.0, average rewards : -122.55
# Episode number 853, and it's corresponding return is -98.0, average rewards : -121.88
# Episode number 854, and it's corresponding return is -94.0, average rewards : -121.5
# Episode number 855, and it's corresponding return is -110.0, average rewards : -121.68
# Episode number 856, and it's corresponding return is -104.0, average rewards : -121.57
# Episode number 857, and it's corresponding return is -91.0, average rewards : -121.67
# Episode number 858, and it's corresponding return is -89.0, average rewards : -121.43
# Episode number 859, and it's corresponding return is -163.0, average rewards : -121.96
# Episode number 860, and it's corresponding return is -103.0, average rewards : -121.71
# Episode number 861, and it's corresponding return is -124.0, average rewards : -121.66
# Episode number 862, and it's corresponding return is -102.0, average rewards : -121.3
# Episode number 863, and it's corresponding return is -101.0, average rewards : -121.35
# Episode number 864, and it's corresponding return is -99.0, average rewards : -121.25
# Episode number 865, and it's corresponding return is -113.0, average rewards : -121.12
# Episode number 866, and it's corresponding return is -113.0, average rewards : -121.13
# Episode number 867, and it's corresponding return is -174.0, average rewards : -121.56
# Episode number 868, and it's corresponding return is -124.0, average rewards : -121.59
# Episode number 869, and it's corresponding return is -125.0, average rewards : -120.92
# Episode number 870, and it's corresponding return is -125.0, average rewards : -120.85
# Episode number 871, and it's corresponding return is -104.0, average rewards : -120.56
# Episode number 872, and it's corresponding return is -95.0, average rewards : -120.34
# Episode number 873, and it's corresponding return is -127.0, average rewards : -120.3
# Episode number 874, and it's corresponding return is -124.0, average rewards : -120.61
# Episode number 875, and it's corresponding return is -96.0, average rewards : -120.38
# Episode number 876, and it's corresponding return is -108.0, average rewards : -119.94
# Episode number 877, and it's corresponding return is -168.0, average rewards : -119.07
# Episode number 878, and it's corresponding return is -115.0, average rewards : -119.08
# Episode number 879, and it's corresponding return is -82.0, average rewards : -118.85
# Episode number 880, and it's corresponding return is -136.0, average rewards : -119.23
# Episode number 881, and it's corresponding return is -150.0, average rewards : -119.45
# Episode number 882, and it's corresponding return is -118.0, average rewards : -117.57
# Episode number 883, and it's corresponding return is -119.0, average rewards : -117.88
# Episode number 884, and it's corresponding return is -98.0, average rewards : -117.55
# Episode number 885, and it's corresponding return is -136.0, average rewards : -117.3
# Episode number 886, and it's corresponding return is -85.0, average rewards : -117.14
# Episode number 887, and it's corresponding return is -107.0, average rewards : -116.83
# Episode number 888, and it's corresponding return is -85.0, average rewards : -116.56
# Episode number 889, and it's corresponding return is -98.0, average rewards : -116.5
# Episode number 890, and it's corresponding return is -112.0, average rewards : -116.35
# Episode number 891, and it's corresponding return is -99.0, average rewards : -116.09
# Episode number 892, and it's corresponding return is -94.0, average rewards : -115.9
# Episode number 893, and it's corresponding return is -92.0, average rewards : -115.68
# Episode number 894, and it's corresponding return is -104.0, average rewards : -115.7
# Episode number 895, and it's corresponding return is -130.0, average rewards : -115.82
# Episode number 896, and it's corresponding return is -99.0, average rewards : -115.41
# Episode number 897, and it's corresponding return is -106.0, average rewards : -115.35
# Episode number 898, and it's corresponding return is -80.0, average rewards : -115.27
# Episode number 899, and it's corresponding return is -119.0, average rewards : -115.44
# Episode number 900, and it's corresponding return is -113.0, average rewards : -115.49
# Episode number 901, and it's corresponding return is -135.0, average rewards : -115.53
# Episode number 902, and it's corresponding return is -88.0, average rewards : -115.49
# Episode number 903, and it's corresponding return is -136.0, average rewards : -115.87
# Episode number 904, and it's corresponding return is -102.0, average rewards : -115.92
# Episode number 905, and it's corresponding return is -88.0, average rewards : -115.81
# Episode number 906, and it's corresponding return is -120.0, average rewards : -116.07
# Episode number 907, and it's corresponding return is -103.0, average rewards : -115.87
# Episode number 908, and it's corresponding return is -92.0, average rewards : -115.6
# Episode number 909, and it's corresponding return is -117.0, average rewards : -115.61
# Episode number 910, and it's corresponding return is -91.0, average rewards : -115.83
# Episode number 911, and it's corresponding return is -98.0, average rewards : -115.88
# Episode number 912, and it's corresponding return is -127.0, average rewards : -115.18
# Episode number 913, and it's corresponding return is -117.0, average rewards : -115.16
# Episode number 914, and it's corresponding return is -82.0, average rewards : -114.76
# Episode number 915, and it's corresponding return is -91.0, average rewards : -114.56
# Episode number 916, and it's corresponding return is -98.0, average rewards : -114.27
# Episode number 917, and it's corresponding return is -112.0, average rewards : -114.38
# Episode number 918, and it's corresponding return is -98.0, average rewards : -114.25
# Episode number 919, and it's corresponding return is -111.0, average rewards : -114.57
# Episode number 920, and it's corresponding return is -145.0, average rewards : -114.97
# Episode number 921, and it's corresponding return is -98.0, average rewards : -114.94
# Episode number 922, and it's corresponding return is -92.0, average rewards : -114.91
# Episode number 923, and it's corresponding return is -106.0, average rewards : -115.01
# Episode number 924, and it's corresponding return is -111.0, average rewards : -114.89
# Episode number 925, and it's corresponding return is -87.0, average rewards : -114.68
# Episode number 926, and it's corresponding return is -100.0, average rewards : -114.8
# Episode number 927, and it's corresponding return is -87.0, average rewards : -114.65
# Episode number 928, and it's corresponding return is -90.0, average rewards : -114.52
# Episode number 929, and it's corresponding return is -117.0, average rewards : -110.69
# Episode number 930, and it's corresponding return is -100.0, average rewards : -110.75
# Episode number 931, and it's corresponding return is -121.0, average rewards : -110.98
# Episode number 932, and it's corresponding return is -111.0, average rewards : -111.01
# Episode number 933, and it's corresponding return is -95.0, average rewards : -110.5
# Episode number 934, and it's corresponding return is -106.0, average rewards : -110.59
# Episode number 935, and it's corresponding return is -85.0, average rewards : -109.94
# Episode number 936, and it's corresponding return is -403.0, average rewards : -112.89
# Episode number 937, and it's corresponding return is -109.0, average rewards : -112.39
# Episode number 938, and it's corresponding return is -107.0, average rewards : -112.48
# Episode number 939, and it's corresponding return is -97.0, average rewards : -112.14
# Episode number 940, and it's corresponding return is -89.0, average rewards : -111.96
# Episode number 941, and it's corresponding return is -101.0, average rewards : -111.61
# Episode number 942, and it's corresponding return is -94.0, average rewards : -110.67
# Episode number 943, and it's corresponding return is -95.0, average rewards : -110.54
# Episode number 944, and it's corresponding return is -113.0, average rewards : -110.39
# Episode number 945, and it's corresponding return is -111.0, average rewards : -110.48
# Episode number 946, and it's corresponding return is -127.0, average rewards : -110.66
# Episode number 947, and it's corresponding return is -71.0, average rewards : -110.11
# Episode number 948, and it's corresponding return is -108.0, average rewards : -110.37
# Episode number 949, and it's corresponding return is -117.0, average rewards : -110.41
# Episode number 950, and it's corresponding return is -253.0, average rewards : -112.01
# Episode number 951, and it's corresponding return is -84.0, average rewards : -111.92
# Episode number 952, and it's corresponding return is -106.0, average rewards : -111.93
# Episode number 953, and it's corresponding return is -207.0, average rewards : -113.02
# Episode number 954, and it's corresponding return is -107.0, average rewards : -113.15
# Episode number 955, and it's corresponding return is -114.0, average rewards : -113.19
# Episode number 956, and it's corresponding return is -84.0, average rewards : -112.99
# Episode number 957, and it's corresponding return is -116.0, average rewards : -113.24
# Episode number 958, and it's corresponding return is -140.0, average rewards : -113.75
# Episode number 959, and it's corresponding return is -109.0, average rewards : -113.21
# Episode number 960, and it's corresponding return is -77.0, average rewards : -112.95
# Episode number 961, and it's corresponding return is -103.0, average rewards : -112.74
# Episode number 962, and it's corresponding return is -110.0, average rewards : -112.82
# Episode number 963, and it's corresponding return is -106.0, average rewards : -112.87
# Episode number 964, and it's corresponding return is -234.0, average rewards : -114.22
# Episode number 965, and it's corresponding return is -89.0, average rewards : -113.98
# Episode number 966, and it's corresponding return is -88.0, average rewards : -113.73
# Episode number 967, and it's corresponding return is -118.0, average rewards : -113.17
# Episode number 968, and it's corresponding return is -89.0, average rewards : -112.82
# Episode number 969, and it's corresponding return is -117.0, average rewards : -112.74
# Episode number 970, and it's corresponding return is -118.0, average rewards : -112.67
# Episode number 971, and it's corresponding return is -86.0, average rewards : -112.49
# Episode number 972, and it's corresponding return is -92.0, average rewards : -112.46
# Episode number 973, and it's corresponding return is -98.0, average rewards : -112.17
# Episode number 974, and it's corresponding return is -94.0, average rewards : -111.87
# Episode number 975, and it's corresponding return is -89.0, average rewards : -111.8
# Episode number 976, and it's corresponding return is -106.0, average rewards : -111.78
# Episode number 977, and it's corresponding return is -110.0, average rewards : -111.2
# Episode number 978, and it's corresponding return is -146.0, average rewards : -111.51
# Episode number 979, and it's corresponding return is -119.0, average rewards : -111.88
# Episode number 980, and it's corresponding return is -127.0, average rewards : -111.79
# Episode number 981, and it's corresponding return is -123.0, average rewards : -111.52
# Episode number 982, and it's corresponding return is -124.0, average rewards : -111.58
# Episode number 983, and it's corresponding return is -111.0, average rewards : -111.5
# Episode number 984, and it's corresponding return is -102.0, average rewards : -111.54
# Episode number 985, and it's corresponding return is -100.0, average rewards : -111.18
# Episode number 986, and it's corresponding return is -104.0, average rewards : -111.37
# Episode number 987, and it's corresponding return is -123.0, average rewards : -111.53
# Episode number 988, and it's corresponding return is -91.0, average rewards : -111.59
# Episode number 989, and it's corresponding return is -101.0, average rewards : -111.62
# Episode number 990, and it's corresponding return is -90.0, average rewards : -111.4
# Episode number 991, and it's corresponding return is -89.0, average rewards : -111.3
# Episode number 992, and it's corresponding return is -88.0, average rewards : -111.24
# Episode number 993, and it's corresponding return is -121.0, average rewards : -111.53
# Episode number 994, and it's corresponding return is -96.0, average rewards : -111.45
# Episode number 995, and it's corresponding return is -87.0, average rewards : -111.02
# Episode number 996, and it's corresponding return is -116.0, average rewards : -111.19
# Episode number 997, and it's corresponding return is -87.0, average rewards : -111.0
# Episode number 998, and it's corresponding return is -102.0, average rewards : -111.22
# Episode number 999, and it's corresponding return is -97.0, average rewards : -111.0
# Episode number 1000, and it's corresponding return is -114.0, average rewards : -111.01

# %%
n_episodes = np.arange(len(list(returns_1_1)))
avg_returns_env1_type_1 = np.mean(returns_1_1_5runs,axis = 0)
std_returns_env1_type_1 = np.std(returns_1_1_5runs,axis = 0)
avg_returns_env1_type_2 = np.mean(returns_1_2_5runs,axis = 0)
std_returns_env1_type_2 = np.std(returns_1_2_5runs,axis = 0)
plt.plot(n_episodes, avg_returns_env1_type_1, color = '#FF0000', label = "Type 1")
plt.plot(n_episodes, avg_returns_env1_type_2, color = '#0000FF', label = "Type 2")
plt.fill_between(n_episodes, avg_returns_env1_type_1 - std_returns_env1_type_1, avg_returns_env1_type_1 + std_returns_env1_type_1, color = '#FF474C')
plt.fill_between(n_episodes, avg_returns_env1_type_2 - std_returns_env1_type_2, avg_returns_env1_type_2 + std_returns_env1_type_2, color = '#ADD8E6')
plt.title("Episodic returns vs number of episodes for Acrobot-v1")
plt.xlabel("Number of episodes")
plt.ylabel("Episodic return averaged over 5 runs")
plt.legend()
plt.show()
